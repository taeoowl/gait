# %%
import pandas as pd
import numpy as np
import cv2
import os

import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# 100Hz(1초에 100번), 16g, 2000degree/s, 
df_length = []
df_dist = []
df_num = []
for i in os.listdir('dataset/benchmark'):
    df = pd.read_csv('dataset/benchmark/'+i, sep=' ', header=None)
    df.columns = ['flag', 'acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z',
              'mag_x', 'mag_y', 'mag_z', 'timestep', 'len_stride', 'num_stride', 'cum_dist']
    print(f'{i} : {len(df)/100} second / {max(df.num_stride)} stride / {np.round(max(df.cum_dist), 2)} m')
    df_length.append(len(df))
    df_num.append(max(df.num_stride))
    df_dist.append(max(df.cum_dist))
print(f'Total : {sum(df_length)/100} second / {sum(df_num)} stride / {np.round(sum(df_dist), 2)} m' )
# Out:
# PDR_Raw_2018-10-02-11-22-00.txt : 1246.99 second / 1000 stride / 1367.23 m
# PDR_Raw_2018-10-02-11-54-00.txt : 1258.86 second / 1000 stride / 1537.49 m
# PDR_Raw_2018-10-03-09-29-57.txt : 1377.38 second / 1008 stride / 1655.68 m
# PDR_Raw_2018-10-05-12-01-25.txt : 1388.05 second / 1001 stride / 1535.55 m
# PDR_Raw_2018-10-06-09-43-41.txt : 1344.27 second / 1005 stride / 1620.04 m
# PDR_Raw_2018-10-06-12-02-13.txt : 1360.77 second / 1000 stride / 1389.39 m
# PDR_Raw_2018-10-07-12-16-56.txt : 1509.39 second / 1014 stride / 1632.06 m
# PDR_Raw_2018-10-14-07-31-10.txt : 516.77 second / 199 stride / 667.19 m
# PDR_Raw_2018-10-23-10-07-37.txt : 104.07 second / 0 stride / 0.0 m
# PDR_Raw_2018-10-24-07-37-35.txt : 270.81 second / 195 stride / 406.35 m
# PDR_Raw_2018-10-24-07-42-38.txt : 548.6 second / 342 stride / 809.79 m
# PDR_Raw_2018-10-24-07-58-43.txt : 304.54 second / 203 stride / 405.4 m
# PDR_Raw_2018-10-25-11-33-56.txt : 20.25 second / 8 stride / 9.76 m
# PDR_Raw_2018-10-25-11-34-35.txt : 17.03 second / 8 stride / 9.62 m
# PDR_Raw_2018-10-25-11-35-12.txt : 16.97 second / 9 stride / 9.94 m
# PDR_Raw_2018-10-25-11-37-09.txt : 27.75 second / 14 stride / 19.89 m
# PDR_Raw_2018-10-25-11-37-52.txt : 41.27 second / 19 stride / 19.86 m
# PDR_Raw_2018-10-25-11-38-58.txt : 32.9 second / 17 stride / 19.91 m
# PDR_Raw_2018-10-25-11-39-50.txt : 37.83 second / 22 stride / 29.94 m
# PDR_Raw_2018-10-25-11-40-45.txt : 40.57 second / 25 stride / 30.42 m
# PDR_Raw_2018-10-25-11-41-50.txt : 40.37 second / 24 stride / 30.15 m
# PDR_Raw_2018-10-28-11-43-07.txt : 22.27 second / 9 stride / 10.01 m
# PDR_Raw_2018-10-28-11-43-48.txt : 24.52 second / 9 stride / 10.14 m
# PDR_Raw_2018-10-28-11-45-16.txt : 31.66 second / 10 stride / 9.93 m
# PDR_Raw_2018-10-28-11-46-08.txt : 48.34 second / 18 stride / 19.94 m
# PDR_Raw_2018-10-28-11-47-12.txt : 45.62 second / 17 stride / 19.88 m
# PDR_Raw_2018-10-28-11-48-13.txt : 50.6 second / 19 stride / 20.2 m
# PDR_Raw_2018-10-28-11-49-27.txt : 68.28 second / 26 stride / 30.15 m
# PDR_Raw_2018-10-28-11-50-49.txt : 67.44 second / 26 stride / 30.14 m
# PDR_Raw_2018-10-28-11-52-13.txt : 60.88 second / 25 stride / 30.24 m
# Total : 11925.05 second / 8272 stride / 13386.31 m

# %%
df_num
# Out:
# [1000,
#  1000,
#  1008,
#  1001,
#  1005,
#  1000,
#  1014,
#  199,
#  0,
#  195,
#  342,
#  203,
#  8,
#  8,
#  9,
#  14,
#  19,
#  17,
#  22,
#  25,
#  24,
#  9,
#  9,
#  10,
#  18,
#  17,
#  19,
#  26,
#  26,
#  25]

# %%
columns = ['flag', 'acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z',
              'mag_x', 'mag_y', 'mag_z', 'timestep', 'stride_dist', 'stride_num', 'cum_dist']
df = pd.read_csv('dataset/benchmark/PDR_Raw_2018-10-02-11-22-00.txt', sep=' ', header=None, names=columns)
df = df.loc[:, ['acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z', 'stride_dist', 'stride_num']]

# %%
### acc & gyro(x) 및 보폭(y) 불러오는 함수
### stirde 별 전처리가 필요할 시 아래 함수 안에 코드 작성

def gait_loader(data_path):
    columns = ['flag', 'acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z',
              'mag_x', 'mag_y', 'mag_z', 'timestep', 'stride_dist', 'stride_num', 'cum_dist']
    readings_acc = []
    readings_gyro = []
    stride_dist = []
    
    # 경로에 있는 모든 파일 가져오기
    for i in os.listdir(data_path):
        df = pd.read_csv(f'{data_path}/{i}', sep=' ', header=None, names=columns)
        df = df.loc[:, ['acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z', 'stride_dist', 'stride_num']]
        
        # stride_num에 따라 데이터 분할
        groups = df.groupby('stride_num')
        result = dict(list(groups))
        
        # 센서 데이터가 10개 이상인 모든 stride를 하나의 리스트로 병합
        readings_acc.append([cv2.resize(np.array(result[idx].iloc[:, 0:3]), dsize=(6, 300))
                         for idx in range(len(result)) if len(result[idx]) > 10])
        readings_gyro.append([cv2.resize(np.array(result[idx].iloc[:, 3:6]), dsize=(6, 300))
                         for idx in range(len(result)) if len(result[idx]) > 10])
        stride_dist.append([np.array(result[idx]['stride_dist'].iloc[-1])
                           for idx in range(len(result)) if len(result[idx]) > 10])
        
    # 이중 리스트 병합
    input_acc = sum(readings_acc, [])
    input_gyro = sum(readings_gyro, [])
    y = sum(stride_dist, [])
    
    return input_acc, input_gyro, y

# %%
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21188\1049141082.py in <module>
# ----> 1 result
#
# NameError: name 'result' is not defined

# %%
acc, gyro, y = gait_loader('dataset/benchmark/')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21188\2665641528.py in <module>
# ----> 1 acc, gyro, y = gait_loader('dataset/benchmark/')[1]
#
# ValueError: too many values to unpack (expected 3)

# %%
x[0]
# Out:
# array([[ 6.52755155e-01,  6.49690575e-01,  1.04644497e+01,
#         -5.25817671e-02,  5.98462923e-02,  2.70541161e-02],
#        [ 7.80318199e-01,  6.46242939e-01,  9.83269898e+00,
#          1.03918645e-01, -9.16360724e-02, -3.34502830e-02],
#        [ 7.61036899e-01,  7.08683700e-01,  8.95910240e+00,
#         -6.19068150e-03,  7.13729136e-02, -4.21165417e-02],
#        ...,
#        [ 3.17311536e-01,  1.96069159e+00,  9.85389580e+00,
#         -6.22617193e-03, -1.01366978e-01, -1.31902096e-01],
#        [ 4.89374808e-01,  2.00806482e+00,  9.77159928e+00,
#          2.02370948e-02, -1.21659226e-01, -1.86547067e-01],
#        [ 4.76350353e-01,  2.04892584e+00,  9.55107732e+00,
#         -9.40037782e-02, -8.13089567e-02, -2.42718062e-01]])

# %%
# num_stride 별 데이터셋에서 len_stride의 마지막 값을 label로 사용
result[0]['len_stride'].iloc[-1]
# Out:
# 0.6189868382278433

# %%
# stride를 300길이로 고정 
# 짧은건 infinite-padded, 긴건 압축? -> cv2.resize 활용
# 데이터가 너무 적어서 resize가 제대로 안되는 문제 -> length가 10 미만인 데이터들은 제외
result[0].iloc[:, 0:6]
# Out:
#         acc_x     acc_y     acc_z    gyro_x    gyro_y    gyro_z
# 0    0.842759  1.810016  9.538500 -0.159139  0.270910  0.062029
# 1    0.890643  1.733402  9.969456 -0.014347  0.116536  0.044995
# 2    0.909797  1.742979  9.806650  0.031416  0.049463  0.027960
# 3    1.015141  1.752556  9.414001  0.048450  0.007941 -0.002897
# 4    1.034295  1.781286  9.212888  0.027157  0.026040 -0.018867
# ..        ...       ...       ...       ...       ...       ...
# 270  0.363919  1.886631  9.461885 -0.128264 -0.070825 -0.426628
# 271  0.296881  1.905785  9.481039 -0.094195 -0.051662 -0.422370
# 272  0.229843  1.982399  9.471462 -0.072902 -0.053791 -0.422370
# 273  0.239420  2.097321  9.375694 -0.057997 -0.065502 -0.427693
# 274  0.268151  2.164358  9.356541 -0.052674 -0.119799 -0.480925
#
# [275 rows x 6 columns]

# %%
plt.plot(cv2.resize(np.array(result[3].iloc[:, 0:6]), dsize=(6, 300)))
# Out:
# [<matplotlib.lines.Line2D at 0x25053150f88>,
#  <matplotlib.lines.Line2D at 0x25052f23148>,
#  <matplotlib.lines.Line2D at 0x25052f34888>,
#  <matplotlib.lines.Line2D at 0x25052f34a48>,
#  <matplotlib.lines.Line2D at 0x25052f34c48>,
#  <matplotlib.lines.Line2D at 0x25052f34e48>]

# %%
plt.plot(np.array(result[3].iloc[:, 0:6]))
# Out:
# [<matplotlib.lines.Line2D at 0x25052e98708>,
#  <matplotlib.lines.Line2D at 0x25052e87248>,
#  <matplotlib.lines.Line2D at 0x25052e98b88>,
#  <matplotlib.lines.Line2D at 0x25052e98d48>,
#  <matplotlib.lines.Line2D at 0x25052e98f88>,
#  <matplotlib.lines.Line2D at 0x25053164208>]

# %%
result[0]
# Out:
#       acc_x     acc_y     acc_z    gyro_x    gyro_y    gyro_z  len_stride  \
# 0  0.555455  0.909797  8.753201 -0.154881  0.149767  0.043145    0.618987
#
#    num_stride
# 0           0

# %%
result[0].iloc[:, 0:6]['acc_x'].values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29744\2469514863.py in <module>
# ----> 1 result[0].iloc[:, 0:6]['acc_x'].values.reshape(300,1)
#
# ValueError: cannot reshape array of size 275 into shape (300,1)

# %%
scaler = MinMaxScaler()
dist_3.iloc[:,1:7] = scaler.fit_transform(dist_3.iloc[:,1:7])
dist_3.head()

# %%
0.98*np.mean(abs(result[1]['acc_z'])) ** (1/3) # 파생변수 : Kim
# Out:
# 0.6589619247855646

# %%
(max(result[1]['acc_z']) - min(result[1]['acc_z'])) ** (1/4) # 파생변수 : Weinberg
# Out:
# 1.0

# %%
(np.mean(abs(result[1]['acc_z'])) - min(result[1]['acc_z'])) / (max(result[1]['acc_z']) - min(result[1]['acc_z']))
# Out:
# 0.3040204079926778

# %%
import os
import glob
import ast
import numpy as np
import pandas as pd

import torch
from torch.utils.data import Dataset, DataLoader, random_split

from matplotlib import pyplot as plt

import pandas as pd
import numpy as np
import cv2
import os

import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
import torchvision.transforms as transforms

# %%
class Gait_Dataset(Dataset):
    def __init__(self, data_path):
        self.data_path = data_path
        self.input_acc, self.input_gyro, self.y = gait_loader(data_path)
        self.len_readings = good_stride(data_path)

    def __getitem__(self, index):
        input_acc = torch.from_numpy(self.input_acc[index]).float()
        input_gyro = torch.from_numpy(self.input_gyro[index]).float()
        y = torch.from_numpy(self.y[index]).float()
        sample = {'input_acc' : input_acc, 'input_gyro' : input_gyro, 'label' : y}
        return sample

    def __len__(self):
        return len(self.len_readings)
    
### acc & gyro(x) 및 보폭(y) 불러오는 함수
### stirde 별 전처리가 필요할 시 아래 함수 안에 코드 작성

def gait_loader(data_path):
    columns = ['flag', 'acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z',
              'mag_x', 'mag_y', 'mag_z', 'timestep', 'stride_dist', 'stride_num', 'cum_dist']
    readings_acc = []
    readings_gyro = []
    stride_dist = []
    
    scaler = MinMaxScaler()

    # 경로에 있는 모든 파일 가져오기
    for i in os.listdir(data_path):
        df = pd.read_csv(f'{data_path}/{i}', sep=' ', header=None, names=columns)
        df = df.loc[:, ['acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z', 'stride_dist', 'stride_num']]
        
        # stride_num에 따라 데이터 분할
        groups = df.groupby('stride_num')
        result = dict(list(groups))
        for j in range(len(result)):
            result[j].iloc[:,0:6] = scaler.fit_transform(result[j].iloc[:,0:6])
        
        # 파일로 나누어진 모든 데이터를 하나의 리스트로 병합
        readings_acc.append([cv2.resize(np.array(result[idx].iloc[:, 0:3]), dsize=(3, 300))
                         for idx in range(len(result)) if len(result[idx]) > 10])
        readings_gyro.append([cv2.resize(np.array(result[idx].iloc[:, 3:6]), dsize=(3, 300))
                         for idx in range(len(result)) if len(result[idx]) > 10])
        stride_dist.append([np.array(result[idx]['stride_dist'].iloc[-1])
                           for idx in range(len(result)) if len(result[idx]) > 10])
        
    # 이중 리스트 병합
    input_acc = sum(readings_acc, [])
    input_gyro = sum(readings_gyro, [])
    y = sum(stride_dist, [])
    
    return input_acc, input_gyro, y

def good_stride(data_path):
    columns = ['flag', 'acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z',
              'mag_x', 'mag_y', 'mag_z', 'timestep', 'stride_dist', 'stride_num', 'cum_dist']
    good_stride = []
    
    # 경로에 있는 모든 파일 가져오기
    for i in os.listdir(data_path):
        df = pd.read_csv(f'{data_path}/{i}', sep=' ', header=None, names=columns)
        df = df.loc[:, ['acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z', 'stride_dist', 'stride_num']]
        
        # stride_num에 따라 데이터 분할
        groups = df.groupby('stride_num')
        result = dict(list(groups))
        
        
        # 파일로 나누어진 모든 데이터를 하나의 리스트로 병합
        good_stride.append([idx for idx in range(len(result)) if len(result[idx]) > 10])
        
    # 이중 리스트 병합
    good_stride = sum(good_stride, [])
    
    return good_stride

# %%
data_path = 'dataset/benchmark/'
dataset = Gait_Dataset(data_path)
val_percent = 0.2
n_val = int(len(dataset) * val_percent)
n_train = len(dataset) - n_val
train, val = random_split(dataset, [n_train, n_val])
train_loader = torch.utils.data.DataLoader(train,
                                           batch_size=128,
                                           shuffle=True)
val_loader = torch.utils.data.DataLoader(val,
                                         batch_size=128,
                                         shuffle=False)

# %%
device = torch.device('cuda' if torch.cuda.is_available else 'cpu')
print('device : ', device)
# 하이퍼 파라미터

sequence_length = 3
input_size = 300
hidden_size = 64
num_layers = 1
num_epochs = 500
num_epochs_DAE = 50
learning_rate = 0.001
# Out:
# device :  cuda

# %%
from LSTM import *

# 모델 할당 후 학습
LSTM = LSTM(input_size, hidden_size, num_layers, learning_rate).to(device)


optimizer = torch.optim.RMSprop(LSTM.parameters(), lr=learning_rate)
criterion = nn.MSELoss()

best = 100
converge_cnt = 0
total_error = 0

# LSTM 학습
for epoch in range(num_epochs):
    total_loss = 0
    total_val_loss = 0
    LSTM.train()
    for i, batch in enumerate(train_loader):
        acc = batch['input_acc'] # (BATCH(100), 1, 28, 28) -> (BATCH(100), 28, 28)
        acc = acc.reshape(-1, sequence_length, input_size).to(device)
        gyro = batch['input_gyro']
        gyro = gyro.reshape(-1, sequence_length, input_size).to(device)
        labels = batch['label'] # Size : (100)
        labels = labels.reshape(-1, 1).to(device)

        # 순전파
        out_lstm, _ = LSTM(acc, gyro)
        loss = criterion(out_lstm, labels)
        
        
        # 역전파 & 최적화
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
    trn_loss = total_loss / len(train_loader)

            
    LSTM.eval()
    with torch.no_grad():
        for i, batch in enumerate(val_loader):
            acc = batch['input_acc'] 
            acc = acc.reshape(-1, sequence_length, input_size).to(device)
            gyro = batch['input_gyro']
            gyro = gyro.reshape(-1, sequence_length, input_size).to(device)
            labels = batch['label']
            labels = labels.reshape(-1, 1).to(device)
            
            out_lstm, _ = LSTM(acc, gyro)
            loss_val = criterion(out_lstm, labels)
            
            total_val_loss += loss_val.item()
    val_loss = total_val_loss / len(val_loader)
    error = torch.sum(torch.abs(out_lstm - labels) / labels) / len(labels)
    
    total_error += error


    print('LSTM_Epoch [{}/{}], Train_Loss: {:.4f}, Valid_Loss: {:.4f}, Error: {:.4f}'.format(
                    epoch+1, num_epochs, trn_loss, val_loss, error))
                
        
        
            
    if val_loss < best:
        best = np.mean(val_loss)
        torch.save(LSTM, './LSTM_best.pth')
        print('Best Valid Loss {:.4f}'.format(best))
        converge_cnt = 0
    else:
        converge_cnt += 1
        
    if converge_cnt > 50:
        print('LSTM_Early stopping')
        print('Total Error Mean {:4f}'.format(total_error/(epoch+1)))
        break
            
            

            
# 저장하고, 불러와서 Freeze 시켜서 DAE 학습
# 이거 또 저장해서 붙여서 학습?
# Out:
# LSTM_Epoch [88/500], Train_Loss: 0.0098, Valid_Loss: 0.7670, Error: 0.0473
# LSTM_Epoch [89/500], Train_Loss: 0.0225, Valid_Loss: 0.6661, Error: 0.0515
# LSTM_Epoch [90/500], Train_Loss: 0.0101, Valid_Loss: 0.6826, Error: 0.0536
# LSTM_Epoch [91/500], Train_Loss: 0.0063, Valid_Loss: 0.7421, Error: 0.0580
# LSTM_Epoch [92/500], Train_Loss: 0.0142, Valid_Loss: 0.8293, Error: 0.0556
# LSTM_Epoch [93/500], Train_Loss: 0.0127, Valid_Loss: 0.7218, Error: 0.0478
# LSTM_Epoch [94/500], Train_Loss: 0.0079, Valid_Loss: 0.6989, Error: 0.0478
# LSTM_Epoch [95/500], Train_Loss: 0.0087, Valid_Loss: 0.7716, Error: 0.0461
# LSTM_Epoch [96/500], Train_Loss: 0.0126, Valid_Loss: 0.7684, Error: 0.0740
# LSTM_Epoch [97/500], Train_Loss: 0.0329, Valid_Loss: 0.6515, Error: 0.0599
# LSTM_Epoch [98/500], Train_Loss: 0.0131, Valid_Loss: 0.7874, Error: 0.0472
# LSTM_Epoch [99/500], Train_Loss: 0.0122, Valid_Loss: 0.6981, Error: 0.0514
# LSTM_Epoch [100/500], Train_Loss: 0.0079, Valid_Loss: 0.7301, Error: 0.0424
# LSTM_Epoch [101/500], Train_Loss: 0.0088, Valid_Loss: 0.6549, Error: 0.0632
# LSTM_Epoch [102/500], Train_Loss: 0.0138, Valid_Loss: 0.7347, Error: 0.0484
# LSTM_Epoch [103/500], Train_Loss: 0.0061, Valid_Loss: 0.7852, Error: 0.0692
# LSTM_Epoch [104/500], Train_Loss: 0.0062, Valid_Loss: 0.6814, Error: 0.0586
# LSTM_Epoch [105/500], Train_Loss: 0.0140, Valid_Loss: 0.8794, Error: 0.0456
# LSTM_Epoch [106/500], Train_Loss: 0.0102, Valid_Loss: 0.7204, Error: 0.0622
# LSTM_Epoch [107/500], Train_Loss: 0.0127, Valid_Loss: 0.7746, Error: 0.0481
# LSTM_Epoch [108/500], Train_Loss: 0.0083, Valid_Loss: 0.8935, Error: 0.0512
# LSTM_Epoch [109/500], Train_Loss: 0.0125, Valid_Loss: 0.7297, Error: 0.0571
# LSTM_Epoch [110/500], Train_Loss: 0.0092, Valid_Loss: 0.7647, Error: 0.0490
# LSTM_Epoch [111/500], Train_Loss: 0.0126, Valid_Loss: 0.6623, Error: 0.0432
# LSTM_Epoch [112/500], Train_Loss: 0.0087, Valid_Loss: 0.6616, Error: 0.0574
# LSTM_Epoch [113/500], Train_Loss: 0.0056, Valid_Loss: 0.6345, Error: 0.0524
# LSTM_Early stopping
# Total Error Mean 0.072895

# %%
# DAE Module
class DAE(nn.Module):
    def __init__(self, hidden_size):
        super(DAE, self).__init__()
        
        self.hidden_size = hidden_size
        self.encoder = nn.Sequential(
            nn.Dropout(),
            nn.Linear(hidden_size*2, 32)
        )
        
        self.decoder = nn.Sequential(
            nn.Sigmoid(),
            nn.Linear(32, hidden_size*2)
        )


    def forward(self, enc_input):
        enc_output = self.encoder(enc_input)
        dec_output = self.decoder(enc_output)
        
        return enc_output, dec_output

# %%
LSTM_module = torch.load('./LSTM_best.pth').to(device)
DAE_module = DAE(hidden_size).to(device)


# 불러온 LSTM 모듈 파라미터 Freeze
for param in LSTM_module.parameters():
    param.requires_grad = False

# %%
optimizer = torch.optim.RMSprop(DAE_module.parameters(), lr=learning_rate)
criterion = nn.MSELoss()

best = 100
converge_cnt = 0

# DAE 학습
for epoch in range(num_epochs_DAE):
    total_loss = 0
    total_val_loss = 0
    DAE_module.train()
    for i, batch in enumerate(train_loader):
        acc = batch['input_acc'] # (BATCH(100), 1, 28, 28) -> (BATCH(100), 28, 28)
        acc = acc.reshape(-1, sequence_length, input_size).to(device)
        gyro = batch['input_gyro']
        gyro = gyro.reshape(-1, sequence_length, input_size).to(device)

        # 순전파
        
        _, enc_input = LSTM_module(acc, gyro)
        enc_output, dec_output = DAE_module(enc_input)
        loss = criterion(enc_input, dec_output)
        
        
        # 역전파 & 최적화
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
    trn_loss = total_loss / len(train_loader)

            
    DAE_module.eval()
    with torch.no_grad():
        for i, batch in enumerate(val_loader):
            acc = batch['input_acc'] 
            acc = acc.reshape(-1, sequence_length, input_size).to(device)
            gyro = batch['input_gyro']
            gyro = gyro.reshape(-1, sequence_length, input_size).to(device)

            
            _, enc_input = LSTM_module(acc, gyro)
            enc_output, dec_output = DAE_module(enc_input)
            loss_val = criterion(enc_input, dec_output)
            
            total_val_loss += loss_val.item()
    val_loss = total_val_loss / len(val_loader)


    print('DAE_Epoch [{}/{}], Train_Loss: {:.4f}, Valid_Loss: {:.4f}'.format(
        epoch+1, num_epochs_DAE, trn_loss, val_loss))
# Out:
# DAE_Epoch [1/50], Train_Loss: 0.0568, Valid_Loss: 0.0268
# DAE_Epoch [2/50], Train_Loss: 0.0260, Valid_Loss: 0.0214
# DAE_Epoch [3/50], Train_Loss: 0.0229, Valid_Loss: 0.0201
# DAE_Epoch [4/50], Train_Loss: 0.0218, Valid_Loss: 0.0191
# DAE_Epoch [5/50], Train_Loss: 0.0207, Valid_Loss: 0.0181
# DAE_Epoch [6/50], Train_Loss: 0.0197, Valid_Loss: 0.0167
# DAE_Epoch [7/50], Train_Loss: 0.0185, Valid_Loss: 0.0156
# DAE_Epoch [8/50], Train_Loss: 0.0177, Valid_Loss: 0.0144
# DAE_Epoch [9/50], Train_Loss: 0.0169, Valid_Loss: 0.0136
# DAE_Epoch [10/50], Train_Loss: 0.0163, Valid_Loss: 0.0129
# DAE_Epoch [11/50], Train_Loss: 0.0159, Valid_Loss: 0.0123
# DAE_Epoch [12/50], Train_Loss: 0.0154, Valid_Loss: 0.0118
# DAE_Epoch [13/50], Train_Loss: 0.0150, Valid_Loss: 0.0115
# DAE_Epoch [14/50], Train_Loss: 0.0148, Valid_Loss: 0.0113
# DAE_Epoch [15/50], Train_Loss: 0.0146, Valid_Loss: 0.0109
# DAE_Epoch [16/50], Train_Loss: 0.0144, Valid_Loss: 0.0108
# DAE_Epoch [17/50], Train_Loss: 0.0142, Valid_Loss: 0.0106
# DAE_Epoch [18/50], Train_Loss: 0.0140, Valid_Loss: 0.0104
# DAE_Epoch [19/50], Train_Loss: 0.0138, Valid_Loss: 0.0102
# DAE_Epoch [20/50], Train_Loss: 0.0137, Valid_Loss: 0.0102
# DAE_Epoch [21/50], Train_Loss: 0.0136, Valid_Loss: 0.0100
# DAE_Epoch [22/50], Train_Loss: 0.0135, Valid_Loss: 0.0098
# DAE_Epoch [23/50], Train_Loss: 0.0134, Valid_Loss: 0.0097
# DAE_Epoch [24/50], Train_Loss: 0.0132, Valid_Loss: 0.0096
# DAE_Epoch [25/50], Train_Loss: 0.0132, Valid_Loss: 0.0096
# DAE_Epoch [26/50], Train_Loss: 0.0131, Valid_Loss: 0.0094
# DAE_Epoch [27/50], Train_Loss: 0.0131, Valid_Loss: 0.0094
# DAE_Epoch [28/50], Train_Loss: 0.0130, Valid_Loss: 0.0093
# DAE_Epoch [29/50], Train_Loss: 0.0129, Valid_Loss: 0.0093
# DAE_Epoch [30/50], Train_Loss: 0.0128, Valid_Loss: 0.0092
# DAE_Epoch [31/50], Train_Loss: 0.0127, Valid_Loss: 0.0092
# DAE_Epoch [32/50], Train_Loss: 0.0127, Valid_Loss: 0.0090
# DAE_Epoch [33/50], Train_Loss: 0.0125, Valid_Loss: 0.0089
# DAE_Epoch [34/50], Train_Loss: 0.0126, Valid_Loss: 0.0090
# DAE_Epoch [35/50], Train_Loss: 0.0126, Valid_Loss: 0.0090
# DAE_Epoch [36/50], Train_Loss: 0.0124, Valid_Loss: 0.0088
# DAE_Epoch [37/50], Train_Loss: 0.0124, Valid_Loss: 0.0089
# DAE_Epoch [38/50], Train_Loss: 0.0124, Valid_Loss: 0.0087
# DAE_Epoch [39/50], Train_Loss: 0.0124, Valid_Loss: 0.0087
# DAE_Epoch [40/50], Train_Loss: 0.0123, Valid_Loss: 0.0087
# DAE_Epoch [41/50], Train_Loss: 0.0122, Valid_Loss: 0.0086
# DAE_Epoch [42/50], Train_Loss: 0.0123, Valid_Loss: 0.0085
# DAE_Epoch [43/50], Train_Loss: 0.0121, Valid_Loss: 0.0086
# DAE_Epoch [44/50], Train_Loss: 0.0121, Valid_Loss: 0.0085
# DAE_Epoch [45/50], Train_Loss: 0.0120, Valid_Loss: 0.0084
# DAE_Epoch [46/50], Train_Loss: 0.0120, Valid_Loss: 0.0085
# DAE_Epoch [47/50], Train_Loss: 0.0120, Valid_Loss: 0.0084
# DAE_Epoch [48/50], Train_Loss: 0.0119, Valid_Loss: 0.0083
# DAE_Epoch [49/50], Train_Loss: 0.0119, Valid_Loss: 0.0084
# DAE_Epoch [50/50], Train_Loss: 0.0119, Valid_Loss: 0.0084

# %%
# 3) 인코더에 3개의 FC레이어를 붙여 최종 reg 수행, 모든 레이어에 대해 fine-tune 되어야함
# 즉 1), 2) 개별 학습 시키고, 여기서는 그 파라미터를 가져와서 fine-tuning
class LSTM_DAE(nn.Module):
    def __init__(self, enc_output_size):
        super(LSTM_DAE, self).__init__()
        
        self.enc_output_size = enc_output_size
        self.reg_module2 = nn.Sequential(
            nn.Linear(enc_output_size, 16),
            nn.ReLU(inplace=True),
            nn.Linear(16, 8),
            nn.ReLU(inplace=True),
            nn.Linear(8, 1)
        )
        

    def forward(self, acc, gyro, LSTM_module, DAE_module):
        _, enc_input = LSTM_module(acc, gyro)
        enc_output, _ = DAE_module(enc_input)
        final_pred = self.reg_module2(enc_output)
        
        return final_pred

# %%
enc_ouput_size = 32
LSTM_DAE = LSTM_DAE(enc_ouput_size).to(device)
LSTM_module = torch.load('./LSTM_best.pth').to(device)
DAE_module = torch.load('./DAE_best.pth').to(device)
param_groups = [
    {'params': LSTM_module.parameters(),'lr':learning_rate},
    {'params': DAE_module.parameters(),'lr':learning_rate},
    {'params': LSTM_DAE.parameters(),'lr':learning_rate},
]
optimizer = torch.optim.RMSprop(param_groups, lr=learning_rate)
criterion = nn.MSELoss()

best = 100
converge_cnt = 0
total_error = 0

# LSTM-DAE 학습
for epoch in range(num_epochs):
    total_loss = 0
    total_val_loss = 0
    LSTM_module.train()
    DAE_module.train()
    LSTM_DAE.train()
    for i, batch in enumerate(train_loader):
        acc = batch['input_acc'] # (BATCH(100), 1, 28, 28) -> (BATCH(100), 28, 28)
        acc = acc.reshape(-1, sequence_length, input_size).to(device)
        gyro = batch['input_gyro']
        gyro = gyro.reshape(-1, sequence_length, input_size).to(device)
        labels = batch['label']
        labels = labels.reshape(-1, 1).to(device)

        # 순전파
        
        pred = LSTM_DAE(acc, gyro, LSTM_module, DAE_module)
        loss = criterion(labels, pred)
        
        
        # 역전파 & 최적화
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
    trn_loss = total_loss / len(train_loader)

    LSTM_module.eval()
    DAE_module.eval()            
    LSTM_DAE.eval()
    with torch.no_grad():
        for i, batch in enumerate(val_loader):
            acc = batch['input_acc'] 
            acc = acc.reshape(-1, sequence_length, input_size).to(device)
            gyro = batch['input_gyro']
            gyro = gyro.reshape(-1, sequence_length, input_size).to(device)
            labels = batch['label']
            labels = labels.reshape(-1, 1).to(device)

            
            pred = LSTM_DAE(acc, gyro, LSTM_module, DAE_module)
            loss_val = criterion(labels, pred)
            
            total_val_loss += loss_val.item()
    val_loss = total_val_loss / len(val_loader)
    
    error = torch.sum(torch.abs(pred - labels) / labels) / len(labels)
    total_error += error

    print('LSTM_DAE_Epoch [{}/{}], Train_Loss: {:.4f}, Valid_Loss: {:.4f}, Error: {:.4f}'.format(
                    epoch+1, num_epochs, trn_loss, val_loss, error))
                
        
            
    if np.mean(val_loss) < best:
        best = np.mean(val_loss)
        torch.save(DAE_module, './LSTM_DAE_best.pth')
        print('Best Valid Loss {:.4f}'.format(best))
        converge_cnt = 0
    else:
        converge_cnt += 1
        
    if converge_cnt > 50:
        print('LSTM_DAE_Early stopping')
        print('Total Error Mean {:4f}'.format(total_error / (epoch+1)))
        break
# Out:
# LSTM_DAE_Epoch [1/500], Train_Loss: 0.9307, Valid_Loss: 0.9996, Error: 0.1181
# Best Valid Loss 0.9996
# LSTM_DAE_Epoch [2/500], Train_Loss: 0.5497, Valid_Loss: 1.0023, Error: 0.0967
# LSTM_DAE_Epoch [169/500], Train_Loss: 0.0323, Valid_Loss: 0.8062, Error: 0.1001
# LSTM_DAE_Epoch [170/500], Train_Loss: 0.0324, Valid_Loss: 0.7754, Error: 0.0783
# LSTM_DAE_Epoch [171/500], Train_Loss: 0.0365, Valid_Loss: 0.7618, Error: 0.0827
# LSTM_DAE_Epoch [172/500], Train_Loss: 0.0287, Valid_Loss: 0.8501, Error: 0.0453
# LSTM_DAE_Epoch [173/500], Train_Loss: 0.0247, Valid_Loss: 0.7761, Error: 0.0583
# LSTM_DAE_Epoch [174/500], Train_Loss: 0.0420, Valid_Loss: 0.7704, Error: 0.0754
# LSTM_DAE_Epoch [175/500], Train_Loss: 0.0387, Valid_Loss: 0.9406, Error: 0.0495
# LSTM_DAE_Epoch [176/500], Train_Loss: 0.0307, Valid_Loss: 0.7260, Error: 0.0578
# LSTM_DAE_Epoch [177/500], Train_Loss: 0.0263, Valid_Loss: 0.8392, Error: 0.0593
# LSTM_DAE_Epoch [178/500], Train_Loss: 0.0335, Valid_Loss: 0.8646, Error: 0.0737
# LSTM_DAE_Epoch [179/500], Train_Loss: 0.0227, Valid_Loss: 0.8696, Error: 0.0504
# LSTM_DAE_Epoch [180/500], Train_Loss: 0.0251, Valid_Loss: 0.8353, Error: 0.0831
# LSTM_DAE_Epoch [181/500], Train_Loss: 0.0441, Valid_Loss: 1.0142, Error: 0.0714
# LSTM_DAE_Early stopping
# Total Error Mean 0.076552

# %%
labels
# Out:
# tensor([[1.1887],
#         [4.5271],
#         [2.8751],
#         [1.3646],
#         [1.2365],
#         [1.3563],
#         [1.4127],
#         [1.2414],
#         [1.3930],
#         [1.0154],
#         [1.3458],
#         [1.3061],
#         [2.7992],
#         [1.3938],
#         [1.4295],
#         [1.3428],
#         [1.3440],
#         [1.4685],
#         [2.8909],
#         [1.2647],
#         [1.4516],
#         [1.4160],
#         [1.2055],
#         [1.3541],
#         [1.4258],
#         [1.4838],
#         [1.3215],
#         [1.4266],
#         [1.1528],
#         [1.4103],
#         [1.4187],
#         [1.3544],
#         [1.3911],
#         [1.4498],
#         [1.3708],
#         [1.3998],
#         [1.3472],
#         [1.4102],
#         [1.4491],
#         [1.2568],
#         [1.3074],
#         [1.3357],
#         [1.3425],
#         [2.9035],
#         [1.4723],
#         [1.4953],
#         [1.4451],
#         [1.4392],
#         [1.3684],
#         [2.5741],
#         [1.4499],
#         [1.3902],
#         [1.4596],
#         [1.4167],
#         [1.5096],
#         [1.3881],
#         [1.4676],
#         [1.3709],
#         [1.3701],
#         [1.4123],
#         [1.4561],
#         [1.4730],
#         [1.4878],
#         [1.3964],
#         [1.4578],
#         [1.4155],
#         [1.3223],
#         [1.3935],
#         [1.4071],
#         [1.4717],
#         [1.4678],
#         [1.3923],
#         [1.4707],
#         [1.3614],
#         [1.3549],
#         [1.4353],
#         [1.3663],
#         [1.3886],
#         [1.4899],
#         [1.4534],
#         [1.1267],
#         [2.8009],
#         [1.3700],
#         [1.4844],
#         [1.3570],
#         [1.3383],
#         [4.1972],
#         [1.3574],
#         [1.3686],
#         [1.4384],
#         [1.4644],
#         [1.1313],
#         [2.8061],
#         [1.3447],
#         [1.4097],
#         [1.4672],
#         [1.3396],
#         [1.4601],
#         [1.3189],
#         [1.3092],
#         [1.4636],
#         [1.3500],
#         [1.3835],
#         [1.1795],
#         [1.4259],
#         [1.3850],
#         [1.4025],
#         [1.4433],
#         [1.3714],
#         [1.4879],
#         [1.4433],
#         [1.4488],
#         [1.3987],
#         [1.3638],
#         [1.5057],
#         [1.3665],
#         [1.3454],
#         [1.4396],
#         [1.3691],
#         [1.3803],
#         [1.4211],
#         [1.3652],
#         [1.3572]], device='cuda:0')

# %%
pred
# Out:
# tensor([[1.2275],
#         [4.7658],
#         [2.9746],
#         [1.3961],
#         [1.3381],
#         [1.4236],
#         [1.4468],
#         [1.3566],
#         [1.4536],
#         [1.3798],
#         [1.4176],
#         [1.3622],
#         [2.8342],
#         [1.4455],
#         [1.4325],
#         [1.4247],
#         [1.3703],
#         [1.4776],
#         [2.9645],
#         [1.4189],
#         [1.4627],
#         [1.4787],
#         [1.4381],
#         [1.4054],
#         [1.4611],
#         [1.4843],
#         [1.4426],
#         [1.4337],
#         [1.2381],
#         [1.4434],
#         [1.4515],
#         [1.4366],
#         [1.4393],
#         [1.4409],
#         [1.4434],
#         [1.4410],
#         [1.4448],
#         [1.3990],
#         [1.4994],
#         [1.3332],
#         [1.3826],
#         [1.4099],
#         [1.3970],
#         [3.0112],
#         [1.4403],
#         [1.4400],
#         [1.4669],
#         [1.4306],
#         [1.4417],
#         [2.7727],
#         [1.4899],
#         [1.3639],
#         [1.4831],
#         [1.4657],
#         [1.5081],
#         [1.4249],
#         [1.4753],
#         [1.4440],
#         [1.3729],
#         [1.3965],
#         [1.4849],
#         [1.4436],
#         [1.4743],
#         [1.4090],
#         [1.4346],
#         [1.4173],
#         [1.3977],
#         [1.4049],
#         [1.3975],
#         [1.4577],
#         [1.4587],
#         [1.4909],
#         [1.4675],
#         [1.3747],
#         [1.4337],
#         [1.4306],
#         [1.4265],
#         [1.4730],
#         [1.5039],
#         [1.4463],
#         [1.2199],
#         [2.9259],
#         [1.3038],
#         [1.4692],
#         [1.3985],
#         [1.3818],
#         [4.5099],
#         [1.4300],
#         [1.3969],
#         [1.4610],
#         [1.4799],
#         [1.1419],
#         [3.0170],
#         [1.4276],
#         [1.4565],
#         [1.4473],
#         [1.3635],
#         [1.4939],
#         [1.3739],
#         [1.4048],
#         [1.5031],
#         [1.4075],
#         [1.4448],
#         [1.2384],
#         [1.4509],
#         [1.4185],
#         [1.4555],
#         [1.4645],
#         [1.4539],
#         [1.4521],
#         [1.4073],
#         [1.4764],
#         [1.4422],
#         [1.4128],
#         [1.4978],
#         [1.4369],
#         [1.3820],
#         [1.4764],
#         [1.4059],
#         [1.4157],
#         [1.4591],
#         [1.4442],
#         [1.3939]], device='cuda:0')

# %%
criterion(labels, pred)
# Out:
# tensor(0.0064, device='cuda:0')

# %%
len(val_loss)
# Out:
# 3500
