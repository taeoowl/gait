# %%
# salted 인솔로 추출한 데이터를 전처리하는 파일

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy

import os 
import glob

# %%
df = pd.read_csv('D:\gait_dataset/salted/왕준기_220608_3km.csv', skiprows=2)
df
# Out:
#                                      date  timestamp  L_value1  L_value2  \
# 0      Wed Jun 08 11:05:57 GMT+09:00 2022      40350         0         0
# 1      Wed Jun 08 11:05:57 GMT+09:00 2022      40360         0         0
# 2      Wed Jun 08 11:05:57 GMT+09:00 2022      40370         0         0
# 3      Wed Jun 08 11:05:57 GMT+09:00 2022      40380         0         0
# 4      Wed Jun 08 11:05:57 GMT+09:00 2022      40390         0         0
# ...                                   ...        ...       ...       ...
# 19931  Wed Jun 08 11:09:14 GMT+09:00 2022     239650         0         0
# 19932  Wed Jun 08 11:09:14 GMT+09:00 2022     239660         0         0
# 19933  Wed Jun 08 11:09:14 GMT+09:00 2022     239670         0         0
# 19934  Wed Jun 08 11:09:14 GMT+09:00 2022     239680         0         0
# 19935  Wed Jun 08 11:09:14 GMT+09:00 2022         -1         0         0
#
#        L_value3  L_value4  R_value1  R_value2  R_value3  R_value4  ...  \
# 0             0         0        39         0        25        56  ...
# 1             0         0        42         0        27        52  ...
# 2             0         0        46         0        30        47  ...
# 3             0         0        50         0        33        41  ...
# 4             0         0        53         0        35        34  ...
# ...         ...       ...       ...       ...       ...       ...  ...
# 19931         0        66        77         9        41         0  ...
# 19932         0        70        74         5        37         0  ...
# 19933         0        74        71         2        33         0  ...
# 19934         0        77        67         0        29         0  ...
# 19935         0         0         0         0         0         0  ...
#
#        R_value5_raw  R_value6_raw  L_GYRO_X  L_GYRO_Y  L_GYRO_Z  R_GYRO_X  \
# 0                 0             0      2524       278       381      -150
# 1                 0             0      2539       287       336      -169
# 2                 0             0      2564       275       367      -188
# 3                 0             0      2565       243       447      -205
# 4                 0             0      2512       219       527      -221
# ...             ...           ...       ...       ...       ...       ...
# 19931             0             0     -1273      -237        37     -2031
# 19932             0             0     -1612      -177         5     -2420
# 19933             0             0     -1039       -27        25     -2800
# 19934             0             0      -515       -12       -24     -3168
# 19935            -1            -1         0         0         0         0
#
#        R_GYRO_Y  R_GYRO_Z  L_TEMPERATURE  R_TEMPERATURE
# 0             3        18           4900          23050
# 1             1        20           4900          23050
# 2             9        21           4900          23050
# 3            13        25           4800          23150
# 4            15        31           4800          23150
# ...         ...       ...            ...            ...
# 19931       441       275          15600         -31386
# 19932       507       332          15250         -31486
# 19933       627       395          15250         -31486
# 19934       701       454          15250         -31486
# 19935         0         0              0              0
#
# [19936 rows x 48 columns]

# %%
# 오른쪽 압력값 평균

# right_prs = df.filter(regex="raw$")
# right_pres_mean = np.mean(right_prs.iloc[:, 4:8], axis=1) 

right_prs = df.filter(regex="R_value") # R_value의 값은 압력 센서의 raw값이 아닌 백분율
right_pres_mean = np.mean(right_prs.iloc[:, 0:4], axis=1) 
plt.figure(figsize=(15,3))
plt.plot(right_pres_mean[0:1500])

# %%
# 노이즈 제거를 위해 가우시안 필터 적용
right_pres_mean_gf = pd.Series(scipy.ndimage.gaussian_filter1d(right_pres_mean, 2))
plt.figure(figsize=(15,3))
plt.plot(right_pres_mean_gf[0:1500])

# %%
# 최종적으로 처리된 압력값을 바이너리로 표현
lev_idx = right_pres_mean_gf > 2 # 가우시안 필터로 인해 0이 아닌 값으로 threshold 설정
right_pres_lev = lev_idx.map(lambda x : 1 if x else 0)
plt.figure(figsize=(15,3))
plt.plot(right_pres_lev[:1500])

# %%
# 이벤트(HS, TO)에 대한 인덱스 추출
event_idx = []
for i in range(len(right_pres_lev)-1):
    if (right_pres_lev[i] - right_pres_lev[i+1]) != 0:
        event_idx.append(i)
event_idx
# Out:
# [31,
#  76,
#  160,
#  202,
#  288,
#  333,
#  424,
#  466,
#  551,
#  592,
#  674,
#  716,
#  806,
#  848,
#  933,
#  973,
#  1059,
#  1102,
#  1186,
#  1231,
#  1319,
#  1360,
#  1444,
#  1486,
#  1573,
#  1616,
#  1701,
#  1742,
#  1828,
#  1868,
#  1951,
#  1992,
#  2079,
#  2121,
#  2208,
#  2250,
#  2329,
#  2369,
#  2450,
#  2485,
#  2573,
#  2608,
#  2693,
#  2730,
#  2813,
#  2855,
#  2937,
#  2975,
#  3053,
#  3096,
#  3176,
#  3215,
#  3297,
#  3334,
#  3418,
#  3454,
#  3537,
#  3574,
#  3657,
#  3693,
#  3775,
#  3813,
#  3897,
#  3936,
#  4014,
#  4053,
#  4137,
#  4175,
#  4256,
#  4295,
#  4372,
#  4413,
#  4497,
#  4538,
#  4619,
#  4658,
#  4739,
#  4776,
#  4856,
#  4896,
#  4975,
#  5014,
#  5097,
#  5137,
#  5220,
#  5260,
#  5343,
#  5380,
#  5459,
#  5500,
#  5580,
#  5621,
#  5703,
#  5744,
#  5826,
#  5868,
#  5952,
#  5991,
#  6072,
#  6113,
#  6194,
#  6233,
#  6315,
#  6356,
#  6433,
#  6475,
#  6552,
#  6589,
#  6671,
#  6711,
#  6796,
#  6837,
#  6922,
#  6962,
#  7042,
#  7081,
#  7159,
#  7201,
#  7277,
#  7318,
#  7401,
#  7440,
#  7522,
#  7562,
#  7644,
#  7684,
#  7765,
#  7806,
#  7886,
#  7932,
#  8014,
#  8058,
#  8139,
#  8179,
#  8258,
#  8304,
#  8388,
#  8432,
#  8513,
#  8556,
#  8636,
#  8678,
#  8764,
#  8803,
#  8884,
#  8923,
#  9006,
#  9051,
#  9129,
#  9174,
#  9256,
#  9297,
#  9382,
#  9423,
#  9506,
#  9547,
#  9633,
#  9673,
#  9760,
#  9801,
#  9881,
#  9922,
#  10008,
#  10047,
#  10131,
#  10169,
#  10251,
#  10290,
#  10374,
#  10411,
#  10490,
#  10530,
#  10616,
#  10654,
#  10734,
#  10775,
#  10863,
#  10904,
#  10986,
#  11028,
#  11111,
#  11150,
#  11229,
#  11267,
#  11348,
#  11384,
#  11466,
#  11500,
#  11581,
#  11615,
#  11697,
#  11727,
#  11809,
#  11851,
#  11921,
#  11958,
#  12036,
#  12075,
#  12160,
#  12199,
#  12283,
#  12322,
#  12400,
#  12439,
#  12520,
#  12564,
#  12646,
#  12685,
#  12765,
#  12809,
#  12889,
#  12927,
#  13008,
#  13044,
#  13124,
#  13163,
#  13240,
#  13278,
#  13358,
#  13397,
#  13478,
#  13516,
#  13598,
#  13636,
#  13714,
#  13755,
#  13834,
#  13873,
#  13954,
#  13992,
#  14073,
#  14113,
#  14197,
#  14236,
#  14315,
#  14355,
#  14435,
#  14473,
#  14552,
#  14591,
#  14679,
#  14721,
#  14802,
#  14842,
#  14926,
#  14967,
#  15048,
#  15086,
#  15168,
#  15205,
#  15284,
#  15318,
#  15395,
#  15430,
#  15511,
#  15545,
#  15632,
#  15666,
#  15746,
#  15781,
#  15862,
#  15899,
#  15983,
#  16019,
#  16104,
#  16142,
#  16222,
#  16259,
#  16339,
#  16378,
#  16460,
#  16501,
#  16581,
#  16622,
#  16704,
#  16745,
#  16823,
#  16864,
#  16944,
#  16983,
#  17063,
#  17106,
#  17186,
#  17228,
#  17309,
#  17349,
#  17432,
#  17470,
#  17554,
#  17594,
#  17679,
#  17717,
#  17797,
#  17836,
#  17915,
#  17955,
#  18036,
#  18075,
#  18157,
#  18196,
#  18279,
#  18316,
#  18396,
#  18434,
#  18518,
#  18555,
#  18634,
#  18676,
#  18755,
#  18793,
#  18874,
#  18912,
#  18996,
#  19032,
#  19112,
#  19149,
#  19228,
#  19267,
#  19350,
#  19388,
#  19469,
#  19507,
#  19588,
#  19626,
#  19706,
#  19745,
#  19824,
#  19862]

# %%
# 일반적으로 Stance가 Swing보다 길다는 사실을 이용하여 첫 이벤트가 HS가 되도록 설정
# HS만 추출하여 단위걸음 분할
if np.diff(event_idx)[0] < np.diff(event_idx)[1]:
    del event_idx[0]
event_hs = event_idx[0::2]
event_hs
# Out:
# [76,
#  202,
#  333,
#  466,
#  592,
#  716,
#  848,
#  973,
#  1102,
#  1231,
#  1360,
#  1486,
#  1616,
#  1742,
#  1868,
#  1992,
#  2121,
#  2250,
#  2369,
#  2485,
#  2608,
#  2730,
#  2855,
#  2975,
#  3096,
#  3215,
#  3334,
#  3454,
#  3574,
#  3693,
#  3813,
#  3936,
#  4053,
#  4175,
#  4295,
#  4413,
#  4538,
#  4658,
#  4776,
#  4896,
#  5014,
#  5137,
#  5260,
#  5380,
#  5500,
#  5621,
#  5744,
#  5868,
#  5991,
#  6113,
#  6233,
#  6356,
#  6475,
#  6589,
#  6711,
#  6837,
#  6962,
#  7081,
#  7201,
#  7318,
#  7440,
#  7562,
#  7684,
#  7806,
#  7932,
#  8058,
#  8179,
#  8304,
#  8432,
#  8556,
#  8678,
#  8803,
#  8923,
#  9051,
#  9174,
#  9297,
#  9423,
#  9547,
#  9673,
#  9801,
#  9922,
#  10047,
#  10169,
#  10290,
#  10411,
#  10530,
#  10654,
#  10775,
#  10904,
#  11028,
#  11150,
#  11267,
#  11384,
#  11500,
#  11615,
#  11727,
#  11851,
#  11958,
#  12075,
#  12199,
#  12322,
#  12439,
#  12564,
#  12685,
#  12809,
#  12927,
#  13044,
#  13163,
#  13278,
#  13397,
#  13516,
#  13636,
#  13755,
#  13873,
#  13992,
#  14113,
#  14236,
#  14355,
#  14473,
#  14591,
#  14721,
#  14842,
#  14967,
#  15086,
#  15205,
#  15318,
#  15430,
#  15545,
#  15666,
#  15781,
#  15899,
#  16019,
#  16142,
#  16259,
#  16378,
#  16501,
#  16622,
#  16745,
#  16864,
#  16983,
#  17106,
#  17228,
#  17349,
#  17470,
#  17594,
#  17717,
#  17836,
#  17955,
#  18075,
#  18196,
#  18316,
#  18434,
#  18555,
#  18676,
#  18793,
#  18912,
#  19032,
#  19149,
#  19267,
#  19388,
#  19507,
#  19626,
#  19745,
#  19862]

# %%
# HS를 기준으로 잘 잘렸는지 확인
plt.figure(figsize=(15,3))
plt.plot(right_pres_lev[:1500])
for i in range(len(event_hs)):
    if event_hs[i] < 1500 :
        plt.axvline(x=event_hs[i], color='k')

# %%
# HS 이벤트를 기준으로 가속도 확인
acc_x = (df.R_ACC_X / 1000) * 9.8066
acc_y = (df.R_ACC_Y / 1000) * 9.8066
acc_z = (df.R_ACC_Z / 1000) * 9.8066


plt.figure(figsize=(15,3))
plt.plot(acc_x[:300])
plt.plot(acc_y[:300])
plt.plot(acc_z[:300])
for i in range(len(event_hs)):
    if event_hs[i] < 300 :
        plt.axvline(x=event_hs[i], color='k')

# %%
# 진행방향(발 앞 방향)인 y축의 가속도를 적분
speed = []
sp = 0
for i in range(76, 202):
    vel = sp + 0.5*(acc_y[:300][i] + acc_y[:300][i+1])*(1/100)    
    sp =+ vel
    speed.append(sp)
    
plt.figure(figsize=(15,3))
plt.axhline(y=3, color='k') # 3km/h
plt.axvline(x=84, color='k') # TO event
plt.plot(np.array(speed)*3.6)

# %%
distance = []
d = 0
di = 0
for i in range(len(speed)-1):
    vel = di + 0.5*(speed[i] +speed[i+1])*(1/40)    
    di =+ vel
    distance.append(di)
    
plt.figure(figsize=(15,3))
plt.axhline(y=1.05, color='k') # 압력센서로 구한 해당 구간 stride length
plt.axvline(x=84, color='k') # TO event
plt.plot(distance)
