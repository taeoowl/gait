# %% [markdown]
# # 모듈 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

import scipy
from scipy.ndimage import gaussian_filter1d
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

import torch
from torch.utils.data import Dataset, DataLoader, random_split
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

import os 
import glob
import cv2
import itertools

from dataloader_distance import *

# %% [markdown]
# # bias 확인

# %%
df = pd.read_csv('D:\gait_dataset/salted/train/김보민_220617_3km.csv', skiprows=2)
acc = df.filter(regex="R_ACC")
gyr = df.filter(regex="R_GYRO")
event_idx = get_event_salted('D:\gait_dataset/salted/train/김보민_220617_3km.csv')

# HS 이벤트 추출
event_hs = event_idx[0::2]

# m/s^2 단위 변환
acc = (acc / 1000) * 9.8066
acc.R_ACC_Z = acc.R_ACC_Z - np.mean(acc.R_ACC_Z)

# %%
inputs_acc[0].shape
# Out:
# (3, 131)

# %%
file_path = "D:\gait_dataset/salted/train/*"
inputs_acc, inputs_gyr, stride_length = get_sensor_salted(file_path, normalization=False)
inputs_pst = get_position_salted(file_path, distance=True)

# %%
plt.figure(figsize=(15,5))
plt.plot(inputs_acc[0].transpose())
plt.axvline(x=216, color='k')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(scipy.integrate.cumulative_trapezoid(inputs_acc[0], dx=(1/100)).transpose())
plt.axhline(y=0, color='k')
plt.axvline(x=87, color='k')
plt.show()

# %%
spd = scipy.integrate.cumulative_trapezoid(inputs_acc[0], dx=(1/100))

# %%
spd.shape
# Out:
# (3, 130)

# %%
# z축 평균

# %%
plt.figure(figsize=(15,5))
plt.plot(scipy.integrate.cumulative_trapezoid(spd, dx=(1/100)).transpose()*100)
plt.show()
pst = pd.DataFrame(scipy.integrate.cumulative_trapezoid(spd, dx=(1/100)).transpose()*100)

# %%
pst
# Out:
#              0          1          2
# 0     0.005962   0.300523   0.011467
# 1     0.018113   0.684746   0.034370
# 2     0.027506   1.062545   0.077389
# 3     0.030854   1.409184   0.135497
# 4     0.033796   1.736871   0.201095
# ..         ...        ...        ...
# 124 -13.040816  31.077973  55.695556
# 125 -13.501745  32.122499  55.838410
# 126 -13.936993  33.382745  55.995545
# 127 -14.348155  34.872196  56.171104
# 128 -14.730866  36.601296  56.364645
#
# [129 rows x 3 columns]

# %%
np.sum(pst, axis=0)
# Out:
# 0    -301.057023
# 1    2657.861174
# 2    3027.176843
# dtype: float64

# %%
pst
# Out:
# 0      0.003180
# 1      0.007372
# 2      0.011674
# 3      0.015755
# 4      0.019718
#          ...
# 124    0.737327
# 125    0.744592
# 126    0.754413
# 127    0.766951
# 128    0.782351
# Length: 129, dtype: float64

# %% [markdown]
# # Linear Regression : Only Distance

# %% [markdown]
# ### 데이터 불러오기

# %%
file_path_train = "D:\gait_dataset/salted/3km/train/*"
_, _, y_train = get_sensor_salted(file_path_train)
inputs_pst_train = get_position_salted(file_path_train, distance=True)

file_path_test = "D:\gait_dataset/salted/3km/test/*"
_, _, y_test = get_sensor_salted(file_path_test)
inputs_pst_test = get_position_salted(file_path_test, distance=True)

# %%
x_train = pd.DataFrame(inputs_pst_train)
x_train.columns =  ['R_DIS_X', 'R_DIS_Y', 'R_DIS_Z']

x_test = pd.DataFrame(inputs_pst_test)
x_test.columns =  ['R_DIS_X', 'R_DIS_Y', 'R_DIS_Z']

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
MAE = mean_absolute_error(y_test, y_pred)
corr = np.corrcoef(y_test, y_pred)
print('MAE : {:.4f}, Corr : {:.4f}'.format(MAE, corr[0, 1]))
# Out:
# MAE : 6.5157, Corr : 0.3488

# %%
plt.figure(figsize=(10, 10))
plt.scatter(y_test, y_pred)
plt.xlim([80, 150])
plt.xlabel('stride_length')
plt.ylim([80, 150])
plt.ylabel('pred')

xpoints = ypoints = plt.xlim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)

plt.show()

# %% [markdown]
# # Encoder-based Model : 최종 노드 1개

# %% [markdown]
# ## 데이터 불러오기

# %%
device = torch.device('cuda:0' if torch.cuda.is_available else 'cpu')

file_path = "D:\gait_dataset/salted/3km/train/*"
dataset = Gait_Dataset_Salted(file_path)
val_percent = 0.2
n_val = int(len(dataset) * val_percent)
n_train = len(dataset) - n_val
train, val = random_split(dataset, [n_train, n_val])

# %%
train_loader = torch.utils.data.DataLoader(train,
                                           batch_size=128,
                                           shuffle=True,
                                           worker_init_fn=np.random.seed(42))
val_loader = torch.utils.data.DataLoader(val,
                                         batch_size=128,
                                         shuffle=False)

# %% [markdown]
# ## Model & Scatter Plot
# - 인코더에 Conv1d만을 사용
# - 인코더의 아웃풋 길이가 늘어나 FC Layer의 수를 늘려 실험
#     - FC Layer : enc_output -> 512 -> 256 -> 128 -> 64 -> 32 -> 1
# - Best Result : Epoch 284, Valid Loss 11.398009, MAE 2.244626

# %%
# seed 고정
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

class Encoder(nn.Module):
    def __init__(self, input_dim, conv1d_dim1, conv1d_dim2, dense_dim):
        super(Encoder, self).__init__()
             
        self.conv1d_acc = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 30),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 30),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.conv1d_gyr = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 30),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 30),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.dense = nn.Sequential(
            nn.Linear(7744*2, dense_dim),
            nn.ReLU(inplace=True),
            nn.Linear(dense_dim, int(dense_dim/2)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/2), int(dense_dim/4)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/4), int(dense_dim/8)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/8), 1)
        )
        

    def forward(self, inputs_acc, inputs_gyr): 
        
        conv1d_output_acc = self.conv1d_acc(inputs_acc)
        conv1d_output_gyr = self.conv1d_gyr(inputs_gyr)
        
        enc_output = torch.concat((conv1d_output_acc, conv1d_output_gyr), 1)
        dense_output = self.dense(enc_output)
        
        return dense_output

# %%
input_dim = 3
conv1d_dim1 = 16
conv1d_dim2 = 32
dense_dim = 512

model = Encoder(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
n_epochs = 2000

criterion = nn.MSELoss()

# %%
# Early Stopping을 위한 변수
best = 1000
converge_cnt = 0
best_MAE = 0
best_corr = 0
best_epoch = 0

# Run Training loop
for epoch in range(0, n_epochs) :
    # Set current loss value 
    tot_trn_loss = 0.0
    
    # Train Mode
    model.train()
    
    # Iterate over the DataLoader for training data 
    for i, data in enumerate(train_loader) :
        inputs_acc, inputs_gyr, stride_length, _ = data
        inputs_acc, inputs_gyr, stride_length = inputs_acc.float(), inputs_gyr.float(), stride_length.float()
        inputs_acc, inputs_gyr = inputs_acc.to(device), inputs_gyr.to(device)
        stride_length = stride_length.reshape(-1, 1)
        stride_length = stride_length.to(device)

        # 순전파 
        outputs = model(inputs_acc, inputs_gyr)
        
        # Loss 계산
        loss = criterion(outputs, stride_length)
        
        # 기울기 초기화 
        optimizer.zero_grad()
        # 역전파
        loss.backward()
        # 옵티마이저
        optimizer.step()

        
        # Print statistics
        tot_trn_loss += loss.item()
        
    # Evaluation Mode
    model.eval()
    
    tot_val_loss = 0
    val_epoch_loss = []

    with torch.no_grad() :
        for i, data in enumerate(val_loader):
            inputs_acc, inputs_gyr, stride_length, _ = data
            inputs_acc, inputs_gyr, stride_length = inputs_acc.float(), inputs_gyr.float(), stride_length.float()
            inputs_acc, inputs_gyr = inputs_acc.to(device), inputs_gyr.to(device)
            stride_length = stride_length.reshape(-1, 1)
            stride_length = stride_length.to(device)

            # 순전파 
            outputs = model(inputs_acc, inputs_gyr)
            
            # Loss 계산
            loss = criterion(outputs, stride_length)
            tot_val_loss += loss.item()            
            

    # Epoch 별 Loss
    trn_loss = tot_trn_loss / len(train_loader)
    val_loss = tot_val_loss / len(val_loader)
    MAE = torch.sum(torch.abs(outputs - stride_length)) / len(stride_length)
    corr = torch.corrcoef(torch.stack([torch.squeeze(stride_length), torch.squeeze(outputs)]))[0, 1]
    
    
    print("Epoch : {}/{}, Train Loss : {:.3f}, Valid Loss {:.3f}, MAE {:.3f}, Corr {:3f}".format(epoch+1, n_epochs,
                                                                                       trn_loss, val_loss,
                                                                                      MAE, corr))
    
    # Early Stopping
    if val_loss < best:
        best = np.mean(val_loss)
        best_MAE = MAE
        best_corr = corr
        best_epoch = epoch+1
        torch.save(model.state_dict(), './encoder_1_best_ks30_nobias.pth')
        print('Best Valid Loss {:.4f}'.format(best))
        converge_cnt = 0
    else:
        converge_cnt += 1
    
    if converge_cnt > 20:
        print('Early stopping')
        print('Best Result : Epoch {}, Valid Loss {:.3f}, MAE {:.3f}, Corr {:3f}'.format(best_epoch, best, best_MAE, best_corr))
        break
    
#     print("Epoch : {}/{} Epoch Loss : {:.6f}".format(epoch+1, n_epochs, current_loss / len(trainloader.dataset)))
# Out:
# Epoch : 1/2000, Train Loss : 11012.951, Valid Loss 4012.295, MAE 63.067, Corr 0.257248
# Epoch : 2/2000, Train Loss : 1765.596, Valid Loss 1585.880, MAE 39.179, Corr 0.289506
# Epoch : 3/2000, Train Loss : 923.697, Valid Loss 777.053, MAE 26.486, Corr 0.318481
# Best Valid Loss 777.0529
# Epoch : 4/2000, Train Loss : 437.928, Valid Loss 514.486, MAE 21.356, Corr 0.350192
# Best Valid Loss 514.4865
# Epoch : 5/2000, Train Loss : 226.816, Valid Loss 165.547, MAE 10.628, Corr 0.362184
# Best Valid Loss 165.5474
# Epoch : 6/2000, Train Loss : 126.743, Valid Loss 80.340, MAE 6.511, Corr 0.380208
# Best Valid Loss 80.3401
# Epoch : 7/2000, Train Loss : 87.857, Valid Loss 90.953, MAE 6.908, Corr 0.393846
# Epoch : 8/2000, Train Loss : 82.052, Valid Loss 86.431, MAE 8.078, Corr 0.403885
# Epoch : 9/2000, Train Loss : 64.612, Valid Loss 78.427, MAE 6.400, Corr 0.417136
# Best Valid Loss 78.4267
# Epoch : 10/2000, Train Loss : 60.311, Valid Loss 60.234, MAE 6.545, Corr 0.427246
# Best Valid Loss 60.2342
# Epoch : 11/2000, Train Loss : 54.320, Valid Loss 59.923, MAE 6.649, Corr 0.437864
# Best Valid Loss 59.9234
# Epoch : 12/2000, Train Loss : 55.034, Valid Loss 65.135, MAE 6.073, Corr 0.449661
# Epoch : 13/2000, Train Loss : 51.996, Valid Loss 57.890, MAE 6.411, Corr 0.459188
# Best Valid Loss 57.8900
# Epoch : 14/2000, Train Loss : 59.650, Valid Loss 57.474, MAE 6.503, Corr 0.469151
# Best Valid Loss 57.4736
# Epoch : 15/2000, Train Loss : 55.716, Valid Loss 69.277, MAE 6.056, Corr 0.481002
# Epoch : 16/2000, Train Loss : 55.138, Valid Loss 56.342, MAE 6.113, Corr 0.490311
# Best Valid Loss 56.3421
# Epoch : 17/2000, Train Loss : 51.336, Valid Loss 58.072, MAE 6.734, Corr 0.499414
# Epoch : 18/2000, Train Loss : 52.590, Valid Loss 55.475, MAE 6.511, Corr 0.509669
# Best Valid Loss 55.4751
# Epoch : 19/2000, Train Loss : 50.913, Valid Loss 58.841, MAE 5.827, Corr 0.520816
# Epoch : 20/2000, Train Loss : 48.637, Valid Loss 58.475, MAE 5.794, Corr 0.530512
# Epoch : 21/2000, Train Loss : 46.931, Valid Loss 52.122, MAE 6.162, Corr 0.539058
# Best Valid Loss 52.1221
# Epoch : 22/2000, Train Loss : 45.638, Valid Loss 53.287, MAE 5.768, Corr 0.549716
# Epoch : 23/2000, Train Loss : 45.366, Valid Loss 55.394, MAE 5.684, Corr 0.559983
# Epoch : 24/2000, Train Loss : 46.741, Valid Loss 50.012, MAE 5.798, Corr 0.569405
# Best Valid Loss 50.0120
# Epoch : 25/2000, Train Loss : 48.379, Valid Loss 50.934, MAE 6.236, Corr 0.578383
# Epoch : 26/2000, Train Loss : 45.426, Valid Loss 48.407, MAE 5.908, Corr 0.587971
# Best Valid Loss 48.4068
# Epoch : 27/2000, Train Loss : 44.295, Valid Loss 48.728, MAE 6.037, Corr 0.595945
# Epoch : 28/2000, Train Loss : 44.489, Valid Loss 48.093, MAE 5.993, Corr 0.604317
# Best Valid Loss 48.0935
# Epoch : 29/2000, Train Loss : 42.171, Valid Loss 46.548, MAE 5.799, Corr 0.612399
# Best Valid Loss 46.5479
# Epoch : 30/2000, Train Loss : 38.887, Valid Loss 45.902, MAE 5.650, Corr 0.619855
# Best Valid Loss 45.9020
# Epoch : 31/2000, Train Loss : 40.104, Valid Loss 46.794, MAE 5.919, Corr 0.626254
# Epoch : 32/2000, Train Loss : 41.543, Valid Loss 45.657, MAE 5.818, Corr 0.634011
# Best Valid Loss 45.6567
# Epoch : 33/2000, Train Loss : 40.863, Valid Loss 45.486, MAE 5.820, Corr 0.641253
# Best Valid Loss 45.4860
# Epoch : 34/2000, Train Loss : 38.992, Valid Loss 43.660, MAE 5.550, Corr 0.648440
# Best Valid Loss 43.6603
# Epoch : 35/2000, Train Loss : 37.372, Valid Loss 48.592, MAE 5.226, Corr 0.656817
# Epoch : 36/2000, Train Loss : 37.187, Valid Loss 44.880, MAE 5.199, Corr 0.662575
# Epoch : 37/2000, Train Loss : 36.552, Valid Loss 46.658, MAE 5.155, Corr 0.668993
# Epoch : 38/2000, Train Loss : 40.157, Valid Loss 55.867, MAE 5.426, Corr 0.675597
# Epoch : 39/2000, Train Loss : 43.416, Valid Loss 43.363, MAE 5.109, Corr 0.679834
# Best Valid Loss 43.3633
# Epoch : 40/2000, Train Loss : 35.934, Valid Loss 46.673, MAE 5.105, Corr 0.686325
# Epoch : 41/2000, Train Loss : 38.483, Valid Loss 44.024, MAE 5.033, Corr 0.691124
# Epoch : 42/2000, Train Loss : 38.367, Valid Loss 48.571, MAE 5.125, Corr 0.697013
# Epoch : 43/2000, Train Loss : 39.072, Valid Loss 53.610, MAE 5.333, Corr 0.703196
# Epoch : 44/2000, Train Loss : 44.843, Valid Loss 39.192, MAE 5.139, Corr 0.705075
# Best Valid Loss 39.1925
# Epoch : 45/2000, Train Loss : 37.036, Valid Loss 40.586, MAE 5.390, Corr 0.711865
# Epoch : 46/2000, Train Loss : 35.143, Valid Loss 37.980, MAE 5.041, Corr 0.718913
# Best Valid Loss 37.9797
# Epoch : 47/2000, Train Loss : 33.816, Valid Loss 37.623, MAE 5.067, Corr 0.723832
# Best Valid Loss 37.6234
# Epoch : 48/2000, Train Loss : 34.511, Valid Loss 37.073, MAE 4.996, Corr 0.729551
# Best Valid Loss 37.0731
# Epoch : 49/2000, Train Loss : 32.675, Valid Loss 40.958, MAE 4.812, Corr 0.736630
# Epoch : 50/2000, Train Loss : 33.550, Valid Loss 36.636, MAE 4.775, Corr 0.740890
# Best Valid Loss 36.6359
# Epoch : 51/2000, Train Loss : 32.490, Valid Loss 36.901, MAE 4.714, Corr 0.746838
# Epoch : 52/2000, Train Loss : 33.752, Valid Loss 35.019, MAE 4.786, Corr 0.752765
# Best Valid Loss 35.0195
# Epoch : 53/2000, Train Loss : 31.449, Valid Loss 34.575, MAE 4.765, Corr 0.758333
# Best Valid Loss 34.5747
# Epoch : 54/2000, Train Loss : 34.951, Valid Loss 35.849, MAE 4.587, Corr 0.764514
# Epoch : 55/2000, Train Loss : 33.453, Valid Loss 38.021, MAE 4.598, Corr 0.770842
# Epoch : 56/2000, Train Loss : 32.295, Valid Loss 34.003, MAE 4.493, Corr 0.776680
# Best Valid Loss 34.0028
# Epoch : 57/2000, Train Loss : 32.243, Valid Loss 32.591, MAE 4.578, Corr 0.781660
# Best Valid Loss 32.5909
# Epoch : 58/2000, Train Loss : 30.387, Valid Loss 31.820, MAE 4.456, Corr 0.787403
# Best Valid Loss 31.8201
# Epoch : 59/2000, Train Loss : 28.114, Valid Loss 32.544, MAE 4.591, Corr 0.792135
# Epoch : 60/2000, Train Loss : 30.659, Valid Loss 30.896, MAE 4.347, Corr 0.798194
# Best Valid Loss 30.8956
# Epoch : 61/2000, Train Loss : 29.510, Valid Loss 31.079, MAE 4.449, Corr 0.802540
# Epoch : 62/2000, Train Loss : 27.816, Valid Loss 29.820, MAE 4.206, Corr 0.809618
# Best Valid Loss 29.8195
# Epoch : 63/2000, Train Loss : 27.594, Valid Loss 39.527, MAE 4.654, Corr 0.815705
# Epoch : 64/2000, Train Loss : 30.811, Valid Loss 33.544, MAE 4.283, Corr 0.820596
# Epoch : 65/2000, Train Loss : 28.360, Valid Loss 28.036, MAE 4.073, Corr 0.824864
# Best Valid Loss 28.0356
# Epoch : 66/2000, Train Loss : 26.371, Valid Loss 27.596, MAE 4.034, Corr 0.829785
# Best Valid Loss 27.5958
# Epoch : 67/2000, Train Loss : 26.153, Valid Loss 32.556, MAE 4.257, Corr 0.835680
# Epoch : 68/2000, Train Loss : 26.674, Valid Loss 26.688, MAE 3.938, Corr 0.839593
# Best Valid Loss 26.6882
# Epoch : 69/2000, Train Loss : 28.720, Valid Loss 26.075, MAE 3.867, Corr 0.844442
# Best Valid Loss 26.0749
# Epoch : 70/2000, Train Loss : 26.399, Valid Loss 36.848, MAE 4.483, Corr 0.848799
# Epoch : 71/2000, Train Loss : 27.742, Valid Loss 25.167, MAE 3.778, Corr 0.851730
# Best Valid Loss 25.1670
# Epoch : 72/2000, Train Loss : 28.998, Valid Loss 24.977, MAE 3.740, Corr 0.854521
# Best Valid Loss 24.9775
# Epoch : 73/2000, Train Loss : 24.265, Valid Loss 24.282, MAE 3.676, Corr 0.857801
# Best Valid Loss 24.2818
# Epoch : 74/2000, Train Loss : 22.665, Valid Loss 30.857, MAE 4.147, Corr 0.858835
# Epoch : 75/2000, Train Loss : 23.239, Valid Loss 25.173, MAE 3.695, Corr 0.864371
# Epoch : 76/2000, Train Loss : 23.269, Valid Loss 23.178, MAE 3.548, Corr 0.866281
# Best Valid Loss 23.1779
# Epoch : 77/2000, Train Loss : 22.114, Valid Loss 27.089, MAE 3.844, Corr 0.870233
# Epoch : 78/2000, Train Loss : 21.070, Valid Loss 24.280, MAE 3.598, Corr 0.871880
# Epoch : 79/2000, Train Loss : 21.765, Valid Loss 22.074, MAE 3.382, Corr 0.873625
# Best Valid Loss 22.0739
# Epoch : 80/2000, Train Loss : 24.200, Valid Loss 31.649, MAE 4.177, Corr 0.877471
# Epoch : 81/2000, Train Loss : 22.471, Valid Loss 22.104, MAE 3.414, Corr 0.878406
# Epoch : 82/2000, Train Loss : 21.273, Valid Loss 23.197, MAE 3.488, Corr 0.879122
# Epoch : 83/2000, Train Loss : 21.582, Valid Loss 20.617, MAE 3.219, Corr 0.881701
# Best Valid Loss 20.6166
# Epoch : 84/2000, Train Loss : 20.633, Valid Loss 21.636, MAE 3.368, Corr 0.883874
# Epoch : 85/2000, Train Loss : 19.948, Valid Loss 20.562, MAE 3.205, Corr 0.884328
# Best Valid Loss 20.5625
# Epoch : 86/2000, Train Loss : 22.426, Valid Loss 19.982, MAE 3.164, Corr 0.886027
# Best Valid Loss 19.9815
# Epoch : 87/2000, Train Loss : 20.150, Valid Loss 20.416, MAE 3.235, Corr 0.887622
# Epoch : 88/2000, Train Loss : 19.927, Valid Loss 20.424, MAE 3.173, Corr 0.887795
# Epoch : 89/2000, Train Loss : 20.402, Valid Loss 21.623, MAE 3.346, Corr 0.889704
# Epoch : 90/2000, Train Loss : 19.011, Valid Loss 21.088, MAE 3.253, Corr 0.889101
# Epoch : 91/2000, Train Loss : 18.907, Valid Loss 18.966, MAE 3.056, Corr 0.891067
# Best Valid Loss 18.9664
# Epoch : 92/2000, Train Loss : 22.031, Valid Loss 27.831, MAE 3.897, Corr 0.893938
# Epoch : 93/2000, Train Loss : 23.846, Valid Loss 18.647, MAE 3.000, Corr 0.893620
# Best Valid Loss 18.6470
# Epoch : 94/2000, Train Loss : 19.329, Valid Loss 19.714, MAE 3.167, Corr 0.895121
# Epoch : 95/2000, Train Loss : 18.634, Valid Loss 22.177, MAE 3.362, Corr 0.896805
# Epoch : 96/2000, Train Loss : 19.590, Valid Loss 22.347, MAE 3.403, Corr 0.893673
# Epoch : 97/2000, Train Loss : 23.491, Valid Loss 20.181, MAE 3.165, Corr 0.897110
# Epoch : 98/2000, Train Loss : 19.711, Valid Loss 20.186, MAE 3.183, Corr 0.900079
# Epoch : 99/2000, Train Loss : 21.036, Valid Loss 32.548, MAE 4.311, Corr 0.899972
# Epoch : 100/2000, Train Loss : 27.202, Valid Loss 21.392, MAE 3.327, Corr 0.897207
# Epoch : 101/2000, Train Loss : 22.920, Valid Loss 38.408, MAE 4.806, Corr 0.902111
# Epoch : 102/2000, Train Loss : 23.138, Valid Loss 28.325, MAE 4.044, Corr 0.899421
# Epoch : 103/2000, Train Loss : 29.615, Valid Loss 31.218, MAE 4.204, Corr 0.903121
# Epoch : 104/2000, Train Loss : 31.826, Valid Loss 17.790, MAE 2.957, Corr 0.903046
# Best Valid Loss 17.7899
# Epoch : 105/2000, Train Loss : 22.908, Valid Loss 18.994, MAE 3.116, Corr 0.902603
# Epoch : 106/2000, Train Loss : 22.728, Valid Loss 21.996, MAE 3.354, Corr 0.906156
# Epoch : 107/2000, Train Loss : 21.802, Valid Loss 17.063, MAE 2.889, Corr 0.904526
# Best Valid Loss 17.0633
# Epoch : 108/2000, Train Loss : 19.575, Valid Loss 23.358, MAE 3.481, Corr 0.904096
# Epoch : 109/2000, Train Loss : 20.933, Valid Loss 23.993, MAE 3.611, Corr 0.903243
# Epoch : 110/2000, Train Loss : 26.246, Valid Loss 35.408, MAE 4.606, Corr 0.907633
# Epoch : 111/2000, Train Loss : 24.601, Valid Loss 20.793, MAE 3.291, Corr 0.907407
# Epoch : 112/2000, Train Loss : 20.732, Valid Loss 17.563, MAE 2.917, Corr 0.908704
# Epoch : 113/2000, Train Loss : 17.408, Valid Loss 16.228, MAE 2.786, Corr 0.910011
# Best Valid Loss 16.2282
# Epoch : 114/2000, Train Loss : 17.573, Valid Loss 18.380, MAE 3.028, Corr 0.911180
# Epoch : 115/2000, Train Loss : 20.325, Valid Loss 35.192, MAE 4.606, Corr 0.911393
# Epoch : 116/2000, Train Loss : 22.535, Valid Loss 21.728, MAE 3.395, Corr 0.910998
# Epoch : 117/2000, Train Loss : 20.378, Valid Loss 18.133, MAE 3.005, Corr 0.913186
# Epoch : 118/2000, Train Loss : 20.197, Valid Loss 17.927, MAE 2.974, Corr 0.914577
# Epoch : 119/2000, Train Loss : 17.923, Valid Loss 16.411, MAE 2.798, Corr 0.914491
# Epoch : 120/2000, Train Loss : 16.319, Valid Loss 15.377, MAE 2.661, Corr 0.915241
# Best Valid Loss 15.3775
# Epoch : 121/2000, Train Loss : 16.114, Valid Loss 20.220, MAE 3.190, Corr 0.916727
# Epoch : 122/2000, Train Loss : 18.833, Valid Loss 17.259, MAE 2.871, Corr 0.913907
# Epoch : 123/2000, Train Loss : 18.922, Valid Loss 14.722, MAE 2.639, Corr 0.916809
# Best Valid Loss 14.7221
# Epoch : 124/2000, Train Loss : 15.608, Valid Loss 14.666, MAE 2.614, Corr 0.916215
# Best Valid Loss 14.6664
# Epoch : 125/2000, Train Loss : 15.416, Valid Loss 15.496, MAE 2.724, Corr 0.918776
# Epoch : 126/2000, Train Loss : 14.726, Valid Loss 14.695, MAE 2.637, Corr 0.919335
# Epoch : 127/2000, Train Loss : 19.247, Valid Loss 22.696, MAE 3.617, Corr 0.916727
# Epoch : 128/2000, Train Loss : 19.209, Valid Loss 20.063, MAE 3.191, Corr 0.921393
# Epoch : 129/2000, Train Loss : 16.807, Valid Loss 20.016, MAE 3.297, Corr 0.921021
# Epoch : 130/2000, Train Loss : 17.201, Valid Loss 16.229, MAE 2.766, Corr 0.922105
# Epoch : 131/2000, Train Loss : 14.666, Valid Loss 13.662, MAE 2.439, Corr 0.923223
# Best Valid Loss 13.6621
# Epoch : 132/2000, Train Loss : 15.932, Valid Loss 14.875, MAE 2.624, Corr 0.923962
# Epoch : 133/2000, Train Loss : 14.803, Valid Loss 15.384, MAE 2.743, Corr 0.923279
# Epoch : 134/2000, Train Loss : 16.511, Valid Loss 20.199, MAE 3.235, Corr 0.924821
# Epoch : 135/2000, Train Loss : 17.948, Valid Loss 14.517, MAE 2.636, Corr 0.925116
# Epoch : 136/2000, Train Loss : 15.182, Valid Loss 13.006, MAE 2.418, Corr 0.926180
# Best Valid Loss 13.0064
# Epoch : 137/2000, Train Loss : 15.494, Valid Loss 12.935, MAE 2.410, Corr 0.927204
# Best Valid Loss 12.9350
# Epoch : 138/2000, Train Loss : 15.637, Valid Loss 13.863, MAE 2.524, Corr 0.927781
# Epoch : 139/2000, Train Loss : 15.854, Valid Loss 24.932, MAE 3.805, Corr 0.928896
# Epoch : 140/2000, Train Loss : 15.809, Valid Loss 12.722, MAE 2.367, Corr 0.928733
# Best Valid Loss 12.7216
# Epoch : 141/2000, Train Loss : 15.508, Valid Loss 13.963, MAE 2.521, Corr 0.929965
# Epoch : 142/2000, Train Loss : 16.276, Valid Loss 16.305, MAE 2.790, Corr 0.930252
# Epoch : 143/2000, Train Loss : 16.542, Valid Loss 17.880, MAE 2.984, Corr 0.930360
# Epoch : 144/2000, Train Loss : 15.774, Valid Loss 20.544, MAE 3.534, Corr 0.929286
# Epoch : 145/2000, Train Loss : 20.026, Valid Loss 28.100, MAE 4.453, Corr 0.932109
# Epoch : 146/2000, Train Loss : 18.651, Valid Loss 15.222, MAE 2.673, Corr 0.932455
# Epoch : 147/2000, Train Loss : 15.291, Valid Loss 12.742, MAE 2.392, Corr 0.930297
# Epoch : 148/2000, Train Loss : 12.590, Valid Loss 11.918, MAE 2.351, Corr 0.932498
# Best Valid Loss 11.9184
# Epoch : 149/2000, Train Loss : 12.593, Valid Loss 11.807, MAE 2.317, Corr 0.931351
# Best Valid Loss 11.8066
# Epoch : 150/2000, Train Loss : 12.406, Valid Loss 14.449, MAE 2.573, Corr 0.933889
# Epoch : 151/2000, Train Loss : 15.894, Valid Loss 17.390, MAE 2.958, Corr 0.934024
# Epoch : 152/2000, Train Loss : 14.682, Valid Loss 11.701, MAE 2.340, Corr 0.933304
# Best Valid Loss 11.7013
# Epoch : 153/2000, Train Loss : 12.299, Valid Loss 14.512, MAE 2.800, Corr 0.932598
# Epoch : 154/2000, Train Loss : 14.305, Valid Loss 11.649, MAE 2.282, Corr 0.934379
# Best Valid Loss 11.6490
# Epoch : 155/2000, Train Loss : 11.747, Valid Loss 19.258, MAE 3.236, Corr 0.935609
# Epoch : 156/2000, Train Loss : 16.719, Valid Loss 22.974, MAE 3.666, Corr 0.935320
# Epoch : 157/2000, Train Loss : 17.888, Valid Loss 22.587, MAE 3.626, Corr 0.935419
# Epoch : 158/2000, Train Loss : 14.808, Valid Loss 13.535, MAE 2.530, Corr 0.935107
# Epoch : 159/2000, Train Loss : 12.327, Valid Loss 14.327, MAE 2.821, Corr 0.935312
# Epoch : 160/2000, Train Loss : 16.309, Valid Loss 19.887, MAE 3.605, Corr 0.936028
# Epoch : 161/2000, Train Loss : 13.529, Valid Loss 11.231, MAE 2.247, Corr 0.933781
# Best Valid Loss 11.2312
# Epoch : 162/2000, Train Loss : 11.894, Valid Loss 10.933, MAE 2.267, Corr 0.937219
# Best Valid Loss 10.9328
# Epoch : 163/2000, Train Loss : 12.566, Valid Loss 17.044, MAE 3.005, Corr 0.937238
# Epoch : 164/2000, Train Loss : 12.929, Valid Loss 12.067, MAE 2.339, Corr 0.937984
# Epoch : 165/2000, Train Loss : 11.496, Valid Loss 12.734, MAE 2.457, Corr 0.938032
# Epoch : 166/2000, Train Loss : 11.207, Valid Loss 15.247, MAE 2.803, Corr 0.937297
# Epoch : 167/2000, Train Loss : 11.942, Valid Loss 13.411, MAE 2.557, Corr 0.938309
# Epoch : 168/2000, Train Loss : 11.887, Valid Loss 13.741, MAE 2.591, Corr 0.939099
# Epoch : 169/2000, Train Loss : 12.103, Valid Loss 11.261, MAE 2.280, Corr 0.939158
# Epoch : 170/2000, Train Loss : 13.641, Valid Loss 20.827, MAE 3.788, Corr 0.938314
# Epoch : 171/2000, Train Loss : 16.586, Valid Loss 30.467, MAE 4.826, Corr 0.935358
# Epoch : 172/2000, Train Loss : 17.997, Valid Loss 12.255, MAE 2.600, Corr 0.936433
# Epoch : 173/2000, Train Loss : 14.972, Valid Loss 28.954, MAE 4.679, Corr 0.935319
# Epoch : 174/2000, Train Loss : 21.650, Valid Loss 14.307, MAE 2.910, Corr 0.938643
# Epoch : 175/2000, Train Loss : 18.224, Valid Loss 11.201, MAE 2.430, Corr 0.933026
# Epoch : 176/2000, Train Loss : 18.245, Valid Loss 9.961, MAE 2.198, Corr 0.938464
# Best Valid Loss 9.9608
# Epoch : 177/2000, Train Loss : 14.806, Valid Loss 10.112, MAE 2.243, Corr 0.938326
# Epoch : 178/2000, Train Loss : 15.822, Valid Loss 10.312, MAE 2.298, Corr 0.937789
# Epoch : 179/2000, Train Loss : 19.261, Valid Loss 11.639, MAE 2.320, Corr 0.938573
# Epoch : 180/2000, Train Loss : 18.452, Valid Loss 10.127, MAE 2.256, Corr 0.935740
# Epoch : 181/2000, Train Loss : 12.587, Valid Loss 14.249, MAE 2.940, Corr 0.937203
# Epoch : 182/2000, Train Loss : 15.156, Valid Loss 16.255, MAE 3.234, Corr 0.938065
# Epoch : 183/2000, Train Loss : 17.078, Valid Loss 11.448, MAE 2.545, Corr 0.937053
# Epoch : 184/2000, Train Loss : 13.738, Valid Loss 14.964, MAE 3.032, Corr 0.938797
# Epoch : 185/2000, Train Loss : 16.754, Valid Loss 13.544, MAE 2.630, Corr 0.936888
# Epoch : 186/2000, Train Loss : 15.089, Valid Loss 16.456, MAE 3.021, Corr 0.938966
# Epoch : 187/2000, Train Loss : 13.707, Valid Loss 15.618, MAE 2.892, Corr 0.938781
# Epoch : 188/2000, Train Loss : 15.054, Valid Loss 36.192, MAE 5.181, Corr 0.938090
# Epoch : 189/2000, Train Loss : 17.273, Valid Loss 12.808, MAE 2.574, Corr 0.939033
# Epoch : 190/2000, Train Loss : 12.397, Valid Loss 42.069, MAE 5.685, Corr 0.939709
# Epoch : 191/2000, Train Loss : 24.404, Valid Loss 13.717, MAE 2.646, Corr 0.938363
# Epoch : 192/2000, Train Loss : 17.331, Valid Loss 12.638, MAE 2.754, Corr 0.938461
# Epoch : 193/2000, Train Loss : 10.649, Valid Loss 9.829, MAE 2.295, Corr 0.939280
# Best Valid Loss 9.8286
# Epoch : 194/2000, Train Loss : 15.639, Valid Loss 14.077, MAE 2.957, Corr 0.939833
# Epoch : 195/2000, Train Loss : 20.944, Valid Loss 16.378, MAE 3.260, Corr 0.933636
# Epoch : 196/2000, Train Loss : 17.565, Valid Loss 16.920, MAE 3.341, Corr 0.937709
# Epoch : 197/2000, Train Loss : 13.869, Valid Loss 9.690, MAE 2.273, Corr 0.939128
# Best Valid Loss 9.6903
# Epoch : 198/2000, Train Loss : 10.536, Valid Loss 13.962, MAE 2.732, Corr 0.937620
# Epoch : 199/2000, Train Loss : 10.883, Valid Loss 9.314, MAE 2.176, Corr 0.939675
# Best Valid Loss 9.3144
# Epoch : 200/2000, Train Loss : 11.821, Valid Loss 9.280, MAE 2.223, Corr 0.939888
# Best Valid Loss 9.2801
# Epoch : 201/2000, Train Loss : 10.200, Valid Loss 9.687, MAE 2.248, Corr 0.936489
# Epoch : 202/2000, Train Loss : 9.244, Valid Loss 10.176, MAE 2.345, Corr 0.939881
# Epoch : 203/2000, Train Loss : 9.222, Valid Loss 12.655, MAE 2.588, Corr 0.939763
# Epoch : 204/2000, Train Loss : 9.711, Valid Loss 10.054, MAE 2.363, Corr 0.939061
# Epoch : 205/2000, Train Loss : 11.914, Valid Loss 9.044, MAE 2.198, Corr 0.940322
# Best Valid Loss 9.0436
# Epoch : 206/2000, Train Loss : 11.569, Valid Loss 16.971, MAE 3.141, Corr 0.939810
# Epoch : 207/2000, Train Loss : 11.004, Valid Loss 8.998, MAE 2.187, Corr 0.939429
# Best Valid Loss 8.9985
# Epoch : 208/2000, Train Loss : 9.193, Valid Loss 9.042, MAE 2.208, Corr 0.939209
# Epoch : 209/2000, Train Loss : 9.377, Valid Loss 10.443, MAE 2.389, Corr 0.939233
# Epoch : 210/2000, Train Loss : 9.156, Valid Loss 9.848, MAE 2.328, Corr 0.939616
# Epoch : 211/2000, Train Loss : 10.270, Valid Loss 22.226, MAE 3.819, Corr 0.939692
# Epoch : 212/2000, Train Loss : 12.268, Valid Loss 11.712, MAE 2.497, Corr 0.938551
# Epoch : 213/2000, Train Loss : 9.834, Valid Loss 9.815, MAE 2.368, Corr 0.939829
# Epoch : 214/2000, Train Loss : 12.036, Valid Loss 9.674, MAE 2.287, Corr 0.939758
# Epoch : 215/2000, Train Loss : 19.539, Valid Loss 47.273, MAE 6.253, Corr 0.936301
# Epoch : 216/2000, Train Loss : 42.171, Valid Loss 9.558, MAE 2.264, Corr 0.935114
# Epoch : 217/2000, Train Loss : 33.617, Valid Loss 46.691, MAE 6.135, Corr 0.937701
# Epoch : 218/2000, Train Loss : 37.848, Valid Loss 39.817, MAE 5.542, Corr 0.938808
# Epoch : 219/2000, Train Loss : 26.637, Valid Loss 26.803, MAE 4.309, Corr 0.930933
# Epoch : 220/2000, Train Loss : 17.010, Valid Loss 15.943, MAE 3.005, Corr 0.939328
# Epoch : 221/2000, Train Loss : 12.492, Valid Loss 10.794, MAE 2.453, Corr 0.938324
# Epoch : 222/2000, Train Loss : 12.110, Valid Loss 9.375, MAE 2.272, Corr 0.936784
# Epoch : 223/2000, Train Loss : 11.392, Valid Loss 13.068, MAE 2.705, Corr 0.937979
# Epoch : 224/2000, Train Loss : 12.277, Valid Loss 14.489, MAE 2.857, Corr 0.937436
# Epoch : 225/2000, Train Loss : 10.637, Valid Loss 9.612, MAE 2.314, Corr 0.936845
# Epoch : 226/2000, Train Loss : 9.936, Valid Loss 9.219, MAE 2.333, Corr 0.937279
# Epoch : 227/2000, Train Loss : 10.288, Valid Loss 10.119, MAE 2.411, Corr 0.935466
# Epoch : 228/2000, Train Loss : 9.262, Valid Loss 9.542, MAE 2.326, Corr 0.936306
# Early stopping
# Best Result : Epoch 207, Valid Loss 8.998, MAE 2.187, Corr 0.939429

# %%
### scatter plot
file_path = "D:\gait_dataset/salted/3km/test/*"
inputs_acc, inputs_gyr, stride_length = get_sensor_salted(file_path, normalization=True)
inputs_acc, inputs_gyr, stride_length = torch.Tensor(np.array(inputs_acc)), torch.Tensor(np.array(inputs_gyr)), torch.Tensor(np.array(stride_length))
inputs_acc, inputs_gyr, stride_length = inputs_acc.float(), inputs_gyr.float(), stride_length.float()
inputs_acc, inputs_gyr = inputs_acc.to(device), inputs_gyr.to(device)

# %%
input_dim = 3
conv1d_dim1 = 16
conv1d_dim2 = 32
dense_dim = 512

model = Encoder(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
model.load_state_dict(torch.load('./encoder_1_best_ks30_nobias.pth'))
model.eval()
# Out:
# Encoder(
#   (conv1d_acc): Sequential(
#     (0): Conv1d(3, 16, kernel_size=(30,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(30,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (conv1d_gyr): Sequential(
#     (0): Conv1d(3, 16, kernel_size=(30,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(30,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (dense): Sequential(
#     (0): Linear(in_features=15488, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=128, out_features=64, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %%
pred = model(inputs_acc, inputs_gyr).detach().cpu().numpy()

plt.figure(figsize=(10, 10))
plt.scatter(stride_length, np.round(pred, 4))
plt.xlim([100, 200])
plt.xlabel('stride_length')
plt.ylim([100, 200])
plt.ylabel('pred')

xpoints = ypoints = plt.xlim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)

plt.show()

# %%
pred = model(inputs_acc, inputs_gyr).detach().cpu().numpy()

plt.figure(figsize=(10, 10))
plt.scatter(stride_length, np.round(pred, 4))
plt.xlim([80, 150])
plt.xlabel('stride_length')
plt.ylim([80, 150])
plt.ylabel('pred')

xpoints = ypoints = plt.xlim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)

plt.show()

# %% [markdown]
# ## Model & Scatter Plot
# - 인코더에 Conv1d만을 사용
# - Conv1d의 kernel_size 조정 : 30 -> 60
# - Best Result : Epoch 177, Valid Loss 18.790442, MAE 2.685503
#     - 큰 영향을 주는 것 같지는 않지만 수렴이 빠름

# %%
# seed 고정
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

class Encoder(nn.Module):
    def __init__(self, input_dim, conv1d_dim1, conv1d_dim2, dense_dim):
        super(Encoder, self).__init__()
             
        self.conv1d_acc = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 60),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 60),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.conv1d_gyr = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 60),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 60),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.dense = nn.Sequential(
            nn.Linear(5824*2, dense_dim),
            nn.ReLU(inplace=True),
            nn.Linear(dense_dim, int(dense_dim/2)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/2), int(dense_dim/4)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/4), int(dense_dim/8)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/8), 1)
        )
        

    def forward(self, inputs_acc, inputs_gyr): 
        
        conv1d_output_acc = self.conv1d_acc(inputs_acc)
        conv1d_output_gyr = self.conv1d_gyr(inputs_gyr)
        
        enc_output = torch.concat((conv1d_output_acc, conv1d_output_gyr), 1)
        dense_output = self.dense(enc_output)
        
        return dense_output

# %%
input_dim = 3
conv1d_dim1 = 16
conv1d_dim2 = 32
dense_dim = 512

model = Encoder(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
n_epochs = 2000

criterion = nn.MSELoss()

# %%
#Early Stopping을 위한 변수
best = 1000
converge_cnt = 0
best_MAE = 0
best_epoch = 0

# Run Training loop
for epoch in range(0, n_epochs) :
    # Set current loss value 
    tot_trn_loss = 0.0
    
    # Train Mode
    model.train()
    
    # Iterate over the DataLoader for training data 
    for i, data in enumerate(train_loader) :
        inputs_acc, inputs_gyr, stride_length, _ = data
        inputs_acc, inputs_gyr, stride_length = inputs_acc.float(), inputs_gyr.float(), stride_length.float()
        inputs_acc, inputs_gyr = inputs_acc.to(device), inputs_gyr.to(device)
        stride_length = stride_length.reshape(-1, 1)
        stride_length = stride_length.to(device)

        # 순전파 
        outputs = model(inputs_acc, inputs_gyr)
        
        # Loss 계산
        loss = criterion(outputs, stride_length)
        
        # 기울기 초기화 
        optimizer.zero_grad()
        # 역전파
        loss.backward()
        # 옵티마이저
        optimizer.step()

        
        # Print statistics
        tot_trn_loss += loss.item()
        
    # Evaluation Mode
    model.eval()
    
    tot_val_loss = 0
    val_epoch_loss = []

    with torch.no_grad() :
        for i, data in enumerate(val_loader):
            inputs_acc, inputs_gyr, stride_length, _ = data
            inputs_acc, inputs_gyr, stride_length = inputs_acc.float(), inputs_gyr.float(), stride_length.float()
            inputs_acc, inputs_gyr = inputs_acc.to(device), inputs_gyr.to(device)
            stride_length = stride_length.reshape(-1, 1)
            stride_length = stride_length.to(device)

            # 순전파 
            outputs = model(inputs_acc, inputs_gyr)
            
            # Loss 계산
            loss = criterion(outputs, stride_length)
            tot_val_loss += loss.item()            
            

    # Epoch 별 Loss
    trn_loss = tot_trn_loss / len(train_loader)
    val_loss = tot_val_loss / len(val_loader)
    MAE = torch.sum(torch.abs(outputs - stride_length)) / len(stride_length)
    
    
    print("Epoch : {}/{}, Train Loss : {:.6f}, Valid Loss {:.6f}, MAE {:.6f}".format(epoch+1, n_epochs,
                                                                                       trn_loss, val_loss,
                                                                                      MAE))
    
    # Early Stopping
    if val_loss < best:
        best = np.mean(val_loss)
        best_MAE = MAE
        best_epoch = epoch+1
        torch.save(model.state_dict(), './encoder_1_best_ks60.pth')
        print('Best Valid Loss {:.4f}'.format(best))
        converge_cnt = 0
    else:
        converge_cnt += 1
    
    if converge_cnt > 20:
        print('Early stopping')
        print('Best Result : Epoch {}, Valid Loss {:4f}, MAE {:4f}'.format(best_epoch, best, best_MAE))
        break
    
#     print("Epoch : {}/{} Epoch Loss : {:.6f}".format(epoch+1, n_epochs, current_loss / len(trainloader.dataset)))
# Out:
# Epoch : 1/2000, Train Loss : 6974.164514, Valid Loss 1220.723450, MAE 31.468950
# Epoch : 2/2000, Train Loss : 752.617633, Valid Loss 443.869064, MAE 17.391273
# Best Valid Loss 443.8691
# Epoch : 3/2000, Train Loss : 287.896519, Valid Loss 233.136396, MAE 12.984757
# Best Valid Loss 233.1364
# Epoch : 4/2000, Train Loss : 239.227547, Valid Loss 244.875636, MAE 13.475310
# Epoch : 5/2000, Train Loss : 233.462458, Valid Loss 227.698840, MAE 12.910347
# Best Valid Loss 227.6988
# Epoch : 6/2000, Train Loss : 228.753220, Valid Loss 226.976115, MAE 12.863390
# Best Valid Loss 226.9761
# Epoch : 7/2000, Train Loss : 226.728002, Valid Loss 224.390429, MAE 12.790303
# Best Valid Loss 224.3904
# Epoch : 8/2000, Train Loss : 224.725432, Valid Loss 221.544782, MAE 12.772385
# Best Valid Loss 221.5448
# Epoch : 9/2000, Train Loss : 223.851826, Valid Loss 218.872658, MAE 12.665787
# Best Valid Loss 218.8727
# Epoch : 10/2000, Train Loss : 221.347144, Valid Loss 216.946645, MAE 12.577463
# Best Valid Loss 216.9466
# Epoch : 11/2000, Train Loss : 223.139594, Valid Loss 218.963135, MAE 12.625329
# Epoch : 12/2000, Train Loss : 224.972544, Valid Loss 248.188957, MAE 13.229249
# Epoch : 13/2000, Train Loss : 219.257027, Valid Loss 215.828728, MAE 12.231522
# Best Valid Loss 215.8287
# Epoch : 14/2000, Train Loss : 217.709614, Valid Loss 208.929998, MAE 12.198687
# Best Valid Loss 208.9300
# Epoch : 15/2000, Train Loss : 217.570183, Valid Loss 206.876595, MAE 12.102323
# Best Valid Loss 206.8766
# Epoch : 16/2000, Train Loss : 213.731970, Valid Loss 205.896294, MAE 11.956412
# Best Valid Loss 205.8963
# Epoch : 17/2000, Train Loss : 210.956931, Valid Loss 202.012248, MAE 11.904961
# Best Valid Loss 202.0122
# Epoch : 18/2000, Train Loss : 207.618886, Valid Loss 203.056389, MAE 11.895570
# Epoch : 19/2000, Train Loss : 213.473368, Valid Loss 199.422295, MAE 11.712140
# Best Valid Loss 199.4223
# Epoch : 20/2000, Train Loss : 200.995677, Valid Loss 207.685216, MAE 11.799335
# Epoch : 21/2000, Train Loss : 215.023475, Valid Loss 196.203158, MAE 11.497764
# Best Valid Loss 196.2032
# Epoch : 22/2000, Train Loss : 223.649739, Valid Loss 235.977933, MAE 12.729642
# Epoch : 23/2000, Train Loss : 205.374906, Valid Loss 204.049787, MAE 11.541966
# Epoch : 24/2000, Train Loss : 195.951963, Valid Loss 178.151967, MAE 10.882207
# Best Valid Loss 178.1520
# Epoch : 25/2000, Train Loss : 188.925120, Valid Loss 205.021194, MAE 11.425232
# Epoch : 26/2000, Train Loss : 185.403692, Valid Loss 166.906164, MAE 10.423314
# Best Valid Loss 166.9062
# Epoch : 27/2000, Train Loss : 173.845318, Valid Loss 159.396111, MAE 10.132872
# Best Valid Loss 159.3961
# Epoch : 28/2000, Train Loss : 160.198718, Valid Loss 151.814011, MAE 9.542158
# Best Valid Loss 151.8140
# Epoch : 29/2000, Train Loss : 154.828607, Valid Loss 138.444162, MAE 8.869831
# Best Valid Loss 138.4442
# Epoch : 30/2000, Train Loss : 141.341149, Valid Loss 128.074588, MAE 8.231473
# Best Valid Loss 128.0746
# Epoch : 31/2000, Train Loss : 136.203188, Valid Loss 111.884712, MAE 8.107002
# Best Valid Loss 111.8847
# Epoch : 32/2000, Train Loss : 112.052305, Valid Loss 112.339466, MAE 8.294457
# Epoch : 33/2000, Train Loss : 99.510347, Valid Loss 77.763972, MAE 6.442734
# Best Valid Loss 77.7640
# Epoch : 34/2000, Train Loss : 73.362459, Valid Loss 68.100551, MAE 6.434570
# Best Valid Loss 68.1006
# Epoch : 35/2000, Train Loss : 70.399206, Valid Loss 59.818256, MAE 5.711380
# Best Valid Loss 59.8183
# Epoch : 36/2000, Train Loss : 65.131871, Valid Loss 48.413531, MAE 5.134885
# Best Valid Loss 48.4135
# Epoch : 37/2000, Train Loss : 51.656481, Valid Loss 56.729210, MAE 5.527871
# Epoch : 38/2000, Train Loss : 59.915784, Valid Loss 103.841199, MAE 7.553636
# Epoch : 39/2000, Train Loss : 60.737746, Valid Loss 41.794694, MAE 4.613196
# Best Valid Loss 41.7947
# Epoch : 40/2000, Train Loss : 53.929993, Valid Loss 40.921678, MAE 4.489444
# Best Valid Loss 40.9217
# Epoch : 41/2000, Train Loss : 70.583177, Valid Loss 42.694760, MAE 4.770292
# Epoch : 42/2000, Train Loss : 42.066341, Valid Loss 39.966035, MAE 4.354200
# Best Valid Loss 39.9660
# Epoch : 43/2000, Train Loss : 46.144461, Valid Loss 48.200368, MAE 5.109429
# Epoch : 44/2000, Train Loss : 50.322758, Valid Loss 43.085425, MAE 4.652131
# Epoch : 45/2000, Train Loss : 55.015280, Valid Loss 53.843423, MAE 5.687893
# Epoch : 46/2000, Train Loss : 53.870153, Valid Loss 40.868704, MAE 4.524774
# Epoch : 47/2000, Train Loss : 60.026891, Valid Loss 39.363642, MAE 4.393616
# Best Valid Loss 39.3636
# Epoch : 48/2000, Train Loss : 44.696599, Valid Loss 53.398479, MAE 5.590528
# Epoch : 49/2000, Train Loss : 46.739110, Valid Loss 38.560628, MAE 4.177911
# Best Valid Loss 38.5606
# Epoch : 50/2000, Train Loss : 56.769510, Valid Loss 37.218065, MAE 4.261879
# Best Valid Loss 37.2181
# Epoch : 51/2000, Train Loss : 46.464462, Valid Loss 37.077644, MAE 4.214164
# Best Valid Loss 37.0776
# Epoch : 52/2000, Train Loss : 44.837903, Valid Loss 40.670224, MAE 4.303189
# Epoch : 53/2000, Train Loss : 40.331837, Valid Loss 49.282846, MAE 5.374907
# Epoch : 54/2000, Train Loss : 46.277544, Valid Loss 35.486031, MAE 3.997714
# Best Valid Loss 35.4860
# Epoch : 55/2000, Train Loss : 38.267209, Valid Loss 38.791817, MAE 4.245508
# Epoch : 56/2000, Train Loss : 37.448142, Valid Loss 37.047882, MAE 4.402042
# Epoch : 57/2000, Train Loss : 41.721814, Valid Loss 34.170310, MAE 3.921978
# Best Valid Loss 34.1703
# Epoch : 58/2000, Train Loss : 40.632565, Valid Loss 49.460620, MAE 5.235797
# Epoch : 59/2000, Train Loss : 45.387113, Valid Loss 38.946395, MAE 4.237482
# Epoch : 60/2000, Train Loss : 39.244361, Valid Loss 34.385489, MAE 4.032516
# Epoch : 61/2000, Train Loss : 39.958068, Valid Loss 41.104349, MAE 4.619031
# Epoch : 62/2000, Train Loss : 53.671318, Valid Loss 35.763107, MAE 3.983968
# Epoch : 63/2000, Train Loss : 52.999548, Valid Loss 65.767141, MAE 6.692248
# Epoch : 64/2000, Train Loss : 43.175708, Valid Loss 37.410142, MAE 4.233803
# Epoch : 65/2000, Train Loss : 44.032372, Valid Loss 87.472598, MAE 7.521151
# Epoch : 66/2000, Train Loss : 45.228528, Valid Loss 43.224854, MAE 4.958917
# Epoch : 67/2000, Train Loss : 39.920981, Valid Loss 34.629849, MAE 4.009794
# Epoch : 68/2000, Train Loss : 40.594967, Valid Loss 32.887800, MAE 3.852380
# Best Valid Loss 32.8878
# Epoch : 69/2000, Train Loss : 35.495710, Valid Loss 38.116942, MAE 4.371798
# Epoch : 70/2000, Train Loss : 42.768397, Valid Loss 43.455477, MAE 4.848736
# Epoch : 71/2000, Train Loss : 65.360227, Valid Loss 102.618818, MAE 8.508606
# Epoch : 72/2000, Train Loss : 46.838483, Valid Loss 54.094558, MAE 5.308337
# Epoch : 73/2000, Train Loss : 39.013124, Valid Loss 50.643717, MAE 5.443555
# Epoch : 74/2000, Train Loss : 44.454258, Valid Loss 30.760081, MAE 3.521820
# Best Valid Loss 30.7601
# Epoch : 75/2000, Train Loss : 50.268617, Valid Loss 59.529037, MAE 6.229937
# Epoch : 76/2000, Train Loss : 78.936000, Valid Loss 51.888446, MAE 5.451674
# Epoch : 77/2000, Train Loss : 58.722975, Valid Loss 31.393901, MAE 3.616676
# Epoch : 78/2000, Train Loss : 33.965555, Valid Loss 33.724910, MAE 3.867218
# Epoch : 79/2000, Train Loss : 35.658454, Valid Loss 55.167786, MAE 5.513889
# Epoch : 80/2000, Train Loss : 40.731694, Valid Loss 42.752599, MAE 4.779235
# Epoch : 81/2000, Train Loss : 36.162774, Valid Loss 41.746529, MAE 4.532994
# Epoch : 82/2000, Train Loss : 38.449454, Valid Loss 31.508764, MAE 3.597742
# Epoch : 83/2000, Train Loss : 41.988385, Valid Loss 30.668357, MAE 3.650210
# Best Valid Loss 30.6684
# Epoch : 84/2000, Train Loss : 34.376213, Valid Loss 32.739745, MAE 3.751639
# Epoch : 85/2000, Train Loss : 38.510635, Valid Loss 31.540458, MAE 3.476914
# Epoch : 86/2000, Train Loss : 35.791927, Valid Loss 30.715653, MAE 3.458231
# Epoch : 87/2000, Train Loss : 33.381251, Valid Loss 33.156116, MAE 3.783117
# Epoch : 88/2000, Train Loss : 35.506698, Valid Loss 45.926820, MAE 4.732314
# Epoch : 89/2000, Train Loss : 32.362432, Valid Loss 32.257892, MAE 3.661492
# Epoch : 90/2000, Train Loss : 39.713400, Valid Loss 28.250438, MAE 3.274059
# Best Valid Loss 28.2504
# Epoch : 91/2000, Train Loss : 41.980013, Valid Loss 46.621770, MAE 5.161680
# Epoch : 92/2000, Train Loss : 44.531623, Valid Loss 29.093645, MAE 3.563305
# Epoch : 93/2000, Train Loss : 51.438906, Valid Loss 33.496254, MAE 3.840176
# Epoch : 94/2000, Train Loss : 48.681498, Valid Loss 34.088320, MAE 4.094054
# Epoch : 95/2000, Train Loss : 42.339382, Valid Loss 28.323343, MAE 3.311499
# Epoch : 96/2000, Train Loss : 36.748939, Valid Loss 51.667736, MAE 5.168609
# Epoch : 97/2000, Train Loss : 37.109599, Valid Loss 28.733579, MAE 3.584707
# Epoch : 98/2000, Train Loss : 33.359232, Valid Loss 30.067620, MAE 3.467336
# Epoch : 99/2000, Train Loss : 32.593034, Valid Loss 28.274392, MAE 3.327130
# Epoch : 100/2000, Train Loss : 38.061912, Valid Loss 26.812831, MAE 3.193783
# Best Valid Loss 26.8128
# Epoch : 101/2000, Train Loss : 31.381788, Valid Loss 28.176177, MAE 3.371308
# Epoch : 102/2000, Train Loss : 32.464003, Valid Loss 51.699924, MAE 5.485721
# Epoch : 103/2000, Train Loss : 34.663943, Valid Loss 26.448321, MAE 3.251493
# Best Valid Loss 26.4483
# Epoch : 104/2000, Train Loss : 33.863060, Valid Loss 37.677169, MAE 4.433468
# Epoch : 105/2000, Train Loss : 41.880779, Valid Loss 65.300717, MAE 6.333389
# Epoch : 106/2000, Train Loss : 66.008823, Valid Loss 46.804860, MAE 5.276776
# Epoch : 107/2000, Train Loss : 43.571939, Valid Loss 42.405494, MAE 4.896914
# Epoch : 108/2000, Train Loss : 38.871317, Valid Loss 27.415330, MAE 3.273065
# Epoch : 109/2000, Train Loss : 30.456834, Valid Loss 29.700940, MAE 3.466736
# Epoch : 110/2000, Train Loss : 35.693272, Valid Loss 31.415049, MAE 3.992985
# Epoch : 111/2000, Train Loss : 44.664261, Valid Loss 26.008978, MAE 3.143530
# Best Valid Loss 26.0090
# Epoch : 112/2000, Train Loss : 29.218387, Valid Loss 29.836214, MAE 3.511770
# Epoch : 113/2000, Train Loss : 37.862259, Valid Loss 37.475471, MAE 4.329517
# Epoch : 114/2000, Train Loss : 40.674333, Valid Loss 27.027841, MAE 2.848033
# Epoch : 115/2000, Train Loss : 37.108581, Valid Loss 35.981948, MAE 3.809496
# Epoch : 116/2000, Train Loss : 31.717424, Valid Loss 32.570013, MAE 3.977315
# Epoch : 117/2000, Train Loss : 34.313832, Valid Loss 41.102707, MAE 4.357145
# Epoch : 118/2000, Train Loss : 30.844344, Valid Loss 27.717746, MAE 3.251917
# Epoch : 119/2000, Train Loss : 29.734376, Valid Loss 25.741653, MAE 3.153306
# Best Valid Loss 25.7417
# Epoch : 120/2000, Train Loss : 30.696002, Valid Loss 82.719285, MAE 7.526345
# Epoch : 121/2000, Train Loss : 55.604140, Valid Loss 43.147087, MAE 4.981192
# Epoch : 122/2000, Train Loss : 46.127611, Valid Loss 32.231774, MAE 4.025900
# Epoch : 123/2000, Train Loss : 28.580000, Valid Loss 28.570678, MAE 3.611346
# Epoch : 124/2000, Train Loss : 46.025909, Valid Loss 26.532892, MAE 3.011720
# Epoch : 125/2000, Train Loss : 28.832801, Valid Loss 24.173914, MAE 3.154496
# Best Valid Loss 24.1739
# Epoch : 126/2000, Train Loss : 35.707163, Valid Loss 25.983197, MAE 3.261787
# Epoch : 127/2000, Train Loss : 29.113363, Valid Loss 24.968237, MAE 3.248676
# Epoch : 128/2000, Train Loss : 26.969190, Valid Loss 24.088174, MAE 3.028788
# Best Valid Loss 24.0882
# Epoch : 129/2000, Train Loss : 25.599931, Valid Loss 23.507253, MAE 3.010921
# Best Valid Loss 23.5073
# Epoch : 130/2000, Train Loss : 39.840405, Valid Loss 89.443996, MAE 7.914155
# Epoch : 131/2000, Train Loss : 40.050864, Valid Loss 24.544990, MAE 3.252842
# Epoch : 132/2000, Train Loss : 27.102611, Valid Loss 35.640392, MAE 4.561912
# Epoch : 133/2000, Train Loss : 28.935674, Valid Loss 28.429750, MAE 3.417814
# Epoch : 134/2000, Train Loss : 26.284990, Valid Loss 40.242314, MAE 4.661803
# Epoch : 135/2000, Train Loss : 33.500091, Valid Loss 30.819572, MAE 4.050694
# Epoch : 136/2000, Train Loss : 29.224423, Valid Loss 32.625344, MAE 3.965436
# Epoch : 137/2000, Train Loss : 25.058571, Valid Loss 21.953852, MAE 2.868105
# Best Valid Loss 21.9539
# Epoch : 138/2000, Train Loss : 32.311090, Valid Loss 22.740827, MAE 2.918751
# Epoch : 139/2000, Train Loss : 38.639655, Valid Loss 49.660927, MAE 6.074388
# Epoch : 140/2000, Train Loss : 43.811531, Valid Loss 22.615028, MAE 2.782824
# Epoch : 141/2000, Train Loss : 32.798166, Valid Loss 49.090146, MAE 5.474413
# Epoch : 142/2000, Train Loss : 29.684669, Valid Loss 45.392909, MAE 5.674434
# Epoch : 143/2000, Train Loss : 43.598825, Valid Loss 31.069186, MAE 3.980528
# Epoch : 144/2000, Train Loss : 26.532011, Valid Loss 26.337449, MAE 3.423515
# Epoch : 145/2000, Train Loss : 26.427414, Valid Loss 32.159336, MAE 4.280311
# Epoch : 146/2000, Train Loss : 33.656916, Valid Loss 21.268366, MAE 2.917974
# Best Valid Loss 21.2684
# Epoch : 147/2000, Train Loss : 37.293375, Valid Loss 26.945563, MAE 3.645081
# Epoch : 148/2000, Train Loss : 25.589225, Valid Loss 28.280706, MAE 3.805489
# Epoch : 149/2000, Train Loss : 30.757169, Valid Loss 30.138124, MAE 3.556937
# Epoch : 150/2000, Train Loss : 29.422655, Valid Loss 29.195234, MAE 3.890144
# Epoch : 151/2000, Train Loss : 56.301453, Valid Loss 70.978291, MAE 7.550276
# Epoch : 152/2000, Train Loss : 33.149301, Valid Loss 22.470386, MAE 3.138482
# Epoch : 153/2000, Train Loss : 25.787588, Valid Loss 20.559046, MAE 2.813802
# Best Valid Loss 20.5590
# Epoch : 154/2000, Train Loss : 25.297965, Valid Loss 29.425711, MAE 3.639440
# Epoch : 155/2000, Train Loss : 24.710737, Valid Loss 20.762020, MAE 2.859534
# Epoch : 156/2000, Train Loss : 45.542260, Valid Loss 94.766229, MAE 9.237349
# Epoch : 157/2000, Train Loss : 58.957328, Valid Loss 26.181937, MAE 3.356776
# Epoch : 158/2000, Train Loss : 27.641525, Valid Loss 25.961359, MAE 3.537826
# Epoch : 159/2000, Train Loss : 30.262559, Valid Loss 21.050897, MAE 2.999217
# Epoch : 160/2000, Train Loss : 26.859510, Valid Loss 24.289167, MAE 3.457522
# Epoch : 161/2000, Train Loss : 26.575999, Valid Loss 19.940007, MAE 2.766089
# Best Valid Loss 19.9400
# Epoch : 162/2000, Train Loss : 45.989871, Valid Loss 22.966118, MAE 2.889059
# Epoch : 163/2000, Train Loss : 48.876107, Valid Loss 104.096231, MAE 9.730433
# Epoch : 164/2000, Train Loss : 70.840155, Valid Loss 52.443483, MAE 6.355639
# Epoch : 165/2000, Train Loss : 31.954529, Valid Loss 23.979605, MAE 3.435117
# Epoch : 166/2000, Train Loss : 22.913178, Valid Loss 20.809899, MAE 3.011856
# Epoch : 167/2000, Train Loss : 25.920904, Valid Loss 22.438522, MAE 2.963340
# Epoch : 168/2000, Train Loss : 23.793759, Valid Loss 20.046731, MAE 2.856509
# Epoch : 169/2000, Train Loss : 28.704340, Valid Loss 20.066674, MAE 2.933232
# Epoch : 170/2000, Train Loss : 25.392748, Valid Loss 19.432202, MAE 2.756741
# Best Valid Loss 19.4322
# Epoch : 171/2000, Train Loss : 35.804088, Valid Loss 20.470727, MAE 2.979899
# Epoch : 172/2000, Train Loss : 31.539373, Valid Loss 20.864420, MAE 2.844408
# Epoch : 173/2000, Train Loss : 23.486821, Valid Loss 19.569408, MAE 2.668199
# Epoch : 174/2000, Train Loss : 22.729815, Valid Loss 20.492317, MAE 3.009362
# Epoch : 175/2000, Train Loss : 22.351234, Valid Loss 29.280256, MAE 3.643823
# Epoch : 176/2000, Train Loss : 23.120776, Valid Loss 20.129180, MAE 2.737904
# Epoch : 177/2000, Train Loss : 21.214314, Valid Loss 18.790442, MAE 2.685503
# Best Valid Loss 18.7904
# Epoch : 178/2000, Train Loss : 20.850164, Valid Loss 19.282722, MAE 2.843111
# Epoch : 179/2000, Train Loss : 21.253193, Valid Loss 19.417911, MAE 2.753095
# Epoch : 180/2000, Train Loss : 22.153478, Valid Loss 28.188601, MAE 4.151103
# Epoch : 181/2000, Train Loss : 23.213811, Valid Loss 21.986703, MAE 3.185810
# Epoch : 182/2000, Train Loss : 20.395437, Valid Loss 25.957317, MAE 3.800766
# Epoch : 183/2000, Train Loss : 40.769928, Valid Loss 22.844893, MAE 3.351362
# Epoch : 184/2000, Train Loss : 62.112917, Valid Loss 60.114113, MAE 6.999923
# Epoch : 185/2000, Train Loss : 32.582332, Valid Loss 23.174910, MAE 3.387387
# Epoch : 186/2000, Train Loss : 22.683339, Valid Loss 32.384924, MAE 4.080436
# Epoch : 187/2000, Train Loss : 21.874893, Valid Loss 18.994836, MAE 2.805763
# Epoch : 188/2000, Train Loss : 21.895712, Valid Loss 25.884535, MAE 3.928463
# Epoch : 189/2000, Train Loss : 26.000074, Valid Loss 31.098601, MAE 3.796467
# Epoch : 190/2000, Train Loss : 26.708748, Valid Loss 19.537712, MAE 2.924045
# Epoch : 191/2000, Train Loss : 28.066316, Valid Loss 32.691548, MAE 4.658004
# Epoch : 192/2000, Train Loss : 30.085934, Valid Loss 30.273857, MAE 3.993636
# Epoch : 193/2000, Train Loss : 31.098686, Valid Loss 28.507752, MAE 4.279517
# Epoch : 194/2000, Train Loss : 22.337927, Valid Loss 20.737375, MAE 3.080997
# Epoch : 195/2000, Train Loss : 24.047351, Valid Loss 20.467080, MAE 3.095972
# Epoch : 196/2000, Train Loss : 21.807607, Valid Loss 18.956130, MAE 2.659858
# Epoch : 197/2000, Train Loss : 21.178189, Valid Loss 29.784920, MAE 4.429771
# Epoch : 198/2000, Train Loss : 23.871010, Valid Loss 19.743055, MAE 2.994084
# Early stopping
# Best Result : Epoch 177, Valid Loss 18.790442, MAE 2.685503

# %%
### scatter plot
file_path = "D:\gait_dataset/salted/test/*"
inputs_acc, inputs_gyr, stride_length = get_sensor_salted(file_path, normalization=True)
inputs_acc, inputs_gyr, stride_length = torch.Tensor(np.array(inputs_acc)), torch.Tensor(np.array(inputs_gyr)), torch.Tensor(np.array(stride_length))
inputs_acc, inputs_gyr, stride_length = inputs_acc.float(), inputs_gyr.float(), stride_length.float()
inputs_acc, inputs_gyr = inputs_acc.to(device), inputs_gyr.to(device)

# %%
input_dim = 3
conv1d_dim1 = 16
conv1d_dim2 = 32
dense_dim = 512

model = Encoder(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
model.load_state_dict(torch.load('./encoder_1_best_ks60.pth'))
model.eval()
# Out:
# Encoder(
#   (conv1d_acc): Sequential(
#     (0): Conv1d(3, 16, kernel_size=(60,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(60,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (conv1d_gyr): Sequential(
#     (0): Conv1d(3, 16, kernel_size=(60,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(60,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (dense): Sequential(
#     (0): Linear(in_features=11648, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=128, out_features=64, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %%
pred = model(inputs_acc, inputs_gyr).detach().cpu().numpy()

plt.figure(figsize=(10, 10))
plt.scatter(stride_length, np.round(pred, 4))
plt.xlim([100, 200])
plt.xlabel('stride_length')
plt.ylim([100, 200])
plt.ylabel('pred')

xpoints = ypoints = plt.xlim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)

plt.show()

# %% [markdown]
# # Encoder-based Model : Acc, Gyro 각각 입력, 최종 노드 3개
# - 최종적으로 출력된 노드 3개를 각 축별 distance와 곱

# %% [markdown]
# ## Model & Scatter Plot
# - Best Result : Epoch 259, Valid Loss 40.381912, MAE 4.223338

# %%
# seed 고정
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

class Encoder_dist(nn.Module):
    def __init__(self, input_dim, conv1d_dim1, conv1d_dim2, dense_dim):
        super(Encoder_dist, self).__init__()
             
        self.conv1d_acc = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 30),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 30),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.conv1d_gyr = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 30),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 30),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.dense = nn.Sequential(
            nn.Linear(7744*2, dense_dim),
            nn.ReLU(inplace=True),
            nn.Linear(dense_dim, int(dense_dim/2)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/2), int(dense_dim/4)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/4), int(dense_dim/8)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/8), 3)
        )
        

    def forward(self, inputs_acc, inputs_gyr, inputs_pst): 
        
        conv1d_output_acc = self.conv1d_acc(inputs_acc)
        conv1d_output_gyr = self.conv1d_gyr(inputs_gyr)
        
        enc_output = torch.concat((conv1d_output_acc, conv1d_output_gyr), 1)
        dense_output = self.dense(enc_output)
        output = torch.unsqueeze(torch.sum(dense_output*inputs_pst, axis=1), 1)

        
        return output

# %%
input_dim = 3
conv1d_dim1 = 16
conv1d_dim2 = 32
dense_dim = 512

model = Encoder_dist(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
n_epochs = 2000

criterion = nn.MSELoss()

# %%
# Early Stopping을 위한 변수
best = 1000
converge_cnt = 0
best_MAE = 0
best_corr = 0
best_epoch = 0

# Run Training loop
for epoch in range(0, n_epochs) :
    # Set current loss value 
    tot_trn_loss = 0.0
    
    # Train Mode
    model.train()
    
    # Iterate over the DataLoader for training data 
    for i, data in enumerate(train_loader) :
        inputs_acc, inputs_gyr, stride_length, inputs_pst = data
        inputs_acc, inputs_gyr, stride_length, inputs_pst = inputs_acc.float(), inputs_gyr.float(), stride_length.float(), inputs_pst.float()
        inputs_acc, inputs_gyr, inputs_pst = inputs_acc.to(device), inputs_gyr.to(device), inputs_pst.to(device)
        stride_length = stride_length.reshape(-1, 1)
        stride_length = stride_length.to(device)

        # 순전파 
        outputs = model(inputs_acc, inputs_gyr, inputs_pst)

        # Loss 계산
        loss = criterion(outputs, stride_length)
        
        # 기울기 초기화 
        optimizer.zero_grad()
        # 역전파
        loss.backward()
        # 옵티마이저
        optimizer.step()
        
        # Print statistics
        tot_trn_loss += loss.item()
        
    # Evaluation Mode
    model.eval()
    
    tot_val_loss = 0
    val_epoch_loss = []

    with torch.no_grad() :
        for i, data in enumerate(val_loader):
            inputs_acc, inputs_gyr, stride_length, inputs_pst = data
            inputs_acc, inputs_gyr, stride_length, inputs_pst = inputs_acc.float(), inputs_gyr.float(), stride_length.float(), inputs_pst.float()
            inputs_acc, inputs_gyr, inputs_pst = inputs_acc.to(device), inputs_gyr.to(device), inputs_pst.to(device)
            stride_length = stride_length.reshape(-1, 1)
            stride_length = stride_length.to(device)

            # 순전파 
            outputs = model(inputs_acc, inputs_gyr, inputs_pst)
            
            # Loss 계산
            loss = criterion(outputs, stride_length)
            tot_val_loss += loss.item()            
            

    # Epoch 별 Loss
    trn_loss = tot_trn_loss / len(train_loader)
    val_loss = tot_val_loss / len(val_loader)
    MAE = torch.sum(torch.abs(outputs - stride_length)) / len(stride_length)
    corr = torch.corrcoef(torch.stack([torch.squeeze(stride_length), torch.squeeze(outputs)]))[0, 1]
    
    
    print("Epoch : {}/{}, Train Loss : {:.3f}, Valid Loss {:.3f}, MAE {:.3f}, Corr {:3f}".format(epoch+1, n_epochs,
                                                                                       trn_loss, val_loss,
                                                                                      MAE, corr))
    
    # Early Stopping
    if val_loss < best:
        best = np.mean(val_loss)
        best_MAE = MAE
        best_corr = corr
        best_epoch = epoch+1
        torch.save(model.state_dict(), './encoder_dist_best_ks30_nobias.pth')
        print('Best Valid Loss {:.4f}'.format(best))
        converge_cnt = 0
    else:
        converge_cnt += 1
    
    if converge_cnt > 20:
        print('Early stopping')
        print('Best Result : Epoch {}, Valid Loss {:.3f}, MAE {:.3f}, Corr {:3f}'.format(best_epoch, best, best_MAE, best_corr))
        break
    
#     print("Epoch : {}/{} Epoch Loss : {:.6f}".format(epoch+1, n_epochs, current_loss / len(trainloader.dataset)))
# Out:
# Epoch : 1/2000, Train Loss : 11303.422, Valid Loss 5710.800, MAE 75.612, Corr -0.240638
# Epoch : 2/2000, Train Loss : 2224.443, Valid Loss 1872.629, MAE 41.909, Corr -0.191760
# Epoch : 3/2000, Train Loss : 1264.355, Valid Loss 825.899, MAE 22.076, Corr -0.121205
# Best Valid Loss 825.8992
# Epoch : 4/2000, Train Loss : 738.546, Valid Loss 1050.029, MAE 30.277, Corr -0.029629
# Epoch : 5/2000, Train Loss : 547.023, Valid Loss 389.905, MAE 14.995, Corr 0.046567
# Best Valid Loss 389.9052
# Epoch : 6/2000, Train Loss : 311.553, Valid Loss 347.626, MAE 14.622, Corr 0.144722
# Best Valid Loss 347.6264
# Epoch : 7/2000, Train Loss : 233.382, Valid Loss 232.871, MAE 11.610, Corr 0.230056
# Best Valid Loss 232.8706
# Epoch : 8/2000, Train Loss : 226.683, Valid Loss 201.235, MAE 10.602, Corr 0.309489
# Best Valid Loss 201.2355
# Epoch : 9/2000, Train Loss : 178.903, Valid Loss 193.416, MAE 10.460, Corr 0.389205
# Best Valid Loss 193.4156
# Epoch : 10/2000, Train Loss : 161.567, Valid Loss 172.935, MAE 9.660, Corr 0.428750
# Best Valid Loss 172.9345
# Epoch : 11/2000, Train Loss : 148.224, Valid Loss 160.407, MAE 9.149, Corr 0.463261
# Best Valid Loss 160.4066
# Epoch : 12/2000, Train Loss : 147.712, Valid Loss 152.956, MAE 8.879, Corr 0.493767
# Best Valid Loss 152.9563
# Epoch : 13/2000, Train Loss : 139.948, Valid Loss 163.290, MAE 8.997, Corr 0.524125
# Epoch : 14/2000, Train Loss : 147.844, Valid Loss 147.984, MAE 8.436, Corr 0.544389
# Best Valid Loss 147.9837
# Epoch : 15/2000, Train Loss : 129.086, Valid Loss 144.450, MAE 8.271, Corr 0.562369
# Best Valid Loss 144.4499
# Epoch : 16/2000, Train Loss : 136.436, Valid Loss 136.318, MAE 8.262, Corr 0.576344
# Best Valid Loss 136.3177
# Epoch : 17/2000, Train Loss : 126.601, Valid Loss 134.351, MAE 8.056, Corr 0.594578
# Best Valid Loss 134.3508
# Epoch : 18/2000, Train Loss : 146.290, Valid Loss 153.046, MAE 8.217, Corr 0.609554
# Epoch : 19/2000, Train Loss : 130.044, Valid Loss 135.894, MAE 7.823, Corr 0.607697
# Epoch : 20/2000, Train Loss : 126.727, Valid Loss 129.201, MAE 7.780, Corr 0.613506
# Best Valid Loss 129.2009
# Epoch : 21/2000, Train Loss : 133.148, Valid Loss 130.522, MAE 7.675, Corr 0.619798
# Epoch : 22/2000, Train Loss : 120.571, Valid Loss 128.669, MAE 8.035, Corr 0.627617
# Best Valid Loss 128.6685
# Epoch : 23/2000, Train Loss : 133.044, Valid Loss 129.345, MAE 8.116, Corr 0.632671
# Epoch : 24/2000, Train Loss : 142.282, Valid Loss 138.657, MAE 7.664, Corr 0.639905
# Epoch : 25/2000, Train Loss : 146.412, Valid Loss 138.858, MAE 7.734, Corr 0.634487
# Epoch : 26/2000, Train Loss : 144.572, Valid Loss 164.355, MAE 8.738, Corr 0.639783
# Epoch : 27/2000, Train Loss : 139.886, Valid Loss 133.270, MAE 7.583, Corr 0.633381
# Epoch : 28/2000, Train Loss : 126.607, Valid Loss 147.821, MAE 8.055, Corr 0.637060
# Epoch : 29/2000, Train Loss : 124.328, Valid Loss 133.367, MAE 7.559, Corr 0.638641
# Epoch : 30/2000, Train Loss : 121.775, Valid Loss 123.283, MAE 7.371, Corr 0.637957
# Best Valid Loss 123.2835
# Epoch : 31/2000, Train Loss : 118.694, Valid Loss 122.985, MAE 7.455, Corr 0.636426
# Best Valid Loss 122.9851
# Epoch : 32/2000, Train Loss : 122.759, Valid Loss 123.540, MAE 7.370, Corr 0.636769
# Epoch : 33/2000, Train Loss : 115.315, Valid Loss 124.308, MAE 7.340, Corr 0.633773
# Epoch : 34/2000, Train Loss : 123.225, Valid Loss 122.899, MAE 7.513, Corr 0.629015
# Best Valid Loss 122.8988
# Epoch : 35/2000, Train Loss : 115.495, Valid Loss 124.226, MAE 7.658, Corr 0.629197
# Epoch : 36/2000, Train Loss : 115.077, Valid Loss 126.661, MAE 7.872, Corr 0.627360
# Epoch : 37/2000, Train Loss : 136.057, Valid Loss 126.946, MAE 7.896, Corr 0.630071
# Epoch : 38/2000, Train Loss : 132.048, Valid Loss 123.379, MAE 7.249, Corr 0.639263
# Epoch : 39/2000, Train Loss : 126.731, Valid Loss 145.711, MAE 7.986, Corr 0.640257
# Epoch : 40/2000, Train Loss : 134.794, Valid Loss 125.508, MAE 7.302, Corr 0.633255
# Epoch : 41/2000, Train Loss : 109.402, Valid Loss 147.516, MAE 8.104, Corr 0.634704
# Epoch : 42/2000, Train Loss : 115.586, Valid Loss 129.912, MAE 7.470, Corr 0.636864
# Epoch : 43/2000, Train Loss : 113.724, Valid Loss 129.863, MAE 7.438, Corr 0.638831
# Epoch : 44/2000, Train Loss : 139.435, Valid Loss 144.586, MAE 7.946, Corr 0.642477
# Epoch : 45/2000, Train Loss : 119.500, Valid Loss 128.044, MAE 7.388, Corr 0.637540
# Epoch : 46/2000, Train Loss : 120.927, Valid Loss 128.778, MAE 7.374, Corr 0.640658
# Epoch : 47/2000, Train Loss : 116.830, Valid Loss 133.571, MAE 7.547, Corr 0.640075
# Epoch : 48/2000, Train Loss : 113.303, Valid Loss 130.958, MAE 7.484, Corr 0.637088
# Epoch : 49/2000, Train Loss : 115.748, Valid Loss 126.729, MAE 7.328, Corr 0.636385
# Epoch : 50/2000, Train Loss : 136.019, Valid Loss 131.980, MAE 7.506, Corr 0.638547
# Epoch : 51/2000, Train Loss : 135.141, Valid Loss 197.924, MAE 10.585, Corr 0.636585
# Epoch : 52/2000, Train Loss : 131.184, Valid Loss 183.515, MAE 9.894, Corr 0.631260
# Epoch : 53/2000, Train Loss : 135.707, Valid Loss 135.869, MAE 7.693, Corr 0.624809
# Epoch : 54/2000, Train Loss : 131.107, Valid Loss 122.217, MAE 7.416, Corr 0.628082
# Best Valid Loss 122.2174
# Epoch : 55/2000, Train Loss : 121.105, Valid Loss 122.465, MAE 7.449, Corr 0.631024
# Epoch : 56/2000, Train Loss : 110.409, Valid Loss 125.100, MAE 7.710, Corr 0.636827
# Epoch : 57/2000, Train Loss : 133.069, Valid Loss 122.318, MAE 7.484, Corr 0.634892
# Epoch : 58/2000, Train Loss : 120.606, Valid Loss 121.341, MAE 7.148, Corr 0.637869
# Best Valid Loss 121.3408
# Epoch : 59/2000, Train Loss : 114.509, Valid Loss 120.316, MAE 7.241, Corr 0.639996
# Best Valid Loss 120.3155
# Epoch : 60/2000, Train Loss : 119.437, Valid Loss 141.640, MAE 7.845, Corr 0.642020
# Epoch : 61/2000, Train Loss : 125.949, Valid Loss 136.717, MAE 7.647, Corr 0.641404
# Epoch : 62/2000, Train Loss : 121.632, Valid Loss 131.806, MAE 7.475, Corr 0.641094
# Epoch : 63/2000, Train Loss : 126.676, Valid Loss 120.684, MAE 7.347, Corr 0.635307
# Epoch : 64/2000, Train Loss : 117.930, Valid Loss 121.326, MAE 7.098, Corr 0.642834
# Epoch : 65/2000, Train Loss : 115.284, Valid Loss 198.356, MAE 10.652, Corr 0.645530
# Epoch : 66/2000, Train Loss : 151.282, Valid Loss 145.284, MAE 8.002, Corr 0.640239
# Epoch : 67/2000, Train Loss : 137.414, Valid Loss 148.694, MAE 8.976, Corr 0.629870
# Epoch : 68/2000, Train Loss : 129.254, Valid Loss 131.134, MAE 8.060, Corr 0.630381
# Epoch : 69/2000, Train Loss : 121.858, Valid Loss 152.465, MAE 8.360, Corr 0.634666
# Epoch : 70/2000, Train Loss : 133.771, Valid Loss 149.466, MAE 8.199, Corr 0.638046
# Epoch : 71/2000, Train Loss : 119.752, Valid Loss 129.300, MAE 7.342, Corr 0.642051
# Epoch : 72/2000, Train Loss : 124.179, Valid Loss 121.722, MAE 7.465, Corr 0.647467
# Epoch : 73/2000, Train Loss : 117.537, Valid Loss 122.933, MAE 7.559, Corr 0.652475
# Epoch : 74/2000, Train Loss : 122.223, Valid Loss 124.153, MAE 7.128, Corr 0.654465
# Epoch : 75/2000, Train Loss : 106.697, Valid Loss 119.363, MAE 7.216, Corr 0.653638
# Best Valid Loss 119.3628
# Epoch : 76/2000, Train Loss : 125.782, Valid Loss 222.894, MAE 11.752, Corr 0.650475
# Epoch : 77/2000, Train Loss : 137.210, Valid Loss 205.787, MAE 10.996, Corr 0.631434
# Epoch : 78/2000, Train Loss : 147.206, Valid Loss 126.964, MAE 7.369, Corr 0.621050
# Epoch : 79/2000, Train Loss : 133.788, Valid Loss 131.829, MAE 8.057, Corr 0.613290
# Epoch : 80/2000, Train Loss : 115.283, Valid Loss 131.500, MAE 8.082, Corr 0.620946
# Epoch : 81/2000, Train Loss : 131.706, Valid Loss 119.819, MAE 7.087, Corr 0.632412
# Epoch : 82/2000, Train Loss : 125.974, Valid Loss 163.998, MAE 8.930, Corr 0.644573
# Epoch : 83/2000, Train Loss : 117.925, Valid Loss 132.129, MAE 7.442, Corr 0.650016
# Epoch : 84/2000, Train Loss : 115.745, Valid Loss 118.016, MAE 7.148, Corr 0.649711
# Best Valid Loss 118.0160
# Epoch : 85/2000, Train Loss : 133.374, Valid Loss 121.462, MAE 7.032, Corr 0.644751
# Epoch : 86/2000, Train Loss : 116.713, Valid Loss 162.769, MAE 8.886, Corr 0.645406
# Epoch : 87/2000, Train Loss : 136.010, Valid Loss 120.133, MAE 7.043, Corr 0.639059
# Epoch : 88/2000, Train Loss : 115.267, Valid Loss 124.406, MAE 7.721, Corr 0.638719
# Epoch : 89/2000, Train Loss : 123.130, Valid Loss 118.165, MAE 7.046, Corr 0.641282
# Epoch : 90/2000, Train Loss : 110.778, Valid Loss 149.858, MAE 8.308, Corr 0.643353
# Epoch : 91/2000, Train Loss : 123.426, Valid Loss 122.513, MAE 7.128, Corr 0.642468
# Epoch : 92/2000, Train Loss : 120.627, Valid Loss 116.765, MAE 7.069, Corr 0.637160
# Best Valid Loss 116.7650
# Epoch : 93/2000, Train Loss : 115.777, Valid Loss 158.713, MAE 8.746, Corr 0.640432
# Epoch : 94/2000, Train Loss : 119.208, Valid Loss 118.857, MAE 7.024, Corr 0.641926
# Epoch : 95/2000, Train Loss : 111.788, Valid Loss 118.276, MAE 7.299, Corr 0.639359
# Epoch : 96/2000, Train Loss : 119.394, Valid Loss 166.316, MAE 9.072, Corr 0.644755
# Epoch : 97/2000, Train Loss : 132.544, Valid Loss 167.447, MAE 9.886, Corr 0.638507
# Epoch : 98/2000, Train Loss : 175.187, Valid Loss 124.151, MAE 7.216, Corr 0.632975
# Epoch : 99/2000, Train Loss : 146.001, Valid Loss 211.111, MAE 11.262, Corr 0.628115
# Epoch : 100/2000, Train Loss : 139.190, Valid Loss 135.270, MAE 8.351, Corr 0.625911
# Epoch : 101/2000, Train Loss : 142.581, Valid Loss 118.597, MAE 7.397, Corr 0.636254
# Epoch : 102/2000, Train Loss : 129.773, Valid Loss 249.823, MAE 12.794, Corr 0.653402
# Epoch : 103/2000, Train Loss : 169.315, Valid Loss 116.377, MAE 7.244, Corr 0.641025
# Best Valid Loss 116.3770
# Epoch : 104/2000, Train Loss : 136.778, Valid Loss 145.999, MAE 8.913, Corr 0.636615
# Epoch : 105/2000, Train Loss : 125.520, Valid Loss 133.891, MAE 7.570, Corr 0.650963
# Epoch : 106/2000, Train Loss : 109.503, Valid Loss 124.095, MAE 7.141, Corr 0.657652
# Epoch : 107/2000, Train Loss : 105.259, Valid Loss 124.059, MAE 7.132, Corr 0.657742
# Epoch : 108/2000, Train Loss : 109.048, Valid Loss 117.276, MAE 7.331, Corr 0.649961
# Epoch : 109/2000, Train Loss : 117.950, Valid Loss 114.423, MAE 6.947, Corr 0.653753
# Best Valid Loss 114.4229
# Epoch : 110/2000, Train Loss : 110.965, Valid Loss 127.801, MAE 7.319, Corr 0.650684
# Epoch : 111/2000, Train Loss : 103.600, Valid Loss 118.320, MAE 6.982, Corr 0.648675
# Epoch : 112/2000, Train Loss : 101.867, Valid Loss 123.107, MAE 7.171, Corr 0.645249
# Epoch : 113/2000, Train Loss : 104.022, Valid Loss 128.516, MAE 7.387, Corr 0.643240
# Epoch : 114/2000, Train Loss : 105.894, Valid Loss 133.374, MAE 7.637, Corr 0.636752
# Epoch : 115/2000, Train Loss : 120.156, Valid Loss 119.109, MAE 7.058, Corr 0.636692
# Epoch : 116/2000, Train Loss : 109.779, Valid Loss 120.938, MAE 7.620, Corr 0.639068
# Epoch : 117/2000, Train Loss : 112.301, Valid Loss 155.656, MAE 8.649, Corr 0.648577
# Epoch : 118/2000, Train Loss : 121.103, Valid Loss 115.016, MAE 6.904, Corr 0.643908
# Epoch : 119/2000, Train Loss : 116.218, Valid Loss 164.903, MAE 9.748, Corr 0.638706
# Epoch : 120/2000, Train Loss : 140.131, Valid Loss 122.965, MAE 7.195, Corr 0.644404
# Epoch : 121/2000, Train Loss : 113.298, Valid Loss 153.043, MAE 8.547, Corr 0.643454
# Epoch : 122/2000, Train Loss : 115.501, Valid Loss 113.004, MAE 6.999, Corr 0.638873
# Best Valid Loss 113.0035
# Epoch : 123/2000, Train Loss : 107.941, Valid Loss 118.067, MAE 7.469, Corr 0.634589
# Epoch : 124/2000, Train Loss : 107.259, Valid Loss 113.793, MAE 7.190, Corr 0.634713
# Epoch : 125/2000, Train Loss : 101.941, Valid Loss 119.233, MAE 7.098, Corr 0.640158
# Epoch : 126/2000, Train Loss : 103.163, Valid Loss 111.971, MAE 6.902, Corr 0.643582
# Best Valid Loss 111.9714
# Epoch : 127/2000, Train Loss : 118.819, Valid Loss 120.554, MAE 7.631, Corr 0.652554
# Epoch : 128/2000, Train Loss : 114.227, Valid Loss 169.438, MAE 9.356, Corr 0.659527
# Epoch : 129/2000, Train Loss : 127.264, Valid Loss 132.500, MAE 8.237, Corr 0.652451
# Epoch : 130/2000, Train Loss : 139.081, Valid Loss 119.210, MAE 7.521, Corr 0.635652
# Epoch : 131/2000, Train Loss : 111.680, Valid Loss 177.717, MAE 9.806, Corr 0.637508
# Epoch : 132/2000, Train Loss : 124.649, Valid Loss 125.790, MAE 7.356, Corr 0.643011
# Epoch : 133/2000, Train Loss : 107.905, Valid Loss 149.481, MAE 9.135, Corr 0.646900
# Epoch : 134/2000, Train Loss : 122.316, Valid Loss 111.991, MAE 6.850, Corr 0.653554
# Epoch : 135/2000, Train Loss : 118.413, Valid Loss 152.512, MAE 8.549, Corr 0.657102
# Epoch : 136/2000, Train Loss : 107.476, Valid Loss 136.989, MAE 8.515, Corr 0.654036
# Epoch : 137/2000, Train Loss : 125.872, Valid Loss 114.810, MAE 6.949, Corr 0.650943
# Epoch : 138/2000, Train Loss : 109.239, Valid Loss 134.388, MAE 7.731, Corr 0.660903
# Epoch : 139/2000, Train Loss : 109.322, Valid Loss 115.999, MAE 7.397, Corr 0.663154
# Epoch : 140/2000, Train Loss : 116.228, Valid Loss 112.627, MAE 6.774, Corr 0.671168
# Epoch : 141/2000, Train Loss : 118.873, Valid Loss 140.892, MAE 7.975, Corr 0.663577
# Epoch : 142/2000, Train Loss : 111.349, Valid Loss 134.972, MAE 8.382, Corr 0.642413
# Epoch : 143/2000, Train Loss : 113.621, Valid Loss 110.549, MAE 6.818, Corr 0.648247
# Best Valid Loss 110.5486
# Epoch : 144/2000, Train Loss : 108.218, Valid Loss 108.800, MAE 6.938, Corr 0.651793
# Best Valid Loss 108.7996
# Epoch : 145/2000, Train Loss : 98.496, Valid Loss 116.570, MAE 6.988, Corr 0.660867
# Epoch : 146/2000, Train Loss : 110.981, Valid Loss 129.632, MAE 7.520, Corr 0.664596
# Epoch : 147/2000, Train Loss : 110.080, Valid Loss 110.207, MAE 6.751, Corr 0.664376
# Epoch : 148/2000, Train Loss : 109.758, Valid Loss 111.657, MAE 7.183, Corr 0.658290
# Epoch : 149/2000, Train Loss : 111.423, Valid Loss 140.425, MAE 8.025, Corr 0.659916
# Epoch : 150/2000, Train Loss : 109.160, Valid Loss 112.749, MAE 6.841, Corr 0.658814
# Epoch : 151/2000, Train Loss : 112.850, Valid Loss 107.514, MAE 6.781, Corr 0.655731
# Best Valid Loss 107.5139
# Epoch : 152/2000, Train Loss : 96.286, Valid Loss 119.194, MAE 7.080, Corr 0.669432
# Epoch : 153/2000, Train Loss : 97.568, Valid Loss 111.131, MAE 7.143, Corr 0.677325
# Epoch : 154/2000, Train Loss : 107.933, Valid Loss 152.382, MAE 8.568, Corr 0.682311
# Epoch : 155/2000, Train Loss : 131.709, Valid Loss 114.249, MAE 7.283, Corr 0.668511
# Epoch : 156/2000, Train Loss : 138.096, Valid Loss 108.362, MAE 7.019, Corr 0.657444
# Epoch : 157/2000, Train Loss : 120.550, Valid Loss 156.007, MAE 8.809, Corr 0.656685
# Epoch : 158/2000, Train Loss : 97.397, Valid Loss 118.124, MAE 7.070, Corr 0.664345
# Epoch : 159/2000, Train Loss : 105.359, Valid Loss 128.426, MAE 8.139, Corr 0.660995
# Epoch : 160/2000, Train Loss : 114.943, Valid Loss 120.008, MAE 7.165, Corr 0.666966
# Epoch : 161/2000, Train Loss : 93.621, Valid Loss 138.298, MAE 8.040, Corr 0.665415
# Epoch : 162/2000, Train Loss : 109.275, Valid Loss 107.529, MAE 6.749, Corr 0.666434
# Epoch : 163/2000, Train Loss : 110.663, Valid Loss 153.132, MAE 8.731, Corr 0.669264
# Epoch : 164/2000, Train Loss : 117.124, Valid Loss 106.493, MAE 6.762, Corr 0.661167
# Best Valid Loss 106.4931
# Epoch : 165/2000, Train Loss : 110.967, Valid Loss 112.742, MAE 6.938, Corr 0.656601
# Epoch : 166/2000, Train Loss : 98.510, Valid Loss 108.136, MAE 6.718, Corr 0.668445
# Epoch : 167/2000, Train Loss : 99.160, Valid Loss 106.700, MAE 6.924, Corr 0.676748
# Epoch : 168/2000, Train Loss : 105.429, Valid Loss 113.735, MAE 6.839, Corr 0.680051
# Epoch : 169/2000, Train Loss : 93.828, Valid Loss 112.016, MAE 6.766, Corr 0.678625
# Epoch : 170/2000, Train Loss : 95.134, Valid Loss 109.472, MAE 6.682, Corr 0.675157
# Epoch : 171/2000, Train Loss : 95.139, Valid Loss 116.677, MAE 7.420, Corr 0.665496
# Epoch : 172/2000, Train Loss : 103.466, Valid Loss 107.051, MAE 6.670, Corr 0.666302
# Epoch : 173/2000, Train Loss : 95.264, Valid Loss 106.288, MAE 6.647, Corr 0.672058
# Best Valid Loss 106.2881
# Epoch : 174/2000, Train Loss : 101.349, Valid Loss 144.569, MAE 8.284, Corr 0.678886
# Epoch : 175/2000, Train Loss : 103.218, Valid Loss 112.846, MAE 7.238, Corr 0.673568
# Epoch : 176/2000, Train Loss : 110.639, Valid Loss 136.098, MAE 7.881, Corr 0.673957
# Epoch : 177/2000, Train Loss : 118.880, Valid Loss 111.456, MAE 6.759, Corr 0.674869
# Epoch : 178/2000, Train Loss : 97.744, Valid Loss 112.387, MAE 7.300, Corr 0.669827
# Epoch : 179/2000, Train Loss : 114.254, Valid Loss 104.770, MAE 6.696, Corr 0.671016
# Best Valid Loss 104.7700
# Epoch : 180/2000, Train Loss : 100.461, Valid Loss 108.400, MAE 6.687, Corr 0.668379
# Epoch : 181/2000, Train Loss : 92.590, Valid Loss 111.061, MAE 6.737, Corr 0.683830
# Epoch : 182/2000, Train Loss : 88.778, Valid Loss 116.239, MAE 6.965, Corr 0.688360
# Epoch : 183/2000, Train Loss : 100.843, Valid Loss 106.319, MAE 6.897, Corr 0.684139
# Epoch : 184/2000, Train Loss : 96.624, Valid Loss 104.292, MAE 6.766, Corr 0.681257
# Best Valid Loss 104.2921
# Epoch : 185/2000, Train Loss : 97.383, Valid Loss 131.167, MAE 7.730, Corr 0.675934
# Epoch : 186/2000, Train Loss : 93.855, Valid Loss 108.166, MAE 6.664, Corr 0.674288
# Epoch : 187/2000, Train Loss : 114.989, Valid Loss 119.584, MAE 7.185, Corr 0.674712
# Epoch : 188/2000, Train Loss : 108.708, Valid Loss 104.545, MAE 6.735, Corr 0.665098
# Epoch : 189/2000, Train Loss : 121.124, Valid Loss 108.630, MAE 7.011, Corr 0.680207
# Epoch : 190/2000, Train Loss : 119.441, Valid Loss 113.410, MAE 6.829, Corr 0.690980
# Epoch : 191/2000, Train Loss : 100.804, Valid Loss 108.937, MAE 6.744, Corr 0.676616
# Epoch : 192/2000, Train Loss : 99.694, Valid Loss 106.301, MAE 6.650, Corr 0.679036
# Epoch : 193/2000, Train Loss : 91.504, Valid Loss 110.383, MAE 6.743, Corr 0.690132
# Epoch : 194/2000, Train Loss : 91.114, Valid Loss 130.385, MAE 7.565, Corr 0.691027
# Epoch : 195/2000, Train Loss : 96.710, Valid Loss 103.713, MAE 6.691, Corr 0.679214
# Best Valid Loss 103.7127
# Epoch : 196/2000, Train Loss : 101.796, Valid Loss 136.707, MAE 7.984, Corr 0.673155
# Epoch : 197/2000, Train Loss : 104.228, Valid Loss 163.863, MAE 9.697, Corr 0.669161
# Epoch : 198/2000, Train Loss : 111.759, Valid Loss 137.025, MAE 7.917, Corr 0.678795
# Epoch : 199/2000, Train Loss : 106.033, Valid Loss 174.460, MAE 10.169, Corr 0.676985
# Epoch : 200/2000, Train Loss : 129.899, Valid Loss 169.617, MAE 9.474, Corr 0.686470
# Epoch : 201/2000, Train Loss : 120.906, Valid Loss 104.689, MAE 6.765, Corr 0.690820
# Epoch : 202/2000, Train Loss : 100.378, Valid Loss 109.086, MAE 6.676, Corr 0.689870
# Epoch : 203/2000, Train Loss : 108.952, Valid Loss 116.401, MAE 7.039, Corr 0.682329
# Epoch : 204/2000, Train Loss : 90.776, Valid Loss 105.394, MAE 6.590, Corr 0.678516
# Epoch : 205/2000, Train Loss : 93.645, Valid Loss 115.170, MAE 7.325, Corr 0.677297
# Epoch : 206/2000, Train Loss : 95.093, Valid Loss 155.123, MAE 8.804, Corr 0.679948
# Epoch : 207/2000, Train Loss : 101.282, Valid Loss 104.166, MAE 6.607, Corr 0.669140
# Epoch : 208/2000, Train Loss : 110.172, Valid Loss 114.808, MAE 7.027, Corr 0.670555
# Epoch : 209/2000, Train Loss : 115.799, Valid Loss 150.009, MAE 8.597, Corr 0.677111
# Epoch : 210/2000, Train Loss : 117.452, Valid Loss 113.651, MAE 7.178, Corr 0.666924
# Epoch : 211/2000, Train Loss : 119.498, Valid Loss 126.248, MAE 7.527, Corr 0.675615
# Epoch : 212/2000, Train Loss : 105.452, Valid Loss 109.580, MAE 7.007, Corr 0.684116
# Epoch : 213/2000, Train Loss : 110.796, Valid Loss 137.620, MAE 7.940, Corr 0.691115
# Epoch : 214/2000, Train Loss : 104.016, Valid Loss 108.754, MAE 7.021, Corr 0.679596
# Epoch : 215/2000, Train Loss : 94.979, Valid Loss 113.371, MAE 6.949, Corr 0.678342
# Epoch : 216/2000, Train Loss : 108.294, Valid Loss 106.433, MAE 6.611, Corr 0.680172
# Early stopping
# Best Result : Epoch 195, Valid Loss 103.713, MAE 6.691, Corr 0.679214

# %%
# scatter plot

file_path = "D:\gait_dataset/salted/3km/test/*"
inputs_acc, inputs_gyr, stride_length = get_sensor_salted(file_path, normalization=True)
inputs_pst = get_position_salted(file_path, distance=True)
inputs_acc, inputs_gyr, stride_length, inputs_pst = torch.Tensor(np.array(inputs_acc)), torch.Tensor(np.array(inputs_gyr)), torch.Tensor(np.array(stride_length)), torch.Tensor(np.array(inputs_pst))
inputs_acc, inputs_gyr, stride_length, inputs_pst = inputs_acc.float(), inputs_gyr.float(), stride_length.float(), inputs_pst.float()
inputs_acc, inputs_gyr, inputs_pst = inputs_acc.to(device), inputs_gyr.to(device), inputs_pst.to(device)

# %%
input_dim = 3
conv1d_dim1 = 16
conv1d_dim2 = 32
dense_dim = 512

model = Encoder_dist(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
model.load_state_dict(torch.load('./encoder_dist_best_ks30_nobias.pth'))
model.eval()
# Out:
# Encoder_dist(
#   (conv1d_acc): Sequential(
#     (0): Conv1d(3, 16, kernel_size=(30,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(30,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (conv1d_gyr): Sequential(
#     (0): Conv1d(3, 16, kernel_size=(30,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(30,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (dense): Sequential(
#     (0): Linear(in_features=15488, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=128, out_features=64, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Linear(in_features=64, out_features=3, bias=True)
#   )
# )

# %%
pred = model(inputs_acc, inputs_gyr)
pred = torch.unsqueeze(torch.sum(pred*inputs_pst, axis=1), 1).detach().cpu().numpy()

plt.figure(figsize=(10, 10))
plt.scatter(stride_length, np.round(pred, 4))
plt.xlim([50, 250])
plt.xlabel('stride_length')
plt.ylim([50, 250])
plt.ylabel('pred')

xpoints = ypoints = plt.xlim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)

plt.show()

# %%
pred = model(inputs_acc, inputs_gyr, inputs_pst).detach().cpu().numpy()

plt.figure(figsize=(10, 10))
plt.scatter(stride_length, np.round(pred, 4))
plt.xlim([80, 150])
plt.xlabel('stride_length')
plt.ylim([80, 150])
plt.ylabel('pred')

xpoints = ypoints = plt.xlim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)

plt.show()

# %% [markdown]
# # Encoder-based Model : Acc, Gyro 축별 입력
# - 각 축 Acc에서 얻어진 축별 distance를 곱해주기 때문에 축별로 데이터를 입력
#     - 축별 Acc/Gyro의 정보가 알맞은 축의 distance와 곱해져야 한다는 생각에 시도
# - 3개의 인코더에는 각각 (Acc_x, Gyro_x) / (Acc_y, Gyro_y) / (Acc_z, Gyro_z)가 입력으로 들어감
#     - 인코더의 각 output을 concat한 뒤 FC-Layer에 넣었을 때, 축별 정보가 순서대로 보존될 수 있을지는 의문 부호
# - Pressure는 축이 따로 없으므로 고려하지 않음

# %% [markdown]
# ## 데이터 불러오기

# %%
file_path = "D:\gait_dataset/salted/train/*"
dataset = Gait_Dataset_Axis_Salted(file_path)
val_percent = 0.2
n_val = int(len(dataset) * val_percent)
n_train = len(dataset) - n_val
train, val = random_split(dataset, [n_train, n_val])

# %%
train_loader = torch.utils.data.DataLoader(train,
                                           batch_size=128,
                                           shuffle=True)
val_loader = torch.utils.data.DataLoader(val,
                                         batch_size=128,
                                         shuffle=False)

# %% [markdown]
# ## Model & Scatter Plot
# - Best Result : Epoch 194, Valid Loss 32.528639, MAE 4.294555

# %%
# seed 고정
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

class Encoder_axis(nn.Module):
    def __init__(self, input_dim, conv1d_dim1, conv1d_dim2, dense_dim):
        super(Encoder_axis, self).__init__()
             
        self.conv1d_x = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 30),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 30),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.conv1d_y = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 30),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 30),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        
        self.conv1d_z = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 30),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 30),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.dense = nn.Sequential(
            nn.Linear(7744*3, dense_dim),
            nn.ReLU(inplace=True),
            nn.Linear(dense_dim, int(dense_dim/2)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/2), int(dense_dim/4)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/4), int(dense_dim/8)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/8), 3)
        )
        

    def forward(self, inputs_x, inputs_y, inputs_z): 
        conv1d_output_x = self.conv1d_x(inputs_x)
        conv1d_output_y = self.conv1d_y(inputs_y)
        conv1d_output_z = self.conv1d_z(inputs_z)
        
        enc_output = torch.concat((conv1d_output_x, conv1d_output_y, conv1d_output_z), 1)
        dense_output = self.dense(enc_output)
        
        return dense_output

# %%
input_dim = 2
conv1d_dim1 = 16
conv1d_dim2 = 32
dense_dim = 512

model = Encoder_dist(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
n_epochs = 2000

criterion = nn.MSELoss()

# %%
# Early Stopping을 위한 변수
best = 1000
converge_cnt = 0
best_MAE = 0
best_epoch = 0

# Run Training loop
for epoch in range(0, n_epochs) :
    # Set current loss value 
    tot_trn_loss = 0.0
    
    # Train Mode
    model.train()
    
    # Iterate over the DataLoader for training data 
    for i, data in enumerate(train_loader) :
        inputs_x, inputs_y, inputs_z, stride_length, inputs_pst = data
        inputs_x, inputs_y, inputs_z, stride_length, inputs_pst = inputs_x.float(), inputs_y.float(), inputs_z.float(), stride_length.float(), inputs_pst.float()
        inputs_x, inputs_y, inputs_z, inputs_pst = inputs_x.to(device), inputs_y.to(device), inputs_z.to(device), inputs_pst.to(device)
        stride_length = stride_length.reshape(-1, 1)
        stride_length = stride_length.to(device)

        # 순전파 
        outputs = model(inputs_x, inputs_y, inputs_z)
        outputs = torch.unsqueeze(torch.sum(outputs*inputs_pst, axis=1), 1)

        
        # Loss 계산
        loss = criterion(outputs, stride_length)
        
        # 기울기 초기화 
        optimizer.zero_grad()
        # 역전파
        loss.backward()
        # 옵티마이저
        optimizer.step()
        
        # Print statistics
        tot_trn_loss += loss.item()
        
    # Evaluation Mode
    model.eval()
    
    tot_val_loss = 0
    val_epoch_loss = []

    with torch.no_grad() :
        for i, data in enumerate(val_loader):
            inputs_x, inputs_y, inputs_z, stride_length, inputs_pst = data
            inputs_x, inputs_y, inputs_z, stride_length, inputs_pst = inputs_x.float(), inputs_y.float(), inputs_z.float(), stride_length.float(), inputs_pst.float()
            inputs_x, inputs_y, inputs_z, inputs_pst = inputs_x.to(device), inputs_y.to(device), inputs_z.to(device), inputs_pst.to(device)
            stride_length = stride_length.reshape(-1, 1)
            stride_length = stride_length.to(device)

            # 순전파 
            outputs = model(inputs_x, inputs_y, inputs_z)
            outputs = torch.unsqueeze(torch.sum(outputs*inputs_pst, axis=1), 1)
            
            # Loss 계산
            loss = criterion(outputs, stride_length)
            tot_val_loss += loss.item()            
            

    # Epoch 별 Loss
    trn_loss = tot_trn_loss / len(train_loader)
    val_loss = tot_val_loss / len(val_loader)
    MAE = torch.sum(torch.abs(outputs - stride_length)) / len(stride_length)
    
    
    print("Epoch : {}/{}, Train Loss : {:.6f}, Valid Loss {:.6f}, MAE {:.6f}".format(epoch+1, n_epochs,
                                                                                       trn_loss, val_loss,
                                                                                      MAE))
    
    # Early Stopping
    if val_loss < best:
        best = np.mean(val_loss)
        best_MAE = MAE
        best_epoch = epoch+1
        torch.save(model.state_dict(), './encoder_axis_best_ks30.pth')
        print('Best Valid Loss {:.4f}'.format(best))
        converge_cnt = 0
    else:
        converge_cnt += 1
    
    if converge_cnt > 20:
        print('Early stopping')
        print('Best Result : Epoch {}, Valid Loss {:4f}, MAE {:4f}'.format(best_epoch, best, best_MAE))
        break
    
#     print("Epoch : {}/{} Epoch Loss : {:.6f}".format(epoch+1, n_epochs, current_loss / len(trainloader.dataset)))
# Out:
# Epoch : 1/2000, Train Loss : 6849.530436, Valid Loss 1168.314697, MAE 31.355806
# Epoch : 2/2000, Train Loss : 864.669326, Valid Loss 612.329783, MAE 16.264860
# Best Valid Loss 612.3298
# Epoch : 3/2000, Train Loss : 589.246938, Valid Loss 526.594884, MAE 18.518312
# Best Valid Loss 526.5949
# Epoch : 4/2000, Train Loss : 553.286203, Valid Loss 512.176890, MAE 18.732841
# Best Valid Loss 512.1769
# Epoch : 5/2000, Train Loss : 548.926233, Valid Loss 526.086319, MAE 20.278049
# Epoch : 6/2000, Train Loss : 511.977479, Valid Loss 473.860921, MAE 17.935377
# Best Valid Loss 473.8609
# Epoch : 7/2000, Train Loss : 489.095901, Valid Loss 448.458491, MAE 17.434975
# Best Valid Loss 448.4585
# Epoch : 8/2000, Train Loss : 473.027990, Valid Loss 432.769114, MAE 16.332811
# Best Valid Loss 432.7691
# Epoch : 9/2000, Train Loss : 444.482322, Valid Loss 412.248550, MAE 15.951297
# Best Valid Loss 412.2486
# Epoch : 10/2000, Train Loss : 414.985577, Valid Loss 397.752101, MAE 17.163071
# Best Valid Loss 397.7521
# Epoch : 11/2000, Train Loss : 387.245276, Valid Loss 363.471802, MAE 15.551014
# Best Valid Loss 363.4718
# Epoch : 12/2000, Train Loss : 370.258083, Valid Loss 345.733149, MAE 15.711052
# Best Valid Loss 345.7331
# Epoch : 13/2000, Train Loss : 334.535508, Valid Loss 323.073110, MAE 14.290074
# Best Valid Loss 323.0731
# Epoch : 14/2000, Train Loss : 309.501123, Valid Loss 342.560786, MAE 15.948507
# Epoch : 15/2000, Train Loss : 304.398463, Valid Loss 280.962496, MAE 13.455321
# Best Valid Loss 280.9625
# Epoch : 16/2000, Train Loss : 288.542037, Valid Loss 264.794589, MAE 12.658875
# Best Valid Loss 264.7946
# Epoch : 17/2000, Train Loss : 264.723057, Valid Loss 307.637693, MAE 13.178854
# Epoch : 18/2000, Train Loss : 257.109468, Valid Loss 248.893519, MAE 12.430366
# Best Valid Loss 248.8935
# Epoch : 19/2000, Train Loss : 243.131791, Valid Loss 253.369685, MAE 12.966020
# Epoch : 20/2000, Train Loss : 231.704594, Valid Loss 228.472768, MAE 11.712345
# Best Valid Loss 228.4728
# Epoch : 21/2000, Train Loss : 219.131103, Valid Loss 224.833183, MAE 12.047770
# Best Valid Loss 224.8332
# Epoch : 22/2000, Train Loss : 243.995718, Valid Loss 281.983821, MAE 12.583950
# Epoch : 23/2000, Train Loss : 255.651252, Valid Loss 232.757001, MAE 12.591807
# Epoch : 24/2000, Train Loss : 222.157600, Valid Loss 334.496150, MAE 16.476152
# Epoch : 25/2000, Train Loss : 224.737459, Valid Loss 195.613584, MAE 10.723135
# Best Valid Loss 195.6136
# Epoch : 26/2000, Train Loss : 199.500159, Valid Loss 236.383794, MAE 12.281063
# Epoch : 27/2000, Train Loss : 192.249783, Valid Loss 183.271533, MAE 10.614248
# Best Valid Loss 183.2715
# Epoch : 28/2000, Train Loss : 177.668783, Valid Loss 209.438082, MAE 11.824372
# Epoch : 29/2000, Train Loss : 168.326333, Valid Loss 169.136859, MAE 9.913210
# Best Valid Loss 169.1369
# Epoch : 30/2000, Train Loss : 166.935015, Valid Loss 183.993439, MAE 10.421740
# Epoch : 31/2000, Train Loss : 153.822451, Valid Loss 165.646882, MAE 9.872968
# Best Valid Loss 165.6469
# Epoch : 32/2000, Train Loss : 152.737401, Valid Loss 190.205739, MAE 11.548679
# Epoch : 33/2000, Train Loss : 182.221328, Valid Loss 196.324437, MAE 10.722951
# Epoch : 34/2000, Train Loss : 164.214244, Valid Loss 185.101504, MAE 10.880881
# Epoch : 35/2000, Train Loss : 144.148109, Valid Loss 165.030413, MAE 9.966783
# Best Valid Loss 165.0304
# Epoch : 36/2000, Train Loss : 153.929985, Valid Loss 163.209073, MAE 10.483407
# Best Valid Loss 163.2091
# Epoch : 37/2000, Train Loss : 143.233499, Valid Loss 191.875102, MAE 11.707152
# Epoch : 38/2000, Train Loss : 143.730138, Valid Loss 154.545982, MAE 9.845748
# Best Valid Loss 154.5460
# Epoch : 39/2000, Train Loss : 138.237906, Valid Loss 153.729263, MAE 9.595087
# Best Valid Loss 153.7293
# Epoch : 40/2000, Train Loss : 139.253510, Valid Loss 165.515738, MAE 11.197406
# Epoch : 41/2000, Train Loss : 163.985495, Valid Loss 204.377482, MAE 13.376908
# Epoch : 42/2000, Train Loss : 148.351719, Valid Loss 141.829858, MAE 10.042327
# Best Valid Loss 141.8299
# Epoch : 43/2000, Train Loss : 142.518992, Valid Loss 142.729965, MAE 9.333824
# Epoch : 44/2000, Train Loss : 122.186106, Valid Loss 149.742625, MAE 10.209596
# Epoch : 45/2000, Train Loss : 128.158665, Valid Loss 141.451856, MAE 9.726485
# Best Valid Loss 141.4519
# Epoch : 46/2000, Train Loss : 130.396893, Valid Loss 148.011859, MAE 10.708977
# Epoch : 47/2000, Train Loss : 117.899459, Valid Loss 143.185591, MAE 8.646138
# Epoch : 48/2000, Train Loss : 135.372740, Valid Loss 138.971825, MAE 9.094011
# Best Valid Loss 138.9718
# Epoch : 49/2000, Train Loss : 126.291392, Valid Loss 135.981064, MAE 10.107448
# Best Valid Loss 135.9811
# Epoch : 50/2000, Train Loss : 120.435141, Valid Loss 129.808100, MAE 9.522839
# Best Valid Loss 129.8081
# Epoch : 51/2000, Train Loss : 136.697033, Valid Loss 132.896442, MAE 9.028161
# Epoch : 52/2000, Train Loss : 115.767964, Valid Loss 134.986811, MAE 10.072718
# Epoch : 53/2000, Train Loss : 114.507066, Valid Loss 132.165136, MAE 9.547529
# Epoch : 54/2000, Train Loss : 124.658691, Valid Loss 135.549098, MAE 9.173765
# Epoch : 55/2000, Train Loss : 105.062323, Valid Loss 135.144114, MAE 10.650173
# Epoch : 56/2000, Train Loss : 103.826369, Valid Loss 127.021620, MAE 9.461794
# Best Valid Loss 127.0216
# Epoch : 57/2000, Train Loss : 111.097172, Valid Loss 144.373898, MAE 11.462378
# Epoch : 58/2000, Train Loss : 113.153330, Valid Loss 125.154769, MAE 9.077899
# Best Valid Loss 125.1548
# Epoch : 59/2000, Train Loss : 125.827109, Valid Loss 128.483233, MAE 8.971922
# Epoch : 60/2000, Train Loss : 105.891735, Valid Loss 136.047394, MAE 10.528322
# Epoch : 61/2000, Train Loss : 111.257333, Valid Loss 123.148169, MAE 9.791872
# Best Valid Loss 123.1482
# Epoch : 62/2000, Train Loss : 101.413307, Valid Loss 119.689837, MAE 9.734125
# Best Valid Loss 119.6898
# Epoch : 63/2000, Train Loss : 92.917829, Valid Loss 134.371538, MAE 10.995436
# Epoch : 64/2000, Train Loss : 92.452849, Valid Loss 114.750917, MAE 9.371403
# Best Valid Loss 114.7509
# Epoch : 65/2000, Train Loss : 95.642601, Valid Loss 125.219182, MAE 10.213758
# Epoch : 66/2000, Train Loss : 97.009568, Valid Loss 116.993415, MAE 9.564902
# Epoch : 67/2000, Train Loss : 101.549719, Valid Loss 149.534696, MAE 12.135713
# Epoch : 68/2000, Train Loss : 98.382318, Valid Loss 116.180375, MAE 10.069129
# Epoch : 69/2000, Train Loss : 97.797745, Valid Loss 112.076228, MAE 8.417457
# Best Valid Loss 112.0762
# Epoch : 70/2000, Train Loss : 86.006707, Valid Loss 148.597519, MAE 11.443407
# Epoch : 71/2000, Train Loss : 88.055808, Valid Loss 110.524818, MAE 9.539676
# Best Valid Loss 110.5248
# Epoch : 72/2000, Train Loss : 87.404342, Valid Loss 114.434788, MAE 8.506341
# Epoch : 73/2000, Train Loss : 101.949634, Valid Loss 195.844523, MAE 14.403815
# Epoch : 74/2000, Train Loss : 89.125622, Valid Loss 112.583617, MAE 9.628480
# Epoch : 75/2000, Train Loss : 79.588739, Valid Loss 96.034125, MAE 8.447037
# Best Valid Loss 96.0341
# Epoch : 76/2000, Train Loss : 77.649046, Valid Loss 94.043612, MAE 8.483420
# Best Valid Loss 94.0436
# Epoch : 77/2000, Train Loss : 79.103427, Valid Loss 97.333369, MAE 9.027922
# Epoch : 78/2000, Train Loss : 74.872430, Valid Loss 96.437667, MAE 8.842958
# Epoch : 79/2000, Train Loss : 84.781935, Valid Loss 99.257956, MAE 8.516674
# Epoch : 80/2000, Train Loss : 87.987225, Valid Loss 93.194918, MAE 8.291640
# Best Valid Loss 93.1949
# Epoch : 81/2000, Train Loss : 77.692641, Valid Loss 104.632212, MAE 8.297071
# Epoch : 82/2000, Train Loss : 79.536039, Valid Loss 119.858407, MAE 9.863821
# Epoch : 83/2000, Train Loss : 71.275332, Valid Loss 86.367098, MAE 8.013584
# Best Valid Loss 86.3671
# Epoch : 84/2000, Train Loss : 73.310477, Valid Loss 139.782375, MAE 11.829194
# Epoch : 85/2000, Train Loss : 90.886523, Valid Loss 94.918449, MAE 8.542629
# Epoch : 86/2000, Train Loss : 84.247577, Valid Loss 163.519113, MAE 13.035497
# Epoch : 87/2000, Train Loss : 89.615854, Valid Loss 88.016961, MAE 7.755093
# Epoch : 88/2000, Train Loss : 69.260438, Valid Loss 98.733467, MAE 8.881948
# Epoch : 89/2000, Train Loss : 63.890947, Valid Loss 87.330814, MAE 8.226727
# Epoch : 90/2000, Train Loss : 73.525779, Valid Loss 91.027737, MAE 8.708851
# Epoch : 91/2000, Train Loss : 74.706654, Valid Loss 99.131299, MAE 8.958774
# Epoch : 92/2000, Train Loss : 75.636869, Valid Loss 86.391444, MAE 7.044824
# Epoch : 93/2000, Train Loss : 68.510008, Valid Loss 75.104710, MAE 7.469372
# Best Valid Loss 75.1047
# Epoch : 94/2000, Train Loss : 60.780403, Valid Loss 76.036847, MAE 7.179021
# Epoch : 95/2000, Train Loss : 67.996763, Valid Loss 79.636118, MAE 7.578677
# Epoch : 96/2000, Train Loss : 65.629438, Valid Loss 88.479898, MAE 7.678430
# Epoch : 97/2000, Train Loss : 58.668947, Valid Loss 74.371758, MAE 7.172230
# Best Valid Loss 74.3718
# Epoch : 98/2000, Train Loss : 57.906890, Valid Loss 76.306203, MAE 6.679660
# Epoch : 99/2000, Train Loss : 64.026802, Valid Loss 80.587857, MAE 7.149890
# Epoch : 100/2000, Train Loss : 61.044780, Valid Loss 85.293031, MAE 8.288418
# Epoch : 101/2000, Train Loss : 70.472009, Valid Loss 100.799805, MAE 8.421721
# Epoch : 102/2000, Train Loss : 81.524724, Valid Loss 93.171730, MAE 8.748089
# Epoch : 103/2000, Train Loss : 59.431019, Valid Loss 68.915815, MAE 6.823329
# Best Valid Loss 68.9158
# Epoch : 104/2000, Train Loss : 54.576843, Valid Loss 68.180007, MAE 6.618252
# Best Valid Loss 68.1800
# Epoch : 105/2000, Train Loss : 52.746727, Valid Loss 76.125436, MAE 7.439564
# Epoch : 106/2000, Train Loss : 57.834811, Valid Loss 78.864081, MAE 7.599059
# Epoch : 107/2000, Train Loss : 57.575296, Valid Loss 76.743680, MAE 8.215931
# Epoch : 108/2000, Train Loss : 75.541167, Valid Loss 79.600613, MAE 8.593306
# Epoch : 109/2000, Train Loss : 70.447941, Valid Loss 67.499453, MAE 6.664669
# Best Valid Loss 67.4995
# Epoch : 110/2000, Train Loss : 68.503809, Valid Loss 86.458166, MAE 6.573776
# Epoch : 111/2000, Train Loss : 65.485555, Valid Loss 92.024916, MAE 8.958922
# Epoch : 112/2000, Train Loss : 50.760483, Valid Loss 65.702554, MAE 6.707016
# Best Valid Loss 65.7026
# Epoch : 113/2000, Train Loss : 59.603678, Valid Loss 71.305937, MAE 7.415384
# Epoch : 114/2000, Train Loss : 63.133062, Valid Loss 66.389866, MAE 6.683492
# Epoch : 115/2000, Train Loss : 50.116899, Valid Loss 66.915868, MAE 7.409076
# Epoch : 116/2000, Train Loss : 52.870495, Valid Loss 60.660575, MAE 6.673170
# Best Valid Loss 60.6606
# Epoch : 117/2000, Train Loss : 49.126556, Valid Loss 59.697346, MAE 6.042588
# Best Valid Loss 59.6973
# Epoch : 118/2000, Train Loss : 48.232013, Valid Loss 74.548539, MAE 8.180537
# Epoch : 119/2000, Train Loss : 49.397938, Valid Loss 90.166941, MAE 7.563303
# Epoch : 120/2000, Train Loss : 64.979260, Valid Loss 64.695304, MAE 7.316425
# Epoch : 121/2000, Train Loss : 56.776794, Valid Loss 61.020588, MAE 7.175826
# Epoch : 122/2000, Train Loss : 48.665852, Valid Loss 61.374760, MAE 5.985227
# Epoch : 123/2000, Train Loss : 48.696562, Valid Loss 82.114561, MAE 8.530149
# Epoch : 124/2000, Train Loss : 59.088202, Valid Loss 60.345046, MAE 6.300944
# Epoch : 125/2000, Train Loss : 52.751222, Valid Loss 57.422431, MAE 5.725809
# Best Valid Loss 57.4224
# Epoch : 126/2000, Train Loss : 51.858141, Valid Loss 67.811942, MAE 7.415526
# Epoch : 127/2000, Train Loss : 43.272807, Valid Loss 68.741239, MAE 7.308789
# Epoch : 128/2000, Train Loss : 41.217724, Valid Loss 63.859947, MAE 6.862699
# Epoch : 129/2000, Train Loss : 40.223312, Valid Loss 52.497164, MAE 5.846940
# Best Valid Loss 52.4972
# Epoch : 130/2000, Train Loss : 45.796447, Valid Loss 52.533108, MAE 6.228130
# Epoch : 131/2000, Train Loss : 42.593058, Valid Loss 52.356743, MAE 5.770965
# Best Valid Loss 52.3567
# Epoch : 132/2000, Train Loss : 44.473044, Valid Loss 49.577597, MAE 5.667422
# Best Valid Loss 49.5776
# Epoch : 133/2000, Train Loss : 40.067452, Valid Loss 59.011324, MAE 6.491197
# Epoch : 134/2000, Train Loss : 43.043911, Valid Loss 53.287752, MAE 5.592583
# Epoch : 135/2000, Train Loss : 41.725649, Valid Loss 48.610457, MAE 5.202616
# Best Valid Loss 48.6105
# Epoch : 136/2000, Train Loss : 40.029612, Valid Loss 50.860301, MAE 5.911734
# Epoch : 137/2000, Train Loss : 42.189538, Valid Loss 54.279519, MAE 6.007038
# Epoch : 138/2000, Train Loss : 49.613403, Valid Loss 78.838868, MAE 8.567632
# Epoch : 139/2000, Train Loss : 57.263100, Valid Loss 62.978631, MAE 6.011249
# Epoch : 140/2000, Train Loss : 43.312609, Valid Loss 49.552670, MAE 5.875918
# Epoch : 141/2000, Train Loss : 43.910309, Valid Loss 108.473349, MAE 8.282476
# Epoch : 142/2000, Train Loss : 53.085534, Valid Loss 57.115216, MAE 6.616241
# Epoch : 143/2000, Train Loss : 44.619031, Valid Loss 59.849823, MAE 6.582692
# Epoch : 144/2000, Train Loss : 49.801326, Valid Loss 61.986410, MAE 5.906200
# Epoch : 145/2000, Train Loss : 49.117713, Valid Loss 48.163755, MAE 5.821173
# Best Valid Loss 48.1638
# Epoch : 146/2000, Train Loss : 35.484363, Valid Loss 50.082689, MAE 5.606406
# Epoch : 147/2000, Train Loss : 35.982584, Valid Loss 49.205837, MAE 5.807935
# Epoch : 148/2000, Train Loss : 35.123976, Valid Loss 46.833613, MAE 5.602286
# Best Valid Loss 46.8336
# Epoch : 149/2000, Train Loss : 33.023830, Valid Loss 59.380943, MAE 6.573398
# Epoch : 150/2000, Train Loss : 33.269161, Valid Loss 48.106468, MAE 5.644657
# Epoch : 151/2000, Train Loss : 39.047877, Valid Loss 49.082456, MAE 5.722898
# Epoch : 152/2000, Train Loss : 34.398106, Valid Loss 54.528721, MAE 6.376148
# Epoch : 153/2000, Train Loss : 32.238363, Valid Loss 47.745982, MAE 5.241077
# Epoch : 154/2000, Train Loss : 52.674860, Valid Loss 43.700290, MAE 4.962184
# Best Valid Loss 43.7003
# Epoch : 155/2000, Train Loss : 34.645091, Valid Loss 40.614431, MAE 4.931321
# Best Valid Loss 40.6144
# Epoch : 156/2000, Train Loss : 33.702477, Valid Loss 47.661685, MAE 6.085156
# Epoch : 157/2000, Train Loss : 34.097677, Valid Loss 44.689873, MAE 5.408656
# Epoch : 158/2000, Train Loss : 33.548459, Valid Loss 47.116184, MAE 4.993263
# Epoch : 159/2000, Train Loss : 32.930467, Valid Loss 45.696634, MAE 4.952268
# Epoch : 160/2000, Train Loss : 31.386195, Valid Loss 46.272777, MAE 5.594141
# Epoch : 161/2000, Train Loss : 31.399016, Valid Loss 48.469557, MAE 5.809306
# Epoch : 162/2000, Train Loss : 39.507804, Valid Loss 43.130447, MAE 5.130952
# Epoch : 163/2000, Train Loss : 28.692998, Valid Loss 39.743743, MAE 4.578847
# Best Valid Loss 39.7437
# Epoch : 164/2000, Train Loss : 34.197595, Valid Loss 42.546360, MAE 5.396434
# Epoch : 165/2000, Train Loss : 35.839237, Valid Loss 39.205948, MAE 4.941702
# Best Valid Loss 39.2059
# Epoch : 166/2000, Train Loss : 28.016380, Valid Loss 41.786905, MAE 4.955933
# Epoch : 167/2000, Train Loss : 34.337239, Valid Loss 45.943044, MAE 5.613954
# Epoch : 168/2000, Train Loss : 36.721594, Valid Loss 40.404570, MAE 5.254696
# Epoch : 169/2000, Train Loss : 28.183101, Valid Loss 45.104766, MAE 5.294269
# Epoch : 170/2000, Train Loss : 39.353953, Valid Loss 45.994598, MAE 5.414926
# Epoch : 171/2000, Train Loss : 52.069107, Valid Loss 57.853603, MAE 5.694982
# Epoch : 172/2000, Train Loss : 40.132072, Valid Loss 42.670593, MAE 5.218566
# Epoch : 173/2000, Train Loss : 27.110568, Valid Loss 40.949519, MAE 5.217942
# Epoch : 174/2000, Train Loss : 35.032241, Valid Loss 51.977168, MAE 5.972138
# Epoch : 175/2000, Train Loss : 30.537086, Valid Loss 37.873419, MAE 4.316422
# Best Valid Loss 37.8734
# Epoch : 176/2000, Train Loss : 30.773574, Valid Loss 47.467405, MAE 5.388588
# Epoch : 177/2000, Train Loss : 27.899824, Valid Loss 40.488739, MAE 4.718631
# Epoch : 178/2000, Train Loss : 25.082569, Valid Loss 37.814572, MAE 4.661010
# Best Valid Loss 37.8146
# Epoch : 179/2000, Train Loss : 27.584673, Valid Loss 42.175940, MAE 5.299731
# Epoch : 180/2000, Train Loss : 38.253813, Valid Loss 48.102062, MAE 5.815944
# Epoch : 181/2000, Train Loss : 28.370389, Valid Loss 43.656838, MAE 5.420093
# Epoch : 182/2000, Train Loss : 27.368175, Valid Loss 43.674180, MAE 5.208352
# Epoch : 183/2000, Train Loss : 27.419817, Valid Loss 37.004870, MAE 4.858326
# Best Valid Loss 37.0049
# Epoch : 184/2000, Train Loss : 28.416117, Valid Loss 36.205483, MAE 4.587934
# Best Valid Loss 36.2055
# Epoch : 185/2000, Train Loss : 31.318300, Valid Loss 49.901450, MAE 6.179817
# Epoch : 186/2000, Train Loss : 31.531459, Valid Loss 37.129492, MAE 4.823731
# Epoch : 187/2000, Train Loss : 25.611301, Valid Loss 36.477384, MAE 4.909324
# Epoch : 188/2000, Train Loss : 28.534552, Valid Loss 39.685956, MAE 4.960168
# Epoch : 189/2000, Train Loss : 27.828972, Valid Loss 35.531005, MAE 4.705150
# Best Valid Loss 35.5310
# Epoch : 190/2000, Train Loss : 22.946041, Valid Loss 36.070809, MAE 4.871584
# Epoch : 191/2000, Train Loss : 22.105016, Valid Loss 33.923166, MAE 4.389168
# Best Valid Loss 33.9232
# Epoch : 192/2000, Train Loss : 25.694903, Valid Loss 36.993320, MAE 4.671802
# Epoch : 193/2000, Train Loss : 26.176221, Valid Loss 42.891813, MAE 5.180143
# Epoch : 194/2000, Train Loss : 24.221730, Valid Loss 32.528639, MAE 4.294555
# Best Valid Loss 32.5286
# Epoch : 195/2000, Train Loss : 25.207433, Valid Loss 35.785869, MAE 4.636862
# Epoch : 196/2000, Train Loss : 26.416232, Valid Loss 37.128935, MAE 4.997412
# Epoch : 197/2000, Train Loss : 23.993095, Valid Loss 41.893327, MAE 4.866847
# Epoch : 198/2000, Train Loss : 23.133130, Valid Loss 33.576603, MAE 4.333020
# Epoch : 199/2000, Train Loss : 25.393146, Valid Loss 47.359198, MAE 5.171652
# Epoch : 200/2000, Train Loss : 35.671273, Valid Loss 45.330066, MAE 5.152297
# Epoch : 201/2000, Train Loss : 26.471109, Valid Loss 36.986179, MAE 4.440410
# Epoch : 202/2000, Train Loss : 26.766417, Valid Loss 41.681213, MAE 4.886549
# Epoch : 203/2000, Train Loss : 35.939796, Valid Loss 49.900145, MAE 5.942390
# Epoch : 204/2000, Train Loss : 25.655564, Valid Loss 44.643739, MAE 5.367122
# Epoch : 205/2000, Train Loss : 34.139870, Valid Loss 33.267732, MAE 4.349169
# Epoch : 206/2000, Train Loss : 20.260177, Valid Loss 47.404694, MAE 5.803188
# Epoch : 207/2000, Train Loss : 26.174275, Valid Loss 38.247211, MAE 4.584253
# Epoch : 208/2000, Train Loss : 25.185549, Valid Loss 40.002431, MAE 4.970451
# Epoch : 209/2000, Train Loss : 28.393414, Valid Loss 34.908066, MAE 4.425115
# Epoch : 210/2000, Train Loss : 24.180269, Valid Loss 43.537245, MAE 5.033843
# Epoch : 211/2000, Train Loss : 33.742741, Valid Loss 108.064372, MAE 10.159065
# Epoch : 212/2000, Train Loss : 38.704379, Valid Loss 42.351073, MAE 5.407018
# Epoch : 213/2000, Train Loss : 22.860700, Valid Loss 33.951815, MAE 4.178888
# Epoch : 214/2000, Train Loss : 29.195867, Valid Loss 54.231017, MAE 5.747066
# Epoch : 215/2000, Train Loss : 34.194812, Valid Loss 39.575134, MAE 4.914944
# Early stopping
# Best Result : Epoch 194, Valid Loss 32.528639, MAE 4.294555

# %%
### scatter plot

file_path = "D:\gait_dataset/salted/test/*"
inputs_x, inputs_y, inputs_z, stride_length = get_axis_sensor_salted(file_path)
inputs_pst = get_position_salted(file_path, distance=True)
inputs_x, inputs_y, inputs_z, stride_length, inputs_pst = torch.Tensor(np.array(inputs_x)), torch.Tensor(np.array(inputs_y)), torch.Tensor(np.array(inputs_z)), torch.Tensor(np.array(stride_length)), torch.Tensor(np.array(inputs_pst))
inputs_x, inputs_y, inputs_z, stride_length, inputs_pst = inputs_x.float(), inputs_y.float(), inputs_z.float(), stride_length.float(), inputs_pst.float()
inputs_x, inputs_y, inputs_z, inputs_pst = inputs_x.to(device), inputs_y.to(device), inputs_z.to(device), inputs_pst.to(device)

# stride_length = stride_length.reshape(-1, 1)
# stride_length = stride_length.to(device)

# %%
input_dim = 2
hidden_dim1 = 16
hidden_dim2 = 32
lstm_hidden = 64

model = Encoder_axis(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
model.load_state_dict(torch.load('./encoder_axis_best_ks30.pth'))
model.eval()
# Out:
# Encoder_axis(
#   (conv1d_x): Sequential(
#     (0): Conv1d(2, 16, kernel_size=(30,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(30,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (conv1d_y): Sequential(
#     (0): Conv1d(2, 16, kernel_size=(30,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(30,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (conv1d_z): Sequential(
#     (0): Conv1d(2, 16, kernel_size=(30,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(30,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (dense): Sequential(
#     (0): Linear(in_features=23232, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=128, out_features=64, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Linear(in_features=64, out_features=3, bias=True)
#   )
# )

# %%
pred = model(inputs_x, inputs_y, inputs_z)
pred = torch.unsqueeze(torch.sum(pred*inputs_pst, axis=1), 1).detach().cpu().numpy()

plt.figure(figsize=(10, 10))
plt.scatter(stride_length, np.round(pred, 4))
plt.xlim([50, 250])
plt.xlabel('stride_length')
plt.ylim([50, 250])
plt.ylabel('pred')

xpoints = ypoints = plt.xlim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)

plt.show()
