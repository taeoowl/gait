# %% [markdown]
# # 모듈 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

import scipy
from scipy.ndimage import gaussian_filter1d
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

import torch
from torch.utils.data import Dataset, DataLoader, random_split
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

import os 
import glob
import cv2
import itertools

from dataloader_distance import *

# %% [markdown]
# # Linear Regression : 전체 속도

# %%
file_path_train = "D:\gait_dataset/salted/train/*"
_, _, y_train = get_sensor_salted(file_path_train)
inputs_pst_train = get_position_salted(file_path_train, distance=True)

file_path_test = "D:\gait_dataset/salted/test/*"
_, _, y_test = get_sensor_salted(file_path_test)
inputs_pst_test = get_position_salted(file_path_test, distance=True)

# %%
x_train = pd.DataFrame(inputs_pst_train)
x_train.columns =  ['R_DIS_X', 'R_DIS_Y', 'R_DIS_Z']

x_test = pd.DataFrame(inputs_pst_test)
x_test.columns =  ['R_DIS_X', 'R_DIS_Y', 'R_DIS_Z']

# %%
x_train
# Out:
#        R_DIS_X   R_DIS_Y   R_DIS_Z
# 0     0.649731  0.175308  0.404984
# 1     0.589614  0.170229  0.418297
# 2     0.707072  0.236557  0.277412
# 3     0.705076  0.213632  0.319986
# 4     0.715850  0.179020  0.290625
# ...        ...       ...       ...
# 3349  0.648799  0.226499  0.524309
# 3350  0.673180  0.350159  0.512037
# 3351  0.631504  0.369093  0.332118
# 3352  0.574268  0.146589  0.530579
# 3353  0.672240  0.268779  0.409025
#
# [3354 rows x 3 columns]

# %%
plt.figure(figsize=(15, 3))
plt.plot(x_train.R_DIS_Y)

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
MAE = mean_absolute_error(y_test, y_pred)
corr = np.corrcoef(y_test, y_pred)
print('MAE : {:.4f}, Corr : {:.4f}'.format(MAE, corr[0, 1]))
# Out:
# MAE : 9.6073, Corr : 0.8433

# %%
plt.figure(figsize=(10, 10))
plt.scatter(y_test, y_pred)
plt.xlim([80, 200])
plt.xlabel('stride_length')
plt.ylim([80, 200])
plt.ylabel('pred')

xpoints = ypoints = plt.xlim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)

plt.show()

# %% [markdown]
# # Encoder-based Model : 최종 노드 1개

# %% [markdown]
# ## No bias
# - Best Result : Epoch 263, Valid Loss 13.012, MAE 2.211, Corr 0.981159

# %% [markdown]
# ### 데이터 불러오기

# %%
device = torch.device('cuda:0' if torch.cuda.is_available else 'cpu')

file_path = "D:\gait_dataset/salted/train/*"
dataset = Gait_Dataset_Salted(file_path, bias=False)
val_percent = 0.2
n_val = int(len(dataset) * val_percent)
n_train = len(dataset) - n_val
train, val = random_split(dataset, [n_train, n_val])

# %%
train_loader = torch.utils.data.DataLoader(train,
                                           batch_size=128,
                                           shuffle=True,
                                           worker_init_fn=np.random.seed(42))
val_loader = torch.utils.data.DataLoader(val,
                                         batch_size=128,
                                         shuffle=False)

# %% [markdown]
# ### Model & Scatter Plot
# - 인코더에 Conv1d만을 사용
# - 인코더의 아웃풋 길이가 늘어나 FC Layer의 수를 늘려 실험
#     - FC Layer : enc_output -> 512 -> 256 -> 128 -> 64 -> 32 -> 1

# %%
# seed 고정
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

class Encoder(nn.Module):
    def __init__(self, input_dim, conv1d_dim1, conv1d_dim2, dense_dim):
        super(Encoder, self).__init__()
             
        self.conv1d_acc = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 30),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 30),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.conv1d_gyr = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 30),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 30),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.dense = nn.Sequential(
            nn.Linear(7744*2, dense_dim),
            nn.ReLU(inplace=True),
            nn.Linear(dense_dim, int(dense_dim/2)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/2), int(dense_dim/4)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/4), int(dense_dim/8)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/8), 1)
        )
        

    def forward(self, inputs_acc, inputs_gyr): 
        
        conv1d_output_acc = self.conv1d_acc(inputs_acc)
        conv1d_output_gyr = self.conv1d_gyr(inputs_gyr)
        
        enc_output = torch.concat((conv1d_output_acc, conv1d_output_gyr), 1)
        dense_output = self.dense(enc_output)
        
        return dense_output

# %%
input_dim = 3
conv1d_dim1 = 16
conv1d_dim2 = 32
dense_dim = 512

model = Encoder(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
n_epochs = 2000

criterion = nn.MSELoss()

# %%
# Early Stopping을 위한 변수
best = 1000
converge_cnt = 0
best_MAE = 0
best_corr = 0
best_epoch = 0

# Run Training loop
for epoch in range(0, n_epochs) :
    # Set current loss value 
    tot_trn_loss = 0.0
    
    # Train Mode
    model.train()
    
    # Iterate over the DataLoader for training data 
    for i, data in enumerate(train_loader) :
        inputs_acc, inputs_gyr, stride_length, _, _ = data
        inputs_acc, inputs_gyr, stride_length = inputs_acc.float(), inputs_gyr.float(), stride_length.float()
        inputs_acc, inputs_gyr = inputs_acc.to(device), inputs_gyr.to(device)
        stride_length = stride_length.reshape(-1, 1)
        stride_length = stride_length.to(device)

        # 순전파 
        outputs = model(inputs_acc, inputs_gyr)
        
        # Loss 계산
        loss = criterion(outputs, stride_length)
        
        # 기울기 초기화 
        optimizer.zero_grad()
        # 역전파
        loss.backward()
        # 옵티마이저
        optimizer.step()

        
        # Print statistics
        tot_trn_loss += loss.item()
        
    # Evaluation Mode
    model.eval()
    
    tot_val_loss = 0
    val_epoch_loss = []

    with torch.no_grad() :
        for i, data in enumerate(val_loader):
            inputs_acc, inputs_gyr, stride_length, _, _ = data
            inputs_acc, inputs_gyr, stride_length = inputs_acc.float(), inputs_gyr.float(), stride_length.float()
            inputs_acc, inputs_gyr = inputs_acc.to(device), inputs_gyr.to(device)
            stride_length = stride_length.reshape(-1, 1)
            stride_length = stride_length.to(device)

            # 순전파 
            outputs = model(inputs_acc, inputs_gyr)
            
            # Loss 계산
            loss = criterion(outputs, stride_length)
            tot_val_loss += loss.item()            
            

    # Epoch 별 Loss
    trn_loss = tot_trn_loss / len(train_loader)
    val_loss = tot_val_loss / len(val_loader)
    MAE = torch.sum(torch.abs(outputs - stride_length)) / len(stride_length)
    corr = torch.corrcoef(torch.stack([torch.squeeze(stride_length), torch.squeeze(outputs)]))[0, 1]
    
    
    print("Epoch : {}/{}, Train Loss : {:.3f}, Valid Loss {:.3f}, MAE {:.3f}, Corr {:3f}".format(epoch+1, n_epochs,
                                                                                       trn_loss, val_loss,
                                                                                      MAE, corr))
    
    # Early Stopping
    if val_loss < best:
        best = np.mean(val_loss)
        best_MAE = MAE
        best_corr = corr
        best_epoch = epoch+1
        torch.save(model.state_dict(), './model/encoder_1_best_ks30_nobias.pth')
        print('Best Valid Loss {:.4f}'.format(best))
        converge_cnt = 0
    else:
        converge_cnt += 1
    
    if converge_cnt > 20:
        print('Early stopping')
        print('Best Result : Epoch {}, Valid Loss {:.3f}, MAE {:.3f}, Corr {:3f}'.format(best_epoch, best, best_MAE, best_corr))
        break
    
#     print("Epoch : {}/{} Epoch Loss : {:.6f}".format(epoch+1, n_epochs, current_loss / len(trainloader.dataset)))
# Out:
# Epoch : 1/2000, Train Loss : 6833.716, Valid Loss 520.661, MAE 16.422, Corr 0.471495
# Best Valid Loss 520.6606
# Epoch : 2/2000, Train Loss : 641.003, Valid Loss 500.829, MAE 19.403, Corr 0.481525
# Best Valid Loss 500.8291
# Epoch : 3/2000, Train Loss : 286.259, Valid Loss 275.083, MAE 14.033, Corr 0.487616
# Best Valid Loss 275.0827
# Epoch : 4/2000, Train Loss : 237.705, Valid Loss 258.076, MAE 13.699, Corr 0.492403
# Best Valid Loss 258.0759
# Epoch : 5/2000, Train Loss : 230.718, Valid Loss 257.639, MAE 13.707, Corr 0.496933
# Best Valid Loss 257.6388
# Epoch : 6/2000, Train Loss : 228.278, Valid Loss 248.898, MAE 13.595, Corr 0.501034
# Best Valid Loss 248.8983
# Epoch : 7/2000, Train Loss : 224.364, Valid Loss 240.394, MAE 13.361, Corr 0.505959
# Best Valid Loss 240.3943
# Epoch : 8/2000, Train Loss : 224.529, Valid Loss 238.829, MAE 13.376, Corr 0.511374
# Best Valid Loss 238.8285
# Epoch : 9/2000, Train Loss : 225.849, Valid Loss 236.538, MAE 13.324, Corr 0.518321
# Best Valid Loss 236.5384
# Epoch : 10/2000, Train Loss : 215.793, Valid Loss 233.895, MAE 13.261, Corr 0.524308
# Best Valid Loss 233.8953
# Epoch : 11/2000, Train Loss : 215.135, Valid Loss 235.414, MAE 13.055, Corr 0.532596
# Epoch : 12/2000, Train Loss : 212.114, Valid Loss 227.062, MAE 13.068, Corr 0.540474
# Best Valid Loss 227.0616
# Epoch : 13/2000, Train Loss : 208.597, Valid Loss 237.066, MAE 13.235, Corr 0.549937
# Epoch : 14/2000, Train Loss : 199.641, Valid Loss 228.246, MAE 13.030, Corr 0.558460
# Epoch : 15/2000, Train Loss : 197.266, Valid Loss 215.578, MAE 12.739, Corr 0.576962
# Best Valid Loss 215.5783
# Epoch : 16/2000, Train Loss : 188.852, Valid Loss 204.908, MAE 12.256, Corr 0.596504
# Best Valid Loss 204.9081
# Epoch : 17/2000, Train Loss : 182.627, Valid Loss 195.709, MAE 12.133, Corr 0.618263
# Best Valid Loss 195.7094
# Epoch : 18/2000, Train Loss : 180.772, Valid Loss 202.297, MAE 12.484, Corr 0.634023
# Epoch : 19/2000, Train Loss : 170.198, Valid Loss 190.301, MAE 11.779, Corr 0.659381
# Best Valid Loss 190.3014
# Epoch : 20/2000, Train Loss : 167.069, Valid Loss 199.596, MAE 12.444, Corr 0.669326
# Epoch : 21/2000, Train Loss : 166.563, Valid Loss 162.032, MAE 11.155, Corr 0.705320
# Best Valid Loss 162.0319
# Epoch : 22/2000, Train Loss : 152.610, Valid Loss 160.912, MAE 11.331, Corr 0.724223
# Best Valid Loss 160.9122
# Epoch : 23/2000, Train Loss : 135.033, Valid Loss 152.871, MAE 11.218, Corr 0.745781
# Best Valid Loss 152.8709
# Epoch : 24/2000, Train Loss : 124.200, Valid Loss 126.545, MAE 9.816, Corr 0.790610
# Best Valid Loss 126.5447
# Epoch : 25/2000, Train Loss : 122.918, Valid Loss 134.833, MAE 9.425, Corr 0.816631
# Epoch : 26/2000, Train Loss : 105.696, Valid Loss 99.678, MAE 8.558, Corr 0.842426
# Best Valid Loss 99.6780
# Epoch : 27/2000, Train Loss : 89.146, Valid Loss 89.300, MAE 7.952, Corr 0.861374
# Best Valid Loss 89.3004
# Epoch : 28/2000, Train Loss : 77.325, Valid Loss 92.627, MAE 7.524, Corr 0.881158
# Epoch : 29/2000, Train Loss : 81.788, Valid Loss 94.335, MAE 7.395, Corr 0.895942
# Epoch : 30/2000, Train Loss : 79.367, Valid Loss 81.658, MAE 6.970, Corr 0.906954
# Best Valid Loss 81.6577
# Epoch : 31/2000, Train Loss : 68.623, Valid Loss 62.821, MAE 5.955, Corr 0.917938
# Best Valid Loss 62.8210
# Epoch : 32/2000, Train Loss : 65.515, Valid Loss 61.380, MAE 5.793, Corr 0.928876
# Best Valid Loss 61.3804
# Epoch : 33/2000, Train Loss : 65.305, Valid Loss 76.044, MAE 7.251, Corr 0.930132
# Epoch : 34/2000, Train Loss : 62.959, Valid Loss 85.938, MAE 6.800, Corr 0.936172
# Epoch : 35/2000, Train Loss : 72.105, Valid Loss 50.047, MAE 5.110, Corr 0.939069
# Best Valid Loss 50.0470
# Epoch : 36/2000, Train Loss : 44.506, Valid Loss 67.008, MAE 6.801, Corr 0.939002
# Epoch : 37/2000, Train Loss : 47.313, Valid Loss 42.682, MAE 4.572, Corr 0.944320
# Best Valid Loss 42.6818
# Epoch : 38/2000, Train Loss : 45.090, Valid Loss 42.195, MAE 4.786, Corr 0.947904
# Best Valid Loss 42.1950
# Epoch : 39/2000, Train Loss : 41.700, Valid Loss 39.046, MAE 4.425, Corr 0.950976
# Best Valid Loss 39.0461
# Epoch : 40/2000, Train Loss : 43.937, Valid Loss 71.282, MAE 6.114, Corr 0.951261
# Epoch : 41/2000, Train Loss : 40.378, Valid Loss 37.349, MAE 4.386, Corr 0.952888
# Best Valid Loss 37.3487
# Epoch : 42/2000, Train Loss : 38.279, Valid Loss 38.882, MAE 4.313, Corr 0.953886
# Epoch : 43/2000, Train Loss : 39.562, Valid Loss 43.717, MAE 4.499, Corr 0.956285
# Epoch : 44/2000, Train Loss : 42.398, Valid Loss 49.455, MAE 5.667, Corr 0.956498
# Epoch : 45/2000, Train Loss : 38.234, Valid Loss 37.034, MAE 4.117, Corr 0.958524
# Best Valid Loss 37.0341
# Epoch : 46/2000, Train Loss : 42.500, Valid Loss 49.437, MAE 5.764, Corr 0.959906
# Epoch : 47/2000, Train Loss : 34.831, Valid Loss 33.133, MAE 4.191, Corr 0.957406
# Best Valid Loss 33.1327
# Epoch : 48/2000, Train Loss : 32.077, Valid Loss 37.561, MAE 4.842, Corr 0.958387
# Epoch : 49/2000, Train Loss : 36.101, Valid Loss 32.373, MAE 4.055, Corr 0.958481
# Best Valid Loss 32.3727
# Epoch : 50/2000, Train Loss : 31.279, Valid Loss 69.977, MAE 6.168, Corr 0.962539
# Epoch : 51/2000, Train Loss : 31.847, Valid Loss 30.558, MAE 4.071, Corr 0.959517
# Best Valid Loss 30.5576
# Epoch : 52/2000, Train Loss : 31.804, Valid Loss 37.732, MAE 4.857, Corr 0.962467
# Epoch : 53/2000, Train Loss : 35.931, Valid Loss 29.354, MAE 3.874, Corr 0.961666
# Best Valid Loss 29.3539
# Epoch : 54/2000, Train Loss : 38.589, Valid Loss 30.760, MAE 3.959, Corr 0.961383
# Epoch : 55/2000, Train Loss : 30.931, Valid Loss 29.126, MAE 3.920, Corr 0.960386
# Best Valid Loss 29.1261
# Epoch : 56/2000, Train Loss : 30.500, Valid Loss 34.403, MAE 4.580, Corr 0.961437
# Epoch : 57/2000, Train Loss : 31.702, Valid Loss 44.749, MAE 5.313, Corr 0.960176
# Epoch : 58/2000, Train Loss : 37.317, Valid Loss 31.206, MAE 4.440, Corr 0.959505
# Epoch : 59/2000, Train Loss : 31.188, Valid Loss 38.308, MAE 5.011, Corr 0.959718
# Epoch : 60/2000, Train Loss : 28.659, Valid Loss 30.527, MAE 4.164, Corr 0.958768
# Epoch : 61/2000, Train Loss : 27.544, Valid Loss 28.002, MAE 3.752, Corr 0.963113
# Best Valid Loss 28.0017
# Epoch : 62/2000, Train Loss : 30.435, Valid Loss 27.210, MAE 3.805, Corr 0.960699
# Best Valid Loss 27.2098
# Epoch : 63/2000, Train Loss : 31.718, Valid Loss 28.671, MAE 3.994, Corr 0.962456
# Epoch : 64/2000, Train Loss : 33.364, Valid Loss 29.250, MAE 3.964, Corr 0.960670
# Epoch : 65/2000, Train Loss : 28.632, Valid Loss 29.742, MAE 4.099, Corr 0.958473
# Epoch : 66/2000, Train Loss : 25.784, Valid Loss 29.566, MAE 4.063, Corr 0.964799
# Epoch : 67/2000, Train Loss : 29.876, Valid Loss 27.974, MAE 3.813, Corr 0.966952
# Epoch : 68/2000, Train Loss : 24.805, Valid Loss 26.567, MAE 3.781, Corr 0.963901
# Best Valid Loss 26.5672
# Epoch : 69/2000, Train Loss : 31.081, Valid Loss 35.772, MAE 4.557, Corr 0.963257
# Epoch : 70/2000, Train Loss : 38.763, Valid Loss 27.691, MAE 4.015, Corr 0.962850
# Epoch : 71/2000, Train Loss : 28.950, Valid Loss 39.218, MAE 4.637, Corr 0.967080
# Epoch : 72/2000, Train Loss : 27.703, Valid Loss 40.253, MAE 4.546, Corr 0.969311
# Epoch : 73/2000, Train Loss : 33.333, Valid Loss 31.773, MAE 4.170, Corr 0.967165
# Epoch : 74/2000, Train Loss : 25.346, Valid Loss 27.327, MAE 3.984, Corr 0.964747
# Epoch : 75/2000, Train Loss : 33.111, Valid Loss 36.774, MAE 4.962, Corr 0.964487
# Epoch : 76/2000, Train Loss : 27.199, Valid Loss 25.080, MAE 3.689, Corr 0.966576
# Best Valid Loss 25.0803
# Epoch : 77/2000, Train Loss : 28.690, Valid Loss 26.323, MAE 3.833, Corr 0.963673
# Epoch : 78/2000, Train Loss : 23.732, Valid Loss 30.819, MAE 4.278, Corr 0.967243
# Epoch : 79/2000, Train Loss : 25.444, Valid Loss 33.256, MAE 4.167, Corr 0.967825
# Epoch : 80/2000, Train Loss : 24.257, Valid Loss 25.114, MAE 3.644, Corr 0.967518
# Epoch : 81/2000, Train Loss : 28.940, Valid Loss 36.601, MAE 4.739, Corr 0.966310
# Epoch : 82/2000, Train Loss : 30.258, Valid Loss 24.828, MAE 3.633, Corr 0.966854
# Best Valid Loss 24.8284
# Epoch : 83/2000, Train Loss : 29.123, Valid Loss 35.083, MAE 4.787, Corr 0.966057
# Epoch : 84/2000, Train Loss : 34.938, Valid Loss 67.061, MAE 6.776, Corr 0.963003
# Epoch : 85/2000, Train Loss : 40.908, Valid Loss 28.392, MAE 4.012, Corr 0.966570
# Epoch : 86/2000, Train Loss : 26.805, Valid Loss 23.531, MAE 3.609, Corr 0.967809
# Best Valid Loss 23.5305
# Epoch : 87/2000, Train Loss : 23.672, Valid Loss 25.599, MAE 3.665, Corr 0.969676
# Epoch : 88/2000, Train Loss : 26.138, Valid Loss 24.176, MAE 3.693, Corr 0.965991
# Epoch : 89/2000, Train Loss : 24.599, Valid Loss 28.790, MAE 4.031, Corr 0.968252
# Epoch : 90/2000, Train Loss : 31.585, Valid Loss 23.028, MAE 3.483, Corr 0.966541
# Best Valid Loss 23.0285
# Epoch : 91/2000, Train Loss : 28.914, Valid Loss 35.170, MAE 4.589, Corr 0.968470
# Epoch : 92/2000, Train Loss : 29.091, Valid Loss 28.114, MAE 3.944, Corr 0.971150
# Epoch : 93/2000, Train Loss : 25.711, Valid Loss 23.495, MAE 3.694, Corr 0.965134
# Epoch : 94/2000, Train Loss : 24.048, Valid Loss 23.850, MAE 3.582, Corr 0.964523
# Epoch : 95/2000, Train Loss : 29.014, Valid Loss 23.885, MAE 3.557, Corr 0.968224
# Epoch : 96/2000, Train Loss : 23.016, Valid Loss 23.601, MAE 3.523, Corr 0.967784
# Epoch : 97/2000, Train Loss : 25.497, Valid Loss 22.395, MAE 3.435, Corr 0.967952
# Best Valid Loss 22.3949
# Epoch : 98/2000, Train Loss : 32.525, Valid Loss 34.650, MAE 4.707, Corr 0.965021
# Epoch : 99/2000, Train Loss : 24.880, Valid Loss 21.754, MAE 3.358, Corr 0.970931
# Best Valid Loss 21.7540
# Epoch : 100/2000, Train Loss : 21.214, Valid Loss 29.907, MAE 4.091, Corr 0.971806
# Epoch : 101/2000, Train Loss : 27.644, Valid Loss 21.920, MAE 3.462, Corr 0.969744
# Epoch : 102/2000, Train Loss : 28.570, Valid Loss 46.647, MAE 5.354, Corr 0.968622
# Epoch : 103/2000, Train Loss : 26.801, Valid Loss 26.971, MAE 3.901, Corr 0.967619
# Epoch : 104/2000, Train Loss : 25.583, Valid Loss 58.411, MAE 5.747, Corr 0.972763
# Epoch : 105/2000, Train Loss : 42.877, Valid Loss 70.601, MAE 7.615, Corr 0.972109
# Epoch : 106/2000, Train Loss : 31.388, Valid Loss 29.120, MAE 4.291, Corr 0.964090
# Epoch : 107/2000, Train Loss : 31.010, Valid Loss 25.321, MAE 3.711, Corr 0.968166
# Epoch : 108/2000, Train Loss : 22.285, Valid Loss 20.910, MAE 3.141, Corr 0.973814
# Best Valid Loss 20.9096
# Epoch : 109/2000, Train Loss : 21.054, Valid Loss 21.705, MAE 3.387, Corr 0.970263
# Epoch : 110/2000, Train Loss : 28.399, Valid Loss 40.067, MAE 5.160, Corr 0.969852
# Epoch : 111/2000, Train Loss : 28.198, Valid Loss 55.389, MAE 5.708, Corr 0.970424
# Epoch : 112/2000, Train Loss : 37.083, Valid Loss 20.923, MAE 3.249, Corr 0.971500
# Epoch : 113/2000, Train Loss : 23.723, Valid Loss 25.397, MAE 3.758, Corr 0.966122
# Epoch : 114/2000, Train Loss : 25.723, Valid Loss 26.781, MAE 3.963, Corr 0.970305
# Epoch : 115/2000, Train Loss : 22.941, Valid Loss 26.639, MAE 3.906, Corr 0.972014
# Epoch : 116/2000, Train Loss : 20.801, Valid Loss 29.486, MAE 4.393, Corr 0.966284
# Epoch : 117/2000, Train Loss : 21.769, Valid Loss 23.243, MAE 3.574, Corr 0.967796
# Epoch : 118/2000, Train Loss : 23.613, Valid Loss 49.637, MAE 5.566, Corr 0.971064
# Epoch : 119/2000, Train Loss : 23.467, Valid Loss 22.455, MAE 3.438, Corr 0.966364
# Epoch : 120/2000, Train Loss : 24.787, Valid Loss 22.752, MAE 3.368, Corr 0.971210
# Epoch : 121/2000, Train Loss : 24.235, Valid Loss 24.271, MAE 3.663, Corr 0.974015
# Epoch : 122/2000, Train Loss : 24.214, Valid Loss 26.143, MAE 3.971, Corr 0.968721
# Epoch : 123/2000, Train Loss : 25.074, Valid Loss 38.711, MAE 4.752, Corr 0.971621
# Epoch : 124/2000, Train Loss : 24.419, Valid Loss 19.567, MAE 2.927, Corr 0.976107
# Best Valid Loss 19.5671
# Epoch : 125/2000, Train Loss : 20.347, Valid Loss 19.801, MAE 3.032, Corr 0.972003
# Epoch : 126/2000, Train Loss : 22.755, Valid Loss 19.463, MAE 3.019, Corr 0.973291
# Best Valid Loss 19.4634
# Epoch : 127/2000, Train Loss : 24.319, Valid Loss 45.923, MAE 5.111, Corr 0.975705
# Epoch : 128/2000, Train Loss : 28.296, Valid Loss 25.216, MAE 3.545, Corr 0.975309
# Epoch : 129/2000, Train Loss : 21.835, Valid Loss 31.033, MAE 4.017, Corr 0.977178
# Epoch : 130/2000, Train Loss : 21.250, Valid Loss 27.083, MAE 4.060, Corr 0.971882
# Epoch : 131/2000, Train Loss : 20.537, Valid Loss 20.856, MAE 3.396, Corr 0.971589
# Epoch : 132/2000, Train Loss : 22.023, Valid Loss 19.666, MAE 3.131, Corr 0.969549
# Epoch : 133/2000, Train Loss : 21.029, Valid Loss 33.440, MAE 4.749, Corr 0.974917
# Epoch : 134/2000, Train Loss : 31.549, Valid Loss 54.521, MAE 5.656, Corr 0.975958
# Epoch : 135/2000, Train Loss : 23.414, Valid Loss 28.649, MAE 4.195, Corr 0.972874
# Epoch : 136/2000, Train Loss : 19.537, Valid Loss 26.342, MAE 4.077, Corr 0.974437
# Epoch : 137/2000, Train Loss : 23.058, Valid Loss 19.509, MAE 3.148, Corr 0.972033
# Epoch : 138/2000, Train Loss : 24.233, Valid Loss 31.578, MAE 4.618, Corr 0.973616
# Epoch : 139/2000, Train Loss : 23.840, Valid Loss 24.624, MAE 3.805, Corr 0.972657
# Epoch : 140/2000, Train Loss : 22.248, Valid Loss 19.772, MAE 3.109, Corr 0.974252
# Epoch : 141/2000, Train Loss : 21.844, Valid Loss 19.359, MAE 3.086, Corr 0.973482
# Best Valid Loss 19.3593
# Epoch : 142/2000, Train Loss : 17.708, Valid Loss 20.214, MAE 3.327, Corr 0.966470
# Epoch : 143/2000, Train Loss : 22.277, Valid Loss 18.170, MAE 2.809, Corr 0.977654
# Best Valid Loss 18.1702
# Epoch : 144/2000, Train Loss : 18.986, Valid Loss 18.207, MAE 2.955, Corr 0.977068
# Epoch : 145/2000, Train Loss : 21.400, Valid Loss 35.330, MAE 4.769, Corr 0.971330
# Epoch : 146/2000, Train Loss : 31.707, Valid Loss 27.272, MAE 3.718, Corr 0.973813
# Epoch : 147/2000, Train Loss : 20.675, Valid Loss 38.740, MAE 5.124, Corr 0.970730
# Epoch : 148/2000, Train Loss : 23.577, Valid Loss 18.066, MAE 2.841, Corr 0.975845
# Best Valid Loss 18.0664
# Epoch : 149/2000, Train Loss : 59.502, Valid Loss 44.135, MAE 5.503, Corr 0.965991
# Epoch : 150/2000, Train Loss : 64.954, Valid Loss 50.918, MAE 5.612, Corr 0.971758
# Epoch : 151/2000, Train Loss : 27.125, Valid Loss 21.827, MAE 3.380, Corr 0.970940
# Epoch : 152/2000, Train Loss : 24.623, Valid Loss 18.823, MAE 3.016, Corr 0.973431
# Epoch : 153/2000, Train Loss : 20.082, Valid Loss 18.861, MAE 3.029, Corr 0.975920
# Epoch : 154/2000, Train Loss : 20.772, Valid Loss 26.932, MAE 4.062, Corr 0.973063
# Epoch : 155/2000, Train Loss : 20.550, Valid Loss 18.914, MAE 3.041, Corr 0.976508
# Epoch : 156/2000, Train Loss : 35.452, Valid Loss 19.919, MAE 3.343, Corr 0.971830
# Epoch : 157/2000, Train Loss : 19.540, Valid Loss 28.174, MAE 4.258, Corr 0.970180
# Epoch : 158/2000, Train Loss : 17.363, Valid Loss 17.509, MAE 2.830, Corr 0.975667
# Best Valid Loss 17.5086
# Epoch : 159/2000, Train Loss : 17.582, Valid Loss 20.628, MAE 3.376, Corr 0.974882
# Epoch : 160/2000, Train Loss : 16.552, Valid Loss 18.715, MAE 3.070, Corr 0.975009
# Epoch : 161/2000, Train Loss : 16.744, Valid Loss 18.628, MAE 2.953, Corr 0.973189
# Epoch : 162/2000, Train Loss : 17.097, Valid Loss 19.971, MAE 3.298, Corr 0.976798
# Epoch : 163/2000, Train Loss : 17.749, Valid Loss 17.315, MAE 2.593, Corr 0.980597
# Best Valid Loss 17.3149
# Epoch : 164/2000, Train Loss : 16.699, Valid Loss 21.863, MAE 3.442, Corr 0.969714
# Epoch : 165/2000, Train Loss : 17.535, Valid Loss 22.663, MAE 3.457, Corr 0.978324
# Epoch : 166/2000, Train Loss : 22.435, Valid Loss 22.247, MAE 3.408, Corr 0.975612
# Epoch : 167/2000, Train Loss : 19.961, Valid Loss 18.161, MAE 2.941, Corr 0.976766
# Epoch : 168/2000, Train Loss : 15.860, Valid Loss 19.392, MAE 3.246, Corr 0.976733
# Epoch : 169/2000, Train Loss : 15.607, Valid Loss 16.609, MAE 2.629, Corr 0.980477
# Best Valid Loss 16.6092
# Epoch : 170/2000, Train Loss : 18.889, Valid Loss 19.898, MAE 3.496, Corr 0.971809
# Epoch : 171/2000, Train Loss : 21.842, Valid Loss 35.389, MAE 4.787, Corr 0.976017
# Epoch : 172/2000, Train Loss : 17.901, Valid Loss 19.130, MAE 3.175, Corr 0.978766
# Epoch : 173/2000, Train Loss : 26.227, Valid Loss 22.249, MAE 3.303, Corr 0.981831
# Epoch : 174/2000, Train Loss : 18.788, Valid Loss 30.315, MAE 4.237, Corr 0.977258
# Epoch : 175/2000, Train Loss : 18.406, Valid Loss 17.627, MAE 2.978, Corr 0.977892
# Epoch : 176/2000, Train Loss : 18.562, Valid Loss 16.952, MAE 2.933, Corr 0.974150
# Epoch : 177/2000, Train Loss : 22.589, Valid Loss 19.270, MAE 3.281, Corr 0.973720
# Epoch : 178/2000, Train Loss : 31.657, Valid Loss 34.981, MAE 5.097, Corr 0.976457
# Epoch : 179/2000, Train Loss : 24.642, Valid Loss 37.327, MAE 4.472, Corr 0.978928
# Epoch : 180/2000, Train Loss : 19.831, Valid Loss 16.029, MAE 2.738, Corr 0.976338
# Best Valid Loss 16.0292
# Epoch : 181/2000, Train Loss : 16.462, Valid Loss 17.586, MAE 3.044, Corr 0.975645
# Epoch : 182/2000, Train Loss : 16.115, Valid Loss 20.050, MAE 3.419, Corr 0.973373
# Epoch : 183/2000, Train Loss : 16.819, Valid Loss 17.487, MAE 2.989, Corr 0.971106
# Epoch : 184/2000, Train Loss : 15.039, Valid Loss 24.368, MAE 3.885, Corr 0.978042
# Epoch : 185/2000, Train Loss : 21.333, Valid Loss 28.400, MAE 4.330, Corr 0.973682
# Epoch : 186/2000, Train Loss : 23.678, Valid Loss 50.092, MAE 5.599, Corr 0.980748
# Epoch : 187/2000, Train Loss : 29.321, Valid Loss 18.770, MAE 3.269, Corr 0.977170
# Epoch : 188/2000, Train Loss : 20.941, Valid Loss 16.078, MAE 2.740, Corr 0.978029
# Epoch : 189/2000, Train Loss : 15.764, Valid Loss 17.541, MAE 3.097, Corr 0.975652
# Epoch : 190/2000, Train Loss : 18.704, Valid Loss 19.830, MAE 3.283, Corr 0.973922
# Epoch : 191/2000, Train Loss : 16.222, Valid Loss 19.306, MAE 3.232, Corr 0.977517
# Epoch : 192/2000, Train Loss : 17.929, Valid Loss 15.634, MAE 2.620, Corr 0.977220
# Best Valid Loss 15.6344
# Epoch : 193/2000, Train Loss : 18.635, Valid Loss 17.598, MAE 3.253, Corr 0.970779
# Epoch : 194/2000, Train Loss : 15.427, Valid Loss 17.099, MAE 2.847, Corr 0.979800
# Epoch : 195/2000, Train Loss : 17.836, Valid Loss 22.674, MAE 3.448, Corr 0.980616
# Epoch : 196/2000, Train Loss : 16.858, Valid Loss 22.799, MAE 3.953, Corr 0.976062
# Epoch : 197/2000, Train Loss : 16.285, Valid Loss 17.305, MAE 3.063, Corr 0.976754
# Epoch : 198/2000, Train Loss : 16.079, Valid Loss 20.188, MAE 3.559, Corr 0.975988
# Epoch : 199/2000, Train Loss : 17.442, Valid Loss 16.927, MAE 2.890, Corr 0.977582
# Epoch : 200/2000, Train Loss : 16.860, Valid Loss 17.575, MAE 3.165, Corr 0.977407
# Epoch : 201/2000, Train Loss : 17.145, Valid Loss 21.361, MAE 3.617, Corr 0.974069
# Epoch : 202/2000, Train Loss : 14.710, Valid Loss 14.430, MAE 2.440, Corr 0.981671
# Best Valid Loss 14.4305
# Epoch : 203/2000, Train Loss : 16.343, Valid Loss 19.411, MAE 3.377, Corr 0.974298
# Epoch : 204/2000, Train Loss : 20.339, Valid Loss 20.416, MAE 3.516, Corr 0.964476
# Epoch : 205/2000, Train Loss : 16.764, Valid Loss 24.410, MAE 4.296, Corr 0.978062
# Epoch : 206/2000, Train Loss : 46.804, Valid Loss 127.229, MAE 10.448, Corr 0.966856
# Epoch : 207/2000, Train Loss : 51.768, Valid Loss 17.691, MAE 3.084, Corr 0.971076
# Epoch : 208/2000, Train Loss : 16.322, Valid Loss 20.380, MAE 3.332, Corr 0.978496
# Epoch : 209/2000, Train Loss : 19.698, Valid Loss 29.168, MAE 4.215, Corr 0.976748
# Epoch : 210/2000, Train Loss : 21.702, Valid Loss 20.048, MAE 3.675, Corr 0.968841
# Epoch : 211/2000, Train Loss : 16.651, Valid Loss 33.915, MAE 4.528, Corr 0.977785
# Epoch : 212/2000, Train Loss : 26.696, Valid Loss 26.239, MAE 4.335, Corr 0.974675
# Epoch : 213/2000, Train Loss : 22.137, Valid Loss 17.824, MAE 2.864, Corr 0.979452
# Epoch : 214/2000, Train Loss : 16.520, Valid Loss 19.233, MAE 3.307, Corr 0.977813
# Epoch : 215/2000, Train Loss : 21.170, Valid Loss 37.155, MAE 5.214, Corr 0.980278
# Epoch : 216/2000, Train Loss : 23.227, Valid Loss 19.306, MAE 3.483, Corr 0.971750
# Epoch : 217/2000, Train Loss : 22.101, Valid Loss 17.597, MAE 3.318, Corr 0.974959
# Epoch : 218/2000, Train Loss : 17.636, Valid Loss 14.739, MAE 2.780, Corr 0.979657
# Epoch : 219/2000, Train Loss : 15.745, Valid Loss 14.111, MAE 2.568, Corr 0.977512
# Best Valid Loss 14.1112
# Epoch : 220/2000, Train Loss : 16.100, Valid Loss 19.279, MAE 3.295, Corr 0.977953
# Epoch : 221/2000, Train Loss : 18.254, Valid Loss 14.789, MAE 2.684, Corr 0.977792
# Epoch : 222/2000, Train Loss : 13.511, Valid Loss 13.858, MAE 2.684, Corr 0.978795
# Best Valid Loss 13.8575
# Epoch : 223/2000, Train Loss : 13.232, Valid Loss 14.607, MAE 2.797, Corr 0.976675
# Epoch : 224/2000, Train Loss : 18.638, Valid Loss 14.722, MAE 2.692, Corr 0.975681
# Epoch : 225/2000, Train Loss : 21.332, Valid Loss 19.914, MAE 3.723, Corr 0.978559
# Epoch : 226/2000, Train Loss : 16.568, Valid Loss 14.371, MAE 2.660, Corr 0.979592
# Epoch : 227/2000, Train Loss : 24.547, Valid Loss 20.433, MAE 3.284, Corr 0.981013
# Epoch : 228/2000, Train Loss : 19.194, Valid Loss 20.218, MAE 3.476, Corr 0.980988
# Epoch : 229/2000, Train Loss : 13.941, Valid Loss 14.742, MAE 2.946, Corr 0.977042
# Epoch : 230/2000, Train Loss : 19.177, Valid Loss 15.410, MAE 2.828, Corr 0.982201
# Epoch : 231/2000, Train Loss : 23.155, Valid Loss 15.211, MAE 2.977, Corr 0.973984
# Epoch : 232/2000, Train Loss : 13.738, Valid Loss 14.184, MAE 2.784, Corr 0.979397
# Epoch : 233/2000, Train Loss : 13.890, Valid Loss 13.761, MAE 2.736, Corr 0.978775
# Best Valid Loss 13.7606
# Epoch : 234/2000, Train Loss : 14.043, Valid Loss 13.661, MAE 2.741, Corr 0.978195
# Best Valid Loss 13.6608
# Epoch : 235/2000, Train Loss : 14.980, Valid Loss 19.131, MAE 3.560, Corr 0.979022
# Epoch : 236/2000, Train Loss : 17.646, Valid Loss 15.323, MAE 3.224, Corr 0.973990
# Epoch : 237/2000, Train Loss : 12.803, Valid Loss 13.531, MAE 2.737, Corr 0.978397
# Best Valid Loss 13.5314
# Epoch : 238/2000, Train Loss : 23.514, Valid Loss 40.444, MAE 5.284, Corr 0.979932
# Epoch : 239/2000, Train Loss : 18.601, Valid Loss 14.442, MAE 2.831, Corr 0.978063
# Epoch : 240/2000, Train Loss : 14.287, Valid Loss 15.952, MAE 3.164, Corr 0.977964
# Epoch : 241/2000, Train Loss : 13.292, Valid Loss 13.586, MAE 2.623, Corr 0.978960
# Epoch : 242/2000, Train Loss : 15.394, Valid Loss 16.414, MAE 3.021, Corr 0.980167
# Epoch : 243/2000, Train Loss : 13.943, Valid Loss 17.856, MAE 3.260, Corr 0.978522
# Epoch : 244/2000, Train Loss : 13.560, Valid Loss 14.209, MAE 2.799, Corr 0.979000
# Epoch : 245/2000, Train Loss : 14.864, Valid Loss 18.149, MAE 3.217, Corr 0.981818
# Epoch : 246/2000, Train Loss : 15.582, Valid Loss 15.799, MAE 3.044, Corr 0.980359
# Epoch : 247/2000, Train Loss : 16.365, Valid Loss 15.771, MAE 3.214, Corr 0.976633
# Epoch : 248/2000, Train Loss : 17.529, Valid Loss 16.962, MAE 3.254, Corr 0.975304
# Epoch : 249/2000, Train Loss : 14.659, Valid Loss 13.156, MAE 2.581, Corr 0.979612
# Best Valid Loss 13.1560
# Epoch : 250/2000, Train Loss : 23.130, Valid Loss 20.405, MAE 3.735, Corr 0.983192
# Epoch : 251/2000, Train Loss : 14.954, Valid Loss 13.615, MAE 2.832, Corr 0.975406
# Epoch : 252/2000, Train Loss : 13.069, Valid Loss 13.728, MAE 2.791, Corr 0.979383
# Epoch : 253/2000, Train Loss : 11.971, Valid Loss 14.846, MAE 2.957, Corr 0.980057
# Epoch : 254/2000, Train Loss : 22.260, Valid Loss 29.347, MAE 4.916, Corr 0.977420
# Epoch : 255/2000, Train Loss : 15.870, Valid Loss 13.321, MAE 2.821, Corr 0.979850
# Epoch : 256/2000, Train Loss : 12.860, Valid Loss 13.093, MAE 2.482, Corr 0.981790
# Best Valid Loss 13.0933
# Epoch : 257/2000, Train Loss : 15.271, Valid Loss 24.341, MAE 4.241, Corr 0.977472
# Epoch : 258/2000, Train Loss : 13.788, Valid Loss 13.787, MAE 2.911, Corr 0.978166
# Epoch : 259/2000, Train Loss : 14.281, Valid Loss 13.204, MAE 2.603, Corr 0.980700
# Epoch : 260/2000, Train Loss : 13.207, Valid Loss 12.724, MAE 2.638, Corr 0.979675
# Best Valid Loss 12.7238
# Epoch : 261/2000, Train Loss : 12.132, Valid Loss 14.742, MAE 2.951, Corr 0.979865
# Epoch : 262/2000, Train Loss : 15.414, Valid Loss 38.491, MAE 5.452, Corr 0.978384
# Epoch : 263/2000, Train Loss : 23.205, Valid Loss 15.958, MAE 3.081, Corr 0.976159
# Epoch : 264/2000, Train Loss : 11.912, Valid Loss 15.910, MAE 3.340, Corr 0.976980
# Epoch : 265/2000, Train Loss : 15.060, Valid Loss 13.251, MAE 2.738, Corr 0.980657
# Epoch : 266/2000, Train Loss : 14.283, Valid Loss 26.741, MAE 4.478, Corr 0.983399
# Epoch : 267/2000, Train Loss : 21.523, Valid Loss 35.727, MAE 5.168, Corr 0.980039
# Epoch : 268/2000, Train Loss : 18.255, Valid Loss 13.105, MAE 2.698, Corr 0.977987
# Epoch : 269/2000, Train Loss : 13.468, Valid Loss 13.015, MAE 2.819, Corr 0.977604
# Epoch : 270/2000, Train Loss : 11.501, Valid Loss 13.266, MAE 2.820, Corr 0.978994
# Epoch : 271/2000, Train Loss : 13.796, Valid Loss 24.921, MAE 3.750, Corr 0.981519
# Epoch : 272/2000, Train Loss : 14.237, Valid Loss 12.980, MAE 2.761, Corr 0.978602
# Epoch : 273/2000, Train Loss : 14.498, Valid Loss 17.051, MAE 3.007, Corr 0.983167
# Epoch : 274/2000, Train Loss : 13.641, Valid Loss 13.898, MAE 2.918, Corr 0.981059
# Epoch : 275/2000, Train Loss : 13.512, Valid Loss 21.665, MAE 3.502, Corr 0.980780
# Epoch : 276/2000, Train Loss : 16.427, Valid Loss 15.574, MAE 3.278, Corr 0.970834
# Epoch : 277/2000, Train Loss : 21.391, Valid Loss 38.234, MAE 5.312, Corr 0.974838
# Epoch : 278/2000, Train Loss : 84.782, Valid Loss 19.243, MAE 3.512, Corr 0.963368
# Epoch : 279/2000, Train Loss : 24.536, Valid Loss 20.306, MAE 3.257, Corr 0.983798
# Epoch : 280/2000, Train Loss : 19.304, Valid Loss 23.391, MAE 3.881, Corr 0.978978
# Epoch : 281/2000, Train Loss : 14.978, Valid Loss 13.024, MAE 2.784, Corr 0.978386
# Early stopping
# Best Result : Epoch 260, Valid Loss 12.724, MAE 2.638, Corr 0.979675

# %%
### scatter plot
file_path = "D:\gait_dataset/salted/test/*"
inputs_acc, inputs_gyr, stride_length = get_sensor_salted(file_path, normalization=True)
inputs_acc, inputs_gyr, stride_length = torch.Tensor(np.array(inputs_acc)), torch.Tensor(np.array(inputs_gyr)), torch.Tensor(np.array(stride_length))
inputs_acc, inputs_gyr, stride_length = inputs_acc.float(), inputs_gyr.float(), stride_length.float()
inputs_acc, inputs_gyr = inputs_acc.to(device), inputs_gyr.to(device)

# %%
input_dim = 3
conv1d_dim1 = 16
conv1d_dim2 = 32
dense_dim = 512

model = Encoder(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
model.load_state_dict(torch.load('./model/encoder_1_best_ks30_nobias.pth'))
model.eval()
# Out:
# Encoder(
#   (conv1d_acc): Sequential(
#     (0): Conv1d(3, 16, kernel_size=(30,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(30,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (conv1d_gyr): Sequential(
#     (0): Conv1d(3, 16, kernel_size=(30,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(30,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (dense): Sequential(
#     (0): Linear(in_features=15488, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=128, out_features=64, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %%
pred = model(inputs_acc, inputs_gyr).detach().cpu().numpy()

plt.figure(figsize=(10, 10))
plt.scatter(stride_length, np.round(pred, 4))
plt.xlim([80, 200])
plt.xlabel('stride_length')
plt.ylim([80, 200])
plt.ylabel('pred')

xpoints = ypoints = plt.xlim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)

plt.show()

# %% [markdown]
# ## Bias
# - Best Result : Epoch 313, Valid Loss 10.596, MAE 2.744, Corr 0.976224

# %% [markdown]
# ### 데이터 불러오기

# %%
device = torch.device('cuda:0' if torch.cuda.is_available else 'cpu')

file_path = "D:\gait_dataset/salted/train/*"
dataset = Gait_Dataset_Salted(file_path, bias=True)
val_percent = 0.2
n_val = int(len(dataset) * val_percent)
n_train = len(dataset) - n_val
train, val = random_split(dataset, [n_train, n_val])

# %%
train_loader = torch.utils.data.DataLoader(train,
                                           batch_size=128,
                                           shuffle=True,
                                           worker_init_fn=np.random.seed(42))
val_loader = torch.utils.data.DataLoader(val,
                                         batch_size=128,
                                         shuffle=False)

# %% [markdown]
# ### Model & Scatter Plot
# - 인코더에 Conv1d만을 사용
# - 인코더의 아웃풋 길이가 늘어나 FC Layer의 수를 늘려 실험
#     - FC Layer : enc_output -> 512 -> 256 -> 128 -> 64 -> 32 -> 1

# %%
# seed 고정
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

class Encoder(nn.Module):
    def __init__(self, input_dim, conv1d_dim1, conv1d_dim2, dense_dim):
        super(Encoder, self).__init__()
             
        self.conv1d_acc = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 30),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 30),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.conv1d_gyr = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 30),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 30),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.dense = nn.Sequential(
            nn.Linear(7744*2, dense_dim),
            nn.ReLU(inplace=True),
            nn.Linear(dense_dim, int(dense_dim/2)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/2), int(dense_dim/4)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/4), int(dense_dim/8)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/8), 1)
        )
        

    def forward(self, inputs_acc, inputs_gyr): 
        
        conv1d_output_acc = self.conv1d_acc(inputs_acc)
        conv1d_output_gyr = self.conv1d_gyr(inputs_gyr)
        
        enc_output = torch.concat((conv1d_output_acc, conv1d_output_gyr), 1)
        dense_output = self.dense(enc_output)
        
        return dense_output

# %%
input_dim = 3
conv1d_dim1 = 16
conv1d_dim2 = 32
dense_dim = 512

model = Encoder(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
n_epochs = 2000

criterion = nn.MSELoss()

# %%
# Early Stopping을 위한 변수
best = 1000
converge_cnt = 0
best_MAE = 0
best_corr = 0
best_epoch = 0

# Run Training loop
for epoch in range(0, n_epochs) :
    # Set current loss value 
    tot_trn_loss = 0.0
    
    # Train Mode
    model.train()
    
    # Iterate over the DataLoader for training data 
    for i, data in enumerate(train_loader) :
        inputs_acc, inputs_gyr, stride_length, _ = data
        inputs_acc, inputs_gyr, stride_length = inputs_acc.float(), inputs_gyr.float(), stride_length.float()
        inputs_acc, inputs_gyr = inputs_acc.to(device), inputs_gyr.to(device)
        stride_length = stride_length.reshape(-1, 1)
        stride_length = stride_length.to(device)

        # 순전파 
        outputs = model(inputs_acc, inputs_gyr)
        
        # Loss 계산
        loss = criterion(outputs, stride_length)
        
        # 기울기 초기화 
        optimizer.zero_grad()
        # 역전파
        loss.backward()
        # 옵티마이저
        optimizer.step()

        
        # Print statistics
        tot_trn_loss += loss.item()
        
    # Evaluation Mode
    model.eval()
    
    tot_val_loss = 0
    val_epoch_loss = []

    with torch.no_grad() :
        for i, data in enumerate(val_loader):
            inputs_acc, inputs_gyr, stride_length, _ = data
            inputs_acc, inputs_gyr, stride_length = inputs_acc.float(), inputs_gyr.float(), stride_length.float()
            inputs_acc, inputs_gyr = inputs_acc.to(device), inputs_gyr.to(device)
            stride_length = stride_length.reshape(-1, 1)
            stride_length = stride_length.to(device)

            # 순전파 
            outputs = model(inputs_acc, inputs_gyr)
            
            # Loss 계산
            loss = criterion(outputs, stride_length)
            tot_val_loss += loss.item()            
            

    # Epoch 별 Loss
    trn_loss = tot_trn_loss / len(train_loader)
    val_loss = tot_val_loss / len(val_loader)
    MAE = torch.sum(torch.abs(outputs - stride_length)) / len(stride_length)
    corr = torch.corrcoef(torch.stack([torch.squeeze(stride_length), torch.squeeze(outputs)]))[0, 1]
    
    
    print("Epoch : {}/{}, Train Loss : {:.3f}, Valid Loss {:.3f}, MAE {:.3f}, Corr {:3f}".format(epoch+1, n_epochs,
                                                                                       trn_loss, val_loss,
                                                                                      MAE, corr))
    
    # Early Stopping
    if val_loss < best:
        best = np.mean(val_loss)
        best_MAE = MAE
        best_corr = corr
        best_epoch = epoch+1
        torch.save(model.state_dict(), './model/encoder_1_best_ks30_bias.pth')
        print('Best Valid Loss {:.4f}'.format(best))
        converge_cnt = 0
    else:
        converge_cnt += 1
    
    if converge_cnt > 20:
        print('Early stopping')
        print('Best Result : Epoch {}, Valid Loss {:.3f}, MAE {:.3f}, Corr {:3f}'.format(best_epoch, best, best_MAE, best_corr))
        break
    
#     print("Epoch : {}/{} Epoch Loss : {:.6f}".format(epoch+1, n_epochs, current_loss / len(trainloader.dataset)))
# Out:
# Epoch : 1/2000, Train Loss : 6744.895, Valid Loss 783.600, MAE 27.136, Corr 0.023566
# Best Valid Loss 783.6002
# Epoch : 2/2000, Train Loss : 587.428, Valid Loss 352.932, MAE 12.824, Corr 0.064475
# Best Valid Loss 352.9320
# Epoch : 3/2000, Train Loss : 277.999, Valid Loss 253.815, MAE 11.697, Corr 0.087255
# Best Valid Loss 253.8146
# Epoch : 4/2000, Train Loss : 237.259, Valid Loss 251.216, MAE 11.707, Corr 0.104823
# Best Valid Loss 251.2164
# Epoch : 5/2000, Train Loss : 236.936, Valid Loss 241.139, MAE 11.785, Corr 0.120193
# Best Valid Loss 241.1391
# Epoch : 6/2000, Train Loss : 232.600, Valid Loss 232.550, MAE 12.672, Corr 0.133611
# Best Valid Loss 232.5495
# Epoch : 7/2000, Train Loss : 230.153, Valid Loss 275.914, MAE 11.903, Corr 0.146945
# Epoch : 8/2000, Train Loss : 231.031, Valid Loss 231.505, MAE 12.859, Corr 0.159554
# Best Valid Loss 231.5050
# Epoch : 9/2000, Train Loss : 221.526, Valid Loss 226.479, MAE 11.948, Corr 0.175167
# Best Valid Loss 226.4786
# Epoch : 10/2000, Train Loss : 222.522, Valid Loss 225.760, MAE 11.767, Corr 0.192271
# Best Valid Loss 225.7599
# Epoch : 11/2000, Train Loss : 214.143, Valid Loss 228.146, MAE 11.569, Corr 0.210753
# Epoch : 12/2000, Train Loss : 212.848, Valid Loss 218.199, MAE 11.572, Corr 0.234167
# Best Valid Loss 218.1989
# Epoch : 13/2000, Train Loss : 207.681, Valid Loss 210.766, MAE 11.893, Corr 0.259454
# Best Valid Loss 210.7660
# Epoch : 14/2000, Train Loss : 211.227, Valid Loss 208.220, MAE 11.213, Corr 0.286242
# Best Valid Loss 208.2205
# Epoch : 15/2000, Train Loss : 196.616, Valid Loss 200.925, MAE 11.767, Corr 0.323627
# Best Valid Loss 200.9251
# Epoch : 16/2000, Train Loss : 198.470, Valid Loss 196.034, MAE 11.739, Corr 0.356901
# Best Valid Loss 196.0336
# Epoch : 17/2000, Train Loss : 186.649, Valid Loss 184.115, MAE 10.770, Corr 0.388844
# Best Valid Loss 184.1148
# Epoch : 18/2000, Train Loss : 175.865, Valid Loss 181.582, MAE 11.381, Corr 0.421346
# Best Valid Loss 181.5823
# Epoch : 19/2000, Train Loss : 171.884, Valid Loss 192.154, MAE 12.569, Corr 0.447589
# Epoch : 20/2000, Train Loss : 165.788, Valid Loss 160.230, MAE 10.863, Corr 0.466637
# Best Valid Loss 160.2300
# Epoch : 21/2000, Train Loss : 145.629, Valid Loss 159.617, MAE 9.950, Corr 0.518745
# Best Valid Loss 159.6174
# Epoch : 22/2000, Train Loss : 138.192, Valid Loss 133.208, MAE 9.903, Corr 0.555838
# Best Valid Loss 133.2077
# Epoch : 23/2000, Train Loss : 119.939, Valid Loss 115.577, MAE 9.497, Corr 0.612369
# Best Valid Loss 115.5771
# Epoch : 24/2000, Train Loss : 113.190, Valid Loss 152.650, MAE 11.373, Corr 0.655770
# Epoch : 25/2000, Train Loss : 121.585, Valid Loss 89.469, MAE 8.453, Corr 0.701922
# Best Valid Loss 89.4695
# Epoch : 26/2000, Train Loss : 82.158, Valid Loss 77.805, MAE 7.700, Corr 0.744860
# Best Valid Loss 77.8047
# Epoch : 27/2000, Train Loss : 71.672, Valid Loss 84.706, MAE 8.276, Corr 0.792568
# Epoch : 28/2000, Train Loss : 71.657, Valid Loss 63.737, MAE 6.874, Corr 0.819042
# Best Valid Loss 63.7373
# Epoch : 29/2000, Train Loss : 55.565, Valid Loss 53.404, MAE 6.081, Corr 0.844920
# Best Valid Loss 53.4043
# Epoch : 30/2000, Train Loss : 52.572, Valid Loss 48.425, MAE 5.794, Corr 0.865747
# Best Valid Loss 48.4250
# Epoch : 31/2000, Train Loss : 49.589, Valid Loss 55.434, MAE 6.154, Corr 0.879980
# Epoch : 32/2000, Train Loss : 55.003, Valid Loss 74.189, MAE 7.143, Corr 0.883164
# Epoch : 33/2000, Train Loss : 57.328, Valid Loss 49.911, MAE 5.577, Corr 0.898312
# Epoch : 34/2000, Train Loss : 49.337, Valid Loss 44.001, MAE 5.133, Corr 0.902257
# Best Valid Loss 44.0009
# Epoch : 35/2000, Train Loss : 50.470, Valid Loss 45.353, MAE 5.418, Corr 0.905634
# Epoch : 36/2000, Train Loss : 40.706, Valid Loss 52.369, MAE 5.355, Corr 0.909125
# Epoch : 37/2000, Train Loss : 68.669, Valid Loss 124.212, MAE 9.902, Corr 0.911326
# Epoch : 38/2000, Train Loss : 61.610, Valid Loss 42.698, MAE 5.262, Corr 0.902754
# Best Valid Loss 42.6982
# Epoch : 39/2000, Train Loss : 40.519, Valid Loss 55.417, MAE 5.671, Corr 0.909057
# Epoch : 40/2000, Train Loss : 44.045, Valid Loss 44.758, MAE 5.284, Corr 0.920325
# Epoch : 41/2000, Train Loss : 40.325, Valid Loss 48.437, MAE 4.941, Corr 0.923311
# Epoch : 42/2000, Train Loss : 43.240, Valid Loss 38.707, MAE 4.370, Corr 0.927914
# Best Valid Loss 38.7065
# Epoch : 43/2000, Train Loss : 39.615, Valid Loss 36.690, MAE 4.528, Corr 0.929612
# Best Valid Loss 36.6899
# Epoch : 44/2000, Train Loss : 37.356, Valid Loss 35.946, MAE 4.634, Corr 0.934007
# Best Valid Loss 35.9461
# Epoch : 45/2000, Train Loss : 34.862, Valid Loss 41.922, MAE 4.367, Corr 0.936084
# Epoch : 46/2000, Train Loss : 45.215, Valid Loss 37.968, MAE 4.743, Corr 0.937558
# Epoch : 47/2000, Train Loss : 37.486, Valid Loss 38.387, MAE 4.797, Corr 0.939145
# Epoch : 48/2000, Train Loss : 36.188, Valid Loss 32.595, MAE 3.916, Corr 0.940225
# Best Valid Loss 32.5953
# Epoch : 49/2000, Train Loss : 35.803, Valid Loss 34.685, MAE 4.425, Corr 0.943341
# Epoch : 50/2000, Train Loss : 36.553, Valid Loss 73.404, MAE 6.227, Corr 0.943277
# Epoch : 51/2000, Train Loss : 38.365, Valid Loss 31.927, MAE 3.804, Corr 0.943428
# Best Valid Loss 31.9273
# Epoch : 52/2000, Train Loss : 32.145, Valid Loss 45.801, MAE 4.543, Corr 0.944510
# Epoch : 53/2000, Train Loss : 33.249, Valid Loss 43.900, MAE 4.332, Corr 0.946717
# Epoch : 54/2000, Train Loss : 33.539, Valid Loss 34.885, MAE 3.835, Corr 0.948103
# Epoch : 55/2000, Train Loss : 30.388, Valid Loss 29.452, MAE 3.749, Corr 0.951344
# Best Valid Loss 29.4518
# Epoch : 56/2000, Train Loss : 38.251, Valid Loss 50.635, MAE 4.775, Corr 0.946786
# Epoch : 57/2000, Train Loss : 48.653, Valid Loss 60.395, MAE 5.656, Corr 0.943334
# Epoch : 58/2000, Train Loss : 42.213, Valid Loss 42.373, MAE 5.298, Corr 0.944616
# Epoch : 59/2000, Train Loss : 42.734, Valid Loss 29.315, MAE 3.702, Corr 0.946985
# Best Valid Loss 29.3148
# Epoch : 60/2000, Train Loss : 35.741, Valid Loss 29.869, MAE 3.756, Corr 0.946338
# Epoch : 61/2000, Train Loss : 30.793, Valid Loss 28.652, MAE 3.619, Corr 0.950937
# Best Valid Loss 28.6517
# Epoch : 62/2000, Train Loss : 29.769, Valid Loss 36.159, MAE 3.963, Corr 0.950153
# Epoch : 63/2000, Train Loss : 39.940, Valid Loss 65.398, MAE 5.749, Corr 0.950475
# Epoch : 64/2000, Train Loss : 39.452, Valid Loss 28.736, MAE 3.651, Corr 0.950450
# Epoch : 65/2000, Train Loss : 29.293, Valid Loss 28.369, MAE 3.664, Corr 0.951266
# Best Valid Loss 28.3691
# Epoch : 66/2000, Train Loss : 30.828, Valid Loss 34.895, MAE 4.685, Corr 0.951693
# Epoch : 67/2000, Train Loss : 27.912, Valid Loss 33.929, MAE 3.733, Corr 0.955350
# Epoch : 68/2000, Train Loss : 29.701, Valid Loss 28.557, MAE 3.460, Corr 0.954419
# Epoch : 69/2000, Train Loss : 31.826, Valid Loss 27.338, MAE 3.627, Corr 0.952796
# Best Valid Loss 27.3376
# Epoch : 70/2000, Train Loss : 29.444, Valid Loss 26.895, MAE 3.432, Corr 0.956169
# Best Valid Loss 26.8955
# Epoch : 71/2000, Train Loss : 27.669, Valid Loss 27.336, MAE 3.577, Corr 0.958013
# Epoch : 72/2000, Train Loss : 34.696, Valid Loss 28.063, MAE 3.663, Corr 0.955421
# Epoch : 73/2000, Train Loss : 26.892, Valid Loss 40.978, MAE 5.573, Corr 0.957345
# Epoch : 74/2000, Train Loss : 30.935, Valid Loss 26.298, MAE 3.407, Corr 0.959096
# Best Valid Loss 26.2982
# Epoch : 75/2000, Train Loss : 28.150, Valid Loss 29.477, MAE 4.012, Corr 0.955479
# Epoch : 76/2000, Train Loss : 26.118, Valid Loss 26.937, MAE 3.436, Corr 0.958515
# Epoch : 77/2000, Train Loss : 29.289, Valid Loss 30.168, MAE 3.798, Corr 0.950026
# Epoch : 78/2000, Train Loss : 36.103, Valid Loss 31.762, MAE 4.523, Corr 0.953113
# Epoch : 79/2000, Train Loss : 32.894, Valid Loss 36.181, MAE 4.080, Corr 0.952842
# Epoch : 80/2000, Train Loss : 26.573, Valid Loss 25.843, MAE 3.422, Corr 0.955090
# Best Valid Loss 25.8433
# Epoch : 81/2000, Train Loss : 35.241, Valid Loss 29.270, MAE 4.023, Corr 0.953337
# Epoch : 82/2000, Train Loss : 27.602, Valid Loss 42.110, MAE 5.599, Corr 0.956913
# Epoch : 83/2000, Train Loss : 31.527, Valid Loss 38.716, MAE 5.403, Corr 0.958012
# Epoch : 84/2000, Train Loss : 35.231, Valid Loss 29.699, MAE 4.227, Corr 0.952700
# Epoch : 85/2000, Train Loss : 45.840, Valid Loss 42.529, MAE 4.508, Corr 0.955664
# Epoch : 86/2000, Train Loss : 31.669, Valid Loss 26.251, MAE 3.574, Corr 0.950290
# Epoch : 87/2000, Train Loss : 35.928, Valid Loss 28.127, MAE 3.609, Corr 0.954715
# Epoch : 88/2000, Train Loss : 30.413, Valid Loss 25.958, MAE 3.385, Corr 0.951393
# Epoch : 89/2000, Train Loss : 24.939, Valid Loss 26.155, MAE 3.712, Corr 0.957608
# Epoch : 90/2000, Train Loss : 24.857, Valid Loss 38.222, MAE 5.400, Corr 0.957677
# Epoch : 91/2000, Train Loss : 27.200, Valid Loss 49.159, MAE 6.440, Corr 0.959607
# Epoch : 92/2000, Train Loss : 43.711, Valid Loss 64.878, MAE 5.952, Corr 0.950347
# Epoch : 93/2000, Train Loss : 30.474, Valid Loss 25.670, MAE 3.469, Corr 0.958812
# Best Valid Loss 25.6699
# Epoch : 94/2000, Train Loss : 39.625, Valid Loss 48.122, MAE 6.163, Corr 0.946228
# Epoch : 95/2000, Train Loss : 34.286, Valid Loss 36.172, MAE 5.120, Corr 0.956447
# Epoch : 96/2000, Train Loss : 26.281, Valid Loss 30.288, MAE 4.491, Corr 0.957653
# Epoch : 97/2000, Train Loss : 24.872, Valid Loss 32.143, MAE 4.685, Corr 0.957510
# Epoch : 98/2000, Train Loss : 27.318, Valid Loss 39.347, MAE 4.230, Corr 0.957136
# Epoch : 99/2000, Train Loss : 33.539, Valid Loss 25.561, MAE 3.487, Corr 0.959481
# Best Valid Loss 25.5605
# Epoch : 100/2000, Train Loss : 25.320, Valid Loss 24.169, MAE 3.482, Corr 0.954729
# Best Valid Loss 24.1693
# Epoch : 101/2000, Train Loss : 32.377, Valid Loss 35.222, MAE 4.997, Corr 0.961114
# Epoch : 102/2000, Train Loss : 25.851, Valid Loss 26.745, MAE 3.489, Corr 0.959421
# Epoch : 103/2000, Train Loss : 23.193, Valid Loss 23.260, MAE 3.273, Corr 0.959431
# Best Valid Loss 23.2601
# Epoch : 104/2000, Train Loss : 29.956, Valid Loss 23.821, MAE 3.276, Corr 0.962408
# Epoch : 105/2000, Train Loss : 25.022, Valid Loss 24.885, MAE 3.568, Corr 0.954746
# Epoch : 106/2000, Train Loss : 30.628, Valid Loss 55.243, MAE 6.721, Corr 0.959020
# Epoch : 107/2000, Train Loss : 33.067, Valid Loss 28.276, MAE 3.403, Corr 0.958814
# Epoch : 108/2000, Train Loss : 25.203, Valid Loss 22.728, MAE 3.203, Corr 0.959747
# Best Valid Loss 22.7278
# Epoch : 109/2000, Train Loss : 32.445, Valid Loss 27.992, MAE 4.301, Corr 0.961908
# Epoch : 110/2000, Train Loss : 25.144, Valid Loss 22.811, MAE 3.280, Corr 0.959348
# Epoch : 111/2000, Train Loss : 30.143, Valid Loss 30.493, MAE 3.802, Corr 0.959047
# Epoch : 112/2000, Train Loss : 34.062, Valid Loss 36.535, MAE 5.276, Corr 0.956511
# Epoch : 113/2000, Train Loss : 25.132, Valid Loss 24.971, MAE 3.851, Corr 0.959000
# Epoch : 114/2000, Train Loss : 27.370, Valid Loss 41.634, MAE 5.714, Corr 0.955526
# Epoch : 115/2000, Train Loss : 27.440, Valid Loss 22.636, MAE 3.392, Corr 0.961112
# Best Valid Loss 22.6363
# Epoch : 116/2000, Train Loss : 22.271, Valid Loss 35.510, MAE 3.966, Corr 0.956832
# Epoch : 117/2000, Train Loss : 32.651, Valid Loss 40.764, MAE 5.573, Corr 0.957707
# Epoch : 118/2000, Train Loss : 25.272, Valid Loss 23.145, MAE 3.531, Corr 0.958874
# Epoch : 119/2000, Train Loss : 22.017, Valid Loss 26.145, MAE 4.128, Corr 0.963525
# Epoch : 120/2000, Train Loss : 54.972, Valid Loss 26.600, MAE 3.940, Corr 0.958085
# Epoch : 121/2000, Train Loss : 42.242, Valid Loss 37.245, MAE 5.325, Corr 0.957780
# Epoch : 122/2000, Train Loss : 25.803, Valid Loss 42.889, MAE 5.955, Corr 0.960340
# Epoch : 123/2000, Train Loss : 28.588, Valid Loss 26.444, MAE 3.469, Corr 0.951157
# Epoch : 124/2000, Train Loss : 23.178, Valid Loss 34.690, MAE 4.050, Corr 0.957116
# Epoch : 125/2000, Train Loss : 30.849, Valid Loss 20.901, MAE 3.172, Corr 0.961390
# Best Valid Loss 20.9010
# Epoch : 126/2000, Train Loss : 22.378, Valid Loss 23.890, MAE 3.345, Corr 0.961647
# Epoch : 127/2000, Train Loss : 25.647, Valid Loss 21.250, MAE 3.250, Corr 0.963395
# Epoch : 128/2000, Train Loss : 24.598, Valid Loss 24.440, MAE 3.445, Corr 0.957743
# Epoch : 129/2000, Train Loss : 21.894, Valid Loss 25.887, MAE 4.147, Corr 0.964080
# Epoch : 130/2000, Train Loss : 25.076, Valid Loss 26.056, MAE 3.599, Corr 0.963482
# Epoch : 131/2000, Train Loss : 24.032, Valid Loss 25.040, MAE 3.968, Corr 0.960069
# Epoch : 132/2000, Train Loss : 24.887, Valid Loss 20.274, MAE 2.978, Corr 0.964804
# Best Valid Loss 20.2737
# Epoch : 133/2000, Train Loss : 35.052, Valid Loss 22.453, MAE 3.318, Corr 0.956913
# Epoch : 134/2000, Train Loss : 32.924, Valid Loss 53.966, MAE 5.325, Corr 0.958911
# Epoch : 135/2000, Train Loss : 28.533, Valid Loss 29.849, MAE 3.735, Corr 0.960362
# Epoch : 136/2000, Train Loss : 20.854, Valid Loss 19.949, MAE 3.074, Corr 0.965779
# Best Valid Loss 19.9489
# Epoch : 137/2000, Train Loss : 28.824, Valid Loss 21.993, MAE 3.171, Corr 0.954807
# Epoch : 138/2000, Train Loss : 31.126, Valid Loss 44.330, MAE 4.595, Corr 0.964786
# Epoch : 139/2000, Train Loss : 23.063, Valid Loss 23.261, MAE 3.239, Corr 0.957193
# Epoch : 140/2000, Train Loss : 28.635, Valid Loss 20.698, MAE 3.279, Corr 0.962782
# Epoch : 141/2000, Train Loss : 28.682, Valid Loss 27.739, MAE 3.539, Corr 0.958231
# Epoch : 142/2000, Train Loss : 29.108, Valid Loss 21.769, MAE 3.557, Corr 0.958794
# Epoch : 143/2000, Train Loss : 21.561, Valid Loss 20.635, MAE 3.145, Corr 0.963138
# Epoch : 144/2000, Train Loss : 23.012, Valid Loss 20.774, MAE 3.424, Corr 0.961689
# Epoch : 145/2000, Train Loss : 25.702, Valid Loss 19.917, MAE 3.229, Corr 0.967197
# Best Valid Loss 19.9175
# Epoch : 146/2000, Train Loss : 21.530, Valid Loss 24.280, MAE 3.373, Corr 0.966398
# Epoch : 147/2000, Train Loss : 23.144, Valid Loss 43.499, MAE 5.999, Corr 0.961194
# Epoch : 148/2000, Train Loss : 34.667, Valid Loss 20.319, MAE 3.261, Corr 0.956874
# Epoch : 149/2000, Train Loss : 35.672, Valid Loss 29.733, MAE 3.997, Corr 0.959828
# Epoch : 150/2000, Train Loss : 24.346, Valid Loss 21.403, MAE 3.602, Corr 0.962228
# Epoch : 151/2000, Train Loss : 23.709, Valid Loss 19.033, MAE 3.148, Corr 0.962779
# Best Valid Loss 19.0334
# Epoch : 152/2000, Train Loss : 22.381, Valid Loss 19.030, MAE 3.107, Corr 0.966239
# Best Valid Loss 19.0301
# Epoch : 153/2000, Train Loss : 20.558, Valid Loss 19.390, MAE 3.021, Corr 0.964267
# Epoch : 154/2000, Train Loss : 20.297, Valid Loss 19.255, MAE 3.255, Corr 0.964953
# Epoch : 155/2000, Train Loss : 23.192, Valid Loss 18.498, MAE 3.185, Corr 0.966513
# Best Valid Loss 18.4983
# Epoch : 156/2000, Train Loss : 23.432, Valid Loss 20.572, MAE 3.170, Corr 0.963098
# Epoch : 157/2000, Train Loss : 25.076, Valid Loss 43.200, MAE 6.055, Corr 0.963676
# Epoch : 158/2000, Train Loss : 21.411, Valid Loss 20.032, MAE 3.137, Corr 0.963137
# Epoch : 159/2000, Train Loss : 21.766, Valid Loss 17.646, MAE 2.964, Corr 0.965558
# Best Valid Loss 17.6462
# Epoch : 160/2000, Train Loss : 21.916, Valid Loss 50.763, MAE 6.606, Corr 0.968615
# Epoch : 161/2000, Train Loss : 43.850, Valid Loss 65.429, MAE 6.187, Corr 0.963130
# Epoch : 162/2000, Train Loss : 37.357, Valid Loss 28.789, MAE 4.497, Corr 0.970244
# Epoch : 163/2000, Train Loss : 21.933, Valid Loss 17.453, MAE 2.957, Corr 0.966879
# Best Valid Loss 17.4527
# Epoch : 164/2000, Train Loss : 18.390, Valid Loss 41.301, MAE 4.525, Corr 0.968799
# Epoch : 165/2000, Train Loss : 20.529, Valid Loss 17.936, MAE 3.106, Corr 0.968212
# Epoch : 166/2000, Train Loss : 23.179, Valid Loss 18.106, MAE 3.003, Corr 0.967338
# Epoch : 167/2000, Train Loss : 25.128, Valid Loss 30.729, MAE 3.834, Corr 0.966890
# Epoch : 168/2000, Train Loss : 19.088, Valid Loss 17.790, MAE 3.004, Corr 0.970874
# Epoch : 169/2000, Train Loss : 17.223, Valid Loss 19.392, MAE 3.377, Corr 0.967608
# Epoch : 170/2000, Train Loss : 18.727, Valid Loss 24.708, MAE 3.521, Corr 0.967551
# Epoch : 171/2000, Train Loss : 18.017, Valid Loss 18.796, MAE 3.252, Corr 0.966892
# Epoch : 172/2000, Train Loss : 24.591, Valid Loss 43.240, MAE 4.538, Corr 0.969057
# Epoch : 173/2000, Train Loss : 20.624, Valid Loss 17.172, MAE 3.026, Corr 0.965995
# Best Valid Loss 17.1718
# Epoch : 174/2000, Train Loss : 18.134, Valid Loss 21.927, MAE 3.347, Corr 0.969800
# Epoch : 175/2000, Train Loss : 20.119, Valid Loss 18.381, MAE 3.014, Corr 0.968894
# Epoch : 176/2000, Train Loss : 21.225, Valid Loss 26.430, MAE 4.293, Corr 0.970680
# Epoch : 177/2000, Train Loss : 19.764, Valid Loss 35.059, MAE 5.251, Corr 0.969948
# Epoch : 178/2000, Train Loss : 19.663, Valid Loss 23.389, MAE 4.004, Corr 0.967554
# Epoch : 179/2000, Train Loss : 21.237, Valid Loss 17.020, MAE 3.094, Corr 0.965865
# Best Valid Loss 17.0197
# Epoch : 180/2000, Train Loss : 23.520, Valid Loss 36.972, MAE 4.554, Corr 0.962050
# Epoch : 181/2000, Train Loss : 34.745, Valid Loss 19.056, MAE 3.280, Corr 0.960106
# Epoch : 182/2000, Train Loss : 19.349, Valid Loss 31.695, MAE 4.775, Corr 0.966842
# Epoch : 183/2000, Train Loss : 21.859, Valid Loss 37.264, MAE 4.220, Corr 0.967675
# Epoch : 184/2000, Train Loss : 23.738, Valid Loss 16.722, MAE 3.167, Corr 0.966282
# Best Valid Loss 16.7223
# Epoch : 185/2000, Train Loss : 18.618, Valid Loss 16.151, MAE 2.941, Corr 0.967526
# Best Valid Loss 16.1508
# Epoch : 186/2000, Train Loss : 20.832, Valid Loss 23.660, MAE 3.588, Corr 0.969890
# Epoch : 187/2000, Train Loss : 17.622, Valid Loss 19.616, MAE 3.362, Corr 0.967983
# Epoch : 188/2000, Train Loss : 17.146, Valid Loss 28.146, MAE 4.568, Corr 0.966775
# Epoch : 189/2000, Train Loss : 16.619, Valid Loss 17.995, MAE 3.373, Corr 0.966584
# Epoch : 190/2000, Train Loss : 17.307, Valid Loss 18.805, MAE 3.255, Corr 0.967671
# Epoch : 191/2000, Train Loss : 16.612, Valid Loss 19.992, MAE 3.634, Corr 0.964438
# Epoch : 192/2000, Train Loss : 21.106, Valid Loss 41.109, MAE 4.842, Corr 0.968431
# Epoch : 193/2000, Train Loss : 18.433, Valid Loss 23.320, MAE 4.006, Corr 0.966577
# Epoch : 194/2000, Train Loss : 20.731, Valid Loss 32.060, MAE 4.870, Corr 0.968228
# Epoch : 195/2000, Train Loss : 23.314, Valid Loss 19.306, MAE 3.461, Corr 0.966934
# Epoch : 196/2000, Train Loss : 23.424, Valid Loss 19.287, MAE 3.129, Corr 0.965603
# Epoch : 197/2000, Train Loss : 27.251, Valid Loss 37.170, MAE 5.416, Corr 0.965063
# Epoch : 198/2000, Train Loss : 25.535, Valid Loss 15.146, MAE 2.890, Corr 0.970083
# Best Valid Loss 15.1465
# Epoch : 199/2000, Train Loss : 16.406, Valid Loss 16.214, MAE 2.871, Corr 0.968906
# Epoch : 200/2000, Train Loss : 18.051, Valid Loss 20.117, MAE 3.594, Corr 0.969246
# Epoch : 201/2000, Train Loss : 21.770, Valid Loss 18.459, MAE 3.291, Corr 0.970087
# Epoch : 202/2000, Train Loss : 16.930, Valid Loss 15.064, MAE 2.815, Corr 0.970225
# Best Valid Loss 15.0644
# Epoch : 203/2000, Train Loss : 36.253, Valid Loss 15.461, MAE 2.815, Corr 0.970002
# Epoch : 204/2000, Train Loss : 15.645, Valid Loss 15.802, MAE 2.955, Corr 0.966193
# Epoch : 205/2000, Train Loss : 19.096, Valid Loss 20.383, MAE 3.304, Corr 0.968685
# Epoch : 206/2000, Train Loss : 15.733, Valid Loss 17.125, MAE 3.190, Corr 0.970112
# Epoch : 207/2000, Train Loss : 14.954, Valid Loss 14.879, MAE 2.766, Corr 0.972764
# Best Valid Loss 14.8786
# Epoch : 208/2000, Train Loss : 17.392, Valid Loss 14.868, MAE 2.927, Corr 0.969645
# Best Valid Loss 14.8677
# Epoch : 209/2000, Train Loss : 16.346, Valid Loss 16.308, MAE 3.012, Corr 0.970792
# Epoch : 210/2000, Train Loss : 17.723, Valid Loss 25.515, MAE 4.189, Corr 0.970337
# Epoch : 211/2000, Train Loss : 37.711, Valid Loss 25.397, MAE 4.366, Corr 0.957730
# Epoch : 212/2000, Train Loss : 24.957, Valid Loss 15.464, MAE 2.955, Corr 0.968045
# Epoch : 213/2000, Train Loss : 18.068, Valid Loss 14.637, MAE 2.887, Corr 0.971654
# Best Valid Loss 14.6375
# Epoch : 214/2000, Train Loss : 14.253, Valid Loss 19.489, MAE 3.489, Corr 0.973301
# Epoch : 215/2000, Train Loss : 21.070, Valid Loss 18.183, MAE 3.235, Corr 0.967405
# Epoch : 216/2000, Train Loss : 19.173, Valid Loss 35.087, MAE 5.044, Corr 0.965420
# Epoch : 217/2000, Train Loss : 21.286, Valid Loss 23.538, MAE 3.939, Corr 0.972953
# Epoch : 218/2000, Train Loss : 15.609, Valid Loss 15.306, MAE 2.738, Corr 0.971209
# Epoch : 219/2000, Train Loss : 14.885, Valid Loss 15.766, MAE 2.994, Corr 0.968659
# Epoch : 220/2000, Train Loss : 15.322, Valid Loss 20.327, MAE 3.390, Corr 0.970719
# Epoch : 221/2000, Train Loss : 19.021, Valid Loss 15.429, MAE 2.830, Corr 0.971602
# Epoch : 222/2000, Train Loss : 15.292, Valid Loss 14.314, MAE 2.732, Corr 0.972436
# Best Valid Loss 14.3143
# Epoch : 223/2000, Train Loss : 18.309, Valid Loss 14.605, MAE 2.772, Corr 0.971709
# Epoch : 224/2000, Train Loss : 16.747, Valid Loss 23.221, MAE 3.951, Corr 0.970281
# Epoch : 225/2000, Train Loss : 15.336, Valid Loss 16.324, MAE 3.101, Corr 0.973058
# Epoch : 226/2000, Train Loss : 19.285, Valid Loss 15.461, MAE 2.902, Corr 0.971128
# Epoch : 227/2000, Train Loss : 40.001, Valid Loss 15.570, MAE 3.022, Corr 0.968851
# Epoch : 228/2000, Train Loss : 25.542, Valid Loss 23.560, MAE 3.586, Corr 0.965521
# Epoch : 229/2000, Train Loss : 15.203, Valid Loss 21.509, MAE 3.356, Corr 0.969768
# Epoch : 230/2000, Train Loss : 17.352, Valid Loss 22.762, MAE 3.585, Corr 0.972668
# Epoch : 231/2000, Train Loss : 18.631, Valid Loss 17.946, MAE 3.413, Corr 0.970197
# Epoch : 232/2000, Train Loss : 16.181, Valid Loss 16.001, MAE 3.047, Corr 0.972538
# Epoch : 233/2000, Train Loss : 14.727, Valid Loss 13.348, MAE 2.879, Corr 0.971841
# Best Valid Loss 13.3480
# Epoch : 234/2000, Train Loss : 15.393, Valid Loss 15.992, MAE 3.093, Corr 0.970370
# Epoch : 235/2000, Train Loss : 13.866, Valid Loss 19.523, MAE 3.555, Corr 0.967744
# Epoch : 236/2000, Train Loss : 23.006, Valid Loss 39.778, MAE 5.191, Corr 0.971164
# Epoch : 237/2000, Train Loss : 19.059, Valid Loss 18.175, MAE 3.380, Corr 0.967620
# Epoch : 238/2000, Train Loss : 21.940, Valid Loss 29.467, MAE 4.301, Corr 0.966600
# Epoch : 239/2000, Train Loss : 16.871, Valid Loss 24.149, MAE 3.706, Corr 0.974307
# Epoch : 240/2000, Train Loss : 24.085, Valid Loss 17.872, MAE 3.046, Corr 0.973327
# Epoch : 241/2000, Train Loss : 16.198, Valid Loss 29.022, MAE 4.519, Corr 0.974075
# Epoch : 242/2000, Train Loss : 18.027, Valid Loss 18.974, MAE 3.623, Corr 0.970213
# Epoch : 243/2000, Train Loss : 20.494, Valid Loss 50.795, MAE 6.461, Corr 0.972999
# Epoch : 244/2000, Train Loss : 18.195, Valid Loss 14.420, MAE 2.851, Corr 0.972779
# Epoch : 245/2000, Train Loss : 20.032, Valid Loss 13.958, MAE 3.055, Corr 0.971702
# Epoch : 246/2000, Train Loss : 15.969, Valid Loss 13.193, MAE 2.755, Corr 0.973492
# Best Valid Loss 13.1931
# Epoch : 247/2000, Train Loss : 13.166, Valid Loss 20.369, MAE 3.379, Corr 0.969776
# Epoch : 248/2000, Train Loss : 13.202, Valid Loss 12.716, MAE 2.776, Corr 0.972285
# Best Valid Loss 12.7164
# Epoch : 249/2000, Train Loss : 12.093, Valid Loss 12.692, MAE 2.846, Corr 0.971005
# Best Valid Loss 12.6922
# Epoch : 250/2000, Train Loss : 12.641, Valid Loss 13.202, MAE 2.947, Corr 0.968684
# Epoch : 251/2000, Train Loss : 14.839, Valid Loss 28.163, MAE 4.312, Corr 0.969380
# Epoch : 252/2000, Train Loss : 31.108, Valid Loss 18.030, MAE 3.314, Corr 0.968620
# Epoch : 253/2000, Train Loss : 14.947, Valid Loss 13.191, MAE 2.710, Corr 0.972701
# Epoch : 254/2000, Train Loss : 17.213, Valid Loss 15.654, MAE 3.103, Corr 0.970728
# Epoch : 255/2000, Train Loss : 16.859, Valid Loss 12.818, MAE 2.880, Corr 0.972479
# Epoch : 256/2000, Train Loss : 19.404, Valid Loss 33.949, MAE 4.778, Corr 0.973285
# Epoch : 257/2000, Train Loss : 18.660, Valid Loss 13.198, MAE 2.848, Corr 0.970466
# Epoch : 258/2000, Train Loss : 13.470, Valid Loss 21.523, MAE 3.733, Corr 0.971381
# Epoch : 259/2000, Train Loss : 12.967, Valid Loss 13.782, MAE 2.991, Corr 0.971273
# Epoch : 260/2000, Train Loss : 12.836, Valid Loss 16.978, MAE 3.187, Corr 0.971762
# Epoch : 261/2000, Train Loss : 13.262, Valid Loss 18.435, MAE 3.415, Corr 0.971860
# Epoch : 262/2000, Train Loss : 14.350, Valid Loss 21.775, MAE 3.778, Corr 0.968313
# Epoch : 263/2000, Train Loss : 20.655, Valid Loss 23.973, MAE 3.819, Corr 0.974405
# Epoch : 264/2000, Train Loss : 17.906, Valid Loss 21.039, MAE 3.462, Corr 0.965149
# Epoch : 265/2000, Train Loss : 16.603, Valid Loss 15.333, MAE 3.094, Corr 0.971259
# Epoch : 266/2000, Train Loss : 18.861, Valid Loss 16.474, MAE 3.189, Corr 0.974132
# Epoch : 267/2000, Train Loss : 16.467, Valid Loss 26.297, MAE 4.098, Corr 0.972380
# Epoch : 268/2000, Train Loss : 22.968, Valid Loss 13.092, MAE 2.830, Corr 0.970899
# Epoch : 269/2000, Train Loss : 16.698, Valid Loss 38.155, MAE 4.976, Corr 0.974503
# Epoch : 270/2000, Train Loss : 17.034, Valid Loss 12.239, MAE 2.624, Corr 0.973870
# Best Valid Loss 12.2385
# Epoch : 271/2000, Train Loss : 12.380, Valid Loss 12.942, MAE 3.082, Corr 0.967513
# Epoch : 272/2000, Train Loss : 12.272, Valid Loss 15.239, MAE 3.024, Corr 0.976655
# Epoch : 273/2000, Train Loss : 13.202, Valid Loss 12.237, MAE 2.854, Corr 0.972502
# Best Valid Loss 12.2371
# Epoch : 274/2000, Train Loss : 13.709, Valid Loss 29.515, MAE 4.274, Corr 0.969867
# Epoch : 275/2000, Train Loss : 18.854, Valid Loss 12.402, MAE 2.896, Corr 0.971727
# Epoch : 276/2000, Train Loss : 24.460, Valid Loss 17.168, MAE 3.462, Corr 0.971496
# Epoch : 277/2000, Train Loss : 32.902, Valid Loss 17.664, MAE 3.156, Corr 0.965767
# Epoch : 278/2000, Train Loss : 18.334, Valid Loss 11.990, MAE 2.938, Corr 0.971612
# Best Valid Loss 11.9903
# Epoch : 279/2000, Train Loss : 11.093, Valid Loss 13.659, MAE 2.955, Corr 0.974177
# Epoch : 280/2000, Train Loss : 12.522, Valid Loss 12.123, MAE 2.749, Corr 0.972369
# Epoch : 281/2000, Train Loss : 10.862, Valid Loss 12.064, MAE 2.591, Corr 0.973861
# Epoch : 282/2000, Train Loss : 11.316, Valid Loss 14.193, MAE 3.021, Corr 0.973361
# Epoch : 283/2000, Train Loss : 14.385, Valid Loss 18.436, MAE 3.491, Corr 0.972658
# Epoch : 284/2000, Train Loss : 20.381, Valid Loss 15.081, MAE 2.940, Corr 0.974059
# Epoch : 285/2000, Train Loss : 28.164, Valid Loss 21.842, MAE 3.586, Corr 0.971382
# Epoch : 286/2000, Train Loss : 22.991, Valid Loss 37.562, MAE 4.809, Corr 0.972219
# Epoch : 287/2000, Train Loss : 15.528, Valid Loss 12.260, MAE 2.554, Corr 0.975452
# Epoch : 288/2000, Train Loss : 12.815, Valid Loss 17.815, MAE 3.353, Corr 0.975585
# Epoch : 289/2000, Train Loss : 12.193, Valid Loss 12.762, MAE 2.963, Corr 0.972539
# Epoch : 290/2000, Train Loss : 13.592, Valid Loss 11.745, MAE 2.897, Corr 0.971774
# Best Valid Loss 11.7451
# Epoch : 291/2000, Train Loss : 12.545, Valid Loss 11.583, MAE 2.677, Corr 0.973937
# Best Valid Loss 11.5829
# Epoch : 292/2000, Train Loss : 17.545, Valid Loss 40.911, MAE 5.680, Corr 0.973544
# Epoch : 293/2000, Train Loss : 18.669, Valid Loss 18.470, MAE 3.373, Corr 0.977691
# Epoch : 294/2000, Train Loss : 16.302, Valid Loss 23.677, MAE 4.055, Corr 0.971168
# Epoch : 295/2000, Train Loss : 25.851, Valid Loss 14.034, MAE 3.311, Corr 0.967832
# Epoch : 296/2000, Train Loss : 14.143, Valid Loss 11.624, MAE 2.864, Corr 0.974066
# Epoch : 297/2000, Train Loss : 15.193, Valid Loss 16.137, MAE 3.090, Corr 0.975938
# Epoch : 298/2000, Train Loss : 14.882, Valid Loss 15.683, MAE 3.209, Corr 0.973573
# Epoch : 299/2000, Train Loss : 12.506, Valid Loss 13.591, MAE 2.990, Corr 0.971580
# Epoch : 300/2000, Train Loss : 12.289, Valid Loss 12.677, MAE 2.824, Corr 0.973766
# Epoch : 301/2000, Train Loss : 11.529, Valid Loss 12.069, MAE 2.651, Corr 0.975935
# Epoch : 302/2000, Train Loss : 13.439, Valid Loss 11.281, MAE 2.772, Corr 0.972025
# Best Valid Loss 11.2808
# Epoch : 303/2000, Train Loss : 14.070, Valid Loss 13.798, MAE 2.938, Corr 0.972598
# Epoch : 304/2000, Train Loss : 20.075, Valid Loss 13.170, MAE 2.622, Corr 0.972430
# Epoch : 305/2000, Train Loss : 14.999, Valid Loss 11.506, MAE 2.551, Corr 0.976093
# Epoch : 306/2000, Train Loss : 14.770, Valid Loss 16.841, MAE 3.323, Corr 0.972249
# Epoch : 307/2000, Train Loss : 12.250, Valid Loss 11.350, MAE 2.530, Corr 0.975933
# Epoch : 308/2000, Train Loss : 14.763, Valid Loss 41.083, MAE 5.464, Corr 0.964414
# Epoch : 309/2000, Train Loss : 18.925, Valid Loss 29.962, MAE 4.235, Corr 0.976278
# Epoch : 310/2000, Train Loss : 19.176, Valid Loss 23.349, MAE 3.932, Corr 0.973100
# Epoch : 311/2000, Train Loss : 17.511, Valid Loss 19.607, MAE 3.219, Corr 0.974101
# Epoch : 312/2000, Train Loss : 11.016, Valid Loss 21.160, MAE 3.503, Corr 0.977946
# Epoch : 313/2000, Train Loss : 12.830, Valid Loss 10.596, MAE 2.744, Corr 0.976224
# Best Valid Loss 10.5957
# Epoch : 314/2000, Train Loss : 10.269, Valid Loss 11.602, MAE 2.635, Corr 0.976331
# Epoch : 315/2000, Train Loss : 11.248, Valid Loss 12.665, MAE 2.894, Corr 0.974883
# Epoch : 316/2000, Train Loss : 11.057, Valid Loss 11.702, MAE 2.642, Corr 0.975694
# Epoch : 317/2000, Train Loss : 12.157, Valid Loss 14.771, MAE 3.338, Corr 0.972821
# Epoch : 318/2000, Train Loss : 10.278, Valid Loss 12.506, MAE 2.736, Corr 0.976222
# Epoch : 319/2000, Train Loss : 9.726, Valid Loss 10.808, MAE 2.594, Corr 0.976577
# Epoch : 320/2000, Train Loss : 9.711, Valid Loss 10.862, MAE 2.648, Corr 0.976942
# Epoch : 321/2000, Train Loss : 9.554, Valid Loss 12.391, MAE 2.696, Corr 0.974460
# Epoch : 322/2000, Train Loss : 10.001, Valid Loss 11.397, MAE 2.714, Corr 0.973338
# Epoch : 323/2000, Train Loss : 10.048, Valid Loss 15.578, MAE 3.209, Corr 0.973894
# Epoch : 324/2000, Train Loss : 12.345, Valid Loss 10.652, MAE 2.582, Corr 0.974230
# Epoch : 325/2000, Train Loss : 12.691, Valid Loss 22.889, MAE 3.931, Corr 0.976294
# Epoch : 326/2000, Train Loss : 15.028, Valid Loss 11.522, MAE 2.908, Corr 0.970713
# Epoch : 327/2000, Train Loss : 10.774, Valid Loss 14.691, MAE 3.199, Corr 0.973824
# Epoch : 328/2000, Train Loss : 9.399, Valid Loss 11.851, MAE 2.794, Corr 0.973054
# Epoch : 329/2000, Train Loss : 9.235, Valid Loss 11.092, MAE 2.573, Corr 0.979199
# Epoch : 330/2000, Train Loss : 10.531, Valid Loss 11.711, MAE 2.729, Corr 0.976873
# Epoch : 331/2000, Train Loss : 11.641, Valid Loss 10.772, MAE 2.664, Corr 0.975841
# Epoch : 332/2000, Train Loss : 11.907, Valid Loss 11.561, MAE 2.694, Corr 0.976764
# Epoch : 333/2000, Train Loss : 11.736, Valid Loss 12.092, MAE 3.001, Corr 0.972583
# Epoch : 334/2000, Train Loss : 17.455, Valid Loss 14.989, MAE 3.072, Corr 0.975407
# Early stopping
# Best Result : Epoch 313, Valid Loss 10.596, MAE 2.744, Corr 0.976224

# %%
### scatter plot
file_path = "D:\gait_dataset/salted/test/*"
inputs_acc, inputs_gyr, stride_length = get_sensor_salted(file_path, normalization=True)
inputs_acc, inputs_gyr, stride_length = torch.Tensor(np.array(inputs_acc)), torch.Tensor(np.array(inputs_gyr)), torch.Tensor(np.array(stride_length))
inputs_acc, inputs_gyr, stride_length = inputs_acc.float(), inputs_gyr.float(), stride_length.float()
inputs_acc, inputs_gyr = inputs_acc.to(device), inputs_gyr.to(device)

# %%
input_dim = 3
conv1d_dim1 = 16
conv1d_dim2 = 32
dense_dim = 512

model = Encoder(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
model.load_state_dict(torch.load('./model/encoder_1_best_ks30_bias.pth'))
model.eval()
# Out:
# Encoder(
#   (conv1d_acc): Sequential(
#     (0): Conv1d(3, 16, kernel_size=(30,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(30,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (conv1d_gyr): Sequential(
#     (0): Conv1d(3, 16, kernel_size=(30,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(30,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (dense): Sequential(
#     (0): Linear(in_features=15488, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=128, out_features=64, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %%
pred = model(inputs_acc, inputs_gyr).detach().cpu().numpy()

plt.figure(figsize=(10, 10))
plt.scatter(stride_length, np.round(pred, 4))
plt.xlim([80, 200])
plt.xlabel('stride_length')
plt.ylim([80, 200])
plt.ylabel('pred')

xpoints = ypoints = plt.xlim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)

plt.show()

# %% [markdown]
# # Encoder-based Model : 3 node / Conv1d
# - 최종적으로 출력된 노드 3개를 각 축별 distance와 곱

# %% [markdown]
# ## Conv1d
# - Best Result : Epoch 334, Valid Loss 10.259, MAE 2.099, Corr 0.982198

# %% [markdown]
# ### 데이터 불러오기

# %%
device = torch.device('cuda:0' if torch.cuda.is_available else 'cpu')

file_path = "D:\gait_dataset/salted/train/*"
dataset = Gait_Dataset_Salted(file_path, bias=False)
val_percent = 0.2
n_val = int(len(dataset) * val_percent)
n_train = len(dataset) - n_val
train, val = random_split(dataset, [n_train, n_val])

# %%
train_loader = torch.utils.data.DataLoader(train,
                                           batch_size=128,
                                           shuffle=True,
                                           worker_init_fn=np.random.seed(42))
val_loader = torch.utils.data.DataLoader(val,
                                         batch_size=128,
                                         shuffle=False)

# %% [markdown]
# ### Model & Scatter Plot
# - Best Result : Epoch 259, Valid Loss 40.381912, MAE 4.223338

# %%
# seed 고정
random_seed=42
torch.manual_seed(random_seed) # torch 
torch.cuda.manual_seed(random_seed)
torch.cuda.manual_seed_all(random_seed) # if use multi-GPU
torch.backends.cudnn.deterministic = True # cudnn
torch.backends.cudnn.benchmark = False # cudnn
np.random.seed(random_seed) # numpy
random.seed(random_seed) # random

class Encoder_dist(nn.Module):
    def __init__(self, input_dim, conv1d_dim1, conv1d_dim2, dense_dim):
        super(Encoder_dist, self).__init__()
             
        self.conv1d_acc = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 30),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 30),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.conv1d_gyr = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 30),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 30),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.dense = nn.Sequential(
            nn.Linear(7744*2+3, dense_dim),
            nn.ReLU(inplace=True),
            nn.Linear(dense_dim, int(dense_dim/2)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/2), int(dense_dim/4)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/4), int(dense_dim/8)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/8), 1)
        )
        

    def forward(self, inputs_acc, inputs_gyr, inputs_pst): 
        
        conv1d_output_acc = self.conv1d_acc(inputs_acc)
        conv1d_output_gyr = self.conv1d_gyr(inputs_gyr)
        
        enc_output = torch.concat((conv1d_output_acc, conv1d_output_gyr, inputs_pst), 1)
        dense_output = self.dense(enc_output)
        
        return dense_output

# %%
input_dim = 3
conv1d_dim1 = 16
conv1d_dim2 = 32
dense_dim = 512

model = Encoder_dist(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
n_epochs = 2000

criterion = nn.MSELoss()

# %%
# Early Stopping을 위한 변수
best = 1000
converge_cnt = 0
best_MAE = 0
best_corr = 0
best_epoch = 0

# Run Training loop
for epoch in range(0, n_epochs) :
    # Set current loss value 
    tot_trn_loss = 0.0
    
    # Train Mode
    model.train()
    
    # Iterate over the DataLoader for training data 
    for i, data in enumerate(train_loader) :
        inputs_acc, inputs_gyr, stride_length, inputs_pst, _ = data
        inputs_acc, inputs_gyr, stride_length, inputs_pst = inputs_acc.float(), inputs_gyr.float(), stride_length.float(), inputs_pst.float()
        inputs_acc, inputs_gyr, inputs_pst = inputs_acc.to(device), inputs_gyr.to(device), inputs_pst.to(device)
        stride_length = stride_length.reshape(-1, 1)
        stride_length = stride_length.to(device)

        # 순전파 
        outputs = model(inputs_acc, inputs_gyr, inputs_pst)

        # Loss 계산
        loss = criterion(outputs, stride_length)
        
        # 기울기 초기화 
        optimizer.zero_grad()
        # 역전파
        loss.backward()
        # 옵티마이저
        optimizer.step()
        
        # Print statistics
        tot_trn_loss += loss.item()
        
    # Evaluation Mode
    model.eval()
    
    tot_val_loss = 0
    val_epoch_loss = []

    with torch.no_grad() :
        for i, data in enumerate(val_loader):
            inputs_acc, inputs_gyr, stride_length, inputs_pst, _ = data
            inputs_acc, inputs_gyr, stride_length, inputs_pst = inputs_acc.float(), inputs_gyr.float(), stride_length.float(), inputs_pst.float()
            inputs_acc, inputs_gyr, inputs_pst = inputs_acc.to(device), inputs_gyr.to(device), inputs_pst.to(device)
            stride_length = stride_length.reshape(-1, 1)
            stride_length = stride_length.to(device)

            # 순전파 
            outputs = model(inputs_acc, inputs_gyr, inputs_pst)
            
            # Loss 계산
            loss = criterion(outputs, stride_length)
            tot_val_loss += loss.item()            
            

    # Epoch 별 Loss
    trn_loss = tot_trn_loss / len(train_loader)
    val_loss = tot_val_loss / len(val_loader)
    MAE = torch.sum(torch.abs(outputs - stride_length)) / len(stride_length)
    corr = torch.corrcoef(torch.stack([torch.squeeze(stride_length), torch.squeeze(outputs)]))[0, 1]
    
    
    print("Epoch : {}/{}, Train Loss : {:.3f}, Valid Loss {:.3f}, MAE {:.3f}, Corr {:3f}".format(epoch+1, n_epochs,
                                                                                       trn_loss, val_loss,
                                                                                      MAE, corr))
    
    # Early Stopping
    if val_loss < best:
        best = np.mean(val_loss)
        best_MAE = MAE
        best_corr = corr
        best_epoch = epoch+1
        torch.save(model.state_dict(), './model/encoder_dist_best_ks30_nobias.pth')
        print('Best Valid Loss {:.4f}'.format(best))
        converge_cnt = 0
    else:
        converge_cnt += 1
    
    if converge_cnt > 20:
        print('Early stopping')
        print('Best Result : Epoch {}, Valid Loss {:.3f}, MAE {:.3f}, Corr {:3f}'.format(best_epoch, best, best_MAE, best_corr))
        break
    
#     print("Epoch : {}/{} Epoch Loss : {:.6f}".format(epoch+1, n_epochs, current_loss / len(trainloader.dataset)))
# Out:
# Epoch : 1/2000, Train Loss : 8987.468, Valid Loss 2353.477, MAE 48.588, Corr 0.563670
# Epoch : 2/2000, Train Loss : 776.056, Valid Loss 359.209, MAE 13.954, Corr 0.562409
# Best Valid Loss 359.2094
# Epoch : 3/2000, Train Loss : 298.732, Valid Loss 223.246, MAE 12.343, Corr 0.559718
# Best Valid Loss 223.2465
# Epoch : 4/2000, Train Loss : 251.014, Valid Loss 227.042, MAE 12.823, Corr 0.557329
# Epoch : 5/2000, Train Loss : 244.595, Valid Loss 221.578, MAE 12.617, Corr 0.555350
# Best Valid Loss 221.5780
# Epoch : 6/2000, Train Loss : 241.148, Valid Loss 216.157, MAE 12.428, Corr 0.552908
# Best Valid Loss 216.1569
# Epoch : 7/2000, Train Loss : 237.935, Valid Loss 214.774, MAE 12.389, Corr 0.550308
# Best Valid Loss 214.7738
# Epoch : 8/2000, Train Loss : 235.425, Valid Loss 213.999, MAE 12.396, Corr 0.548193
# Best Valid Loss 213.9992
# Epoch : 9/2000, Train Loss : 235.458, Valid Loss 223.228, MAE 12.254, Corr 0.546623
# Epoch : 10/2000, Train Loss : 234.004, Valid Loss 219.029, MAE 12.544, Corr 0.545667
# Epoch : 11/2000, Train Loss : 235.787, Valid Loss 215.739, MAE 12.198, Corr 0.544463
# Epoch : 12/2000, Train Loss : 234.283, Valid Loss 237.619, MAE 13.200, Corr 0.543674
# Epoch : 13/2000, Train Loss : 233.506, Valid Loss 208.545, MAE 12.255, Corr 0.543441
# Best Valid Loss 208.5453
# Epoch : 14/2000, Train Loss : 228.702, Valid Loss 207.353, MAE 12.248, Corr 0.542272
# Best Valid Loss 207.3528
# Epoch : 15/2000, Train Loss : 225.592, Valid Loss 206.308, MAE 12.247, Corr 0.541600
# Best Valid Loss 206.3077
# Epoch : 16/2000, Train Loss : 222.801, Valid Loss 213.835, MAE 12.454, Corr 0.542778
# Epoch : 17/2000, Train Loss : 221.375, Valid Loss 209.756, MAE 12.345, Corr 0.544419
# Epoch : 18/2000, Train Loss : 225.328, Valid Loss 204.195, MAE 12.143, Corr 0.547019
# Best Valid Loss 204.1952
# Epoch : 19/2000, Train Loss : 221.107, Valid Loss 200.660, MAE 12.136, Corr 0.548733
# Best Valid Loss 200.6598
# Epoch : 20/2000, Train Loss : 217.319, Valid Loss 228.817, MAE 12.893, Corr 0.552858
# Epoch : 21/2000, Train Loss : 217.402, Valid Loss 203.437, MAE 12.141, Corr 0.558502
# Epoch : 22/2000, Train Loss : 211.886, Valid Loss 193.967, MAE 11.953, Corr 0.568274
# Best Valid Loss 193.9675
# Epoch : 23/2000, Train Loss : 208.159, Valid Loss 190.697, MAE 11.816, Corr 0.580106
# Best Valid Loss 190.6968
# Epoch : 24/2000, Train Loss : 203.857, Valid Loss 186.777, MAE 11.698, Corr 0.593739
# Best Valid Loss 186.7769
# Epoch : 25/2000, Train Loss : 200.728, Valid Loss 181.853, MAE 11.507, Corr 0.611437
# Best Valid Loss 181.8530
# Epoch : 26/2000, Train Loss : 194.933, Valid Loss 186.440, MAE 11.374, Corr 0.631977
# Epoch : 27/2000, Train Loss : 206.537, Valid Loss 208.296, MAE 12.558, Corr 0.649706
# Epoch : 28/2000, Train Loss : 195.603, Valid Loss 161.265, MAE 10.652, Corr 0.674357
# Best Valid Loss 161.2646
# Epoch : 29/2000, Train Loss : 177.867, Valid Loss 157.257, MAE 10.319, Corr 0.698346
# Best Valid Loss 157.2572
# Epoch : 30/2000, Train Loss : 157.802, Valid Loss 144.143, MAE 9.751, Corr 0.722772
# Best Valid Loss 144.1427
# Epoch : 31/2000, Train Loss : 143.958, Valid Loss 130.351, MAE 9.186, Corr 0.744326
# Best Valid Loss 130.3511
# Epoch : 32/2000, Train Loss : 128.158, Valid Loss 110.276, MAE 8.962, Corr 0.768009
# Best Valid Loss 110.2760
# Epoch : 33/2000, Train Loss : 110.669, Valid Loss 101.577, MAE 9.386, Corr 0.787721
# Best Valid Loss 101.5766
# Epoch : 34/2000, Train Loss : 94.874, Valid Loss 83.527, MAE 8.469, Corr 0.808228
# Best Valid Loss 83.5267
# Epoch : 35/2000, Train Loss : 84.641, Valid Loss 89.474, MAE 9.164, Corr 0.832830
# Epoch : 36/2000, Train Loss : 82.698, Valid Loss 78.409, MAE 7.633, Corr 0.851174
# Best Valid Loss 78.4090
# Epoch : 37/2000, Train Loss : 77.202, Valid Loss 59.449, MAE 7.036, Corr 0.868305
# Best Valid Loss 59.4488
# Epoch : 38/2000, Train Loss : 70.695, Valid Loss 61.209, MAE 6.758, Corr 0.881614
# Epoch : 39/2000, Train Loss : 60.937, Valid Loss 62.188, MAE 6.695, Corr 0.889632
# Epoch : 40/2000, Train Loss : 62.574, Valid Loss 54.798, MAE 6.296, Corr 0.895297
# Best Valid Loss 54.7984
# Epoch : 41/2000, Train Loss : 56.993, Valid Loss 46.515, MAE 6.026, Corr 0.907382
# Best Valid Loss 46.5154
# Epoch : 42/2000, Train Loss : 49.897, Valid Loss 48.093, MAE 5.826, Corr 0.906225
# Epoch : 43/2000, Train Loss : 51.358, Valid Loss 44.221, MAE 5.791, Corr 0.916306
# Best Valid Loss 44.2212
# Epoch : 44/2000, Train Loss : 54.400, Valid Loss 55.390, MAE 6.730, Corr 0.918570
# Epoch : 45/2000, Train Loss : 53.430, Valid Loss 59.293, MAE 6.160, Corr 0.920624
# Epoch : 46/2000, Train Loss : 52.492, Valid Loss 40.030, MAE 5.280, Corr 0.922098
# Best Valid Loss 40.0296
# Epoch : 47/2000, Train Loss : 69.783, Valid Loss 40.952, MAE 5.253, Corr 0.920963
# Epoch : 48/2000, Train Loss : 55.048, Valid Loss 40.503, MAE 5.258, Corr 0.922323
# Epoch : 49/2000, Train Loss : 47.399, Valid Loss 52.702, MAE 5.790, Corr 0.924744
# Epoch : 50/2000, Train Loss : 53.498, Valid Loss 47.737, MAE 6.291, Corr 0.926605
# Epoch : 51/2000, Train Loss : 53.941, Valid Loss 70.043, MAE 6.475, Corr 0.925988
# Epoch : 52/2000, Train Loss : 56.253, Valid Loss 37.974, MAE 5.122, Corr 0.929225
# Best Valid Loss 37.9739
# Epoch : 53/2000, Train Loss : 40.740, Valid Loss 35.821, MAE 5.204, Corr 0.932006
# Best Valid Loss 35.8206
# Epoch : 54/2000, Train Loss : 46.273, Valid Loss 62.079, MAE 7.437, Corr 0.933962
# Epoch : 55/2000, Train Loss : 56.594, Valid Loss 46.631, MAE 6.322, Corr 0.931367
# Epoch : 56/2000, Train Loss : 46.305, Valid Loss 41.599, MAE 5.245, Corr 0.934046
# Epoch : 57/2000, Train Loss : 43.225, Valid Loss 41.078, MAE 5.843, Corr 0.936057
# Epoch : 58/2000, Train Loss : 38.250, Valid Loss 35.495, MAE 5.357, Corr 0.937148
# Best Valid Loss 35.4955
# Epoch : 59/2000, Train Loss : 41.734, Valid Loss 32.732, MAE 4.774, Corr 0.938891
# Best Valid Loss 32.7318
# Epoch : 60/2000, Train Loss : 42.459, Valid Loss 36.994, MAE 5.486, Corr 0.940227
# Epoch : 61/2000, Train Loss : 43.738, Valid Loss 32.332, MAE 5.004, Corr 0.940162
# Best Valid Loss 32.3318
# Epoch : 62/2000, Train Loss : 34.421, Valid Loss 32.062, MAE 5.068, Corr 0.938988
# Best Valid Loss 32.0616
# Epoch : 63/2000, Train Loss : 39.937, Valid Loss 50.864, MAE 6.850, Corr 0.941754
# Epoch : 64/2000, Train Loss : 38.022, Valid Loss 33.529, MAE 5.276, Corr 0.940698
# Epoch : 65/2000, Train Loss : 35.805, Valid Loss 30.134, MAE 4.727, Corr 0.941484
# Best Valid Loss 30.1344
# Epoch : 66/2000, Train Loss : 42.788, Valid Loss 42.676, MAE 5.020, Corr 0.943255
# Epoch : 67/2000, Train Loss : 34.436, Valid Loss 30.140, MAE 4.918, Corr 0.942786
# Epoch : 68/2000, Train Loss : 34.707, Valid Loss 49.144, MAE 5.275, Corr 0.944228
# Epoch : 69/2000, Train Loss : 34.076, Valid Loss 30.201, MAE 5.063, Corr 0.944849
# Epoch : 70/2000, Train Loss : 35.172, Valid Loss 40.301, MAE 6.024, Corr 0.945019
# Epoch : 71/2000, Train Loss : 33.175, Valid Loss 33.039, MAE 4.698, Corr 0.943619
# Epoch : 72/2000, Train Loss : 32.419, Valid Loss 28.168, MAE 4.632, Corr 0.944588
# Best Valid Loss 28.1682
# Epoch : 73/2000, Train Loss : 37.035, Valid Loss 33.289, MAE 4.529, Corr 0.945597
# Epoch : 74/2000, Train Loss : 41.153, Valid Loss 28.231, MAE 4.504, Corr 0.947041
# Epoch : 75/2000, Train Loss : 38.528, Valid Loss 32.267, MAE 4.428, Corr 0.948426
# Epoch : 76/2000, Train Loss : 34.745, Valid Loss 27.005, MAE 4.771, Corr 0.947256
# Best Valid Loss 27.0045
# Epoch : 77/2000, Train Loss : 33.891, Valid Loss 27.455, MAE 4.867, Corr 0.947633
# Epoch : 78/2000, Train Loss : 32.962, Valid Loss 26.845, MAE 4.481, Corr 0.947657
# Best Valid Loss 26.8445
# Epoch : 79/2000, Train Loss : 30.189, Valid Loss 39.611, MAE 6.017, Corr 0.949096
# Epoch : 80/2000, Train Loss : 35.983, Valid Loss 39.447, MAE 4.755, Corr 0.949663
# Epoch : 81/2000, Train Loss : 32.907, Valid Loss 33.272, MAE 5.499, Corr 0.948793
# Epoch : 82/2000, Train Loss : 31.429, Valid Loss 42.099, MAE 6.245, Corr 0.949965
# Epoch : 83/2000, Train Loss : 28.870, Valid Loss 27.606, MAE 4.901, Corr 0.952220
# Epoch : 84/2000, Train Loss : 31.478, Valid Loss 37.246, MAE 5.919, Corr 0.950472
# Epoch : 85/2000, Train Loss : 34.902, Valid Loss 24.700, MAE 4.516, Corr 0.951946
# Best Valid Loss 24.6997
# Epoch : 86/2000, Train Loss : 33.231, Valid Loss 26.313, MAE 4.826, Corr 0.952247
# Epoch : 87/2000, Train Loss : 29.935, Valid Loss 25.275, MAE 4.257, Corr 0.953095
# Epoch : 88/2000, Train Loss : 28.892, Valid Loss 26.287, MAE 4.751, Corr 0.952878
# Epoch : 89/2000, Train Loss : 30.143, Valid Loss 33.755, MAE 4.376, Corr 0.954693
# Epoch : 90/2000, Train Loss : 31.762, Valid Loss 26.855, MAE 4.870, Corr 0.954904
# Epoch : 91/2000, Train Loss : 27.688, Valid Loss 41.086, MAE 6.157, Corr 0.953974
# Epoch : 92/2000, Train Loss : 33.619, Valid Loss 31.828, MAE 4.249, Corr 0.955919
# Epoch : 93/2000, Train Loss : 35.050, Valid Loss 46.634, MAE 6.527, Corr 0.954738
# Epoch : 94/2000, Train Loss : 44.106, Valid Loss 60.768, MAE 7.580, Corr 0.955962
# Epoch : 95/2000, Train Loss : 40.692, Valid Loss 46.304, MAE 6.467, Corr 0.956553
# Epoch : 96/2000, Train Loss : 38.654, Valid Loss 26.515, MAE 4.807, Corr 0.950321
# Epoch : 97/2000, Train Loss : 29.801, Valid Loss 25.054, MAE 4.180, Corr 0.954005
# Epoch : 98/2000, Train Loss : 27.380, Valid Loss 22.700, MAE 4.176, Corr 0.956496
# Best Valid Loss 22.7003
# Epoch : 99/2000, Train Loss : 24.879, Valid Loss 22.645, MAE 4.268, Corr 0.957869
# Best Valid Loss 22.6450
# Epoch : 100/2000, Train Loss : 25.345, Valid Loss 21.900, MAE 3.946, Corr 0.959581
# Best Valid Loss 21.8997
# Epoch : 101/2000, Train Loss : 27.366, Valid Loss 27.180, MAE 4.934, Corr 0.958206
# Epoch : 102/2000, Train Loss : 31.751, Valid Loss 25.138, MAE 3.912, Corr 0.958323
# Epoch : 103/2000, Train Loss : 29.223, Valid Loss 45.415, MAE 4.935, Corr 0.959888
# Epoch : 104/2000, Train Loss : 43.345, Valid Loss 22.098, MAE 3.955, Corr 0.960022
# Epoch : 105/2000, Train Loss : 24.825, Valid Loss 23.748, MAE 3.910, Corr 0.959052
# Epoch : 106/2000, Train Loss : 27.216, Valid Loss 29.705, MAE 4.157, Corr 0.958325
# Epoch : 107/2000, Train Loss : 43.433, Valid Loss 22.317, MAE 3.956, Corr 0.960075
# Epoch : 108/2000, Train Loss : 27.908, Valid Loss 21.496, MAE 4.152, Corr 0.959740
# Best Valid Loss 21.4960
# Epoch : 109/2000, Train Loss : 29.117, Valid Loss 22.643, MAE 3.876, Corr 0.960381
# Epoch : 110/2000, Train Loss : 25.376, Valid Loss 35.514, MAE 5.523, Corr 0.962456
# Epoch : 111/2000, Train Loss : 29.927, Valid Loss 27.295, MAE 4.891, Corr 0.960890
# Epoch : 112/2000, Train Loss : 25.467, Valid Loss 36.074, MAE 5.752, Corr 0.959641
# Epoch : 113/2000, Train Loss : 26.518, Valid Loss 46.046, MAE 5.090, Corr 0.960521
# Epoch : 114/2000, Train Loss : 37.974, Valid Loss 24.634, MAE 4.675, Corr 0.960433
# Epoch : 115/2000, Train Loss : 26.644, Valid Loss 24.414, MAE 3.814, Corr 0.960977
# Epoch : 116/2000, Train Loss : 31.074, Valid Loss 20.400, MAE 3.842, Corr 0.962523
# Best Valid Loss 20.3997
# Epoch : 117/2000, Train Loss : 23.588, Valid Loss 27.049, MAE 3.805, Corr 0.964646
# Epoch : 118/2000, Train Loss : 27.857, Valid Loss 51.450, MAE 7.124, Corr 0.963124
# Epoch : 119/2000, Train Loss : 37.325, Valid Loss 24.184, MAE 4.582, Corr 0.962161
# Epoch : 120/2000, Train Loss : 24.879, Valid Loss 22.431, MAE 4.427, Corr 0.962724
# Epoch : 121/2000, Train Loss : 26.071, Valid Loss 21.178, MAE 3.582, Corr 0.965022
# Epoch : 122/2000, Train Loss : 25.380, Valid Loss 26.853, MAE 3.925, Corr 0.962599
# Epoch : 123/2000, Train Loss : 31.813, Valid Loss 19.809, MAE 3.668, Corr 0.964383
# Best Valid Loss 19.8093
# Epoch : 124/2000, Train Loss : 23.784, Valid Loss 22.679, MAE 3.530, Corr 0.964933
# Epoch : 125/2000, Train Loss : 23.287, Valid Loss 22.703, MAE 3.612, Corr 0.964546
# Epoch : 126/2000, Train Loss : 27.777, Valid Loss 24.030, MAE 4.437, Corr 0.967328
# Epoch : 127/2000, Train Loss : 24.735, Valid Loss 31.698, MAE 4.080, Corr 0.966246
# Epoch : 128/2000, Train Loss : 31.189, Valid Loss 30.394, MAE 5.082, Corr 0.965529
# Epoch : 129/2000, Train Loss : 28.768, Valid Loss 21.675, MAE 4.362, Corr 0.963351
# Epoch : 130/2000, Train Loss : 29.499, Valid Loss 18.992, MAE 3.677, Corr 0.966887
# Best Valid Loss 18.9921
# Epoch : 131/2000, Train Loss : 21.587, Valid Loss 20.388, MAE 3.459, Corr 0.965808
# Epoch : 132/2000, Train Loss : 27.776, Valid Loss 25.145, MAE 4.753, Corr 0.963400
# Epoch : 133/2000, Train Loss : 24.663, Valid Loss 19.331, MAE 3.439, Corr 0.967529
# Epoch : 134/2000, Train Loss : 20.284, Valid Loss 21.649, MAE 3.350, Corr 0.968800
# Epoch : 135/2000, Train Loss : 32.103, Valid Loss 77.471, MAE 6.763, Corr 0.967255
# Epoch : 136/2000, Train Loss : 47.190, Valid Loss 34.089, MAE 4.266, Corr 0.964839
# Epoch : 137/2000, Train Loss : 24.533, Valid Loss 23.407, MAE 3.526, Corr 0.967468
# Epoch : 138/2000, Train Loss : 21.581, Valid Loss 18.406, MAE 3.688, Corr 0.968248
# Best Valid Loss 18.4061
# Epoch : 139/2000, Train Loss : 28.519, Valid Loss 22.796, MAE 3.433, Corr 0.967153
# Epoch : 140/2000, Train Loss : 27.490, Valid Loss 22.089, MAE 4.368, Corr 0.967700
# Epoch : 141/2000, Train Loss : 22.457, Valid Loss 19.318, MAE 3.320, Corr 0.970117
# Epoch : 142/2000, Train Loss : 22.063, Valid Loss 18.156, MAE 3.542, Corr 0.969538
# Best Valid Loss 18.1556
# Epoch : 143/2000, Train Loss : 21.128, Valid Loss 20.346, MAE 4.025, Corr 0.970014
# Epoch : 144/2000, Train Loss : 21.260, Valid Loss 18.145, MAE 3.734, Corr 0.969527
# Best Valid Loss 18.1446
# Epoch : 145/2000, Train Loss : 23.965, Valid Loss 18.946, MAE 3.355, Corr 0.969049
# Epoch : 146/2000, Train Loss : 21.817, Valid Loss 19.978, MAE 4.093, Corr 0.968391
# Epoch : 147/2000, Train Loss : 20.591, Valid Loss 22.482, MAE 4.267, Corr 0.971406
# Epoch : 148/2000, Train Loss : 37.752, Valid Loss 18.721, MAE 3.893, Corr 0.967682
# Epoch : 149/2000, Train Loss : 20.385, Valid Loss 17.806, MAE 3.323, Corr 0.970959
# Best Valid Loss 17.8065
# Epoch : 150/2000, Train Loss : 22.947, Valid Loss 18.487, MAE 3.832, Corr 0.969239
# Epoch : 151/2000, Train Loss : 23.124, Valid Loss 18.125, MAE 3.288, Corr 0.969936
# Epoch : 152/2000, Train Loss : 23.308, Valid Loss 19.567, MAE 4.021, Corr 0.969778
# Epoch : 153/2000, Train Loss : 28.046, Valid Loss 39.412, MAE 5.851, Corr 0.971066
# Epoch : 154/2000, Train Loss : 20.872, Valid Loss 18.729, MAE 3.121, Corr 0.971714
# Epoch : 155/2000, Train Loss : 22.968, Valid Loss 19.396, MAE 3.944, Corr 0.971848
# Epoch : 156/2000, Train Loss : 37.841, Valid Loss 52.759, MAE 7.076, Corr 0.969663
# Epoch : 157/2000, Train Loss : 37.430, Valid Loss 28.017, MAE 4.789, Corr 0.969532
# Epoch : 158/2000, Train Loss : 22.213, Valid Loss 18.146, MAE 3.727, Corr 0.971275
# Epoch : 159/2000, Train Loss : 21.473, Valid Loss 31.576, MAE 5.269, Corr 0.971654
# Epoch : 160/2000, Train Loss : 22.100, Valid Loss 19.187, MAE 3.940, Corr 0.970131
# Epoch : 161/2000, Train Loss : 21.644, Valid Loss 37.703, MAE 5.886, Corr 0.972854
# Epoch : 162/2000, Train Loss : 19.928, Valid Loss 27.005, MAE 4.797, Corr 0.973006
# Epoch : 163/2000, Train Loss : 23.511, Valid Loss 40.689, MAE 4.459, Corr 0.973084
# Epoch : 164/2000, Train Loss : 25.429, Valid Loss 40.137, MAE 6.093, Corr 0.970080
# Epoch : 165/2000, Train Loss : 21.349, Valid Loss 16.769, MAE 3.167, Corr 0.973982
# Best Valid Loss 16.7687
# Epoch : 166/2000, Train Loss : 27.451, Valid Loss 33.973, MAE 5.522, Corr 0.970335
# Epoch : 167/2000, Train Loss : 22.377, Valid Loss 23.312, MAE 4.410, Corr 0.972251
# Epoch : 168/2000, Train Loss : 22.105, Valid Loss 16.968, MAE 3.492, Corr 0.972969
# Epoch : 169/2000, Train Loss : 22.454, Valid Loss 21.931, MAE 4.132, Corr 0.974100
# Epoch : 170/2000, Train Loss : 22.775, Valid Loss 17.160, MAE 3.253, Corr 0.972025
# Epoch : 171/2000, Train Loss : 18.334, Valid Loss 19.637, MAE 3.061, Corr 0.974626
# Epoch : 172/2000, Train Loss : 18.581, Valid Loss 16.964, MAE 3.070, Corr 0.974038
# Epoch : 173/2000, Train Loss : 25.173, Valid Loss 69.124, MAE 8.385, Corr 0.973764
# Epoch : 174/2000, Train Loss : 32.795, Valid Loss 25.508, MAE 3.507, Corr 0.972344
# Epoch : 175/2000, Train Loss : 22.731, Valid Loss 24.096, MAE 4.520, Corr 0.971563
# Epoch : 176/2000, Train Loss : 18.273, Valid Loss 17.312, MAE 3.518, Corr 0.972560
# Epoch : 177/2000, Train Loss : 18.896, Valid Loss 19.015, MAE 3.809, Corr 0.973606
# Epoch : 178/2000, Train Loss : 17.871, Valid Loss 18.415, MAE 3.821, Corr 0.974714
# Epoch : 179/2000, Train Loss : 21.907, Valid Loss 35.835, MAE 5.694, Corr 0.970544
# Epoch : 180/2000, Train Loss : 27.185, Valid Loss 68.583, MAE 6.490, Corr 0.973822
# Epoch : 181/2000, Train Loss : 27.642, Valid Loss 16.796, MAE 3.314, Corr 0.972835
# Epoch : 182/2000, Train Loss : 24.077, Valid Loss 19.668, MAE 3.016, Corr 0.973278
# Epoch : 183/2000, Train Loss : 29.331, Valid Loss 29.406, MAE 5.079, Corr 0.970601
# Epoch : 184/2000, Train Loss : 19.914, Valid Loss 19.412, MAE 3.936, Corr 0.975975
# Epoch : 185/2000, Train Loss : 17.864, Valid Loss 22.938, MAE 4.310, Corr 0.975479
# Epoch : 186/2000, Train Loss : 20.642, Valid Loss 17.828, MAE 3.708, Corr 0.974362
# Early stopping
# Best Result : Epoch 165, Valid Loss 16.769, MAE 3.167, Corr 0.973982

# %%
# scatter plot

file_path = "D:\gait_dataset/salted/test/*"
inputs_acc, inputs_gyr, stride_length = get_sensor_salted(file_path, normalization=True)
inputs_pst = get_position_salted(file_path, distance=True)
inputs_acc, inputs_gyr, stride_length, inputs_pst = torch.Tensor(np.array(inputs_acc)), torch.Tensor(np.array(inputs_gyr)), torch.Tensor(np.array(stride_length)), torch.Tensor(np.array(inputs_pst))
inputs_acc, inputs_gyr, stride_length, inputs_pst = inputs_acc.float(), inputs_gyr.float(), stride_length.float(), inputs_pst.float()
inputs_acc, inputs_gyr, inputs_pst = inputs_acc.to(device), inputs_gyr.to(device), inputs_pst.to(device)

# %%
input_dim = 3
conv1d_dim1 = 16
conv1d_dim2 = 32
dense_dim = 512

model = Encoder_dist(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
model.load_state_dict(torch.load('./model/encoder_dist_best_ks30_nobias.pth'))
model.eval()
# Out:
# Encoder_dist(
#   (conv1d_acc): Sequential(
#     (0): Conv1d(3, 16, kernel_size=(30,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(30,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (conv1d_gyr): Sequential(
#     (0): Conv1d(3, 16, kernel_size=(30,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(30,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (dense): Sequential(
#     (0): Linear(in_features=15491, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=128, out_features=64, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %%
pred = model(inputs_acc, inputs_gyr, inputs_pst).detach().cpu().numpy()

plt.figure(figsize=(10, 10))
plt.scatter(stride_length, np.round(pred, 4))
plt.xlim([80, 200])
plt.xlabel('stride_length')
plt.ylim([80, 200])
plt.ylabel('pred')

xpoints = ypoints = plt.xlim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)

plt.show()

# %% [markdown]
# ## LSTM
# - Best Result : Epoch 301, Valid Loss 11.655, MAE 2.259, Corr 0.985151

# %% [markdown]
# ### 데이터 불러오기

# %%
device = torch.device('cuda:0' if torch.cuda.is_available else 'cpu')

file_path = "D:\gait_dataset/salted/train/*"
dataset = Gait_Dataset_Salted(file_path, bias=False)
val_percent = 0.2
n_val = int(len(dataset) * val_percent)
n_train = len(dataset) - n_val
train, val = random_split(dataset, [n_train, n_val])

# %%
train_loader = torch.utils.data.DataLoader(train,
                                           batch_size=128,
                                           shuffle=True,
                                           worker_init_fn=np.random.seed(42))
val_loader = torch.utils.data.DataLoader(val,
                                         batch_size=128,
                                         shuffle=False)

# %% [markdown]
# ### Model & Scatter Plot

# %%
# seed 고정
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

class Encoder_lstm(nn.Module):
    def __init__(self, input_dim, lstm_dim, num_layers, dense_dim):
        super(Encoder_lstm, self).__init__()
        
        self.lstm_dim = lstm_dim
        self.num_layers = num_layers
             
        self.lstm_acc = nn.LSTM(input_dim, lstm_dim, num_layers, batch_first=True)
        self.lstm_gyr = nn.LSTM(input_dim, lstm_dim, num_layers, batch_first=True)
        
        self.dense = nn.Sequential(
            nn.Linear(lstm_dim*2, dense_dim),
            nn.ReLU(inplace=True),
            nn.Linear(dense_dim, int(dense_dim/2)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/2), int(dense_dim/4)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/4), int(dense_dim/8)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/8), 3)
        )
        

    def forward(self, inputs_acc, inputs_gyr, inputs_pst): 
        
        # 다음 학습에 영향을 주지 않기 위해 초기 h_0과 c_0 초기화
        h0 = torch.zeros(self.num_layers, inputs_acc.size(0), self.lstm_dim).to(device)
        c0 = torch.zeros(self.num_layers, inputs_acc.size(0), self.lstm_dim).to(device)
        
        lstm_output_acc = self.lstm_acc(inputs_acc)
        lstm_output_gyr = self.lstm_gyr(inputs_gyr)
        
        _, (h_acc, _) = self.lstm_acc(inputs_acc, (h0, c0))
        _, (h_gyr, _) = self.lstm_gyr(inputs_gyr, (h0, c0))
    
        enc_output = torch.cat((h_acc.view(-1, lstm_dim), h_gyr.view(-1, lstm_dim)), dim=1)
        dense_output = self.dense(enc_output)
        output = torch.unsqueeze(torch.sum(dense_output*inputs_pst, axis=1), 1)
        
        return output

# %%
input_dim = 300
lstm_dim = 64
num_layers = 1
dense_dim = 512


model = Encoder_lstm(input_dim, lstm_dim, num_layers, dense_dim).to(device)
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
n_epochs = 2000

criterion = nn.MSELoss()

# %%
# Early Stopping을 위한 변수
best = 1000
converge_cnt = 0
best_MAE = 0
best_corr = 0
best_epoch = 0

# Run Training loop
for epoch in range(0, n_epochs) :
    # Set current loss value 
    tot_trn_loss = 0.0
    
    # Train Mode
    model.train()
    
    # Iterate over the DataLoader for training data 
    for i, data in enumerate(train_loader) :
        inputs_acc, inputs_gyr, stride_length, inputs_pst = data
        inputs_acc, inputs_gyr, stride_length, inputs_pst = inputs_acc.float(), inputs_gyr.float(), stride_length.float(), inputs_pst.float()
        inputs_acc, inputs_gyr, inputs_pst = inputs_acc.to(device), inputs_gyr.to(device), inputs_pst.to(device)
        stride_length = stride_length.reshape(-1, 1)
        stride_length = stride_length.to(device)

        # 순전파 
        outputs = model(inputs_acc, inputs_gyr, inputs_pst)

        # Loss 계산
        loss = criterion(outputs, stride_length)
        
        # 기울기 초기화 
        optimizer.zero_grad()
        # 역전파
        loss.backward()
        # 옵티마이저
        optimizer.step()
        
        # Print statistics
        tot_trn_loss += loss.item()
        
    # Evaluation Mode
    model.eval()
    
    tot_val_loss = 0
    val_epoch_loss = []

    with torch.no_grad() :
        for i, data in enumerate(val_loader):
            inputs_acc, inputs_gyr, stride_length, inputs_pst = data
            inputs_acc, inputs_gyr, stride_length, inputs_pst = inputs_acc.float(), inputs_gyr.float(), stride_length.float(), inputs_pst.float()
            inputs_acc, inputs_gyr, inputs_pst = inputs_acc.to(device), inputs_gyr.to(device), inputs_pst.to(device)
            stride_length = stride_length.reshape(-1, 1)
            stride_length = stride_length.to(device)

            # 순전파 
            outputs = model(inputs_acc, inputs_gyr, inputs_pst)
            
            # Loss 계산
            loss = criterion(outputs, stride_length)
            tot_val_loss += loss.item()            
            

    # Epoch 별 Loss
    trn_loss = tot_trn_loss / len(train_loader)
    val_loss = tot_val_loss / len(val_loader)
    MAE = torch.sum(torch.abs(outputs - stride_length)) / len(stride_length)
    corr = torch.corrcoef(torch.stack([torch.squeeze(stride_length), torch.squeeze(outputs)]))[0, 1]
    
    
    
    print("Epoch : {}/{}, Train Loss : {:.3f}, Valid Loss {:.3f}, MAE {:.3f}, Corr {:3f}".format(epoch+1, n_epochs,
                                                                                       trn_loss, val_loss,
                                                                                      MAE, corr))
    
    # Early Stopping
    if val_loss < best:
        best = np.mean(val_loss)
        best_MAE = MAE
        best_corr = corr
        best_epoch = epoch+1
        torch.save(model.state_dict(), './model/encoder_dist_best_ks30_bias.pth')
        print('Best Valid Loss {:.4f}'.format(best))
        converge_cnt = 0
    else:
        converge_cnt += 1
    
    if converge_cnt > 20:
        print('Early stopping')
        print('Best Result : Epoch {}, Valid Loss {:.3f}, MAE {:.3f}, Corr {:3f}'.format(best_epoch, best, best_MAE, best_corr))
        break
    
#     print("Epoch : {}/{} Epoch Loss : {:.6f}".format(epoch+1, n_epochs, current_loss / len(trainloader.dataset)))
# Out:
# Epoch : 1/2000, Train Loss : 15213.859, Valid Loss 5106.789, MAE 67.893, Corr 0.658045
# Epoch : 2/2000, Train Loss : 1523.620, Valid Loss 561.030, MAE 18.085, Corr 0.652574
# Best Valid Loss 561.0302
# Epoch : 3/2000, Train Loss : 347.202, Valid Loss 229.659, MAE 10.369, Corr 0.657544
# Best Valid Loss 229.6589
# Epoch : 4/2000, Train Loss : 223.382, Valid Loss 201.197, MAE 11.406, Corr 0.662875
# Best Valid Loss 201.1974
# Epoch : 5/2000, Train Loss : 200.994, Valid Loss 191.355, MAE 10.756, Corr 0.668398
# Best Valid Loss 191.3547
# Epoch : 6/2000, Train Loss : 194.898, Valid Loss 186.333, MAE 10.574, Corr 0.673361
# Best Valid Loss 186.3332
# Epoch : 7/2000, Train Loss : 190.556, Valid Loss 181.769, MAE 10.702, Corr 0.677284
# Best Valid Loss 181.7691
# Epoch : 8/2000, Train Loss : 186.695, Valid Loss 178.068, MAE 10.598, Corr 0.680634
# Best Valid Loss 178.0680
# Epoch : 9/2000, Train Loss : 183.684, Valid Loss 175.079, MAE 10.583, Corr 0.683594
# Best Valid Loss 175.0790
# Epoch : 10/2000, Train Loss : 182.196, Valid Loss 178.547, MAE 11.177, Corr 0.685681
# Epoch : 11/2000, Train Loss : 180.769, Valid Loss 171.201, MAE 10.586, Corr 0.687783
# Best Valid Loss 171.2015
# Epoch : 12/2000, Train Loss : 178.240, Valid Loss 171.710, MAE 10.346, Corr 0.689484
# Epoch : 13/2000, Train Loss : 177.828, Valid Loss 168.698, MAE 10.412, Corr 0.690696
# Best Valid Loss 168.6982
# Epoch : 14/2000, Train Loss : 178.934, Valid Loss 168.094, MAE 10.412, Corr 0.691515
# Best Valid Loss 168.0944
# Epoch : 15/2000, Train Loss : 176.288, Valid Loss 167.823, MAE 10.368, Corr 0.692931
# Best Valid Loss 167.8235
# Epoch : 16/2000, Train Loss : 176.400, Valid Loss 166.655, MAE 10.468, Corr 0.693195
# Best Valid Loss 166.6548
# Epoch : 17/2000, Train Loss : 176.123, Valid Loss 166.950, MAE 10.361, Corr 0.694597
# Epoch : 18/2000, Train Loss : 176.840, Valid Loss 165.044, MAE 10.354, Corr 0.696849
# Best Valid Loss 165.0445
# Epoch : 19/2000, Train Loss : 173.766, Valid Loss 161.259, MAE 10.313, Corr 0.705998
# Best Valid Loss 161.2590
# Epoch : 20/2000, Train Loss : 168.952, Valid Loss 154.295, MAE 9.905, Corr 0.718928
# Best Valid Loss 154.2952
# Epoch : 21/2000, Train Loss : 161.600, Valid Loss 153.114, MAE 9.991, Corr 0.733528
# Best Valid Loss 153.1138
# Epoch : 22/2000, Train Loss : 165.428, Valid Loss 145.456, MAE 9.585, Corr 0.748074
# Best Valid Loss 145.4557
# Epoch : 23/2000, Train Loss : 156.873, Valid Loss 136.755, MAE 9.123, Corr 0.760279
# Best Valid Loss 136.7548
# Epoch : 24/2000, Train Loss : 149.727, Valid Loss 143.172, MAE 8.931, Corr 0.772187
# Epoch : 25/2000, Train Loss : 142.540, Valid Loss 122.807, MAE 8.369, Corr 0.794809
# Best Valid Loss 122.8073
# Epoch : 26/2000, Train Loss : 132.265, Valid Loss 115.529, MAE 7.833, Corr 0.807119
# Best Valid Loss 115.5290
# Epoch : 27/2000, Train Loss : 128.764, Valid Loss 109.198, MAE 7.424, Corr 0.826620
# Best Valid Loss 109.1981
# Epoch : 28/2000, Train Loss : 131.067, Valid Loss 105.012, MAE 7.178, Corr 0.837631
# Best Valid Loss 105.0122
# Epoch : 29/2000, Train Loss : 115.738, Valid Loss 101.679, MAE 7.033, Corr 0.847188
# Best Valid Loss 101.6792
# Epoch : 30/2000, Train Loss : 114.522, Valid Loss 99.503, MAE 6.947, Corr 0.856274
# Best Valid Loss 99.5027
# Epoch : 31/2000, Train Loss : 105.267, Valid Loss 111.187, MAE 7.513, Corr 0.873265
# Epoch : 32/2000, Train Loss : 100.613, Valid Loss 88.440, MAE 6.075, Corr 0.887587
# Best Valid Loss 88.4405
# Epoch : 33/2000, Train Loss : 96.015, Valid Loss 87.884, MAE 5.884, Corr 0.891741
# Best Valid Loss 87.8843
# Epoch : 34/2000, Train Loss : 91.678, Valid Loss 87.684, MAE 6.416, Corr 0.896456
# Best Valid Loss 87.6839
# Epoch : 35/2000, Train Loss : 84.927, Valid Loss 75.561, MAE 5.578, Corr 0.904821
# Best Valid Loss 75.5614
# Epoch : 36/2000, Train Loss : 81.933, Valid Loss 77.581, MAE 5.803, Corr 0.906010
# Epoch : 37/2000, Train Loss : 79.813, Valid Loss 72.485, MAE 5.965, Corr 0.916080
# Best Valid Loss 72.4849
# Epoch : 38/2000, Train Loss : 90.067, Valid Loss 66.450, MAE 5.210, Corr 0.919183
# Best Valid Loss 66.4497
# Epoch : 39/2000, Train Loss : 77.055, Valid Loss 68.110, MAE 5.422, Corr 0.916013
# Epoch : 40/2000, Train Loss : 70.593, Valid Loss 67.516, MAE 5.950, Corr 0.923011
# Epoch : 41/2000, Train Loss : 67.239, Valid Loss 59.020, MAE 5.210, Corr 0.928198
# Best Valid Loss 59.0195
# Epoch : 42/2000, Train Loss : 64.399, Valid Loss 73.536, MAE 6.328, Corr 0.934636
# Epoch : 43/2000, Train Loss : 67.984, Valid Loss 59.363, MAE 5.594, Corr 0.932552
# Epoch : 44/2000, Train Loss : 60.708, Valid Loss 56.114, MAE 5.197, Corr 0.938206
# Best Valid Loss 56.1136
# Epoch : 45/2000, Train Loss : 56.317, Valid Loss 50.723, MAE 4.767, Corr 0.939668
# Best Valid Loss 50.7234
# Epoch : 46/2000, Train Loss : 55.253, Valid Loss 49.300, MAE 4.632, Corr 0.936966
# Best Valid Loss 49.2996
# Epoch : 47/2000, Train Loss : 51.606, Valid Loss 46.184, MAE 4.523, Corr 0.940919
# Best Valid Loss 46.1844
# Epoch : 48/2000, Train Loss : 50.447, Valid Loss 46.876, MAE 4.490, Corr 0.940040
# Epoch : 49/2000, Train Loss : 47.763, Valid Loss 42.494, MAE 4.678, Corr 0.944456
# Best Valid Loss 42.4941
# Epoch : 50/2000, Train Loss : 46.942, Valid Loss 55.626, MAE 5.137, Corr 0.947592
# Epoch : 51/2000, Train Loss : 51.082, Valid Loss 46.510, MAE 4.498, Corr 0.941880
# Epoch : 52/2000, Train Loss : 54.594, Valid Loss 64.772, MAE 6.342, Corr 0.953372
# Epoch : 53/2000, Train Loss : 44.522, Valid Loss 44.697, MAE 4.527, Corr 0.948875
# Epoch : 54/2000, Train Loss : 46.462, Valid Loss 55.716, MAE 6.289, Corr 0.950607
# Epoch : 55/2000, Train Loss : 43.039, Valid Loss 37.038, MAE 4.270, Corr 0.951690
# Best Valid Loss 37.0378
# Epoch : 56/2000, Train Loss : 45.198, Valid Loss 51.924, MAE 5.985, Corr 0.954941
# Epoch : 57/2000, Train Loss : 45.828, Valid Loss 38.761, MAE 4.289, Corr 0.954219
# Epoch : 58/2000, Train Loss : 44.862, Valid Loss 37.439, MAE 4.278, Corr 0.950282
# Epoch : 59/2000, Train Loss : 42.400, Valid Loss 38.824, MAE 4.915, Corr 0.955060
# Epoch : 60/2000, Train Loss : 43.935, Valid Loss 52.474, MAE 5.887, Corr 0.955244
# Epoch : 61/2000, Train Loss : 38.529, Valid Loss 36.146, MAE 4.545, Corr 0.956145
# Best Valid Loss 36.1463
# Epoch : 62/2000, Train Loss : 37.418, Valid Loss 34.618, MAE 4.248, Corr 0.952011
# Best Valid Loss 34.6183
# Epoch : 63/2000, Train Loss : 38.751, Valid Loss 43.224, MAE 4.506, Corr 0.954977
# Epoch : 64/2000, Train Loss : 37.929, Valid Loss 37.319, MAE 4.643, Corr 0.958692
# Epoch : 65/2000, Train Loss : 34.319, Valid Loss 36.749, MAE 4.760, Corr 0.959041
# Epoch : 66/2000, Train Loss : 35.222, Valid Loss 45.964, MAE 5.665, Corr 0.959125
# Epoch : 67/2000, Train Loss : 37.665, Valid Loss 36.969, MAE 4.223, Corr 0.958169
# Epoch : 68/2000, Train Loss : 46.033, Valid Loss 77.479, MAE 6.571, Corr 0.957645
# Epoch : 69/2000, Train Loss : 44.216, Valid Loss 38.951, MAE 4.951, Corr 0.959222
# Epoch : 70/2000, Train Loss : 38.095, Valid Loss 36.122, MAE 4.567, Corr 0.961891
# Epoch : 71/2000, Train Loss : 42.696, Valid Loss 37.308, MAE 4.695, Corr 0.957768
# Epoch : 72/2000, Train Loss : 36.520, Valid Loss 31.792, MAE 4.284, Corr 0.962156
# Best Valid Loss 31.7918
# Epoch : 73/2000, Train Loss : 31.138, Valid Loss 34.542, MAE 4.132, Corr 0.962164
# Epoch : 74/2000, Train Loss : 33.617, Valid Loss 39.835, MAE 4.431, Corr 0.963970
# Epoch : 75/2000, Train Loss : 34.231, Valid Loss 29.994, MAE 3.979, Corr 0.962483
# Best Valid Loss 29.9935
# Epoch : 76/2000, Train Loss : 28.987, Valid Loss 34.480, MAE 4.127, Corr 0.961973
# Epoch : 77/2000, Train Loss : 29.835, Valid Loss 29.727, MAE 4.032, Corr 0.966126
# Best Valid Loss 29.7274
# Epoch : 78/2000, Train Loss : 31.586, Valid Loss 39.979, MAE 5.261, Corr 0.964949
# Epoch : 79/2000, Train Loss : 29.087, Valid Loss 32.456, MAE 4.286, Corr 0.968907
# Epoch : 80/2000, Train Loss : 30.294, Valid Loss 36.756, MAE 4.115, Corr 0.967338
# Epoch : 81/2000, Train Loss : 30.268, Valid Loss 27.896, MAE 3.816, Corr 0.967853
# Best Valid Loss 27.8959
# Epoch : 82/2000, Train Loss : 31.434, Valid Loss 29.640, MAE 4.211, Corr 0.967351
# Epoch : 83/2000, Train Loss : 30.404, Valid Loss 26.982, MAE 3.650, Corr 0.968174
# Best Valid Loss 26.9816
# Epoch : 84/2000, Train Loss : 26.802, Valid Loss 27.272, MAE 3.839, Corr 0.966820
# Epoch : 85/2000, Train Loss : 30.384, Valid Loss 38.457, MAE 5.205, Corr 0.969634
# Epoch : 86/2000, Train Loss : 31.190, Valid Loss 26.934, MAE 3.618, Corr 0.971386
# Best Valid Loss 26.9336
# Epoch : 87/2000, Train Loss : 26.588, Valid Loss 26.454, MAE 3.698, Corr 0.973035
# Best Valid Loss 26.4537
# Epoch : 88/2000, Train Loss : 35.032, Valid Loss 31.109, MAE 3.681, Corr 0.970174
# Epoch : 89/2000, Train Loss : 35.504, Valid Loss 34.560, MAE 4.765, Corr 0.972631
# Epoch : 90/2000, Train Loss : 36.118, Valid Loss 38.805, MAE 4.235, Corr 0.971888
# Epoch : 91/2000, Train Loss : 31.583, Valid Loss 31.708, MAE 3.801, Corr 0.962828
# Epoch : 92/2000, Train Loss : 26.188, Valid Loss 27.829, MAE 3.824, Corr 0.972040
# Epoch : 93/2000, Train Loss : 30.700, Valid Loss 36.450, MAE 4.999, Corr 0.970228
# Epoch : 94/2000, Train Loss : 31.840, Valid Loss 25.587, MAE 3.391, Corr 0.971617
# Best Valid Loss 25.5870
# Epoch : 95/2000, Train Loss : 25.128, Valid Loss 24.540, MAE 3.394, Corr 0.972327
# Best Valid Loss 24.5395
# Epoch : 96/2000, Train Loss : 25.149, Valid Loss 24.742, MAE 3.520, Corr 0.972162
# Epoch : 97/2000, Train Loss : 25.595, Valid Loss 23.926, MAE 3.347, Corr 0.974940
# Best Valid Loss 23.9265
# Epoch : 98/2000, Train Loss : 24.093, Valid Loss 27.857, MAE 3.424, Corr 0.974765
# Epoch : 99/2000, Train Loss : 25.580, Valid Loss 23.689, MAE 3.133, Corr 0.977813
# Best Valid Loss 23.6891
# Epoch : 100/2000, Train Loss : 25.696, Valid Loss 26.309, MAE 3.251, Corr 0.977683
# Epoch : 101/2000, Train Loss : 24.125, Valid Loss 25.980, MAE 3.741, Corr 0.976355
# Epoch : 102/2000, Train Loss : 25.301, Valid Loss 24.036, MAE 3.460, Corr 0.976724
# Epoch : 103/2000, Train Loss : 24.528, Valid Loss 24.489, MAE 3.150, Corr 0.976144
# Epoch : 104/2000, Train Loss : 23.664, Valid Loss 25.798, MAE 3.876, Corr 0.975525
# Epoch : 105/2000, Train Loss : 26.697, Valid Loss 29.822, MAE 4.373, Corr 0.978126
# Epoch : 106/2000, Train Loss : 30.349, Valid Loss 22.680, MAE 3.148, Corr 0.977209
# Best Valid Loss 22.6797
# Epoch : 107/2000, Train Loss : 22.544, Valid Loss 22.598, MAE 3.398, Corr 0.976889
# Best Valid Loss 22.5978
# Epoch : 108/2000, Train Loss : 21.075, Valid Loss 23.675, MAE 3.596, Corr 0.977556
# Epoch : 109/2000, Train Loss : 25.995, Valid Loss 23.223, MAE 3.472, Corr 0.975139
# Epoch : 110/2000, Train Loss : 23.048, Valid Loss 22.084, MAE 3.056, Corr 0.979111
# Best Valid Loss 22.0839
# Epoch : 111/2000, Train Loss : 24.338, Valid Loss 22.421, MAE 3.418, Corr 0.978847
# Epoch : 112/2000, Train Loss : 25.184, Valid Loss 42.231, MAE 5.437, Corr 0.976704
# Epoch : 113/2000, Train Loss : 26.662, Valid Loss 29.377, MAE 4.447, Corr 0.975567
# Epoch : 114/2000, Train Loss : 21.467, Valid Loss 21.110, MAE 3.067, Corr 0.977665
# Best Valid Loss 21.1101
# Epoch : 115/2000, Train Loss : 21.172, Valid Loss 23.445, MAE 3.599, Corr 0.976754
# Epoch : 116/2000, Train Loss : 22.172, Valid Loss 20.665, MAE 2.885, Corr 0.980309
# Best Valid Loss 20.6651
# Epoch : 117/2000, Train Loss : 30.316, Valid Loss 24.057, MAE 2.889, Corr 0.978915
# Epoch : 118/2000, Train Loss : 21.589, Valid Loss 28.440, MAE 4.343, Corr 0.977449
# Epoch : 119/2000, Train Loss : 22.399, Valid Loss 20.606, MAE 3.065, Corr 0.978668
# Best Valid Loss 20.6058
# Epoch : 120/2000, Train Loss : 21.502, Valid Loss 20.341, MAE 3.026, Corr 0.978645
# Best Valid Loss 20.3412
# Epoch : 121/2000, Train Loss : 24.408, Valid Loss 24.883, MAE 3.072, Corr 0.978064
# Epoch : 122/2000, Train Loss : 23.090, Valid Loss 38.352, MAE 5.023, Corr 0.976218
# Epoch : 123/2000, Train Loss : 23.760, Valid Loss 22.476, MAE 3.300, Corr 0.980228
# Epoch : 124/2000, Train Loss : 23.890, Valid Loss 35.948, MAE 4.921, Corr 0.980763
# Epoch : 125/2000, Train Loss : 26.891, Valid Loss 22.953, MAE 3.489, Corr 0.973708
# Epoch : 126/2000, Train Loss : 20.776, Valid Loss 19.341, MAE 2.941, Corr 0.979660
# Best Valid Loss 19.3408
# Epoch : 127/2000, Train Loss : 22.309, Valid Loss 29.692, MAE 4.115, Corr 0.980866
# Epoch : 128/2000, Train Loss : 26.595, Valid Loss 22.468, MAE 2.980, Corr 0.980542
# Epoch : 129/2000, Train Loss : 25.623, Valid Loss 19.763, MAE 2.917, Corr 0.979465
# Epoch : 130/2000, Train Loss : 20.917, Valid Loss 25.225, MAE 3.128, Corr 0.979013
# Epoch : 131/2000, Train Loss : 25.912, Valid Loss 22.966, MAE 3.468, Corr 0.980599
# Epoch : 132/2000, Train Loss : 21.596, Valid Loss 20.092, MAE 2.623, Corr 0.983002
# Epoch : 133/2000, Train Loss : 19.752, Valid Loss 19.783, MAE 3.026, Corr 0.978687
# Epoch : 134/2000, Train Loss : 20.022, Valid Loss 19.995, MAE 3.000, Corr 0.977999
# Epoch : 135/2000, Train Loss : 21.276, Valid Loss 27.352, MAE 3.694, Corr 0.978285
# Epoch : 136/2000, Train Loss : 19.678, Valid Loss 20.906, MAE 2.853, Corr 0.980036
# Epoch : 137/2000, Train Loss : 21.169, Valid Loss 20.913, MAE 3.390, Corr 0.981554
# Epoch : 138/2000, Train Loss : 19.284, Valid Loss 20.906, MAE 3.430, Corr 0.981565
# Epoch : 139/2000, Train Loss : 25.471, Valid Loss 21.429, MAE 2.864, Corr 0.982415
# Epoch : 140/2000, Train Loss : 25.281, Valid Loss 36.040, MAE 4.349, Corr 0.977409
# Epoch : 141/2000, Train Loss : 22.014, Valid Loss 19.323, MAE 2.947, Corr 0.978744
# Best Valid Loss 19.3231
# Epoch : 142/2000, Train Loss : 29.462, Valid Loss 23.882, MAE 3.217, Corr 0.979867
# Epoch : 143/2000, Train Loss : 20.375, Valid Loss 19.449, MAE 3.057, Corr 0.981539
# Epoch : 144/2000, Train Loss : 17.800, Valid Loss 17.992, MAE 2.583, Corr 0.983227
# Best Valid Loss 17.9923
# Epoch : 145/2000, Train Loss : 17.733, Valid Loss 17.935, MAE 2.720, Corr 0.982381
# Best Valid Loss 17.9350
# Epoch : 146/2000, Train Loss : 19.008, Valid Loss 18.075, MAE 2.864, Corr 0.980747
# Epoch : 147/2000, Train Loss : 20.880, Valid Loss 17.630, MAE 2.722, Corr 0.982693
# Best Valid Loss 17.6300
# Epoch : 148/2000, Train Loss : 19.399, Valid Loss 19.273, MAE 2.715, Corr 0.981862
# Epoch : 149/2000, Train Loss : 18.476, Valid Loss 17.744, MAE 2.663, Corr 0.982472
# Epoch : 150/2000, Train Loss : 21.492, Valid Loss 17.878, MAE 2.923, Corr 0.980419
# Epoch : 151/2000, Train Loss : 20.610, Valid Loss 22.794, MAE 3.613, Corr 0.980730
# Epoch : 152/2000, Train Loss : 16.424, Valid Loss 19.535, MAE 3.158, Corr 0.980114
# Epoch : 153/2000, Train Loss : 21.288, Valid Loss 18.223, MAE 2.714, Corr 0.981926
# Epoch : 154/2000, Train Loss : 16.851, Valid Loss 18.566, MAE 2.618, Corr 0.983479
# Epoch : 155/2000, Train Loss : 21.740, Valid Loss 22.039, MAE 3.757, Corr 0.984559
# Epoch : 156/2000, Train Loss : 17.340, Valid Loss 19.516, MAE 3.372, Corr 0.979788
# Epoch : 157/2000, Train Loss : 24.892, Valid Loss 17.304, MAE 2.751, Corr 0.985852
# Best Valid Loss 17.3036
# Epoch : 158/2000, Train Loss : 20.670, Valid Loss 23.524, MAE 3.035, Corr 0.981937
# Epoch : 159/2000, Train Loss : 22.758, Valid Loss 24.280, MAE 3.257, Corr 0.983824
# Epoch : 160/2000, Train Loss : 18.238, Valid Loss 23.019, MAE 2.998, Corr 0.980543
# Epoch : 161/2000, Train Loss : 17.084, Valid Loss 22.893, MAE 3.309, Corr 0.980046
# Epoch : 162/2000, Train Loss : 15.702, Valid Loss 20.718, MAE 2.924, Corr 0.979366
# Epoch : 163/2000, Train Loss : 17.762, Valid Loss 18.148, MAE 2.645, Corr 0.984770
# Epoch : 164/2000, Train Loss : 15.665, Valid Loss 23.824, MAE 3.930, Corr 0.983530
# Epoch : 165/2000, Train Loss : 16.301, Valid Loss 16.755, MAE 2.600, Corr 0.983365
# Best Valid Loss 16.7554
# Epoch : 166/2000, Train Loss : 15.211, Valid Loss 19.039, MAE 3.210, Corr 0.983019
# Epoch : 167/2000, Train Loss : 15.263, Valid Loss 15.821, MAE 2.635, Corr 0.983423
# Best Valid Loss 15.8210
# Epoch : 168/2000, Train Loss : 14.559, Valid Loss 17.501, MAE 3.069, Corr 0.981538
# Epoch : 169/2000, Train Loss : 21.891, Valid Loss 34.524, MAE 3.856, Corr 0.982321
# Epoch : 170/2000, Train Loss : 21.560, Valid Loss 17.651, MAE 2.819, Corr 0.980141
# Epoch : 171/2000, Train Loss : 18.321, Valid Loss 25.377, MAE 4.000, Corr 0.984212
# Epoch : 172/2000, Train Loss : 19.993, Valid Loss 33.377, MAE 4.296, Corr 0.983511
# Epoch : 173/2000, Train Loss : 20.630, Valid Loss 16.715, MAE 2.642, Corr 0.982812
# Epoch : 174/2000, Train Loss : 16.506, Valid Loss 17.298, MAE 2.586, Corr 0.984927
# Epoch : 175/2000, Train Loss : 21.829, Valid Loss 19.033, MAE 3.318, Corr 0.985752
# Epoch : 176/2000, Train Loss : 16.559, Valid Loss 19.780, MAE 3.490, Corr 0.984805
# Epoch : 177/2000, Train Loss : 15.941, Valid Loss 16.336, MAE 2.776, Corr 0.982035
# Epoch : 178/2000, Train Loss : 17.586, Valid Loss 25.487, MAE 3.966, Corr 0.982994
# Epoch : 179/2000, Train Loss : 19.860, Valid Loss 18.479, MAE 2.528, Corr 0.983919
# Epoch : 180/2000, Train Loss : 18.863, Valid Loss 16.495, MAE 2.868, Corr 0.985274
# Epoch : 181/2000, Train Loss : 17.372, Valid Loss 23.707, MAE 3.852, Corr 0.984072
# Epoch : 182/2000, Train Loss : 18.559, Valid Loss 18.280, MAE 2.901, Corr 0.984748
# Epoch : 183/2000, Train Loss : 15.414, Valid Loss 20.376, MAE 3.444, Corr 0.985579
# Epoch : 184/2000, Train Loss : 16.142, Valid Loss 15.181, MAE 2.532, Corr 0.983142
# Best Valid Loss 15.1813
# Epoch : 185/2000, Train Loss : 16.632, Valid Loss 39.772, MAE 4.964, Corr 0.984323
# Epoch : 186/2000, Train Loss : 22.185, Valid Loss 21.973, MAE 3.769, Corr 0.985043
# Epoch : 187/2000, Train Loss : 14.513, Valid Loss 16.005, MAE 2.724, Corr 0.985812
# Epoch : 188/2000, Train Loss : 19.993, Valid Loss 26.753, MAE 3.810, Corr 0.986217
# Epoch : 189/2000, Train Loss : 19.549, Valid Loss 19.616, MAE 3.449, Corr 0.980759
# Epoch : 190/2000, Train Loss : 19.172, Valid Loss 19.531, MAE 3.497, Corr 0.983451
# Epoch : 191/2000, Train Loss : 17.726, Valid Loss 18.513, MAE 2.759, Corr 0.984117
# Epoch : 192/2000, Train Loss : 15.017, Valid Loss 16.770, MAE 2.969, Corr 0.981801
# Epoch : 193/2000, Train Loss : 15.447, Valid Loss 14.584, MAE 2.333, Corr 0.985500
# Best Valid Loss 14.5842
# Epoch : 194/2000, Train Loss : 16.468, Valid Loss 20.615, MAE 3.576, Corr 0.981868
# Epoch : 195/2000, Train Loss : 15.432, Valid Loss 14.507, MAE 2.562, Corr 0.984117
# Best Valid Loss 14.5071
# Epoch : 196/2000, Train Loss : 18.165, Valid Loss 14.384, MAE 2.490, Corr 0.985654
# Best Valid Loss 14.3835
# Epoch : 197/2000, Train Loss : 13.119, Valid Loss 16.580, MAE 2.597, Corr 0.982996
# Epoch : 198/2000, Train Loss : 17.717, Valid Loss 19.338, MAE 3.460, Corr 0.985661
# Epoch : 199/2000, Train Loss : 22.455, Valid Loss 19.422, MAE 3.085, Corr 0.986149
# Epoch : 200/2000, Train Loss : 20.575, Valid Loss 14.165, MAE 2.459, Corr 0.983822
# Best Valid Loss 14.1648
# Epoch : 201/2000, Train Loss : 24.160, Valid Loss 30.221, MAE 4.131, Corr 0.985469
# Epoch : 202/2000, Train Loss : 28.536, Valid Loss 31.757, MAE 4.482, Corr 0.984773
# Epoch : 203/2000, Train Loss : 23.424, Valid Loss 19.789, MAE 3.395, Corr 0.983222
# Epoch : 204/2000, Train Loss : 13.003, Valid Loss 14.456, MAE 2.593, Corr 0.982994
# Epoch : 205/2000, Train Loss : 14.373, Valid Loss 20.986, MAE 3.183, Corr 0.984878
# Epoch : 206/2000, Train Loss : 15.434, Valid Loss 18.198, MAE 2.858, Corr 0.984202
# Epoch : 207/2000, Train Loss : 15.696, Valid Loss 15.605, MAE 2.570, Corr 0.984137
# Epoch : 208/2000, Train Loss : 17.959, Valid Loss 14.460, MAE 2.360, Corr 0.985594
# Epoch : 209/2000, Train Loss : 15.136, Valid Loss 26.882, MAE 3.625, Corr 0.984816
# Epoch : 210/2000, Train Loss : 15.129, Valid Loss 14.676, MAE 2.503, Corr 0.985520
# Epoch : 211/2000, Train Loss : 13.033, Valid Loss 14.041, MAE 2.377, Corr 0.984754
# Best Valid Loss 14.0408
# Epoch : 212/2000, Train Loss : 14.046, Valid Loss 14.331, MAE 2.471, Corr 0.984460
# Epoch : 213/2000, Train Loss : 13.529, Valid Loss 14.448, MAE 2.631, Corr 0.984990
# Epoch : 214/2000, Train Loss : 18.339, Valid Loss 24.671, MAE 3.441, Corr 0.986205
# Epoch : 215/2000, Train Loss : 14.606, Valid Loss 13.809, MAE 2.468, Corr 0.985106
# Best Valid Loss 13.8094
# Epoch : 216/2000, Train Loss : 13.579, Valid Loss 15.063, MAE 2.437, Corr 0.984926
# Epoch : 217/2000, Train Loss : 13.226, Valid Loss 14.365, MAE 2.689, Corr 0.984775
# Epoch : 218/2000, Train Loss : 12.716, Valid Loss 20.738, MAE 2.872, Corr 0.982047
# Epoch : 219/2000, Train Loss : 13.355, Valid Loss 19.734, MAE 3.191, Corr 0.986940
# Epoch : 220/2000, Train Loss : 16.641, Valid Loss 14.593, MAE 2.386, Corr 0.985035
# Epoch : 221/2000, Train Loss : 18.624, Valid Loss 14.320, MAE 2.437, Corr 0.986164
# Epoch : 222/2000, Train Loss : 17.843, Valid Loss 13.893, MAE 2.491, Corr 0.983739
# Epoch : 223/2000, Train Loss : 12.699, Valid Loss 15.726, MAE 2.386, Corr 0.985902
# Epoch : 224/2000, Train Loss : 16.956, Valid Loss 19.041, MAE 3.332, Corr 0.984622
# Epoch : 225/2000, Train Loss : 14.507, Valid Loss 18.928, MAE 2.841, Corr 0.984170
# Epoch : 226/2000, Train Loss : 14.536, Valid Loss 14.226, MAE 2.498, Corr 0.985882
# Epoch : 227/2000, Train Loss : 12.773, Valid Loss 13.886, MAE 2.532, Corr 0.982696
# Epoch : 228/2000, Train Loss : 15.886, Valid Loss 21.162, MAE 3.519, Corr 0.986105
# Epoch : 229/2000, Train Loss : 17.972, Valid Loss 27.529, MAE 4.422, Corr 0.983852
# Epoch : 230/2000, Train Loss : 16.378, Valid Loss 24.429, MAE 3.231, Corr 0.985783
# Epoch : 231/2000, Train Loss : 16.111, Valid Loss 28.984, MAE 4.552, Corr 0.984779
# Epoch : 232/2000, Train Loss : 15.418, Valid Loss 19.730, MAE 3.037, Corr 0.985394
# Epoch : 233/2000, Train Loss : 14.209, Valid Loss 17.178, MAE 3.202, Corr 0.986460
# Epoch : 234/2000, Train Loss : 12.703, Valid Loss 15.291, MAE 2.691, Corr 0.982443
# Epoch : 235/2000, Train Loss : 13.849, Valid Loss 19.474, MAE 3.172, Corr 0.984476
# Epoch : 236/2000, Train Loss : 17.758, Valid Loss 13.650, MAE 2.286, Corr 0.985862
# Best Valid Loss 13.6500
# Epoch : 237/2000, Train Loss : 15.969, Valid Loss 24.807, MAE 3.715, Corr 0.983651
# Epoch : 238/2000, Train Loss : 13.878, Valid Loss 13.649, MAE 2.419, Corr 0.985757
# Best Valid Loss 13.6492
# Epoch : 239/2000, Train Loss : 11.391, Valid Loss 16.654, MAE 2.773, Corr 0.984852
# Epoch : 240/2000, Train Loss : 13.888, Valid Loss 14.291, MAE 2.743, Corr 0.986081
# Epoch : 241/2000, Train Loss : 18.579, Valid Loss 14.053, MAE 2.464, Corr 0.984323
# Epoch : 242/2000, Train Loss : 16.674, Valid Loss 20.384, MAE 3.609, Corr 0.982177
# Epoch : 243/2000, Train Loss : 24.763, Valid Loss 15.128, MAE 2.522, Corr 0.984803
# Epoch : 244/2000, Train Loss : 13.064, Valid Loss 18.344, MAE 2.922, Corr 0.985515
# Epoch : 245/2000, Train Loss : 18.281, Valid Loss 32.187, MAE 4.201, Corr 0.984396
# Epoch : 246/2000, Train Loss : 16.036, Valid Loss 13.796, MAE 2.529, Corr 0.983732
# Epoch : 247/2000, Train Loss : 15.356, Valid Loss 13.305, MAE 2.428, Corr 0.985473
# Best Valid Loss 13.3053
# Epoch : 248/2000, Train Loss : 18.205, Valid Loss 31.083, MAE 4.165, Corr 0.985138
# Epoch : 249/2000, Train Loss : 17.670, Valid Loss 13.664, MAE 2.514, Corr 0.985599
# Epoch : 250/2000, Train Loss : 13.572, Valid Loss 31.920, MAE 4.261, Corr 0.982167
# Epoch : 251/2000, Train Loss : 19.981, Valid Loss 21.733, MAE 2.979, Corr 0.980461
# Epoch : 252/2000, Train Loss : 15.158, Valid Loss 14.008, MAE 2.585, Corr 0.982390
# Epoch : 253/2000, Train Loss : 16.743, Valid Loss 14.416, MAE 2.656, Corr 0.985923
# Epoch : 254/2000, Train Loss : 20.750, Valid Loss 28.033, MAE 4.463, Corr 0.983719
# Epoch : 255/2000, Train Loss : 16.667, Valid Loss 17.849, MAE 3.011, Corr 0.983630
# Epoch : 256/2000, Train Loss : 18.947, Valid Loss 15.351, MAE 2.673, Corr 0.984383
# Epoch : 257/2000, Train Loss : 12.927, Valid Loss 13.000, MAE 2.452, Corr 0.985400
# Best Valid Loss 13.0002
# Epoch : 258/2000, Train Loss : 12.370, Valid Loss 16.673, MAE 2.881, Corr 0.985059
# Epoch : 259/2000, Train Loss : 15.025, Valid Loss 14.762, MAE 2.644, Corr 0.981871
# Epoch : 260/2000, Train Loss : 13.825, Valid Loss 14.069, MAE 2.599, Corr 0.984328
# Epoch : 261/2000, Train Loss : 12.804, Valid Loss 12.731, MAE 2.344, Corr 0.985006
# Best Valid Loss 12.7307
# Epoch : 262/2000, Train Loss : 11.224, Valid Loss 12.960, MAE 2.466, Corr 0.985428
# Epoch : 263/2000, Train Loss : 12.467, Valid Loss 13.693, MAE 2.431, Corr 0.985679
# Epoch : 264/2000, Train Loss : 12.288, Valid Loss 17.798, MAE 3.360, Corr 0.984503
# Epoch : 265/2000, Train Loss : 11.950, Valid Loss 12.852, MAE 2.376, Corr 0.986377
# Epoch : 266/2000, Train Loss : 11.670, Valid Loss 13.368, MAE 2.323, Corr 0.985099
# Epoch : 267/2000, Train Loss : 12.033, Valid Loss 13.038, MAE 2.403, Corr 0.984734
# Epoch : 268/2000, Train Loss : 14.591, Valid Loss 13.406, MAE 2.666, Corr 0.984408
# Epoch : 269/2000, Train Loss : 10.568, Valid Loss 14.224, MAE 2.740, Corr 0.985532
# Epoch : 270/2000, Train Loss : 11.627, Valid Loss 12.425, MAE 2.297, Corr 0.986671
# Best Valid Loss 12.4247
# Epoch : 271/2000, Train Loss : 13.105, Valid Loss 19.294, MAE 2.901, Corr 0.984131
# Epoch : 272/2000, Train Loss : 15.104, Valid Loss 12.589, MAE 2.401, Corr 0.985872
# Epoch : 273/2000, Train Loss : 12.106, Valid Loss 13.301, MAE 2.567, Corr 0.984243
# Epoch : 274/2000, Train Loss : 10.675, Valid Loss 12.967, MAE 2.311, Corr 0.986349
# Epoch : 275/2000, Train Loss : 10.516, Valid Loss 16.062, MAE 2.829, Corr 0.984452
# Epoch : 276/2000, Train Loss : 13.291, Valid Loss 20.666, MAE 3.809, Corr 0.986656
# Epoch : 277/2000, Train Loss : 14.345, Valid Loss 14.144, MAE 2.764, Corr 0.984763
# Epoch : 278/2000, Train Loss : 11.242, Valid Loss 14.208, MAE 2.356, Corr 0.986430
# Epoch : 279/2000, Train Loss : 12.654, Valid Loss 13.791, MAE 2.850, Corr 0.987479
# Epoch : 280/2000, Train Loss : 12.481, Valid Loss 12.598, MAE 2.351, Corr 0.985075
# Epoch : 281/2000, Train Loss : 11.923, Valid Loss 22.150, MAE 3.717, Corr 0.984056
# Epoch : 282/2000, Train Loss : 16.314, Valid Loss 12.774, MAE 2.365, Corr 0.985624
# Epoch : 283/2000, Train Loss : 9.928, Valid Loss 12.846, MAE 2.593, Corr 0.984866
# Epoch : 284/2000, Train Loss : 12.739, Valid Loss 16.635, MAE 2.838, Corr 0.983157
# Epoch : 285/2000, Train Loss : 12.400, Valid Loss 21.110, MAE 3.395, Corr 0.984945
# Epoch : 286/2000, Train Loss : 14.165, Valid Loss 15.525, MAE 2.691, Corr 0.982817
# Epoch : 287/2000, Train Loss : 11.521, Valid Loss 11.944, MAE 2.207, Corr 0.986639
# Best Valid Loss 11.9437
# Epoch : 288/2000, Train Loss : 13.580, Valid Loss 11.902, MAE 2.257, Corr 0.985525
# Best Valid Loss 11.9023
# Epoch : 289/2000, Train Loss : 10.642, Valid Loss 12.087, MAE 2.421, Corr 0.985318
# Epoch : 290/2000, Train Loss : 14.205, Valid Loss 13.846, MAE 2.404, Corr 0.985193
# Epoch : 291/2000, Train Loss : 10.187, Valid Loss 14.754, MAE 2.959, Corr 0.985852
# Epoch : 292/2000, Train Loss : 16.160, Valid Loss 34.940, MAE 5.103, Corr 0.982732
# Epoch : 293/2000, Train Loss : 19.925, Valid Loss 20.873, MAE 2.912, Corr 0.980098
# Epoch : 294/2000, Train Loss : 15.745, Valid Loss 14.063, MAE 2.525, Corr 0.983612
# Epoch : 295/2000, Train Loss : 14.452, Valid Loss 12.207, MAE 2.291, Corr 0.985467
# Epoch : 296/2000, Train Loss : 11.724, Valid Loss 14.737, MAE 2.708, Corr 0.985343
# Epoch : 297/2000, Train Loss : 11.208, Valid Loss 13.530, MAE 2.446, Corr 0.984070
# Epoch : 298/2000, Train Loss : 13.323, Valid Loss 14.659, MAE 2.864, Corr 0.984023
# Epoch : 299/2000, Train Loss : 11.379, Valid Loss 12.269, MAE 2.357, Corr 0.985135
# Epoch : 300/2000, Train Loss : 10.102, Valid Loss 19.417, MAE 3.562, Corr 0.985221
# Epoch : 301/2000, Train Loss : 10.322, Valid Loss 11.655, MAE 2.259, Corr 0.985151
# Best Valid Loss 11.6546
# Epoch : 302/2000, Train Loss : 10.928, Valid Loss 19.055, MAE 3.269, Corr 0.985903
# Epoch : 303/2000, Train Loss : 10.427, Valid Loss 12.597, MAE 2.514, Corr 0.982832
# Epoch : 304/2000, Train Loss : 9.700, Valid Loss 12.008, MAE 2.350, Corr 0.985006
# Epoch : 305/2000, Train Loss : 11.479, Valid Loss 12.217, MAE 2.419, Corr 0.984745
# Epoch : 306/2000, Train Loss : 13.537, Valid Loss 22.697, MAE 3.643, Corr 0.986935
# Epoch : 307/2000, Train Loss : 34.061, Valid Loss 37.134, MAE 5.245, Corr 0.985443
# Epoch : 308/2000, Train Loss : 18.378, Valid Loss 21.402, MAE 4.045, Corr 0.983599
# Epoch : 309/2000, Train Loss : 15.092, Valid Loss 12.460, MAE 2.360, Corr 0.984867
# Epoch : 310/2000, Train Loss : 15.684, Valid Loss 19.015, MAE 3.146, Corr 0.986515
# Epoch : 311/2000, Train Loss : 10.945, Valid Loss 12.473, MAE 2.463, Corr 0.985460
# Epoch : 312/2000, Train Loss : 10.861, Valid Loss 12.711, MAE 2.483, Corr 0.986331
# Epoch : 313/2000, Train Loss : 9.595, Valid Loss 11.830, MAE 2.298, Corr 0.985354
# Epoch : 314/2000, Train Loss : 9.906, Valid Loss 19.504, MAE 3.747, Corr 0.984191
# Epoch : 315/2000, Train Loss : 13.374, Valid Loss 11.723, MAE 2.394, Corr 0.983808
# Epoch : 316/2000, Train Loss : 14.502, Valid Loss 15.182, MAE 2.690, Corr 0.982991
# Epoch : 317/2000, Train Loss : 10.389, Valid Loss 17.536, MAE 3.259, Corr 0.985349
# Epoch : 318/2000, Train Loss : 12.094, Valid Loss 26.578, MAE 3.640, Corr 0.984088
# Epoch : 319/2000, Train Loss : 16.899, Valid Loss 11.957, MAE 2.379, Corr 0.984371
# Epoch : 320/2000, Train Loss : 10.483, Valid Loss 13.011, MAE 2.404, Corr 0.983715
# Epoch : 321/2000, Train Loss : 11.285, Valid Loss 19.320, MAE 3.666, Corr 0.983559
# Epoch : 322/2000, Train Loss : 12.390, Valid Loss 25.782, MAE 4.380, Corr 0.985669
# Early stopping
# Best Result : Epoch 301, Valid Loss 11.655, MAE 2.259, Corr 0.985151

# %%
# scatter plot

file_path = "D:\gait_dataset/salted/test/*"
inputs_acc, inputs_gyr, stride_length = get_sensor_salted(file_path, normalization=True)
inputs_pst = get_position_salted(file_path, distance=True)
inputs_acc, inputs_gyr, stride_length, inputs_pst = torch.Tensor(np.array(inputs_acc)), torch.Tensor(np.array(inputs_gyr)), torch.Tensor(np.array(stride_length)), torch.Tensor(np.array(inputs_pst))
inputs_acc, inputs_gyr, stride_length, inputs_pst = inputs_acc.float(), inputs_gyr.float(), stride_length.float(), inputs_pst.float()
inputs_acc, inputs_gyr, inputs_pst = inputs_acc.to(device), inputs_gyr.to(device), inputs_pst.to(device)

# %%
input_dim = 300
lstm_dim = 64
num_layers = 1
dense_dim = 512


model = Encoder_lstm(input_dim, lstm_dim, num_layers, dense_dim).to(device)
model.load_state_dict(torch.load('./model/encoder_dist_best_ks30_bias.pth'))
model.eval()
# Out:
# Encoder_lstm(
#   (lstm_acc): LSTM(300, 64, batch_first=True)
#   (lstm_gyr): LSTM(300, 64, batch_first=True)
#   (dense): Sequential(
#     (0): Linear(in_features=128, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=128, out_features=64, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Linear(in_features=64, out_features=3, bias=True)
#   )
# )

# %%
pred = model(inputs_acc, inputs_gyr, inputs_pst).detach().cpu().numpy()

plt.figure(figsize=(10, 10))
plt.scatter(stride_length, np.round(pred, 4))
plt.xlim([50, 250])
plt.xlabel('stride_length')
plt.ylim([50, 250])
plt.ylabel('pred')

xpoints = ypoints = plt.xlim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)

plt.show()

# %% [markdown]
# ## FC
# - Best Result : Epoch 202, Valid Loss 15.980, MAE 2.838, Corr 0.978071

# %% [markdown]
# ### 데이터 불러오기

# %%
device = torch.device('cuda:0' if torch.cuda.is_available else 'cpu')

file_path = "D:\gait_dataset/salted/train/*"
dataset = Gait_Dataset_Salted(file_path, bias=False)
val_percent = 0.2
n_val = int(len(dataset) * val_percent)
n_train = len(dataset) - n_val
train, val = random_split(dataset, [n_train, n_val])

# %%
train_loader = torch.utils.data.DataLoader(train,
                                           batch_size=128,
                                           shuffle=True,
                                           worker_init_fn=np.random.seed(42))
val_loader = torch.utils.data.DataLoader(val,
                                         batch_size=128,
                                         shuffle=False)

# %% [markdown]
# ### Model & Scatter Plot

# %%
# seed 고정
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

class Encoder_fc(nn.Module):
    def __init__(self, input_dim, dense_dim):
        super(Encoder_fc, self).__init__()
        
        self.fc_acc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(input_dim, dense_dim),
            nn.ReLU(inplace=True),
            nn.Linear(dense_dim, int(dense_dim/2)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/2), int(dense_dim/4)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/4), int(dense_dim/8)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/8), 3)
        )
            
        self.fc_gyr = nn.Sequential(
            nn.Flatten(),
            nn.Linear(input_dim, dense_dim),
            nn.ReLU(inplace=True),
            nn.Linear(dense_dim, int(dense_dim/2)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/2), int(dense_dim/4)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/4), int(dense_dim/8)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/8), 3)
        )
        

    def forward(self, inputs_acc, inputs_gyr, inputs_pst): 
        
        
        fc_output_acc = self.fc_acc(inputs_acc)
        fc_output_gyr = self.fc_gyr(inputs_gyr)
    
        enc_output = fc_output_acc+fc_output_gyr
        output = torch.unsqueeze(torch.sum(enc_output*inputs_pst, axis=1), 1)
        
        return output

# %%
input_dim = 900
dense_dim = 512


model = Encoder_fc(input_dim, dense_dim).to(device)
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
n_epochs = 2000

criterion = nn.MSELoss()

# %%
# Early Stopping을 위한 변수
best = 1000
converge_cnt = 0
best_MAE = 0
best_corr = 0
best_epoch = 0

# Run Training loop
for epoch in range(0, n_epochs) :
    # Set current loss value 
    tot_trn_loss = 0.0
    
    # Train Mode
    model.train()
    
    # Iterate over the DataLoader for training data 
    for i, data in enumerate(train_loader) :
        inputs_acc, inputs_gyr, stride_length, inputs_pst = data
        inputs_acc, inputs_gyr, stride_length, inputs_pst = inputs_acc.float(), inputs_gyr.float(), stride_length.float(), inputs_pst.float()
        inputs_acc, inputs_gyr, inputs_pst = inputs_acc.to(device), inputs_gyr.to(device), inputs_pst.to(device)
        stride_length = stride_length.reshape(-1, 1)
        stride_length = stride_length.to(device)

        # 순전파 
        outputs = model(inputs_acc, inputs_gyr, inputs_pst)

        # Loss 계산
        loss = criterion(outputs, stride_length)
        
        # 기울기 초기화 
        optimizer.zero_grad()
        # 역전파
        loss.backward()
        # 옵티마이저
        optimizer.step()
        
        # Print statistics
        tot_trn_loss += loss.item()
        
    # Evaluation Mode
    model.eval()
    
    tot_val_loss = 0
    val_epoch_loss = []

    with torch.no_grad() :
        for i, data in enumerate(val_loader):
            inputs_acc, inputs_gyr, stride_length, inputs_pst = data
            inputs_acc, inputs_gyr, stride_length, inputs_pst = inputs_acc.float(), inputs_gyr.float(), stride_length.float(), inputs_pst.float()
            inputs_acc, inputs_gyr, inputs_pst = inputs_acc.to(device), inputs_gyr.to(device), inputs_pst.to(device)
            stride_length = stride_length.reshape(-1, 1)
            stride_length = stride_length.to(device)

            # 순전파 
            outputs = model(inputs_acc, inputs_gyr, inputs_pst)
            
            # Loss 계산
            loss = criterion(outputs, stride_length)
            tot_val_loss += loss.item()            
            

    # Epoch 별 Loss
    trn_loss = tot_trn_loss / len(train_loader)
    val_loss = tot_val_loss / len(val_loader)
    MAE = torch.sum(torch.abs(outputs - stride_length)) / len(stride_length)
    corr = torch.corrcoef(torch.stack([torch.squeeze(stride_length), torch.squeeze(outputs)]))[0, 1]
    
    
    
    print("Epoch : {}/{}, Train Loss : {:.3f}, Valid Loss {:.3f}, MAE {:.3f}, Corr {:3f}".format(epoch+1, n_epochs,
                                                                                       trn_loss, val_loss,
                                                                                      MAE, corr))
    
    # Early Stopping
    if val_loss < best:
        best = np.mean(val_loss)
        best_MAE = MAE
        best_corr = corr
        best_epoch = epoch+1
        torch.save(model.state_dict(), './model/encoder_fc_best_ks30_bias.pth')
        print('Best Valid Loss {:.4f}'.format(best))
        converge_cnt = 0
    else:
        converge_cnt += 1
    
    if converge_cnt > 20:
        print('Early stopping')
        print('Best Result : Epoch {}, Valid Loss {:.3f}, MAE {:.3f}, Corr {:3f}'.format(best_epoch, best, best_MAE, best_corr))
        break
    
#     print("Epoch : {}/{} Epoch Loss : {:.6f}".format(epoch+1, n_epochs, current_loss / len(trainloader.dataset)))
# Out:
# Epoch : 1/2000, Train Loss : 10589.328, Valid Loss 2840.316, MAE 51.328, Corr 0.758227
# Epoch : 2/2000, Train Loss : 792.145, Valid Loss 459.394, MAE 18.621, Corr 0.764055
# Best Valid Loss 459.3944
# Epoch : 3/2000, Train Loss : 262.022, Valid Loss 158.407, MAE 9.931, Corr 0.769647
# Best Valid Loss 158.4069
# Epoch : 4/2000, Train Loss : 184.241, Valid Loss 157.846, MAE 9.435, Corr 0.774622
# Best Valid Loss 157.8457
# Epoch : 5/2000, Train Loss : 168.792, Valid Loss 147.891, MAE 9.726, Corr 0.778792
# Best Valid Loss 147.8908
# Epoch : 6/2000, Train Loss : 164.063, Valid Loss 143.390, MAE 9.593, Corr 0.782603
# Best Valid Loss 143.3895
# Epoch : 7/2000, Train Loss : 159.547, Valid Loss 140.427, MAE 9.456, Corr 0.786012
# Best Valid Loss 140.4275
# Epoch : 8/2000, Train Loss : 156.333, Valid Loss 142.234, MAE 9.656, Corr 0.788876
# Epoch : 9/2000, Train Loss : 154.132, Valid Loss 137.248, MAE 9.258, Corr 0.791679
# Best Valid Loss 137.2480
# Epoch : 10/2000, Train Loss : 151.609, Valid Loss 138.226, MAE 9.170, Corr 0.794145
# Epoch : 11/2000, Train Loss : 149.902, Valid Loss 133.171, MAE 9.246, Corr 0.796410
# Best Valid Loss 133.1711
# Epoch : 12/2000, Train Loss : 147.632, Valid Loss 133.343, MAE 9.082, Corr 0.798891
# Epoch : 13/2000, Train Loss : 147.500, Valid Loss 130.621, MAE 9.097, Corr 0.801043
# Best Valid Loss 130.6207
# Epoch : 14/2000, Train Loss : 147.464, Valid Loss 129.769, MAE 8.976, Corr 0.803690
# Best Valid Loss 129.7687
# Epoch : 15/2000, Train Loss : 143.879, Valid Loss 128.338, MAE 8.928, Corr 0.805864
# Best Valid Loss 128.3375
# Epoch : 16/2000, Train Loss : 142.480, Valid Loss 127.286, MAE 8.845, Corr 0.808595
# Best Valid Loss 127.2862
# Epoch : 17/2000, Train Loss : 141.250, Valid Loss 127.167, MAE 8.843, Corr 0.810823
# Best Valid Loss 127.1666
# Epoch : 18/2000, Train Loss : 141.247, Valid Loss 125.421, MAE 8.757, Corr 0.813343
# Best Valid Loss 125.4215
# Epoch : 19/2000, Train Loss : 138.831, Valid Loss 124.047, MAE 8.668, Corr 0.816011
# Best Valid Loss 124.0472
# Epoch : 20/2000, Train Loss : 139.179, Valid Loss 123.704, MAE 8.603, Corr 0.818654
# Best Valid Loss 123.7039
# Epoch : 21/2000, Train Loss : 138.360, Valid Loss 124.295, MAE 8.572, Corr 0.821359
# Epoch : 22/2000, Train Loss : 135.513, Valid Loss 121.294, MAE 8.455, Corr 0.824022
# Best Valid Loss 121.2940
# Epoch : 23/2000, Train Loss : 134.630, Valid Loss 123.476, MAE 8.518, Corr 0.826728
# Epoch : 24/2000, Train Loss : 134.749, Valid Loss 118.294, MAE 8.331, Corr 0.829372
# Best Valid Loss 118.2942
# Epoch : 25/2000, Train Loss : 131.735, Valid Loss 117.198, MAE 8.261, Corr 0.831997
# Best Valid Loss 117.1984
# Epoch : 26/2000, Train Loss : 130.919, Valid Loss 116.112, MAE 8.189, Corr 0.835087
# Best Valid Loss 116.1123
# Epoch : 27/2000, Train Loss : 129.044, Valid Loss 128.460, MAE 8.554, Corr 0.837777
# Epoch : 28/2000, Train Loss : 133.463, Valid Loss 113.856, MAE 8.081, Corr 0.840758
# Best Valid Loss 113.8563
# Epoch : 29/2000, Train Loss : 127.534, Valid Loss 116.771, MAE 8.208, Corr 0.843395
# Epoch : 30/2000, Train Loss : 125.942, Valid Loss 112.461, MAE 7.980, Corr 0.846306
# Best Valid Loss 112.4606
# Epoch : 31/2000, Train Loss : 124.492, Valid Loss 114.179, MAE 7.938, Corr 0.849564
# Epoch : 32/2000, Train Loss : 122.614, Valid Loss 113.706, MAE 7.869, Corr 0.852575
# Epoch : 33/2000, Train Loss : 119.223, Valid Loss 109.529, MAE 7.815, Corr 0.856070
# Best Valid Loss 109.5287
# Epoch : 34/2000, Train Loss : 119.669, Valid Loss 107.271, MAE 7.696, Corr 0.859125
# Best Valid Loss 107.2706
# Epoch : 35/2000, Train Loss : 115.999, Valid Loss 105.074, MAE 7.608, Corr 0.862267
# Best Valid Loss 105.0737
# Epoch : 36/2000, Train Loss : 114.952, Valid Loss 103.786, MAE 7.538, Corr 0.865522
# Best Valid Loss 103.7864
# Epoch : 37/2000, Train Loss : 114.030, Valid Loss 104.877, MAE 7.557, Corr 0.868992
# Epoch : 38/2000, Train Loss : 113.206, Valid Loss 100.966, MAE 7.358, Corr 0.871608
# Best Valid Loss 100.9656
# Epoch : 39/2000, Train Loss : 109.330, Valid Loss 100.040, MAE 7.268, Corr 0.874244
# Best Valid Loss 100.0401
# Epoch : 40/2000, Train Loss : 111.810, Valid Loss 106.263, MAE 7.390, Corr 0.877383
# Epoch : 41/2000, Train Loss : 105.312, Valid Loss 98.699, MAE 7.148, Corr 0.880387
# Best Valid Loss 98.6987
# Epoch : 42/2000, Train Loss : 103.494, Valid Loss 95.370, MAE 7.050, Corr 0.883907
# Best Valid Loss 95.3697
# Epoch : 43/2000, Train Loss : 101.983, Valid Loss 93.007, MAE 7.073, Corr 0.887263
# Best Valid Loss 93.0074
# Epoch : 44/2000, Train Loss : 98.199, Valid Loss 93.356, MAE 7.139, Corr 0.890549
# Epoch : 45/2000, Train Loss : 100.425, Valid Loss 90.853, MAE 7.049, Corr 0.893448
# Best Valid Loss 90.8527
# Epoch : 46/2000, Train Loss : 93.695, Valid Loss 87.458, MAE 6.861, Corr 0.896592
# Best Valid Loss 87.4577
# Epoch : 47/2000, Train Loss : 93.741, Valid Loss 87.068, MAE 6.890, Corr 0.898940
# Best Valid Loss 87.0676
# Epoch : 48/2000, Train Loss : 91.745, Valid Loss 84.626, MAE 6.745, Corr 0.901708
# Best Valid Loss 84.6260
# Epoch : 49/2000, Train Loss : 90.818, Valid Loss 81.195, MAE 6.615, Corr 0.904177
# Best Valid Loss 81.1952
# Epoch : 50/2000, Train Loss : 85.041, Valid Loss 79.017, MAE 6.495, Corr 0.906611
# Best Valid Loss 79.0170
# Epoch : 51/2000, Train Loss : 81.058, Valid Loss 78.078, MAE 6.387, Corr 0.910171
# Best Valid Loss 78.0783
# Epoch : 52/2000, Train Loss : 79.091, Valid Loss 90.639, MAE 7.124, Corr 0.912552
# Epoch : 53/2000, Train Loss : 86.115, Valid Loss 81.798, MAE 6.695, Corr 0.914251
# Epoch : 54/2000, Train Loss : 79.438, Valid Loss 71.074, MAE 6.123, Corr 0.918899
# Best Valid Loss 71.0736
# Epoch : 55/2000, Train Loss : 71.412, Valid Loss 71.590, MAE 6.272, Corr 0.922092
# Epoch : 56/2000, Train Loss : 67.798, Valid Loss 65.472, MAE 5.860, Corr 0.926395
# Best Valid Loss 65.4721
# Epoch : 57/2000, Train Loss : 65.490, Valid Loss 73.733, MAE 6.674, Corr 0.929537
# Epoch : 58/2000, Train Loss : 70.709, Valid Loss 77.191, MAE 6.383, Corr 0.931879
# Epoch : 59/2000, Train Loss : 61.930, Valid Loss 57.195, MAE 5.400, Corr 0.936634
# Best Valid Loss 57.1951
# Epoch : 60/2000, Train Loss : 58.273, Valid Loss 54.782, MAE 5.018, Corr 0.938990
# Best Valid Loss 54.7817
# Epoch : 61/2000, Train Loss : 61.210, Valid Loss 55.414, MAE 5.499, Corr 0.941188
# Epoch : 62/2000, Train Loss : 53.557, Valid Loss 56.616, MAE 5.100, Corr 0.943235
# Epoch : 63/2000, Train Loss : 53.833, Valid Loss 48.132, MAE 4.796, Corr 0.945534
# Best Valid Loss 48.1320
# Epoch : 64/2000, Train Loss : 47.663, Valid Loss 46.042, MAE 4.622, Corr 0.948022
# Best Valid Loss 46.0419
# Epoch : 65/2000, Train Loss : 52.922, Valid Loss 44.482, MAE 4.434, Corr 0.951890
# Best Valid Loss 44.4815
# Epoch : 66/2000, Train Loss : 50.763, Valid Loss 43.732, MAE 4.359, Corr 0.951378
# Best Valid Loss 43.7320
# Epoch : 67/2000, Train Loss : 60.212, Valid Loss 42.580, MAE 4.210, Corr 0.952994
# Best Valid Loss 42.5796
# Epoch : 68/2000, Train Loss : 59.215, Valid Loss 47.534, MAE 4.679, Corr 0.957135
# Epoch : 69/2000, Train Loss : 47.085, Valid Loss 45.765, MAE 4.536, Corr 0.957288
# Epoch : 70/2000, Train Loss : 44.368, Valid Loss 39.959, MAE 4.294, Corr 0.957496
# Best Valid Loss 39.9590
# Epoch : 71/2000, Train Loss : 40.002, Valid Loss 40.453, MAE 4.358, Corr 0.958717
# Epoch : 72/2000, Train Loss : 45.956, Valid Loss 44.966, MAE 4.906, Corr 0.962310
# Epoch : 73/2000, Train Loss : 43.526, Valid Loss 46.736, MAE 5.174, Corr 0.964335
# Epoch : 74/2000, Train Loss : 41.422, Valid Loss 42.542, MAE 4.505, Corr 0.963046
# Epoch : 75/2000, Train Loss : 39.627, Valid Loss 53.821, MAE 5.338, Corr 0.962954
# Epoch : 76/2000, Train Loss : 41.025, Valid Loss 52.063, MAE 5.213, Corr 0.963973
# Epoch : 77/2000, Train Loss : 41.230, Valid Loss 38.896, MAE 4.401, Corr 0.964043
# Best Valid Loss 38.8961
# Epoch : 78/2000, Train Loss : 40.024, Valid Loss 34.663, MAE 3.902, Corr 0.967886
# Best Valid Loss 34.6632
# Epoch : 79/2000, Train Loss : 35.824, Valid Loss 36.529, MAE 4.025, Corr 0.968630
# Epoch : 80/2000, Train Loss : 40.151, Valid Loss 40.213, MAE 4.305, Corr 0.964781
# Epoch : 81/2000, Train Loss : 41.704, Valid Loss 33.557, MAE 3.658, Corr 0.969590
# Best Valid Loss 33.5571
# Epoch : 82/2000, Train Loss : 34.625, Valid Loss 33.444, MAE 3.732, Corr 0.971579
# Best Valid Loss 33.4444
# Epoch : 83/2000, Train Loss : 35.774, Valid Loss 47.593, MAE 5.340, Corr 0.967891
# Epoch : 84/2000, Train Loss : 39.814, Valid Loss 37.803, MAE 4.076, Corr 0.972469
# Epoch : 85/2000, Train Loss : 37.179, Valid Loss 42.752, MAE 4.843, Corr 0.964449
# Epoch : 86/2000, Train Loss : 40.322, Valid Loss 40.290, MAE 4.565, Corr 0.973000
# Epoch : 87/2000, Train Loss : 34.722, Valid Loss 33.300, MAE 3.989, Corr 0.971779
# Best Valid Loss 33.3003
# Epoch : 88/2000, Train Loss : 32.496, Valid Loss 48.852, MAE 5.101, Corr 0.967488
# Epoch : 89/2000, Train Loss : 45.489, Valid Loss 44.193, MAE 4.824, Corr 0.967817
# Epoch : 90/2000, Train Loss : 36.337, Valid Loss 31.580, MAE 3.588, Corr 0.971525
# Best Valid Loss 31.5796
# Epoch : 91/2000, Train Loss : 31.100, Valid Loss 33.198, MAE 4.072, Corr 0.971403
# Epoch : 92/2000, Train Loss : 33.841, Valid Loss 33.444, MAE 3.707, Corr 0.972700
# Epoch : 93/2000, Train Loss : 31.109, Valid Loss 29.741, MAE 3.412, Corr 0.973569
# Best Valid Loss 29.7413
# Epoch : 94/2000, Train Loss : 33.638, Valid Loss 29.517, MAE 3.371, Corr 0.970120
# Best Valid Loss 29.5175
# Epoch : 95/2000, Train Loss : 29.154, Valid Loss 31.482, MAE 3.970, Corr 0.972580
# Epoch : 96/2000, Train Loss : 31.016, Valid Loss 31.147, MAE 3.750, Corr 0.974291
# Epoch : 97/2000, Train Loss : 29.645, Valid Loss 33.878, MAE 3.703, Corr 0.973902
# Epoch : 98/2000, Train Loss : 29.067, Valid Loss 28.009, MAE 3.290, Corr 0.973089
# Best Valid Loss 28.0092
# Epoch : 99/2000, Train Loss : 29.760, Valid Loss 35.197, MAE 3.968, Corr 0.968582
# Epoch : 100/2000, Train Loss : 32.426, Valid Loss 27.500, MAE 3.506, Corr 0.973087
# Best Valid Loss 27.4999
# Epoch : 101/2000, Train Loss : 31.665, Valid Loss 30.738, MAE 3.506, Corr 0.976294
# Epoch : 102/2000, Train Loss : 39.279, Valid Loss 31.256, MAE 3.699, Corr 0.969269
# Epoch : 103/2000, Train Loss : 46.753, Valid Loss 58.855, MAE 5.587, Corr 0.974765
# Epoch : 104/2000, Train Loss : 41.133, Valid Loss 64.848, MAE 6.214, Corr 0.969304
# Epoch : 105/2000, Train Loss : 39.645, Valid Loss 33.625, MAE 3.836, Corr 0.972115
# Epoch : 106/2000, Train Loss : 30.479, Valid Loss 27.177, MAE 3.344, Corr 0.972066
# Best Valid Loss 27.1767
# Epoch : 107/2000, Train Loss : 30.633, Valid Loss 28.565, MAE 3.367, Corr 0.972944
# Epoch : 108/2000, Train Loss : 32.816, Valid Loss 28.428, MAE 3.476, Corr 0.973488
# Epoch : 109/2000, Train Loss : 28.076, Valid Loss 26.821, MAE 3.337, Corr 0.972228
# Best Valid Loss 26.8210
# Epoch : 110/2000, Train Loss : 25.278, Valid Loss 26.244, MAE 3.269, Corr 0.972558
# Best Valid Loss 26.2437
# Epoch : 111/2000, Train Loss : 26.350, Valid Loss 29.416, MAE 3.476, Corr 0.970742
# Epoch : 112/2000, Train Loss : 26.874, Valid Loss 43.388, MAE 4.382, Corr 0.975621
# Epoch : 113/2000, Train Loss : 30.146, Valid Loss 31.973, MAE 4.363, Corr 0.975133
# Epoch : 114/2000, Train Loss : 25.255, Valid Loss 25.180, MAE 3.477, Corr 0.973132
# Best Valid Loss 25.1802
# Epoch : 115/2000, Train Loss : 31.035, Valid Loss 26.274, MAE 3.636, Corr 0.973254
# Epoch : 116/2000, Train Loss : 27.428, Valid Loss 26.027, MAE 3.333, Corr 0.972530
# Epoch : 117/2000, Train Loss : 25.676, Valid Loss 31.351, MAE 4.261, Corr 0.972555
# Epoch : 118/2000, Train Loss : 30.540, Valid Loss 25.420, MAE 3.314, Corr 0.970513
# Epoch : 119/2000, Train Loss : 26.754, Valid Loss 26.016, MAE 3.536, Corr 0.974598
# Epoch : 120/2000, Train Loss : 24.023, Valid Loss 24.634, MAE 3.420, Corr 0.970983
# Best Valid Loss 24.6338
# Epoch : 121/2000, Train Loss : 23.984, Valid Loss 26.757, MAE 3.525, Corr 0.976194
# Epoch : 122/2000, Train Loss : 22.770, Valid Loss 25.575, MAE 3.122, Corr 0.973822
# Epoch : 123/2000, Train Loss : 23.748, Valid Loss 30.372, MAE 3.715, Corr 0.974219
# Epoch : 124/2000, Train Loss : 24.231, Valid Loss 22.858, MAE 2.999, Corr 0.973672
# Best Valid Loss 22.8582
# Epoch : 125/2000, Train Loss : 28.032, Valid Loss 24.329, MAE 3.293, Corr 0.974218
# Epoch : 126/2000, Train Loss : 24.505, Valid Loss 23.800, MAE 3.071, Corr 0.972214
# Epoch : 127/2000, Train Loss : 31.791, Valid Loss 38.082, MAE 4.964, Corr 0.974666
# Epoch : 128/2000, Train Loss : 32.881, Valid Loss 47.346, MAE 4.689, Corr 0.977211
# Epoch : 129/2000, Train Loss : 27.453, Valid Loss 23.200, MAE 3.122, Corr 0.975503
# Epoch : 130/2000, Train Loss : 23.669, Valid Loss 28.881, MAE 3.857, Corr 0.976975
# Epoch : 131/2000, Train Loss : 30.904, Valid Loss 51.693, MAE 5.648, Corr 0.971861
# Epoch : 132/2000, Train Loss : 32.172, Valid Loss 27.312, MAE 3.872, Corr 0.973380
# Epoch : 133/2000, Train Loss : 27.915, Valid Loss 25.582, MAE 3.805, Corr 0.972497
# Epoch : 134/2000, Train Loss : 30.102, Valid Loss 25.643, MAE 3.799, Corr 0.972711
# Epoch : 135/2000, Train Loss : 27.819, Valid Loss 26.057, MAE 3.313, Corr 0.973385
# Epoch : 136/2000, Train Loss : 30.317, Valid Loss 26.361, MAE 3.776, Corr 0.969747
# Epoch : 137/2000, Train Loss : 25.018, Valid Loss 25.077, MAE 3.065, Corr 0.977094
# Epoch : 138/2000, Train Loss : 25.632, Valid Loss 24.997, MAE 3.169, Corr 0.976574
# Epoch : 139/2000, Train Loss : 27.140, Valid Loss 32.373, MAE 4.269, Corr 0.976940
# Epoch : 140/2000, Train Loss : 20.669, Valid Loss 22.187, MAE 3.033, Corr 0.977252
# Best Valid Loss 22.1874
# Epoch : 141/2000, Train Loss : 20.568, Valid Loss 24.639, MAE 3.155, Corr 0.969695
# Epoch : 142/2000, Train Loss : 20.661, Valid Loss 21.155, MAE 3.092, Corr 0.974948
# Best Valid Loss 21.1554
# Epoch : 143/2000, Train Loss : 25.812, Valid Loss 21.095, MAE 2.850, Corr 0.976785
# Best Valid Loss 21.0950
# Epoch : 144/2000, Train Loss : 26.307, Valid Loss 33.049, MAE 3.867, Corr 0.974620
# Epoch : 145/2000, Train Loss : 25.742, Valid Loss 23.334, MAE 2.912, Corr 0.975574
# Epoch : 146/2000, Train Loss : 19.777, Valid Loss 30.217, MAE 4.219, Corr 0.975352
# Epoch : 147/2000, Train Loss : 22.357, Valid Loss 28.526, MAE 3.548, Corr 0.973957
# Epoch : 148/2000, Train Loss : 27.063, Valid Loss 39.983, MAE 5.073, Corr 0.970959
# Epoch : 149/2000, Train Loss : 31.716, Valid Loss 40.060, MAE 4.841, Corr 0.973258
# Epoch : 150/2000, Train Loss : 25.032, Valid Loss 23.587, MAE 3.562, Corr 0.973353
# Epoch : 151/2000, Train Loss : 19.467, Valid Loss 20.525, MAE 2.867, Corr 0.979376
# Best Valid Loss 20.5248
# Epoch : 152/2000, Train Loss : 19.638, Valid Loss 19.812, MAE 3.209, Corr 0.975619
# Best Valid Loss 19.8116
# Epoch : 153/2000, Train Loss : 23.431, Valid Loss 21.978, MAE 3.174, Corr 0.973377
# Epoch : 154/2000, Train Loss : 22.421, Valid Loss 19.400, MAE 3.075, Corr 0.973959
# Best Valid Loss 19.3998
# Epoch : 155/2000, Train Loss : 18.748, Valid Loss 20.031, MAE 2.960, Corr 0.977230
# Epoch : 156/2000, Train Loss : 21.465, Valid Loss 30.716, MAE 4.414, Corr 0.970974
# Epoch : 157/2000, Train Loss : 22.247, Valid Loss 22.983, MAE 3.750, Corr 0.975888
# Epoch : 158/2000, Train Loss : 20.160, Valid Loss 19.273, MAE 3.122, Corr 0.975321
# Best Valid Loss 19.2733
# Epoch : 159/2000, Train Loss : 21.474, Valid Loss 19.377, MAE 3.128, Corr 0.978460
# Epoch : 160/2000, Train Loss : 18.121, Valid Loss 21.260, MAE 3.469, Corr 0.974360
# Epoch : 161/2000, Train Loss : 19.031, Valid Loss 20.789, MAE 3.427, Corr 0.974153
# Epoch : 162/2000, Train Loss : 18.111, Valid Loss 19.254, MAE 3.011, Corr 0.975583
# Best Valid Loss 19.2539
# Epoch : 163/2000, Train Loss : 18.007, Valid Loss 27.955, MAE 4.319, Corr 0.974801
# Epoch : 164/2000, Train Loss : 20.585, Valid Loss 22.327, MAE 3.607, Corr 0.979257
# Epoch : 165/2000, Train Loss : 17.529, Valid Loss 18.840, MAE 2.839, Corr 0.978438
# Best Valid Loss 18.8400
# Epoch : 166/2000, Train Loss : 21.000, Valid Loss 22.463, MAE 3.740, Corr 0.974608
# Epoch : 167/2000, Train Loss : 26.294, Valid Loss 42.727, MAE 5.393, Corr 0.971978
# Epoch : 168/2000, Train Loss : 25.783, Valid Loss 19.805, MAE 3.134, Corr 0.974103
# Epoch : 169/2000, Train Loss : 17.161, Valid Loss 19.612, MAE 3.337, Corr 0.976508
# Epoch : 170/2000, Train Loss : 16.997, Valid Loss 18.229, MAE 3.134, Corr 0.976983
# Best Valid Loss 18.2292
# Epoch : 171/2000, Train Loss : 21.501, Valid Loss 21.461, MAE 3.005, Corr 0.975289
# Epoch : 172/2000, Train Loss : 19.169, Valid Loss 22.235, MAE 3.228, Corr 0.973479
# Epoch : 173/2000, Train Loss : 22.244, Valid Loss 18.161, MAE 2.822, Corr 0.977598
# Best Valid Loss 18.1607
# Epoch : 174/2000, Train Loss : 25.755, Valid Loss 20.731, MAE 2.975, Corr 0.970273
# Epoch : 175/2000, Train Loss : 21.378, Valid Loss 19.125, MAE 3.148, Corr 0.976517
# Epoch : 176/2000, Train Loss : 23.833, Valid Loss 18.896, MAE 2.860, Corr 0.975883
# Epoch : 177/2000, Train Loss : 18.672, Valid Loss 19.011, MAE 2.818, Corr 0.976773
# Epoch : 178/2000, Train Loss : 17.237, Valid Loss 22.629, MAE 3.883, Corr 0.973554
# Epoch : 179/2000, Train Loss : 24.830, Valid Loss 17.629, MAE 2.889, Corr 0.977238
# Best Valid Loss 17.6286
# Epoch : 180/2000, Train Loss : 20.937, Valid Loss 18.071, MAE 2.975, Corr 0.974878
# Epoch : 181/2000, Train Loss : 17.749, Valid Loss 24.796, MAE 3.082, Corr 0.980354
# Epoch : 182/2000, Train Loss : 19.651, Valid Loss 18.884, MAE 3.202, Corr 0.973285
# Epoch : 183/2000, Train Loss : 18.335, Valid Loss 19.902, MAE 3.347, Corr 0.979243
# Epoch : 184/2000, Train Loss : 16.851, Valid Loss 24.076, MAE 3.902, Corr 0.977654
# Epoch : 185/2000, Train Loss : 16.595, Valid Loss 29.445, MAE 4.214, Corr 0.976060
# Epoch : 186/2000, Train Loss : 17.311, Valid Loss 20.084, MAE 3.017, Corr 0.978628
# Epoch : 187/2000, Train Loss : 17.005, Valid Loss 22.396, MAE 3.126, Corr 0.980426
# Epoch : 188/2000, Train Loss : 19.342, Valid Loss 18.198, MAE 2.634, Corr 0.977286
# Epoch : 189/2000, Train Loss : 17.405, Valid Loss 17.067, MAE 2.741, Corr 0.974723
# Best Valid Loss 17.0671
# Epoch : 190/2000, Train Loss : 21.249, Valid Loss 30.009, MAE 4.098, Corr 0.977157
# Epoch : 191/2000, Train Loss : 18.271, Valid Loss 19.839, MAE 2.752, Corr 0.976438
# Epoch : 192/2000, Train Loss : 18.692, Valid Loss 22.378, MAE 3.801, Corr 0.975681
# Epoch : 193/2000, Train Loss : 18.386, Valid Loss 29.430, MAE 4.474, Corr 0.977997
# Epoch : 194/2000, Train Loss : 22.311, Valid Loss 29.097, MAE 4.508, Corr 0.977069
# Epoch : 195/2000, Train Loss : 21.452, Valid Loss 18.656, MAE 3.268, Corr 0.979150
# Epoch : 196/2000, Train Loss : 18.522, Valid Loss 19.101, MAE 2.801, Corr 0.980183
# Epoch : 197/2000, Train Loss : 22.496, Valid Loss 29.299, MAE 3.722, Corr 0.979951
# Epoch : 198/2000, Train Loss : 24.835, Valid Loss 40.160, MAE 4.649, Corr 0.976219
# Epoch : 199/2000, Train Loss : 24.520, Valid Loss 19.828, MAE 3.265, Corr 0.977975
# Epoch : 200/2000, Train Loss : 15.699, Valid Loss 18.818, MAE 3.171, Corr 0.981842
# Epoch : 201/2000, Train Loss : 16.179, Valid Loss 19.952, MAE 3.471, Corr 0.977955
# Epoch : 202/2000, Train Loss : 16.442, Valid Loss 15.980, MAE 2.838, Corr 0.978071
# Best Valid Loss 15.9798
# Epoch : 203/2000, Train Loss : 15.146, Valid Loss 17.156, MAE 3.025, Corr 0.977132
# Epoch : 204/2000, Train Loss : 15.124, Valid Loss 19.248, MAE 3.316, Corr 0.980386
# Epoch : 205/2000, Train Loss : 18.633, Valid Loss 17.777, MAE 3.118, Corr 0.978485
# Epoch : 206/2000, Train Loss : 14.459, Valid Loss 19.025, MAE 2.765, Corr 0.974663
# Epoch : 207/2000, Train Loss : 14.755, Valid Loss 18.199, MAE 3.290, Corr 0.975964
# Epoch : 208/2000, Train Loss : 15.110, Valid Loss 16.283, MAE 2.725, Corr 0.979597
# Epoch : 209/2000, Train Loss : 17.708, Valid Loss 18.942, MAE 2.485, Corr 0.980293
# Epoch : 210/2000, Train Loss : 17.673, Valid Loss 26.996, MAE 4.112, Corr 0.974530
# Epoch : 211/2000, Train Loss : 21.663, Valid Loss 41.527, MAE 5.668, Corr 0.977958
# Epoch : 212/2000, Train Loss : 18.273, Valid Loss 20.732, MAE 3.705, Corr 0.975338
# Epoch : 213/2000, Train Loss : 14.582, Valid Loss 18.719, MAE 3.097, Corr 0.979483
# Epoch : 214/2000, Train Loss : 13.920, Valid Loss 16.418, MAE 2.583, Corr 0.980533
# Epoch : 215/2000, Train Loss : 15.759, Valid Loss 19.711, MAE 3.393, Corr 0.975494
# Epoch : 216/2000, Train Loss : 16.136, Valid Loss 21.534, MAE 3.015, Corr 0.980155
# Epoch : 217/2000, Train Loss : 16.130, Valid Loss 30.501, MAE 3.774, Corr 0.977971
# Epoch : 218/2000, Train Loss : 15.906, Valid Loss 16.410, MAE 3.013, Corr 0.976605
# Epoch : 219/2000, Train Loss : 19.591, Valid Loss 21.583, MAE 3.341, Corr 0.979360
# Epoch : 220/2000, Train Loss : 14.158, Valid Loss 16.246, MAE 2.743, Corr 0.980195
# Epoch : 221/2000, Train Loss : 15.762, Valid Loss 28.645, MAE 3.557, Corr 0.979165
# Epoch : 222/2000, Train Loss : 16.897, Valid Loss 21.051, MAE 3.491, Corr 0.975012
# Epoch : 223/2000, Train Loss : 14.095, Valid Loss 17.771, MAE 2.562, Corr 0.978094
# Early stopping
# Best Result : Epoch 202, Valid Loss 15.980, MAE 2.838, Corr 0.978071

# %%
# scatter plot

file_path = "D:\gait_dataset/salted/test/*"
inputs_acc, inputs_gyr, stride_length = get_sensor_salted(file_path, normalization=True)
inputs_pst = get_position_salted(file_path, distance=True)
inputs_acc, inputs_gyr, stride_length, inputs_pst = torch.Tensor(np.array(inputs_acc)), torch.Tensor(np.array(inputs_gyr)), torch.Tensor(np.array(stride_length)), torch.Tensor(np.array(inputs_pst))
inputs_acc, inputs_gyr, stride_length, inputs_pst = inputs_acc.float(), inputs_gyr.float(), stride_length.float(), inputs_pst.float()
inputs_acc, inputs_gyr, inputs_pst = inputs_acc.to(device), inputs_gyr.to(device), inputs_pst.to(device)

# %%
input_dim = 900
dense_dim = 512


model = Encoder_fc(input_dim, dense_dim).to(device)
model.load_state_dict(torch.load('./model/encoder_fc_best_ks30_bias.pth'))
model.eval()
# Out:
# Encoder_fc(
#   (fc_acc): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=900, out_features=512, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Linear(in_features=512, out_features=256, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Linear(in_features=256, out_features=128, bias=True)
#     (6): ReLU(inplace=True)
#     (7): Linear(in_features=128, out_features=64, bias=True)
#     (8): ReLU(inplace=True)
#     (9): Linear(in_features=64, out_features=3, bias=True)
#   )
#   (fc_gyr): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=900, out_features=512, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Linear(in_features=512, out_features=256, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Linear(in_features=256, out_features=128, bias=True)
#     (6): ReLU(inplace=True)
#     (7): Linear(in_features=128, out_features=64, bias=True)
#     (8): ReLU(inplace=True)
#     (9): Linear(in_features=64, out_features=3, bias=True)
#   )
# )

# %%
pred = model(inputs_acc, inputs_gyr, inputs_pst).detach().cpu().numpy()

plt.figure(figsize=(10, 10))
plt.scatter(stride_length, np.round(pred, 4))
plt.xlim([50, 250])
plt.xlabel('stride_length')
plt.ylim([50, 250])
plt.ylabel('pred')

xpoints = ypoints = plt.xlim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)

plt.show()

# %% [markdown]
# # Encoder-based Model : Acc, Gyro 축별 입력
# - 각 축 Acc에서 얻어진 축별 distance를 곱해주기 때문에 축별로 데이터를 입력
#     - 축별 Acc/Gyro의 정보가 알맞은 축의 distance와 곱해져야 한다는 생각에 시도
# - 3개의 인코더에는 각각 (Acc_x, Gyro_x) / (Acc_y, Gyro_y) / (Acc_z, Gyro_z)가 입력으로 들어감
#     - 인코더의 각 output을 concat한 뒤 FC-Layer에 넣었을 때, 축별 정보가 순서대로 보존될 수 있을지는 의문 부호
# - Pressure는 축이 따로 없으므로 고려하지 않음

# %%
file_path = "D:\gait_dataset/salted/train/*"
dataset = Gait_Dataset_Axis_Salted(file_path)
val_percent = 0.2
n_val = int(len(dataset) * val_percent)
n_train = len(dataset) - n_val
train, val = random_split(dataset, [n_train, n_val])

# %%
train_loader = torch.utils.data.DataLoader(train,
                                           batch_size=128,
                                           shuffle=True)
val_loader = torch.utils.data.DataLoader(val,
                                         batch_size=128,
                                         shuffle=False)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available else 'cpu')

class Encoder_axis(nn.Module):
    def __init__(self, input_dim, dense_dim):
        super(Encoder_axis, self).__init__()
        
        
        self.fc_x = nn.Sequential(
            nn.Flatten(),
            nn.Linear(input_dim, dense_dim),
            nn.ReLU(inplace=True),
            nn.Linear(dense_dim, int(dense_dim/2)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/2), int(dense_dim/4)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/4), int(dense_dim/8)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/8), 1)
        )
        
        self.fc_y = nn.Sequential(
            nn.Flatten(),
            nn.Linear(input_dim, dense_dim),
            nn.ReLU(inplace=True),
            nn.Linear(dense_dim, int(dense_dim/2)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/2), int(dense_dim/4)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/4), int(dense_dim/8)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/8), 1)
        )
        
        self.fc_z = nn.Sequential(
            nn.Flatten(),
            nn.Linear(input_dim, dense_dim),
            nn.ReLU(inplace=True),
            nn.Linear(dense_dim, int(dense_dim/2)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/2), int(dense_dim/4)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/4), int(dense_dim/8)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/8), 1)
        )
        
        

    def forward(self, inputs_x, inputs_y, inputs_z): 
        

        fc_output_x = self.fc_x(inputs_x)
        fc_output_y = self.fc_y(inputs_y)
        fc_output_z = self.fc_z(inputs_z)
        
        
        enc_output = torch.concat((fc_output_x, fc_output_y, fc_output_z), 1)
        output = torch.unsqueeze(torch.sum(enc_output*inputs_pst, axis=1), 1)

        return output

# %%
input_dim = 600
dense_dim = 512

model = Encoder_axis(input_dim, dense_dim).to(device)
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
n_epochs = 2000

criterion = nn.MSELoss()

# %%
# Early Stopping을 위한 변수
best = 1000
converge_cnt = 0
best_MAE = 0
best_epoch = 0

# Run Training loop
for epoch in range(0, n_epochs) :
    # Set current loss value 
    tot_trn_loss = 0.0
    
    # Train Mode
    model.train()
    
    # Iterate over the DataLoader for training data 
    for i, data in enumerate(train_loader) :
        inputs_x, inputs_y, inputs_z, stride_length, inputs_pst = data
        inputs_x, inputs_y, inputs_z, stride_length, inputs_pst = inputs_x.float(), inputs_y.float(), inputs_z.float(), stride_length.float(), inputs_pst.float()
        inputs_x, inputs_y, inputs_z, inputs_pst = inputs_x.to(device), inputs_y.to(device), inputs_z.to(device), inputs_pst.to(device)
        stride_length = stride_length.reshape(-1, 1)
        stride_length = stride_length.to(device)

        # 순전파 
        outputs = model(inputs_x, inputs_y, inputs_z)
        
        # Loss 계산
        loss = criterion(outputs, stride_length)
        
        # 기울기 초기화 
        optimizer.zero_grad()
        # 역전파
        loss.backward()
        # 옵티마이저
        optimizer.step()
        
        # Print statistics
        tot_trn_loss += loss.item()
        
    # Evaluation Mode
    model.eval()
    
    tot_val_loss = 0
    val_epoch_loss = []

    with torch.no_grad() :
        for i, data in enumerate(val_loader):
            inputs_x, inputs_y, inputs_z, stride_length, inputs_pst = data
            inputs_x, inputs_y, inputs_z, stride_length, inputs_pst = inputs_x.float(), inputs_y.float(), inputs_z.float(), stride_length.float(), inputs_pst.float()
            inputs_x, inputs_y, inputs_z, inputs_pst = inputs_x.to(device), inputs_y.to(device), inputs_z.to(device), inputs_pst.to(device)
            stride_length = stride_length.reshape(-1, 1)
            stride_length = stride_length.to(device)

            # 순전파 
            outputs = model(inputs_x, inputs_y, inputs_z)
            
            # Loss 계산
            loss = criterion(outputs, stride_length)
            tot_val_loss += loss.item()            
            

    # Epoch 별 Loss
    trn_loss = tot_trn_loss / len(train_loader)
    val_loss = tot_val_loss / len(val_loader)
    MAE = torch.sum(torch.abs(outputs - stride_length)) / len(stride_length)
    
    
    print("Epoch : {}/{}, Train Loss : {:.6f}, Valid Loss {:.6f}, MAE {:.6f}".format(epoch+1, n_epochs,
                                                                                       trn_loss, val_loss,
                                                                                      MAE))
    
    # Early Stopping
    if val_loss < best:
        best = np.mean(val_loss)
        best_MAE = MAE
        best_epoch = epoch+1
        torch.save(model.state_dict(), './encoder_axis_best.pth')
        print('Best Valid Loss {:.4f}'.format(best))
        converge_cnt = 0
    else:
        converge_cnt += 1
    
    if converge_cnt > 20:
        print('Early stopping')
        print('Best Result : Epoch {}, Valid Loss {:4f}, MAE {:4f}'.format(best_epoch, best, best_MAE))
        break
    
#     print("Epoch : {}/{} Epoch Loss : {:.6f}".format(epoch+1, n_epochs, current_loss / len(trainloader.dataset)))
# Out:
# Epoch : 1/2000, Train Loss : 4204.483070, Valid Loss 960.211477, MAE 18.732618
# Best Valid Loss 960.2115
# Epoch : 2/2000, Train Loss : 740.092518, Valid Loss 682.783244, MAE 21.815802
# Best Valid Loss 682.7832
# Epoch : 3/2000, Train Loss : 672.514692, Valid Loss 643.312449, MAE 20.371880
# Best Valid Loss 643.3124
# Epoch : 4/2000, Train Loss : 654.339292, Valid Loss 623.736908, MAE 19.857491
# Best Valid Loss 623.7369
# Epoch : 5/2000, Train Loss : 643.132443, Valid Loss 608.725906, MAE 19.476088
# Best Valid Loss 608.7259
# Epoch : 6/2000, Train Loss : 629.894007, Valid Loss 597.531306, MAE 19.109816
# Best Valid Loss 597.5313
# Epoch : 7/2000, Train Loss : 618.994101, Valid Loss 586.731923, MAE 18.686306
# Best Valid Loss 586.7319
# Epoch : 8/2000, Train Loss : 620.693370, Valid Loss 594.880473, MAE 19.484201
# Epoch : 9/2000, Train Loss : 599.383153, Valid Loss 564.362340, MAE 18.882992
# Best Valid Loss 564.3623
# Epoch : 10/2000, Train Loss : 597.239210, Valid Loss 600.098083, MAE 17.494865
# Epoch : 11/2000, Train Loss : 578.893840, Valid Loss 543.235753, MAE 18.902126
# Best Valid Loss 543.2358
# Epoch : 12/2000, Train Loss : 534.360946, Valid Loss 507.778193, MAE 17.744028
# Best Valid Loss 507.7782
# Epoch : 13/2000, Train Loss : 520.282346, Valid Loss 522.745453, MAE 19.395428
# Epoch : 14/2000, Train Loss : 534.803079, Valid Loss 493.476720, MAE 18.248104
# Best Valid Loss 493.4767
# Epoch : 15/2000, Train Loss : 568.787346, Valid Loss 485.965164, MAE 16.065880
# Best Valid Loss 485.9652
# Epoch : 16/2000, Train Loss : 497.477157, Valid Loss 490.966405, MAE 15.864824
# Epoch : 17/2000, Train Loss : 498.107874, Valid Loss 526.822617, MAE 16.811295
# Epoch : 18/2000, Train Loss : 498.905641, Valid Loss 444.657654, MAE 16.228035
# Best Valid Loss 444.6577
# Epoch : 19/2000, Train Loss : 489.369770, Valid Loss 479.644984, MAE 19.135098
# Epoch : 20/2000, Train Loss : 450.823037, Valid Loss 464.667338, MAE 18.559401
# Epoch : 21/2000, Train Loss : 437.960028, Valid Loss 419.032852, MAE 15.457354
# Best Valid Loss 419.0329
# Epoch : 22/2000, Train Loss : 436.039963, Valid Loss 437.796351, MAE 17.559021
# Epoch : 23/2000, Train Loss : 462.127978, Valid Loss 458.994354, MAE 15.175824
# Epoch : 24/2000, Train Loss : 443.170399, Valid Loss 414.280853, MAE 15.959772
# Best Valid Loss 414.2809
# Epoch : 25/2000, Train Loss : 430.895659, Valid Loss 443.811417, MAE 18.365904
# Epoch : 26/2000, Train Loss : 399.838268, Valid Loss 411.142893, MAE 16.997028
# Best Valid Loss 411.1429
# Epoch : 27/2000, Train Loss : 397.925755, Valid Loss 385.956670, MAE 15.448458
# Best Valid Loss 385.9567
# Epoch : 28/2000, Train Loss : 394.932457, Valid Loss 370.084351, MAE 15.332590
# Best Valid Loss 370.0844
# Epoch : 29/2000, Train Loss : 378.335121, Valid Loss 392.059316, MAE 16.492947
# Epoch : 30/2000, Train Loss : 390.343356, Valid Loss 360.805654, MAE 15.558483
# Best Valid Loss 360.8057
# Epoch : 31/2000, Train Loss : 383.674436, Valid Loss 352.980021, MAE 14.575624
# Best Valid Loss 352.9800
# Epoch : 32/2000, Train Loss : 344.498868, Valid Loss 338.493861, MAE 15.126178
# Best Valid Loss 338.4939
# Epoch : 33/2000, Train Loss : 362.579472, Valid Loss 417.755783, MAE 18.200535
# Epoch : 34/2000, Train Loss : 385.489689, Valid Loss 333.772614, MAE 15.193232
# Best Valid Loss 333.7726
# Epoch : 35/2000, Train Loss : 380.121355, Valid Loss 336.932210, MAE 15.936528
# Epoch : 36/2000, Train Loss : 362.377421, Valid Loss 378.431040, MAE 14.876084
# Epoch : 37/2000, Train Loss : 322.583771, Valid Loss 331.090810, MAE 15.464411
# Best Valid Loss 331.0908
# Epoch : 38/2000, Train Loss : 347.083625, Valid Loss 310.514099, MAE 15.111868
# Best Valid Loss 310.5141
# Epoch : 39/2000, Train Loss : 321.448390, Valid Loss 343.884946, MAE 17.501564
# Epoch : 40/2000, Train Loss : 318.484650, Valid Loss 330.080154, MAE 15.818390
# Epoch : 41/2000, Train Loss : 298.718188, Valid Loss 309.189443, MAE 16.101839
# Best Valid Loss 309.1894
# Epoch : 42/2000, Train Loss : 332.815593, Valid Loss 360.670497, MAE 13.988887
# Epoch : 43/2000, Train Loss : 305.534605, Valid Loss 312.249517, MAE 14.299508
# Epoch : 44/2000, Train Loss : 287.863651, Valid Loss 315.327593, MAE 16.439096
# Epoch : 45/2000, Train Loss : 299.062279, Valid Loss 301.917041, MAE 15.805243
# Best Valid Loss 301.9170
# Epoch : 46/2000, Train Loss : 292.599052, Valid Loss 321.927175, MAE 16.976082
# Epoch : 47/2000, Train Loss : 337.692695, Valid Loss 308.822268, MAE 16.421921
# Epoch : 48/2000, Train Loss : 382.918235, Valid Loss 298.738597, MAE 13.286773
# Best Valid Loss 298.7386
# Epoch : 49/2000, Train Loss : 356.785373, Valid Loss 384.545202, MAE 13.926924
# Epoch : 50/2000, Train Loss : 318.749336, Valid Loss 286.495562, MAE 14.907921
# Best Valid Loss 286.4956
# Epoch : 51/2000, Train Loss : 278.102468, Valid Loss 290.487322, MAE 15.544626
# Epoch : 52/2000, Train Loss : 288.600418, Valid Loss 327.309214, MAE 17.285797
# Epoch : 53/2000, Train Loss : 310.283202, Valid Loss 315.812673, MAE 13.355238
# Epoch : 54/2000, Train Loss : 323.734004, Valid Loss 351.080521, MAE 17.724953
# Epoch : 55/2000, Train Loss : 274.536364, Valid Loss 291.163541, MAE 15.852151
# Epoch : 56/2000, Train Loss : 284.968908, Valid Loss 356.190526, MAE 18.113794
# Epoch : 57/2000, Train Loss : 319.164645, Valid Loss 312.751719, MAE 16.587122
# Epoch : 58/2000, Train Loss : 310.506563, Valid Loss 442.511363, MAE 12.372651
# Epoch : 59/2000, Train Loss : 308.965056, Valid Loss 358.967870, MAE 13.721699
# Epoch : 60/2000, Train Loss : 264.332843, Valid Loss 282.414810, MAE 15.575701
# Best Valid Loss 282.4148
# Epoch : 61/2000, Train Loss : 254.661275, Valid Loss 268.786758, MAE 14.537168
# Best Valid Loss 268.7868
# Epoch : 62/2000, Train Loss : 304.159712, Valid Loss 318.795113, MAE 16.870209
# Epoch : 63/2000, Train Loss : 261.026377, Valid Loss 291.267700, MAE 14.079115
# Epoch : 64/2000, Train Loss : 252.872216, Valid Loss 274.848193, MAE 15.255350
# Epoch : 65/2000, Train Loss : 246.545858, Valid Loss 262.577922, MAE 14.392272
# Best Valid Loss 262.5779
# Epoch : 66/2000, Train Loss : 259.272040, Valid Loss 306.001094, MAE 13.792887
# Epoch : 67/2000, Train Loss : 272.984936, Valid Loss 296.325745, MAE 16.239441
# Epoch : 68/2000, Train Loss : 268.440365, Valid Loss 285.432231, MAE 15.964619
# Epoch : 69/2000, Train Loss : 256.351894, Valid Loss 318.542501, MAE 13.867747
# Epoch : 70/2000, Train Loss : 276.361539, Valid Loss 311.409849, MAE 16.777567
# Epoch : 71/2000, Train Loss : 251.706294, Valid Loss 270.050056, MAE 15.476438
# Epoch : 72/2000, Train Loss : 281.805636, Valid Loss 287.403437, MAE 16.155590
# Epoch : 73/2000, Train Loss : 261.258969, Valid Loss 287.739922, MAE 13.154982
# Epoch : 74/2000, Train Loss : 237.838733, Valid Loss 278.934809, MAE 16.313175
# Epoch : 75/2000, Train Loss : 262.344192, Valid Loss 288.038923, MAE 13.672954
# Epoch : 76/2000, Train Loss : 246.375958, Valid Loss 280.645983, MAE 13.408783
# Epoch : 77/2000, Train Loss : 248.765299, Valid Loss 275.722689, MAE 12.822148
# Epoch : 78/2000, Train Loss : 238.452122, Valid Loss 268.105426, MAE 14.456664
# Epoch : 79/2000, Train Loss : 291.659863, Valid Loss 298.878436, MAE 16.616026
# Epoch : 80/2000, Train Loss : 239.486808, Valid Loss 303.910451, MAE 14.040716
# Epoch : 81/2000, Train Loss : 257.504828, Valid Loss 252.778885, MAE 14.345213
# Best Valid Loss 252.7789
# Epoch : 82/2000, Train Loss : 254.119490, Valid Loss 261.727796, MAE 14.663642
# Epoch : 83/2000, Train Loss : 244.638292, Valid Loss 270.936058, MAE 13.814148
# Epoch : 84/2000, Train Loss : 260.419097, Valid Loss 261.965436, MAE 13.714786
# Epoch : 85/2000, Train Loss : 241.049099, Valid Loss 250.267029, MAE 14.783106
# Best Valid Loss 250.2670
# Epoch : 86/2000, Train Loss : 262.333245, Valid Loss 272.944061, MAE 15.447268
# Epoch : 87/2000, Train Loss : 260.429855, Valid Loss 245.079956, MAE 14.034186
# Best Valid Loss 245.0800
# Epoch : 88/2000, Train Loss : 258.616858, Valid Loss 261.145599, MAE 12.572328
# Epoch : 89/2000, Train Loss : 239.027942, Valid Loss 315.642138, MAE 12.445998
# Epoch : 90/2000, Train Loss : 235.879906, Valid Loss 247.082649, MAE 14.469528
# Epoch : 91/2000, Train Loss : 219.414388, Valid Loss 246.770543, MAE 13.338692
# Epoch : 92/2000, Train Loss : 219.368833, Valid Loss 250.599556, MAE 14.076403
# Epoch : 93/2000, Train Loss : 220.720981, Valid Loss 253.532117, MAE 14.380571
# Epoch : 94/2000, Train Loss : 243.172365, Valid Loss 288.398824, MAE 12.626323
# Epoch : 95/2000, Train Loss : 254.135312, Valid Loss 237.997208, MAE 13.818307
# Best Valid Loss 237.9972
# Epoch : 96/2000, Train Loss : 218.618420, Valid Loss 240.439158, MAE 13.829137
# Epoch : 97/2000, Train Loss : 224.414599, Valid Loss 356.595851, MAE 14.280470
# Epoch : 98/2000, Train Loss : 228.745526, Valid Loss 237.988360, MAE 13.156813
# Best Valid Loss 237.9884
# Epoch : 99/2000, Train Loss : 222.886017, Valid Loss 256.208115, MAE 14.809103
# Epoch : 100/2000, Train Loss : 243.921161, Valid Loss 244.645859, MAE 13.140440
# Epoch : 101/2000, Train Loss : 269.264781, Valid Loss 447.129400, MAE 14.575147
# Epoch : 102/2000, Train Loss : 261.608053, Valid Loss 245.502991, MAE 14.338456
# Epoch : 103/2000, Train Loss : 233.777489, Valid Loss 413.139114, MAE 14.149916
# Epoch : 104/2000, Train Loss : 251.044906, Valid Loss 250.410014, MAE 14.467360
# Epoch : 105/2000, Train Loss : 207.769081, Valid Loss 253.500000, MAE 14.559004
# Epoch : 106/2000, Train Loss : 230.540902, Valid Loss 244.426598, MAE 13.544866
# Epoch : 107/2000, Train Loss : 212.129381, Valid Loss 229.457113, MAE 13.045004
# Best Valid Loss 229.4571
# Epoch : 108/2000, Train Loss : 208.940658, Valid Loss 254.473852, MAE 14.575455
# Epoch : 109/2000, Train Loss : 244.596528, Valid Loss 254.575427, MAE 13.692219
# Epoch : 110/2000, Train Loss : 205.435479, Valid Loss 261.444672, MAE 14.849936
# Epoch : 111/2000, Train Loss : 225.010364, Valid Loss 261.661346, MAE 12.025026
# Epoch : 112/2000, Train Loss : 214.849311, Valid Loss 256.394142, MAE 14.826268
# Epoch : 113/2000, Train Loss : 217.412423, Valid Loss 285.106544, MAE 12.565442
# Epoch : 114/2000, Train Loss : 247.552932, Valid Loss 248.944623, MAE 13.985316
# Epoch : 115/2000, Train Loss : 211.634395, Valid Loss 245.956273, MAE 12.499514
# Epoch : 116/2000, Train Loss : 204.974649, Valid Loss 224.917908, MAE 12.468025
# Best Valid Loss 224.9179
# Epoch : 117/2000, Train Loss : 196.921805, Valid Loss 271.352094, MAE 14.822633
# Epoch : 118/2000, Train Loss : 209.926294, Valid Loss 233.353282, MAE 13.383452
# Epoch : 119/2000, Train Loss : 195.348193, Valid Loss 232.682401, MAE 12.241904
# Epoch : 120/2000, Train Loss : 208.876346, Valid Loss 236.440605, MAE 13.464458
# Epoch : 121/2000, Train Loss : 196.765946, Valid Loss 227.835602, MAE 13.022877
# Epoch : 122/2000, Train Loss : 193.517637, Valid Loss 218.278470, MAE 12.707296
# Best Valid Loss 218.2785
# Epoch : 123/2000, Train Loss : 195.901348, Valid Loss 224.071073, MAE 13.885612
# Epoch : 124/2000, Train Loss : 193.404612, Valid Loss 218.878212, MAE 12.183580
# Epoch : 125/2000, Train Loss : 186.360992, Valid Loss 259.533915, MAE 12.093356
# Epoch : 126/2000, Train Loss : 219.266644, Valid Loss 218.800779, MAE 12.193208
# Epoch : 127/2000, Train Loss : 187.771560, Valid Loss 219.157356, MAE 13.078177
# Epoch : 128/2000, Train Loss : 202.913928, Valid Loss 218.808955, MAE 12.372823
# Epoch : 129/2000, Train Loss : 195.568213, Valid Loss 230.642036, MAE 12.800875
# Epoch : 130/2000, Train Loss : 210.071047, Valid Loss 339.974434, MAE 16.857981
# Epoch : 131/2000, Train Loss : 253.012704, Valid Loss 218.265778, MAE 12.316258
# Best Valid Loss 218.2658
# Epoch : 132/2000, Train Loss : 243.815232, Valid Loss 359.759165, MAE 14.057345
# Epoch : 133/2000, Train Loss : 203.191589, Valid Loss 223.229645, MAE 13.143655
# Epoch : 134/2000, Train Loss : 193.063918, Valid Loss 228.638166, MAE 11.715737
# Epoch : 135/2000, Train Loss : 195.340675, Valid Loss 271.466220, MAE 15.066877
# Epoch : 136/2000, Train Loss : 231.799189, Valid Loss 224.516210, MAE 13.529267
# Epoch : 137/2000, Train Loss : 192.899308, Valid Loss 213.529269, MAE 11.626940
# Best Valid Loss 213.5293
# Epoch : 138/2000, Train Loss : 198.101690, Valid Loss 325.454015, MAE 13.854384
# Epoch : 139/2000, Train Loss : 204.601064, Valid Loss 214.701668, MAE 11.662326
# Epoch : 140/2000, Train Loss : 212.835910, Valid Loss 287.133965, MAE 15.122499
# Epoch : 141/2000, Train Loss : 199.048575, Valid Loss 219.052264, MAE 12.948186
# Epoch : 142/2000, Train Loss : 187.101924, Valid Loss 220.289856, MAE 11.261027
# Epoch : 143/2000, Train Loss : 187.742869, Valid Loss 225.543332, MAE 12.732025
# Epoch : 144/2000, Train Loss : 184.997295, Valid Loss 259.832115, MAE 12.479071
# Epoch : 145/2000, Train Loss : 194.808164, Valid Loss 221.602956, MAE 11.568373
# Epoch : 146/2000, Train Loss : 191.326534, Valid Loss 220.752322, MAE 13.095728
# Epoch : 147/2000, Train Loss : 177.777755, Valid Loss 224.105771, MAE 11.487336
# Epoch : 148/2000, Train Loss : 190.216237, Valid Loss 215.220909, MAE 11.234654
# Epoch : 149/2000, Train Loss : 173.959217, Valid Loss 276.528173, MAE 13.025703
# Epoch : 150/2000, Train Loss : 182.704240, Valid Loss 265.526573, MAE 12.273990
# Epoch : 151/2000, Train Loss : 185.066928, Valid Loss 243.393463, MAE 13.019588
# Epoch : 152/2000, Train Loss : 213.740728, Valid Loss 276.795074, MAE 12.546719
# Epoch : 153/2000, Train Loss : 203.783161, Valid Loss 302.667292, MAE 12.893096
# Epoch : 154/2000, Train Loss : 179.261233, Valid Loss 236.930285, MAE 12.515727
# Epoch : 155/2000, Train Loss : 199.396572, Valid Loss 237.898534, MAE 12.102600
# Epoch : 156/2000, Train Loss : 203.836657, Valid Loss 220.282262, MAE 12.463799
# Epoch : 157/2000, Train Loss : 178.784119, Valid Loss 238.878899, MAE 12.801421
# Epoch : 158/2000, Train Loss : 196.458556, Valid Loss 235.963000, MAE 11.841576
# Early stopping
# Best Result : Epoch 137, Valid Loss 213.529269, MAE 11.626940

# %%
file_path = "D:\gait_dataset/salted/test/*"
inputs_x, inputs_y, inputs_z, stride_length = get_axis_sensor_salted(file_path)
inputs_pst = get_position_salted(file_path, distance=True)
inputs_x, inputs_y, inputs_z, stride_length, inputs_pst = torch.Tensor(np.array(inputs_x)), torch.Tensor(np.array(inputs_y)), torch.Tensor(np.array(inputs_z)), torch.Tensor(np.array(stride_length)), torch.Tensor(np.array(inputs_pst))
inputs_x, inputs_y, inputs_z, stride_length, inputs_pst = inputs_x.float(), inputs_y.float(), inputs_z.float(), stride_length.float(), inputs_pst.float()
inputs_x, inputs_y, inputs_z, inputs_pst = inputs_x.to(device), inputs_y.to(device), inputs_z.to(device), inputs_pst.to(device)

# stride_length = stride_length.reshape(-1, 1)
# stride_length = stride_length.to(device)

# %%
input_dim = 600
dense_dim = 512

model = Encoder_axis(input_dim, dense_dim).to(device)
model.load_state_dict(torch.load('./encoder_axis_best.pth'))
model.eval()
# Out:
# Encoder_axis(
#   (fc_x): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=600, out_features=512, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Linear(in_features=512, out_features=256, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Linear(in_features=256, out_features=128, bias=True)
#     (6): ReLU(inplace=True)
#     (7): Linear(in_features=128, out_features=64, bias=True)
#     (8): ReLU(inplace=True)
#     (9): Linear(in_features=64, out_features=1, bias=True)
#   )
#   (fc_y): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=600, out_features=512, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Linear(in_features=512, out_features=256, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Linear(in_features=256, out_features=128, bias=True)
#     (6): ReLU(inplace=True)
#     (7): Linear(in_features=128, out_features=64, bias=True)
#     (8): ReLU(inplace=True)
#     (9): Linear(in_features=64, out_features=1, bias=True)
#   )
#   (fc_z): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=600, out_features=512, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Linear(in_features=512, out_features=256, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Linear(in_features=256, out_features=128, bias=True)
#     (6): ReLU(inplace=True)
#     (7): Linear(in_features=128, out_features=64, bias=True)
#     (8): ReLU(inplace=True)
#     (9): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %%
pred = model(inputs_x, inputs_y, inputs_z).detach().cpu().numpy()

plt.figure(figsize=(10, 10))
plt.scatter(stride_length, np.round(pred, 4))
plt.xlim([50, 250])
plt.xlabel('stride_length')
plt.ylim([50, 250])
plt.ylabel('pred')

xpoints = ypoints = plt.xlim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import scipy
from scipy.ndimage import gaussian_filter1d
from sklearn.preprocessing import MinMaxScaler, StandardScaler

import torch
from torch.utils.data import Dataset, DataLoader, random_split

import os 
import glob
import cv2
import itertools



class Gait_Dataset_Salted(Dataset):
    def __init__(self, file_path, bias=False):
        self.bias = bias
        self.file_path = file_path
        self.inputs_acc, self.inputs_gyr, self.stride_length = get_sensor_salted(file_path, bias=bias)
#         self.inputs_spd = get_speed_salted(file_path)
        self.inputs_pst = get_position_salted(file_path, distance=True, bias=bias)
        
    def __len__(self) :
        return len(self.inputs_acc)
    
    def __getitem__(self, idx):
        return self.inputs_acc[idx], self.inputs_gyr[idx], self.stride_length[idx], self.inputs_pst[idx]
    
    
class Gait_Dataset_Axis_Salted(Dataset):
    def __init__(self, file_path, axis=None):
        self.file_path = file_path
        self.inputs_x, self.inputs_y, self.inputs_z, self.stride_length = get_axis_sensor_salted(file_path)
        self.inputs_pst = get_position_salted(file_path, distance=True)
        
    def __len__(self) :
        return len(self.stride_length)
    
    def __getitem__(self, idx):
        return self.inputs_x[idx], self.inputs_y[idx], self.inputs_z[idx], self.stride_length[idx], self.inputs_pst[idx]



def get_event_salted(file_path):
    
    df = pd.read_csv(file_path, skiprows=2)
    
    # 압력값 불러오기
    prs = df.filter(regex="R_value")
    prs_mean = np.mean(prs.iloc[:, 0:4], axis=1) 
    
    # Gaussian Filter : Smoothing pressure data
    prs_mean_gf = pd.Series(scipy.ndimage.gaussian_filter1d(prs_mean, 2))
    
    # Level Shift 
    lev_idx = prs_mean_gf > 5 # 가우시안 필터로 인해 0이 아닌 값으로 threshold 설정
    prs_lev = lev_idx.map(lambda x : 1 if x else 0)
    
    # HS, TO Index 추출
    event_idx = []
    for i in range(len(prs_lev)-1):
        if (prs_lev[i] - prs_lev[i+1]) != 0:
            event_idx.append(i)
            
    # HS 이벤트가 먼저 시작하도록 : 나중에 lev shift를 통해 구하는 방법으로 변경하는 것도 괜찮을 듯
    if np.diff(event_idx)[0] < np.diff(event_idx)[1]: # Swing Phase가 Stand Phase보다 길다는 것을 가정 : 장애 데이터에서도 확인 필요
        del event_idx[0]
    
    
    return event_idx

def get_sensor_salted(file_path, normalization=True, bias=False):
    inputs_acc = []
    inputs_gyr = []
    stride_length = []
    for file_name in glob.glob(file_path):
        df = pd.read_csv(file_name, skiprows=2)
        acc = df.filter(regex="R_ACC")
        gyr = df.filter(regex="R_GYRO")
        event_idx = get_event_salted(file_name)

        # HS 이벤트 추출
        event_hs = event_idx[0::2]

        # m/s^2 단위 변환
        acc = acc / 1000 * 9.8066
        
        # x축과 z축에 적용되는 bias 제거(z축의 경우 중력가속도)
        if bias == False:
            acc['R_ACC_X']= acc['R_ACC_X'] - np.mean(acc['R_ACC_X'])
            acc['R_ACC_Z']= acc['R_ACC_Z'] - np.mean(acc['R_ACC_Z']) 
        
        # Normalization
        if normalization == True:
            scaler = MinMaxScaler()
            acc_norm = scaler.fit_transform(acc)
            gyr_norm = scaler.fit_transform(gyr)

        # 가속도와 자이로 센서 값
        for i in range(1, len(event_hs)):
            if normalization == True:
                inputs_acc.append(np.transpose(cv2.resize(acc_norm[event_hs[i-1]:event_hs[i]], dsize=(3, 300))))
                inputs_gyr.append(np.transpose(cv2.resize(gyr_norm[event_hs[i-1]:event_hs[i]], dsize=(3, 300))))
            else:
                inputs_acc.append(np.transpose(acc[event_hs[i-1]:event_hs[i]]))
                inputs_gyr.append(np.transpose(gyr[event_hs[i-1]:event_hs[i]]))

            #             inputs_gyr.append(acc_norm[event_hs[i-1]:event_hs[i]])
    
        if '3km' in file_name:
            stride_length.append(np.diff(event_hs) * (3000/3600))
        elif '4km' in file_name:
            stride_length.append(np.diff(event_hs) * (4000/3600))
        else:
            stride_length.append(np.diff(event_hs) * (5000/3600))
            
    stride_length = np.round(np.array(list(itertools.chain.from_iterable(stride_length))), 3)
    
    return inputs_acc, inputs_gyr, stride_length

def get_axis_sensor_salted(file_path, normalization=True, bias=False):
    inputs_x = []
    inputs_y = []
    inputs_z = []
    stride_length = []
    for file_name in glob.glob(file_path):
        df = pd.read_csv(file_name, skiprows=2)
        acc = df.filter(regex="R_ACC")
        gyr = df.filter(regex="R_GYRO")
        event_idx = get_event_salted(file_name)

        # HS 이벤트 추출
        event_hs = event_idx[0::2]

        # m/s^2 단위 변환
        acc = acc / 1000 * 9.8066
        
        # x축과 z축에 적용되는 bias 제거(z축의 경우 중력가속도)
        if bias == False:
            acc['R_ACC_X']= acc['R_ACC_X'] - np.mean(acc['R_ACC_X'])
            acc['R_ACC_Z']= acc['R_ACC_Z'] - np.mean(acc['R_ACC_Z']) 

        # Normalization
        if normalization == True:
            scaler = MinMaxScaler()
            acc_norm = scaler.fit_transform(acc)
            gyr_norm = scaler.fit_transform(gyr)

            
        # 가속도와 자이로 센서 값
        for i in range(1, len(event_hs)):
            if normalization == True:
                inputs_x.append(np.vstack([np.transpose(cv2.resize(acc_norm[:, 0][event_hs[i-1]:event_hs[i]], dsize=(1, 300))), 
                                           np.transpose(cv2.resize(gyr_norm[:, 0][event_hs[i-1]:event_hs[i]], dsize=(1, 300)))]))
                inputs_y.append(np.vstack([np.transpose(cv2.resize(acc_norm[:, 1][event_hs[i-1]:event_hs[i]], dsize=(1, 300))), 
                                           np.transpose(cv2.resize(gyr_norm[:, 1][event_hs[i-1]:event_hs[i]], dsize=(1, 300)))]))
                inputs_z.append(np.vstack([np.transpose(cv2.resize(acc_norm[:, 2][event_hs[i-1]:event_hs[i]], dsize=(1, 300))), 
                                           np.transpose(cv2.resize(gyr_norm[:, 2][event_hs[i-1]:event_hs[i]], dsize=(1, 300)))]))
            else:
                inputs_acc.append(np.transpose(acc[event_hs[i-1]:event_hs[i]]))
                inputs_gyr.append(np.transpose(gyr[event_hs[i-1]:event_hs[i]]))

    
        if '3km' in file_name:
            stride_length.append(np.diff(event_hs) * (3000/3600))
        elif '4km' in file_name:
            stride_length.append(np.diff(event_hs) * (4000/3600))
        else:
            stride_length.append(np.diff(event_hs) * (5000/3600))
            
    stride_length = np.round(np.array(list(itertools.chain.from_iterable(stride_length))), 3)
    
    return inputs_x, inputs_y, inputs_z, stride_length



def get_speed_salted(file_path, bias=False):
    bias = bias
    inputs_acc, _, _ = get_sensor_salted(file_path, normalization=False, bias=bias)
    inputs_spd = []
    for i in range(len(inputs_acc)):
        spd = pd.DataFrame(scipy.integrate.cumulative_trapezoid(inputs_acc[i], dx=(1/100)))
        inputs_spd.append(spd) #m/s
    return inputs_spd

def get_position_salted(file_path, distance=False, bias=False):
    bias = bias
    inputs_spd = get_speed_salted(file_path, bias = bias)
    inputs_pst = []
    for i in range(len(inputs_spd)):
        pst = pd.DataFrame(scipy.integrate.cumulative_trapezoid(inputs_spd[i], dx=(1/100)))
        if distance==True:
            pst = np.array(np.sum(pst, axis=1))
        inputs_pst.append(pst)
    
    scaler = MinMaxScaler()
    inputs_pst = scaler.fit_transform(inputs_pst)

        
    return inputs_pst

# %%
file_path = "D:\gait_dataset/salted/train/*"
inputs_acc, inputs_gyr, stride_length = get_sensor_salted(file_path, normalization=False)
inputs_pst = get_position_salted(file_path, distance=True)
inputs_spd = get_speed_salted(file_path)

# %%
inputs_acc[0]
# Out:
#               0         1         2         3         4         5         6    \
# R_ACC_X  0.062411 -0.967282  0.317382  2.386575  1.700113  0.533128  0.395835
# R_ACC_Y -0.382457 -2.245711 -3.608829 -1.510216 -0.804141 -0.460910 -0.107873
# R_ACC_Z  9.052672  1.609462 -0.646056  1.050486 -0.018433 -1.263872 -0.577410
#
#               7         8         9    ...        121        122        123  \
# R_ACC_X -0.163141 -0.771150 -0.996702  ...  -1.398773  -0.908443  -0.908443
# R_ACC_Y -0.117679  0.362844  1.372924  ...  14.396089  16.327989  16.327989
# R_ACC_Z -0.989287 -2.401437 -2.313178  ...  -6.039686  -3.980300  -3.980300
#
#                124        125        126        127        128        129  \
# R_ACC_X  -0.418113   0.003571   0.189897   0.023184  -0.604438  -0.310240
# R_ACC_Y  18.357955  20.132950  21.398001  21.956977  22.221756  22.555180
# R_ACC_Z  -2.018980  -0.243985   1.217198   2.188052   1.070099   1.246618
#
#                130
# R_ACC_X   0.582161
# R_ACC_Y  22.829765
# R_ACC_Z   0.618996
#
# [3 rows x 131 columns]

# %%
plt.figure(figsize=(15, 3))
plt.plot(inputs_acc[2].transpose())
# Out:
# [<matplotlib.lines.Line2D at 0x158f7563408>,
#  <matplotlib.lines.Line2D at 0x158f762a388>,
#  <matplotlib.lines.Line2D at 0x158f7687548>]

# %%
spd = scipy.integrate.cumulative_trapezoid(inputs_acc[2], dx=1/100)
plt.figure(figsize=(15, 3))
plt.plot(pd.DataFrame(spd.transpose()))
plt.axhline(y=0, color='k')
plt.axhline(y=0.833, color='k')

# %%
pst = scipy.integrate.cumulative_trapezoid(spd, dx=(1/100))
plt.figure(figsize=(15, 3))
plt.plot(pd.DataFrame(pst.transpose()))
plt.axhline(y=0, color='k')

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_virtual_device_configuration(
        gpus[0],[tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5120)])
    except RuntimeError as e:
        print(e)
# Out:
# Virtual devices cannot be modified after being initialized

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

import tensorflow as tf
import tensorflow_probability as tfp

import matplotlib.pyplot as plt

import Data_generator as gen

plt.style.use("seaborn-whitegrid")

X, sigma_square, epsilon, y = gen.DataGenerator(num_of_data=1000).get()

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=42)

plt.plot(X, y, ".")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Total dataset")
plt.show()


def plot_results(x, y, y_est_mu, title, y_est_std=None):
    plt.figure(figsize=(10, 6))
    plt.plot(x, y, ".", label="y")
    plt.plot(x, y_est_mu, "-y", label="y_estimate_mu")
    plt.plot(x, np.sin(4 * x) * np.sin(5 * x), "-g", label="true_mu")
    if y_est_std is not None:
        plt.plot(x, y_est_mu + 2 * y_est_std, "-r", label="estimate_mu+2std")
        plt.plot(x, y_est_mu - 2 * y_est_std, "-r", label="estimate_mu-2std")

    plt.legend()
    plt.title(title)
    plt.show()


def plot_model_results(model, x, y, title, tfp_model: bool = True):
    si = np.argsort(x)
    x = x[si]
    y = y[si]
    yhat = model(x)
    if tfp_model:
        y_est_mu = yhat.mean()
        y_est_std = yhat.stddev()
    else:
        y_est_mu = yhat
        y_est_std = None
    plot_results(x, y, y_est_mu, title, y_est_std)


def negloglik(y, distr):
    return -distr.log_prob(y)


model_lin_reg_tfp = tf.keras.Sequential(
    [
        tf.keras.layers.Input(shape=(1,)),
        tf.keras.layers.Dense(100, activation="sigmoid"),
        tf.keras.layers.Dense(1),
    ]
)

model_lin_reg_tfp.compile(
    optimizer=tf.optimizers.SGD(learning_rate=0.05), loss=tf.keras.losses.mse
)
model_lin_reg_tfp.summary()
history = model_lin_reg_tfp.fit(x_train, y_train, epochs=6000, verbose=0)

plot_model_results(model_lin_reg_tfp, x_train, y_train, 'Standard NN model train result', tfp_model=False)
plot_model_results(model_lin_reg_tfp, x_test, y_test, 'Standard NN model test result', tfp_model=False)

model_lin_reg_std_nn_tfp = tf.keras.Sequential(
    [
        tf.keras.layers.Input(shape=(1,)),
        tf.keras.layers.Dense(100, activation="sigmoid"),
        tf.keras.layers.Dense(2),
        tfp.layers.DistributionLambda(
            lambda t: tfp.distributions.Normal(
                loc=t[:, 0:1], scale=tf.math.softplus(t[:, 1:2])
            )
        ),
    ]
)

model_lin_reg_std_nn_tfp.compile(
    optimizer=tf.optimizers.SGD(learning_rate=0.05), loss=negloglik
)
model_lin_reg_std_nn_tfp.summary()
history = model_lin_reg_std_nn_tfp.fit(x_train, y_train, epochs=6000, verbose=0)

plot_model_results(model_lin_reg_std_nn_tfp, x_train, y_train, 'Heteroscedastic NN model train result', tfp_model=True)
plot_model_results(model_lin_reg_std_nn_tfp, x_test, y_test, 'Heteroscedastic NN model test result', tfp_model=True)
results = pd.DataFrame(index=["Train", "Test"])

models = {
    "Linear regression": model_lin_reg_tfp,
    "Neural network + std": model_lin_reg_std_nn_tfp,
}
rmse = tf.keras.metrics.RootMeanSquaredError()
for model in models:
    results[model] = [
        rmse(y_train[:, tf.newaxis], models[model](x_train)
             ).numpy(),
        rmse(y_test[:, tf.newaxis], models[model](x_test)
             ).numpy(),
    ]
results.transpose()
print(results)

results_2 = pd.DataFrame(index=["Train", "Test"])

models = {
    "Linear regression": model_lin_reg_tfp,
    "Neural network + std": model_lin_reg_std_nn_tfp,
}
mae = tf.keras.metrics.MeanAbsoluteError()
for model in models:
    results_2[model] = [
        mae(y_train[:, tf.newaxis], models[model](x_train))
            .numpy(),
        mae(y_test[:, tf.newaxis], models[model](x_test))
            .numpy(),
    ]
results_2.transpose()
print(results_2)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 100)               200
#
#  dense_3 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 301
# Trainable params: 301
# Non-trainable params: 0
# _________________________________________________________________
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6768\738968537.py in <module>
#      67 )
#      68 model_lin_reg_tfp.summary()
# ---> 69 history = model_lin_reg_tfp.fit(x_train, y_train, epochs=6000, verbose=0)
#      70
#      71 plot_model_results(model_lin_reg_tfp, x_train, y_train, 'Standard NN model train result', tfp_model=False)
#
# ~\anaconda3\envs\gait\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\anaconda3\envs\gait\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# InternalError: Graph execution error:
#
# Detected at node 'sequential_1/dense_2/MatMul' defined at (most recent call last):
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\runpy.py", line 193, in _run_module_as_main
#       "__main__", mod_spec)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\runpy.py", line 85, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#       app.launch_new_instance()
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#       app.start()
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\ipykernel\kernelapp.py", line 677, in start
#       self.io_loop.start()
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\asyncio\base_events.py", line 541, in run_forever
#       self._run_once()
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\asyncio\base_events.py", line 1786, in _run_once
#       handle._run()
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\asyncio\events.py", line 88, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\ipykernel\kernelbase.py", line 461, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\ipykernel\kernelbase.py", line 450, in process_one
#       await dispatch(*args)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\ipykernel\kernelbase.py", line 357, in dispatch_shell
#       await result
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\ipykernel\kernelbase.py", line 652, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\ipykernel\ipkernel.py", line 359, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\ipykernel\zmqshell.py", line 532, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\IPython\core\interactiveshell.py", line 2915, in run_cell
#       raw_cell, store_history, silent, shell_futures)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#       return runner(coro)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\IPython\core\interactiveshell.py", line 3186, in run_cell_async
#       interactivity=interactivity, compiler=compiler, result=result)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#       if (await self.run_code(code, result,  async_=asy)):
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\taeoo\AppData\Local\Temp\ipykernel_6768\738968537.py", line 69, in <module>
#       history = model_lin_reg_tfp.fit(x_train, y_train, epochs=6000, verbose=0)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\keras\engine\training.py", line 1409, in fit
#       tmp_logs = self.train_function(iterator)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\keras\engine\training.py", line 1051, in train_function
#       return step_function(self, iterator)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\keras\engine\training.py", line 1040, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\keras\engine\training.py", line 1030, in run_step
#       outputs = model.train_step(data)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\keras\engine\training.py", line 889, in train_step
#       y_pred = self(x, training=True)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\keras\engine\training.py", line 490, in __call__
#       return super().__call__(*args, **kwargs)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\keras\engine\base_layer.py", line 1014, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\keras\utils\traceback_utils.py", line 92, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\keras\engine\sequential.py", line 374, in call
#       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\keras\engine\functional.py", line 459, in call
#       inputs, training=training, mask=mask)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\keras\engine\functional.py", line 596, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\keras\engine\base_layer.py", line 1014, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\keras\utils\traceback_utils.py", line 92, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\taeoo\anaconda3\envs\gait\lib\site-packages\keras\layers\core\dense.py", line 221, in call
#       outputs = tf.matmul(a=inputs, b=self.kernel)
# Node: 'sequential_1/dense_2/MatMul'
# Attempting to perform BLAS operation using StreamExecutor without BLAS support
# 	 [[{{node sequential_1/dense_2/MatMul}}]] [Op:__inference_train_function_909]
