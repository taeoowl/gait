# %% [markdown]
# # 모듈 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

import scipy
from scipy.ndimage import gaussian_filter1d
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

import torch
from torch.utils.data import Dataset, DataLoader, random_split
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

import os 
import glob
import cv2
import itertools

from dataloader_distance import *

# %% [markdown]
# # Linear Regression : Only Distance

# %% [markdown]
# ### 데이터 불러오기

# %%
file_path = "D:\gait_dataset/salted/train/*"
_, _, stride_length = get_sensor_salted(file_path)
inputs_pst = get_position_salted(file_path, distance=True)

# %%
train = pd.DataFrame(inputs_pst)
train.columns =  ['R_DIS_X', 'R_DIS_Y', 'R_DIS_Z']
train
# Out:
#        R_DIS_X   R_DIS_Y   R_DIS_Z
# 0     0.325056  0.295638  0.591209
# 1     0.408169  0.226372  0.594593
# 2     0.385037  0.185862  0.569153
# 3     0.432047  0.206133  0.605114
# 4     0.483833  0.175300  0.620395
# ...        ...       ...       ...
# 3348  0.586512  0.318631  0.656599
# 3349  0.603322  0.399322  0.698904
# 3350  0.649342  0.543410  0.669275
# 3351  0.533692  0.235974  0.705292
# 3352  0.603229  0.343022  0.703307
#
# [3353 rows x 3 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(train, stride_length, train_size=0.8, test_size=0.2)

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
MAE = mean_absolute_error(y_test, y_pred)
MAE
# Out:
# 12.341223032825697

# %%
plt.figure(figsize=(10, 10))
plt.scatter(y_test, y_pred)
plt.xlim([80, 180])
plt.xlabel('stride_length')
plt.ylim([80, 180])
plt.ylabel('pred')

xpoints = ypoints = plt.xlim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)

plt.show()

# %% [markdown]
# # Encoder-based Model : 최종 노드 1개

# %% [markdown]
# ## 데이터 불러오기

# %%
device = torch.device('cuda:0' if torch.cuda.is_available else 'cpu')

file_path = "D:\gait_dataset/salted/train/*"
dataset = Gait_Dataset_Salted(file_path)
val_percent = 0.2
n_val = int(len(dataset) * val_percent)
n_train = len(dataset) - n_val
train, val = random_split(dataset, [n_train, n_val])

# %%
train_loader = torch.utils.data.DataLoader(train,
                                           batch_size=128,
                                           shuffle=True,
                                           worker_init_fn=np.random.seed(42))
val_loader = torch.utils.data.DataLoader(val,
                                         batch_size=128,
                                         shuffle=False)

# %% [markdown]
# ## Model & Scatter Plot
# - 인코더에 Conv1d만을 사용
# - 인코더의 아웃풋 길이가 늘어나 FC Layer의 수를 늘려 실험
#     - FC Layer : enc_output -> 512 -> 256 -> 128 -> 64 -> 32 -> 1
# - Best Result : Epoch 284, Valid Loss 11.398009, MAE 2.244626

# %%
# seed 고정
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

class Encoder(nn.Module):
    def __init__(self, input_dim, conv1d_dim1, conv1d_dim2, dense_dim):
        super(Encoder, self).__init__()
             
        self.conv1d_acc = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 30),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 30),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.conv1d_gyr = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 30),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 30),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.dense = nn.Sequential(
            nn.Linear(7744*2, dense_dim),
            nn.ReLU(inplace=True),
            nn.Linear(dense_dim, int(dense_dim/2)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/2), int(dense_dim/4)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/4), int(dense_dim/8)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/8), 1)
        )
        

    def forward(self, inputs_acc, inputs_gyr): 
        
        conv1d_output_acc = self.conv1d_acc(inputs_acc)
        conv1d_output_gyr = self.conv1d_gyr(inputs_gyr)
        
        enc_output = torch.concat((conv1d_output_acc, conv1d_output_gyr), 1)
        dense_output = self.dense(enc_output)
        
        return dense_output

# %%
input_dim = 3
conv1d_dim1 = 16
conv1d_dim2 = 32
dense_dim = 512

model = Encoder(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
n_epochs = 2000

criterion = nn.MSELoss()

# %%
# Early Stopping을 위한 변수
best = 1000
converge_cnt = 0
best_MAE = 0
best_epoch = 0

# Run Training loop
for epoch in range(0, n_epochs) :
    # Set current loss value 
    tot_trn_loss = 0.0
    
    # Train Mode
    model.train()
    
    # Iterate over the DataLoader for training data 
    for i, data in enumerate(train_loader) :
        inputs_acc, inputs_gyr, stride_length, _ = data
        inputs_acc, inputs_gyr, stride_length = inputs_acc.float(), inputs_gyr.float(), stride_length.float()
        inputs_acc, inputs_gyr = inputs_acc.to(device), inputs_gyr.to(device)
        stride_length = stride_length.reshape(-1, 1)
        stride_length = stride_length.to(device)

        # 순전파 
        outputs = model(inputs_acc, inputs_gyr)
        
        # Loss 계산
        loss = criterion(outputs, stride_length)
        
        # 기울기 초기화 
        optimizer.zero_grad()
        # 역전파
        loss.backward()
        # 옵티마이저
        optimizer.step()

        
        # Print statistics
        tot_trn_loss += loss.item()
        
    # Evaluation Mode
    model.eval()
    
    tot_val_loss = 0
    val_epoch_loss = []

    with torch.no_grad() :
        for i, data in enumerate(val_loader):
            inputs_acc, inputs_gyr, stride_length, _ = data
            inputs_acc, inputs_gyr, stride_length = inputs_acc.float(), inputs_gyr.float(), stride_length.float()
            inputs_acc, inputs_gyr = inputs_acc.to(device), inputs_gyr.to(device)
            stride_length = stride_length.reshape(-1, 1)
            stride_length = stride_length.to(device)

            # 순전파 
            outputs = model(inputs_acc, inputs_gyr)
            
            # Loss 계산
            loss = criterion(outputs, stride_length)
            tot_val_loss += loss.item()            
            

    # Epoch 별 Loss
    trn_loss = tot_trn_loss / len(train_loader)
    val_loss = tot_val_loss / len(val_loader)
    MAE = torch.sum(torch.abs(outputs - stride_length)) / len(stride_length)
    
    
    print("Epoch : {}/{}, Train Loss : {:.6f}, Valid Loss {:.6f}, MAE {:.6f}".format(epoch+1, n_epochs,
                                                                                       trn_loss, val_loss,
                                                                                      MAE))
    
    # Early Stopping
    if val_loss < best:
        best = np.mean(val_loss)
        best_MAE = MAE
        best_epoch = epoch+1
        torch.save(model.state_dict(), './encoder_1_best_ks30.pth')
        print('Best Valid Loss {:.4f}'.format(best))
        converge_cnt = 0
    else:
        converge_cnt += 1
    
    if converge_cnt > 20:
        print('Early stopping')
        print('Best Result : Epoch {}, Valid Loss {:4f}, MAE {:4f}'.format(best_epoch, best, best_MAE))
        break
    
#     print("Epoch : {}/{} Epoch Loss : {:.6f}".format(epoch+1, n_epochs, current_loss / len(trainloader.dataset)))
# Out:
# Epoch : 1/2000, Train Loss : 7002.886353, Valid Loss 541.382904, MAE 19.552557
# Best Valid Loss 541.3829
# Epoch : 2/2000, Train Loss : 648.184015, Valid Loss 373.309865, MAE 15.579275
# Best Valid Loss 373.3099
# Epoch : 3/2000, Train Loss : 275.804032, Valid Loss 233.055702, MAE 12.957404
# Best Valid Loss 233.0557
# Epoch : 4/2000, Train Loss : 241.108407, Valid Loss 251.107620, MAE 13.730339
# Epoch : 5/2000, Train Loss : 238.490223, Valid Loss 229.044795, MAE 12.891615
# Best Valid Loss 229.0448
# Epoch : 6/2000, Train Loss : 243.040333, Valid Loss 236.756040, MAE 12.767365
# Epoch : 7/2000, Train Loss : 248.560199, Valid Loss 231.687731, MAE 13.145042
# Epoch : 8/2000, Train Loss : 234.829238, Valid Loss 229.903422, MAE 13.074877
# Epoch : 9/2000, Train Loss : 231.608902, Valid Loss 222.452087, MAE 12.840273
# Best Valid Loss 222.4521
# Epoch : 10/2000, Train Loss : 229.802407, Valid Loss 217.188484, MAE 12.553919
# Best Valid Loss 217.1885
# Epoch : 11/2000, Train Loss : 217.721795, Valid Loss 220.568982, MAE 12.761562
# Epoch : 12/2000, Train Loss : 215.746745, Valid Loss 212.878985, MAE 12.523201
# Best Valid Loss 212.8790
# Epoch : 13/2000, Train Loss : 212.949443, Valid Loss 206.841304, MAE 12.307674
# Best Valid Loss 206.8413
# Epoch : 14/2000, Train Loss : 207.308769, Valid Loss 206.748266, MAE 12.304902
# Best Valid Loss 206.7483
# Epoch : 15/2000, Train Loss : 204.108041, Valid Loss 195.880330, MAE 11.876172
# Best Valid Loss 195.8803
# Epoch : 16/2000, Train Loss : 196.167632, Valid Loss 238.113937, MAE 13.167178
# Epoch : 17/2000, Train Loss : 194.104627, Valid Loss 179.670072, MAE 11.234594
# Best Valid Loss 179.6701
# Epoch : 18/2000, Train Loss : 181.767441, Valid Loss 176.825129, MAE 10.641556
# Best Valid Loss 176.8251
# Epoch : 19/2000, Train Loss : 172.493026, Valid Loss 163.812874, MAE 10.486532
# Best Valid Loss 163.8129
# Epoch : 20/2000, Train Loss : 171.105947, Valid Loss 160.941274, MAE 10.123040
# Best Valid Loss 160.9413
# Epoch : 21/2000, Train Loss : 174.778035, Valid Loss 200.713689, MAE 11.713061
# Epoch : 22/2000, Train Loss : 151.153238, Valid Loss 141.159804, MAE 9.326348
# Best Valid Loss 141.1598
# Epoch : 23/2000, Train Loss : 141.191461, Valid Loss 126.374367, MAE 9.061131
# Best Valid Loss 126.3744
# Epoch : 24/2000, Train Loss : 126.842104, Valid Loss 151.021161, MAE 10.050036
# Epoch : 25/2000, Train Loss : 110.500579, Valid Loss 108.841452, MAE 8.469858
# Best Valid Loss 108.8415
# Epoch : 26/2000, Train Loss : 100.898983, Valid Loss 91.428151, MAE 7.745711
# Best Valid Loss 91.4282
# Epoch : 27/2000, Train Loss : 98.468233, Valid Loss 117.347911, MAE 9.342656
# Epoch : 28/2000, Train Loss : 81.335080, Valid Loss 96.305313, MAE 8.523199
# Epoch : 29/2000, Train Loss : 73.098154, Valid Loss 67.541016, MAE 6.745465
# Best Valid Loss 67.5410
# Epoch : 30/2000, Train Loss : 66.773121, Valid Loss 59.449613, MAE 6.057384
# Best Valid Loss 59.4496
# Epoch : 31/2000, Train Loss : 74.866282, Valid Loss 68.544778, MAE 6.868209
# Epoch : 32/2000, Train Loss : 62.266986, Valid Loss 58.048774, MAE 5.481474
# Best Valid Loss 58.0488
# Epoch : 33/2000, Train Loss : 52.649044, Valid Loss 63.739181, MAE 6.429369
# Epoch : 34/2000, Train Loss : 56.268328, Valid Loss 49.552937, MAE 4.918242
# Best Valid Loss 49.5529
# Epoch : 35/2000, Train Loss : 50.061514, Valid Loss 47.252131, MAE 4.625911
# Best Valid Loss 47.2521
# Epoch : 36/2000, Train Loss : 52.630613, Valid Loss 44.173943, MAE 4.490190
# Best Valid Loss 44.1739
# Epoch : 37/2000, Train Loss : 45.241496, Valid Loss 43.232370, MAE 4.233365
# Best Valid Loss 43.2324
# Epoch : 38/2000, Train Loss : 52.515841, Valid Loss 40.443806, MAE 4.201499
# Best Valid Loss 40.4438
# Epoch : 39/2000, Train Loss : 45.115587, Valid Loss 48.148467, MAE 4.719098
# Epoch : 40/2000, Train Loss : 45.604807, Valid Loss 41.165111, MAE 4.669529
# Epoch : 41/2000, Train Loss : 41.677313, Valid Loss 35.985324, MAE 3.916584
# Best Valid Loss 35.9853
# Epoch : 42/2000, Train Loss : 42.173710, Valid Loss 36.167627, MAE 3.876984
# Epoch : 43/2000, Train Loss : 37.799104, Valid Loss 33.872154, MAE 3.804449
# Best Valid Loss 33.8722
# Epoch : 44/2000, Train Loss : 39.133039, Valid Loss 38.169953, MAE 4.185569
# Epoch : 45/2000, Train Loss : 42.430589, Valid Loss 33.114333, MAE 3.714029
# Best Valid Loss 33.1143
# Epoch : 46/2000, Train Loss : 36.883080, Valid Loss 41.889721, MAE 4.570477
# Epoch : 47/2000, Train Loss : 38.039190, Valid Loss 40.766171, MAE 4.669367
# Epoch : 48/2000, Train Loss : 49.399899, Valid Loss 32.286862, MAE 3.824883
# Best Valid Loss 32.2869
# Epoch : 49/2000, Train Loss : 34.683261, Valid Loss 40.770697, MAE 4.687292
# Epoch : 50/2000, Train Loss : 35.786634, Valid Loss 35.531981, MAE 4.183028
# Epoch : 51/2000, Train Loss : 35.469577, Valid Loss 35.007893, MAE 4.132928
# Epoch : 52/2000, Train Loss : 32.303391, Valid Loss 36.186439, MAE 4.345856
# Epoch : 53/2000, Train Loss : 39.906090, Valid Loss 35.169016, MAE 4.228193
# Epoch : 54/2000, Train Loss : 32.494309, Valid Loss 81.897327, MAE 8.041303
# Epoch : 55/2000, Train Loss : 41.083019, Valid Loss 34.461986, MAE 4.356065
# Epoch : 56/2000, Train Loss : 30.585335, Valid Loss 27.591602, MAE 3.343774
# Best Valid Loss 27.5916
# Epoch : 57/2000, Train Loss : 30.971493, Valid Loss 43.522066, MAE 5.342876
# Epoch : 58/2000, Train Loss : 31.993367, Valid Loss 27.201000, MAE 3.543974
# Best Valid Loss 27.2010
# Epoch : 59/2000, Train Loss : 50.535241, Valid Loss 77.434161, MAE 6.900904
# Epoch : 60/2000, Train Loss : 39.671861, Valid Loss 31.870381, MAE 3.585977
# Epoch : 61/2000, Train Loss : 28.952666, Valid Loss 27.529524, MAE 3.253703
# Epoch : 62/2000, Train Loss : 27.025451, Valid Loss 25.950962, MAE 3.207564
# Best Valid Loss 25.9510
# Epoch : 63/2000, Train Loss : 27.480678, Valid Loss 29.558308, MAE 3.914974
# Epoch : 64/2000, Train Loss : 29.167113, Valid Loss 48.566013, MAE 6.066973
# Epoch : 65/2000, Train Loss : 30.282521, Valid Loss 29.813108, MAE 4.043251
# Epoch : 66/2000, Train Loss : 28.605420, Valid Loss 28.735184, MAE 3.717101
# Epoch : 67/2000, Train Loss : 30.527148, Valid Loss 25.617998, MAE 3.101322
# Best Valid Loss 25.6180
# Epoch : 68/2000, Train Loss : 27.968747, Valid Loss 24.181194, MAE 3.051435
# Best Valid Loss 24.1812
# Epoch : 69/2000, Train Loss : 27.848202, Valid Loss 49.285669, MAE 4.985247
# Epoch : 70/2000, Train Loss : 36.416376, Valid Loss 41.362192, MAE 5.435234
# Epoch : 71/2000, Train Loss : 31.782281, Valid Loss 28.872498, MAE 4.117436
# Epoch : 72/2000, Train Loss : 27.963285, Valid Loss 24.555048, MAE 3.417653
# Epoch : 73/2000, Train Loss : 33.264423, Valid Loss 25.956027, MAE 2.947890
# Epoch : 74/2000, Train Loss : 28.658281, Valid Loss 35.807799, MAE 4.790350
# Epoch : 75/2000, Train Loss : 24.908683, Valid Loss 22.782290, MAE 2.993638
# Best Valid Loss 22.7823
# Epoch : 76/2000, Train Loss : 31.372576, Valid Loss 22.736691, MAE 2.890999
# Best Valid Loss 22.7367
# Epoch : 77/2000, Train Loss : 29.314132, Valid Loss 36.286125, MAE 4.957413
# Epoch : 78/2000, Train Loss : 26.127588, Valid Loss 30.489434, MAE 4.323040
# Epoch : 79/2000, Train Loss : 30.574911, Valid Loss 26.957761, MAE 3.112965
# Epoch : 80/2000, Train Loss : 31.236063, Valid Loss 23.432978, MAE 3.205299
# Epoch : 81/2000, Train Loss : 29.487895, Valid Loss 22.173686, MAE 3.000969
# Best Valid Loss 22.1737
# Epoch : 82/2000, Train Loss : 24.540599, Valid Loss 24.973815, MAE 2.773108
# Epoch : 83/2000, Train Loss : 32.987110, Valid Loss 48.064386, MAE 6.236740
# Epoch : 84/2000, Train Loss : 39.920947, Valid Loss 25.845897, MAE 2.914795
# Epoch : 85/2000, Train Loss : 27.079175, Valid Loss 21.683704, MAE 3.060640
# Best Valid Loss 21.6837
# Epoch : 86/2000, Train Loss : 23.941085, Valid Loss 22.872995, MAE 3.222356
# Epoch : 87/2000, Train Loss : 31.300491, Valid Loss 31.474028, MAE 3.368723
# Epoch : 88/2000, Train Loss : 26.781526, Valid Loss 23.345629, MAE 2.641409
# Epoch : 89/2000, Train Loss : 27.188824, Valid Loss 21.018902, MAE 2.843064
# Best Valid Loss 21.0189
# Epoch : 90/2000, Train Loss : 21.982812, Valid Loss 24.181463, MAE 2.857922
# Epoch : 91/2000, Train Loss : 28.548288, Valid Loss 23.129379, MAE 3.335367
# Epoch : 92/2000, Train Loss : 24.084610, Valid Loss 25.686762, MAE 4.014599
# Epoch : 93/2000, Train Loss : 23.051550, Valid Loss 49.321424, MAE 4.887842
# Epoch : 94/2000, Train Loss : 37.786496, Valid Loss 32.787756, MAE 4.830739
# Epoch : 95/2000, Train Loss : 31.520301, Valid Loss 23.085201, MAE 2.642345
# Epoch : 96/2000, Train Loss : 27.540021, Valid Loss 28.068455, MAE 3.015725
# Epoch : 97/2000, Train Loss : 25.643863, Valid Loss 21.833506, MAE 2.638607
# Epoch : 98/2000, Train Loss : 27.236865, Valid Loss 22.075190, MAE 2.782692
# Epoch : 99/2000, Train Loss : 25.931828, Valid Loss 26.556599, MAE 4.246325
# Epoch : 100/2000, Train Loss : 30.387209, Valid Loss 64.696114, MAE 7.622036
# Epoch : 101/2000, Train Loss : 40.939139, Valid Loss 32.288205, MAE 3.718620
# Epoch : 102/2000, Train Loss : 25.114440, Valid Loss 21.341325, MAE 2.752770
# Epoch : 103/2000, Train Loss : 21.817115, Valid Loss 40.625549, MAE 5.627954
# Epoch : 104/2000, Train Loss : 31.641634, Valid Loss 29.248182, MAE 3.211133
# Epoch : 105/2000, Train Loss : 22.957987, Valid Loss 21.179958, MAE 2.508746
# Epoch : 106/2000, Train Loss : 22.114271, Valid Loss 20.459517, MAE 2.983494
# Best Valid Loss 20.4595
# Epoch : 107/2000, Train Loss : 21.935760, Valid Loss 19.458315, MAE 2.603780
# Best Valid Loss 19.4583
# Epoch : 108/2000, Train Loss : 21.772286, Valid Loss 19.926039, MAE 3.147213
# Epoch : 109/2000, Train Loss : 25.554220, Valid Loss 63.227436, MAE 6.062035
# Epoch : 110/2000, Train Loss : 27.419393, Valid Loss 19.256345, MAE 2.754052
# Best Valid Loss 19.2563
# Epoch : 111/2000, Train Loss : 25.587700, Valid Loss 28.148334, MAE 4.363215
# Epoch : 112/2000, Train Loss : 22.169484, Valid Loss 19.519983, MAE 2.786681
# Epoch : 113/2000, Train Loss : 20.110877, Valid Loss 26.803305, MAE 4.136164
# Epoch : 114/2000, Train Loss : 21.213387, Valid Loss 19.423901, MAE 2.999377
# Epoch : 115/2000, Train Loss : 19.741252, Valid Loss 22.998384, MAE 3.460610
# Epoch : 116/2000, Train Loss : 23.928057, Valid Loss 19.848017, MAE 2.754233
# Epoch : 117/2000, Train Loss : 22.721909, Valid Loss 29.621472, MAE 4.618948
# Epoch : 118/2000, Train Loss : 36.280914, Valid Loss 29.215917, MAE 4.559025
# Epoch : 119/2000, Train Loss : 25.042362, Valid Loss 18.784593, MAE 2.634264
# Best Valid Loss 18.7846
# Epoch : 120/2000, Train Loss : 21.218017, Valid Loss 19.720622, MAE 2.555050
# Epoch : 121/2000, Train Loss : 24.938976, Valid Loss 35.836961, MAE 5.299704
# Epoch : 122/2000, Train Loss : 23.910651, Valid Loss 18.026237, MAE 2.529976
# Best Valid Loss 18.0262
# Epoch : 123/2000, Train Loss : 21.648666, Valid Loss 22.708579, MAE 3.640964
# Epoch : 124/2000, Train Loss : 22.421135, Valid Loss 23.248030, MAE 3.746101
# Epoch : 125/2000, Train Loss : 24.693417, Valid Loss 53.053448, MAE 5.446264
# Epoch : 126/2000, Train Loss : 30.999459, Valid Loss 20.656624, MAE 2.220182
# Epoch : 127/2000, Train Loss : 37.463775, Valid Loss 35.457120, MAE 5.186024
# Epoch : 128/2000, Train Loss : 30.224913, Valid Loss 19.591411, MAE 3.171027
# Epoch : 129/2000, Train Loss : 21.736969, Valid Loss 38.782746, MAE 4.201419
# Epoch : 130/2000, Train Loss : 20.078063, Valid Loss 23.731432, MAE 3.830938
# Epoch : 131/2000, Train Loss : 23.301900, Valid Loss 17.487730, MAE 2.567399
# Best Valid Loss 17.4877
# Epoch : 132/2000, Train Loss : 18.492133, Valid Loss 23.222370, MAE 3.829175
# Epoch : 133/2000, Train Loss : 24.079470, Valid Loss 19.557389, MAE 3.256966
# Epoch : 134/2000, Train Loss : 24.438348, Valid Loss 17.481294, MAE 2.494234
# Best Valid Loss 17.4813
# Epoch : 135/2000, Train Loss : 27.881596, Valid Loss 23.904775, MAE 3.837717
# Epoch : 136/2000, Train Loss : 22.585527, Valid Loss 22.339229, MAE 2.618001
# Epoch : 137/2000, Train Loss : 19.417754, Valid Loss 17.482696, MAE 2.801574
# Epoch : 138/2000, Train Loss : 31.203082, Valid Loss 22.269783, MAE 3.696874
# Epoch : 139/2000, Train Loss : 20.357761, Valid Loss 27.273108, MAE 4.386104
# Epoch : 140/2000, Train Loss : 38.090115, Valid Loss 26.046045, MAE 4.031862
# Epoch : 141/2000, Train Loss : 27.210302, Valid Loss 31.535239, MAE 3.517501
# Epoch : 142/2000, Train Loss : 28.242616, Valid Loss 23.043566, MAE 3.714803
# Epoch : 143/2000, Train Loss : 21.139078, Valid Loss 17.805847, MAE 2.651076
# Epoch : 144/2000, Train Loss : 28.428764, Valid Loss 32.756596, MAE 5.047992
# Epoch : 145/2000, Train Loss : 19.893602, Valid Loss 18.640347, MAE 2.287024
# Epoch : 146/2000, Train Loss : 16.862581, Valid Loss 17.461979, MAE 2.226612
# Best Valid Loss 17.4620
# Epoch : 147/2000, Train Loss : 20.253137, Valid Loss 16.471441, MAE 2.439840
# Best Valid Loss 16.4714
# Epoch : 148/2000, Train Loss : 16.502132, Valid Loss 17.664516, MAE 2.968813
# Epoch : 149/2000, Train Loss : 20.600077, Valid Loss 22.035412, MAE 3.409441
# Epoch : 150/2000, Train Loss : 18.086052, Valid Loss 40.469411, MAE 4.415104
# Epoch : 151/2000, Train Loss : 33.552836, Valid Loss 28.593882, MAE 3.525762
# Epoch : 152/2000, Train Loss : 22.247337, Valid Loss 17.315057, MAE 2.611691
# Epoch : 153/2000, Train Loss : 19.232747, Valid Loss 17.611744, MAE 2.753500
# Epoch : 154/2000, Train Loss : 21.643152, Valid Loss 18.976993, MAE 2.189399
# Epoch : 155/2000, Train Loss : 23.901709, Valid Loss 55.251605, MAE 6.951578
# Epoch : 156/2000, Train Loss : 40.134165, Valid Loss 53.125296, MAE 5.458065
# Epoch : 157/2000, Train Loss : 40.237416, Valid Loss 27.844927, MAE 4.329447
# Epoch : 158/2000, Train Loss : 19.189094, Valid Loss 16.172465, MAE 2.249796
# Best Valid Loss 16.1725
# Epoch : 159/2000, Train Loss : 17.398689, Valid Loss 28.076914, MAE 3.569474
# Epoch : 160/2000, Train Loss : 21.218719, Valid Loss 21.905372, MAE 3.667415
# Epoch : 161/2000, Train Loss : 19.811073, Valid Loss 15.738232, MAE 2.227847
# Best Valid Loss 15.7382
# Epoch : 162/2000, Train Loss : 18.097735, Valid Loss 16.250406, MAE 2.540814
# Epoch : 163/2000, Train Loss : 17.396750, Valid Loss 16.517533, MAE 2.592079
# Epoch : 164/2000, Train Loss : 19.263810, Valid Loss 16.287409, MAE 2.163002
# Epoch : 165/2000, Train Loss : 20.742046, Valid Loss 19.120019, MAE 2.819426
# Epoch : 166/2000, Train Loss : 24.435684, Valid Loss 19.678706, MAE 2.503061
# Epoch : 167/2000, Train Loss : 53.195060, Valid Loss 32.292843, MAE 4.768248
# Epoch : 168/2000, Train Loss : 23.441387, Valid Loss 17.281516, MAE 2.249311
# Epoch : 169/2000, Train Loss : 17.575365, Valid Loss 29.847128, MAE 4.594118
# Epoch : 170/2000, Train Loss : 23.357093, Valid Loss 17.343283, MAE 2.327535
# Epoch : 171/2000, Train Loss : 15.986756, Valid Loss 16.123478, MAE 2.242090
# Epoch : 172/2000, Train Loss : 19.160142, Valid Loss 25.480954, MAE 4.085992
# Epoch : 173/2000, Train Loss : 16.701529, Valid Loss 15.656821, MAE 2.426100
# Best Valid Loss 15.6568
# Epoch : 174/2000, Train Loss : 14.676687, Valid Loss 19.812144, MAE 3.342024
# Epoch : 175/2000, Train Loss : 22.758537, Valid Loss 16.807477, MAE 2.770414
# Epoch : 176/2000, Train Loss : 29.999974, Valid Loss 44.795885, MAE 4.922460
# Epoch : 177/2000, Train Loss : 17.199641, Valid Loss 15.503029, MAE 2.449916
# Best Valid Loss 15.5030
# Epoch : 178/2000, Train Loss : 16.400980, Valid Loss 16.257237, MAE 1.974138
# Epoch : 179/2000, Train Loss : 16.486379, Valid Loss 15.663797, MAE 2.724926
# Epoch : 180/2000, Train Loss : 15.368606, Valid Loss 15.760674, MAE 2.003228
# Epoch : 181/2000, Train Loss : 14.879645, Valid Loss 14.905303, MAE 2.207115
# Best Valid Loss 14.9053
# Epoch : 182/2000, Train Loss : 16.863493, Valid Loss 15.880323, MAE 2.680318
# Epoch : 183/2000, Train Loss : 15.308491, Valid Loss 20.134266, MAE 3.461431
# Epoch : 184/2000, Train Loss : 18.745985, Valid Loss 19.476760, MAE 2.248441
# Epoch : 185/2000, Train Loss : 30.093168, Valid Loss 74.848073, MAE 6.807582
# Epoch : 186/2000, Train Loss : 35.269703, Valid Loss 18.958566, MAE 2.480599
# Epoch : 187/2000, Train Loss : 18.563448, Valid Loss 26.697905, MAE 4.178452
# Epoch : 188/2000, Train Loss : 16.669217, Valid Loss 14.478355, MAE 2.134554
# Best Valid Loss 14.4784
# Epoch : 189/2000, Train Loss : 20.017885, Valid Loss 28.965892, MAE 4.512539
# Epoch : 190/2000, Train Loss : 23.935902, Valid Loss 16.540962, MAE 2.137101
# Epoch : 191/2000, Train Loss : 21.902188, Valid Loss 27.763312, MAE 4.361204
# Epoch : 192/2000, Train Loss : 18.447340, Valid Loss 15.714197, MAE 2.128087
# Epoch : 193/2000, Train Loss : 13.986789, Valid Loss 19.565992, MAE 3.325615
# Epoch : 194/2000, Train Loss : 17.887315, Valid Loss 15.430432, MAE 2.075137
# Epoch : 195/2000, Train Loss : 16.065411, Valid Loss 19.218708, MAE 3.243108
# Epoch : 196/2000, Train Loss : 27.537973, Valid Loss 15.074234, MAE 2.023610
# Epoch : 197/2000, Train Loss : 39.042767, Valid Loss 18.221701, MAE 2.342706
# Epoch : 198/2000, Train Loss : 20.406498, Valid Loss 15.200685, MAE 2.438461
# Epoch : 199/2000, Train Loss : 18.360821, Valid Loss 18.147005, MAE 3.085206
# Epoch : 200/2000, Train Loss : 15.262610, Valid Loss 16.520124, MAE 2.180109
# Epoch : 201/2000, Train Loss : 14.633078, Valid Loss 14.938373, MAE 1.994450
# Epoch : 202/2000, Train Loss : 18.934428, Valid Loss 21.532327, MAE 3.636878
# Epoch : 203/2000, Train Loss : 16.059434, Valid Loss 17.825967, MAE 2.855155
# Epoch : 204/2000, Train Loss : 14.390974, Valid Loss 14.343484, MAE 2.220970
# Best Valid Loss 14.3435
# Epoch : 205/2000, Train Loss : 14.722759, Valid Loss 14.641535, MAE 2.469389
# Epoch : 206/2000, Train Loss : 21.486102, Valid Loss 18.165423, MAE 3.154851
# Epoch : 207/2000, Train Loss : 18.797068, Valid Loss 17.854275, MAE 2.372422
# Epoch : 208/2000, Train Loss : 18.865529, Valid Loss 14.651629, MAE 2.106555
# Epoch : 209/2000, Train Loss : 16.866552, Valid Loss 29.154668, MAE 4.618260
# Epoch : 210/2000, Train Loss : 18.993418, Valid Loss 17.853521, MAE 3.100759
# Epoch : 211/2000, Train Loss : 20.990277, Valid Loss 35.787297, MAE 4.190413
# Epoch : 212/2000, Train Loss : 19.680556, Valid Loss 13.977003, MAE 1.948969
# Best Valid Loss 13.9770
# Epoch : 213/2000, Train Loss : 19.150867, Valid Loss 14.734125, MAE 2.666985
# Epoch : 214/2000, Train Loss : 20.291114, Valid Loss 15.645786, MAE 2.463170
# Epoch : 215/2000, Train Loss : 15.904844, Valid Loss 14.443565, MAE 2.394116
# Epoch : 216/2000, Train Loss : 17.606600, Valid Loss 31.798438, MAE 3.623310
# Epoch : 217/2000, Train Loss : 18.194082, Valid Loss 18.662767, MAE 2.205888
# Epoch : 218/2000, Train Loss : 16.080646, Valid Loss 21.717735, MAE 3.070360
# Epoch : 219/2000, Train Loss : 27.388423, Valid Loss 32.658647, MAE 4.992464
# Epoch : 220/2000, Train Loss : 22.127396, Valid Loss 22.720201, MAE 2.843636
# Epoch : 221/2000, Train Loss : 16.013887, Valid Loss 13.420032, MAE 2.252256
# Best Valid Loss 13.4200
# Epoch : 222/2000, Train Loss : 13.126167, Valid Loss 14.329798, MAE 2.306232
# Epoch : 223/2000, Train Loss : 13.818154, Valid Loss 13.658706, MAE 2.245944
# Epoch : 224/2000, Train Loss : 15.270340, Valid Loss 14.140776, MAE 2.092964
# Epoch : 225/2000, Train Loss : 22.411388, Valid Loss 26.561432, MAE 4.318160
# Epoch : 226/2000, Train Loss : 29.211451, Valid Loss 14.913593, MAE 2.405152
# Epoch : 227/2000, Train Loss : 34.474699, Valid Loss 25.918691, MAE 4.199233
# Epoch : 228/2000, Train Loss : 19.666344, Valid Loss 20.917001, MAE 3.558237
# Epoch : 229/2000, Train Loss : 19.833779, Valid Loss 15.401606, MAE 2.252077
# Epoch : 230/2000, Train Loss : 13.673642, Valid Loss 13.404975, MAE 2.365903
# Best Valid Loss 13.4050
# Epoch : 231/2000, Train Loss : 12.376357, Valid Loss 14.875980, MAE 2.641139
# Epoch : 232/2000, Train Loss : 13.260807, Valid Loss 14.026605, MAE 2.266096
# Epoch : 233/2000, Train Loss : 12.062011, Valid Loss 15.405056, MAE 2.395218
# Epoch : 234/2000, Train Loss : 12.203868, Valid Loss 13.268999, MAE 2.389342
# Best Valid Loss 13.2690
# Epoch : 235/2000, Train Loss : 15.451967, Valid Loss 31.035354, MAE 4.941968
# Epoch : 236/2000, Train Loss : 18.766501, Valid Loss 19.438734, MAE 2.782740
# Epoch : 237/2000, Train Loss : 21.921617, Valid Loss 43.663922, MAE 6.099955
# Epoch : 238/2000, Train Loss : 17.293173, Valid Loss 14.580480, MAE 2.468818
# Epoch : 239/2000, Train Loss : 16.501098, Valid Loss 13.779961, MAE 2.450836
# Epoch : 240/2000, Train Loss : 16.388779, Valid Loss 29.137545, MAE 4.756961
# Epoch : 241/2000, Train Loss : 13.923808, Valid Loss 25.108275, MAE 3.392441
# Epoch : 242/2000, Train Loss : 12.937816, Valid Loss 13.582877, MAE 2.352946
# Epoch : 243/2000, Train Loss : 14.000588, Valid Loss 14.406240, MAE 2.748699
# Epoch : 244/2000, Train Loss : 12.432558, Valid Loss 20.227950, MAE 2.770613
# Epoch : 245/2000, Train Loss : 20.207549, Valid Loss 15.628596, MAE 2.279838
# Epoch : 246/2000, Train Loss : 16.213992, Valid Loss 18.939155, MAE 2.550449
# Epoch : 247/2000, Train Loss : 20.403837, Valid Loss 28.200204, MAE 3.638269
# Epoch : 248/2000, Train Loss : 19.505833, Valid Loss 12.847002, MAE 2.382701
# Best Valid Loss 12.8470
# Epoch : 249/2000, Train Loss : 13.885022, Valid Loss 18.928068, MAE 3.347534
# Epoch : 250/2000, Train Loss : 24.887181, Valid Loss 48.931211, MAE 5.350536
# Epoch : 251/2000, Train Loss : 19.594145, Valid Loss 13.227264, MAE 2.452270
# Epoch : 252/2000, Train Loss : 13.496650, Valid Loss 15.829955, MAE 2.500156
# Epoch : 253/2000, Train Loss : 11.913643, Valid Loss 12.409144, MAE 2.399280
# Best Valid Loss 12.4091
# Epoch : 254/2000, Train Loss : 13.791168, Valid Loss 21.644862, MAE 3.757475
# Epoch : 255/2000, Train Loss : 15.808350, Valid Loss 17.868957, MAE 3.211919
# Epoch : 256/2000, Train Loss : 12.363264, Valid Loss 14.634795, MAE 2.808380
# Epoch : 257/2000, Train Loss : 19.444955, Valid Loss 16.958473, MAE 3.154872
# Epoch : 258/2000, Train Loss : 14.212424, Valid Loss 15.396365, MAE 2.298015
# Epoch : 259/2000, Train Loss : 15.066549, Valid Loss 12.611887, MAE 2.411065
# Epoch : 260/2000, Train Loss : 20.465343, Valid Loss 14.865698, MAE 2.646389
# Epoch : 261/2000, Train Loss : 19.265937, Valid Loss 33.066595, MAE 5.147542
# Epoch : 262/2000, Train Loss : 31.607362, Valid Loss 13.878983, MAE 2.654225
# Epoch : 263/2000, Train Loss : 13.956727, Valid Loss 16.806544, MAE 2.299955
# Epoch : 264/2000, Train Loss : 14.239292, Valid Loss 12.175112, MAE 2.269797
# Best Valid Loss 12.1751
# Epoch : 265/2000, Train Loss : 15.565765, Valid Loss 12.065106, MAE 2.248995
# Best Valid Loss 12.0651
# Epoch : 266/2000, Train Loss : 13.629799, Valid Loss 19.275931, MAE 3.375948
# Epoch : 267/2000, Train Loss : 14.845535, Valid Loss 12.530322, MAE 2.231576
# Epoch : 268/2000, Train Loss : 13.378444, Valid Loss 11.679859, MAE 1.997379
# Best Valid Loss 11.6799
# Epoch : 269/2000, Train Loss : 20.700217, Valid Loss 23.710555, MAE 3.943458
# Epoch : 270/2000, Train Loss : 14.439638, Valid Loss 12.481512, MAE 2.301362
# Epoch : 271/2000, Train Loss : 11.526606, Valid Loss 12.953033, MAE 2.479556
# Epoch : 272/2000, Train Loss : 12.140456, Valid Loss 12.554552, MAE 2.152602
# Epoch : 273/2000, Train Loss : 10.820961, Valid Loss 12.111657, MAE 1.951250
# Epoch : 274/2000, Train Loss : 11.960291, Valid Loss 12.053409, MAE 2.069476
# Epoch : 275/2000, Train Loss : 11.959588, Valid Loss 14.478913, MAE 2.412794
# Epoch : 276/2000, Train Loss : 13.106945, Valid Loss 12.463057, MAE 2.436264
# Epoch : 277/2000, Train Loss : 13.910494, Valid Loss 17.876235, MAE 2.513448
# Epoch : 278/2000, Train Loss : 12.519297, Valid Loss 14.768831, MAE 3.016298
# Epoch : 279/2000, Train Loss : 13.841799, Valid Loss 13.542978, MAE 2.815546
# Epoch : 280/2000, Train Loss : 15.923301, Valid Loss 11.839273, MAE 2.370087
# Epoch : 281/2000, Train Loss : 12.025170, Valid Loss 11.935322, MAE 2.256818
# Epoch : 282/2000, Train Loss : 13.053007, Valid Loss 15.232493, MAE 2.414746
# Epoch : 283/2000, Train Loss : 15.890540, Valid Loss 12.846531, MAE 1.913655
# Epoch : 284/2000, Train Loss : 11.138277, Valid Loss 11.398009, MAE 2.244626
# Best Valid Loss 11.3980
# Epoch : 285/2000, Train Loss : 15.982123, Valid Loss 28.036526, MAE 3.827118
# Epoch : 286/2000, Train Loss : 22.029720, Valid Loss 33.579117, MAE 4.395711
# Epoch : 287/2000, Train Loss : 19.801858, Valid Loss 25.874356, MAE 3.681495
# Epoch : 288/2000, Train Loss : 16.376021, Valid Loss 14.329005, MAE 2.550789
# Epoch : 289/2000, Train Loss : 13.254652, Valid Loss 13.036547, MAE 2.406736
# Epoch : 290/2000, Train Loss : 11.995963, Valid Loss 18.692193, MAE 3.581832
# Epoch : 291/2000, Train Loss : 22.608519, Valid Loss 19.650080, MAE 3.596864
# Epoch : 292/2000, Train Loss : 31.777196, Valid Loss 26.543117, MAE 4.563425
# Epoch : 293/2000, Train Loss : 14.137174, Valid Loss 12.052066, MAE 2.443907
# Epoch : 294/2000, Train Loss : 10.964996, Valid Loss 11.508835, MAE 2.208451
# Epoch : 295/2000, Train Loss : 12.601482, Valid Loss 35.474325, MAE 4.429090
# Epoch : 296/2000, Train Loss : 18.270090, Valid Loss 31.804018, MAE 5.032679
# Epoch : 297/2000, Train Loss : 17.134132, Valid Loss 12.599558, MAE 2.600763
# Epoch : 298/2000, Train Loss : 12.038140, Valid Loss 12.982747, MAE 2.794765
# Epoch : 299/2000, Train Loss : 11.542457, Valid Loss 18.987388, MAE 2.871438
# Epoch : 300/2000, Train Loss : 13.723449, Valid Loss 15.564533, MAE 2.719672
# Epoch : 301/2000, Train Loss : 21.744781, Valid Loss 133.808111, MAE 10.712399
# Epoch : 302/2000, Train Loss : 64.156838, Valid Loss 35.547419, MAE 5.286212
# Epoch : 303/2000, Train Loss : 13.882062, Valid Loss 21.063680, MAE 3.839345
# Epoch : 304/2000, Train Loss : 14.601012, Valid Loss 11.942030, MAE 2.532932
# Epoch : 305/2000, Train Loss : 10.895348, Valid Loss 13.297266, MAE 2.871878
# Early stopping
# Best Result : Epoch 284, Valid Loss 11.398009, MAE 2.244626

# %%
### scatter plot
file_path = "D:\gait_dataset/salted/test/*"
inputs_acc, inputs_gyr, stride_length = get_sensor_salted(file_path, normalization=True)
inputs_acc, inputs_gyr, stride_length = torch.Tensor(np.array(inputs_acc)), torch.Tensor(np.array(inputs_gyr)), torch.Tensor(np.array(stride_length))
inputs_acc, inputs_gyr, stride_length = inputs_acc.float(), inputs_gyr.float(), stride_length.float()
inputs_acc, inputs_gyr = inputs_acc.to(device), inputs_gyr.to(device)

# %%
input_dim = 3
conv1d_dim1 = 16
conv1d_dim2 = 32
dense_dim = 512

model = Encoder(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
model.load_state_dict(torch.load('./encoder_1_best_ks30.pth'))
model.eval()
# Out:
# Encoder(
#   (conv1d_acc): Sequential(
#     (0): Conv1d(3, 16, kernel_size=(30,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(30,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (conv1d_gyr): Sequential(
#     (0): Conv1d(3, 16, kernel_size=(30,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(30,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (dense): Sequential(
#     (0): Linear(in_features=15488, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=128, out_features=64, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %%
pred = model(inputs_acc, inputs_gyr).detach().cpu().numpy()

plt.figure(figsize=(10, 10))
plt.scatter(stride_length, np.round(pred, 4))
plt.xlim([100, 200])
plt.xlabel('stride_length')
plt.ylim([100, 200])
plt.ylabel('pred')

xpoints = ypoints = plt.xlim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)

plt.show()

# %% [markdown]
# ## Model & Scatter Plot
# - 인코더에 Conv1d만을 사용
# - Conv1d의 kernel_size 조정 : 30 -> 60
# - Best Result : Epoch 177, Valid Loss 18.790442, MAE 2.685503
#     - 큰 영향을 주는 것 같지는 않지만 수렴이 빠름

# %%
# seed 고정
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

class Encoder(nn.Module):
    def __init__(self, input_dim, conv1d_dim1, conv1d_dim2, dense_dim):
        super(Encoder, self).__init__()
             
        self.conv1d_acc = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 60),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 60),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.conv1d_gyr = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 60),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 60),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.dense = nn.Sequential(
            nn.Linear(5824*2, dense_dim),
            nn.ReLU(inplace=True),
            nn.Linear(dense_dim, int(dense_dim/2)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/2), int(dense_dim/4)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/4), int(dense_dim/8)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/8), 1)
        )
        

    def forward(self, inputs_acc, inputs_gyr): 
        
        conv1d_output_acc = self.conv1d_acc(inputs_acc)
        conv1d_output_gyr = self.conv1d_gyr(inputs_gyr)
        
        enc_output = torch.concat((conv1d_output_acc, conv1d_output_gyr), 1)
        dense_output = self.dense(enc_output)
        
        return dense_output

# %%
input_dim = 3
conv1d_dim1 = 16
conv1d_dim2 = 32
dense_dim = 512

model = Encoder(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
n_epochs = 2000

criterion = nn.MSELoss()

# %%
#Early Stopping을 위한 변수
best = 1000
converge_cnt = 0
best_MAE = 0
best_epoch = 0

# Run Training loop
for epoch in range(0, n_epochs) :
    # Set current loss value 
    tot_trn_loss = 0.0
    
    # Train Mode
    model.train()
    
    # Iterate over the DataLoader for training data 
    for i, data in enumerate(train_loader) :
        inputs_acc, inputs_gyr, stride_length, _ = data
        inputs_acc, inputs_gyr, stride_length = inputs_acc.float(), inputs_gyr.float(), stride_length.float()
        inputs_acc, inputs_gyr = inputs_acc.to(device), inputs_gyr.to(device)
        stride_length = stride_length.reshape(-1, 1)
        stride_length = stride_length.to(device)

        # 순전파 
        outputs = model(inputs_acc, inputs_gyr)
        
        # Loss 계산
        loss = criterion(outputs, stride_length)
        
        # 기울기 초기화 
        optimizer.zero_grad()
        # 역전파
        loss.backward()
        # 옵티마이저
        optimizer.step()

        
        # Print statistics
        tot_trn_loss += loss.item()
        
    # Evaluation Mode
    model.eval()
    
    tot_val_loss = 0
    val_epoch_loss = []

    with torch.no_grad() :
        for i, data in enumerate(val_loader):
            inputs_acc, inputs_gyr, stride_length, _ = data
            inputs_acc, inputs_gyr, stride_length = inputs_acc.float(), inputs_gyr.float(), stride_length.float()
            inputs_acc, inputs_gyr = inputs_acc.to(device), inputs_gyr.to(device)
            stride_length = stride_length.reshape(-1, 1)
            stride_length = stride_length.to(device)

            # 순전파 
            outputs = model(inputs_acc, inputs_gyr)
            
            # Loss 계산
            loss = criterion(outputs, stride_length)
            tot_val_loss += loss.item()            
            

    # Epoch 별 Loss
    trn_loss = tot_trn_loss / len(train_loader)
    val_loss = tot_val_loss / len(val_loader)
    MAE = torch.sum(torch.abs(outputs - stride_length)) / len(stride_length)
    
    
    print("Epoch : {}/{}, Train Loss : {:.6f}, Valid Loss {:.6f}, MAE {:.6f}".format(epoch+1, n_epochs,
                                                                                       trn_loss, val_loss,
                                                                                      MAE))
    
    # Early Stopping
    if val_loss < best:
        best = np.mean(val_loss)
        best_MAE = MAE
        best_epoch = epoch+1
        torch.save(model.state_dict(), './encoder_1_best_ks60.pth')
        print('Best Valid Loss {:.4f}'.format(best))
        converge_cnt = 0
    else:
        converge_cnt += 1
    
    if converge_cnt > 20:
        print('Early stopping')
        print('Best Result : Epoch {}, Valid Loss {:4f}, MAE {:4f}'.format(best_epoch, best, best_MAE))
        break
    
#     print("Epoch : {}/{} Epoch Loss : {:.6f}".format(epoch+1, n_epochs, current_loss / len(trainloader.dataset)))
# Out:
# Epoch : 1/2000, Train Loss : 6974.164514, Valid Loss 1220.723450, MAE 31.468950
# Epoch : 2/2000, Train Loss : 752.617633, Valid Loss 443.869064, MAE 17.391273
# Best Valid Loss 443.8691
# Epoch : 3/2000, Train Loss : 287.896519, Valid Loss 233.136396, MAE 12.984757
# Best Valid Loss 233.1364
# Epoch : 4/2000, Train Loss : 239.227547, Valid Loss 244.875636, MAE 13.475310
# Epoch : 5/2000, Train Loss : 233.462458, Valid Loss 227.698840, MAE 12.910347
# Best Valid Loss 227.6988
# Epoch : 6/2000, Train Loss : 228.753220, Valid Loss 226.976115, MAE 12.863390
# Best Valid Loss 226.9761
# Epoch : 7/2000, Train Loss : 226.728002, Valid Loss 224.390429, MAE 12.790303
# Best Valid Loss 224.3904
# Epoch : 8/2000, Train Loss : 224.725432, Valid Loss 221.544782, MAE 12.772385
# Best Valid Loss 221.5448
# Epoch : 9/2000, Train Loss : 223.851826, Valid Loss 218.872658, MAE 12.665787
# Best Valid Loss 218.8727
# Epoch : 10/2000, Train Loss : 221.347144, Valid Loss 216.946645, MAE 12.577463
# Best Valid Loss 216.9466
# Epoch : 11/2000, Train Loss : 223.139594, Valid Loss 218.963135, MAE 12.625329
# Epoch : 12/2000, Train Loss : 224.972544, Valid Loss 248.188957, MAE 13.229249
# Epoch : 13/2000, Train Loss : 219.257027, Valid Loss 215.828728, MAE 12.231522
# Best Valid Loss 215.8287
# Epoch : 14/2000, Train Loss : 217.709614, Valid Loss 208.929998, MAE 12.198687
# Best Valid Loss 208.9300
# Epoch : 15/2000, Train Loss : 217.570183, Valid Loss 206.876595, MAE 12.102323
# Best Valid Loss 206.8766
# Epoch : 16/2000, Train Loss : 213.731970, Valid Loss 205.896294, MAE 11.956412
# Best Valid Loss 205.8963
# Epoch : 17/2000, Train Loss : 210.956931, Valid Loss 202.012248, MAE 11.904961
# Best Valid Loss 202.0122
# Epoch : 18/2000, Train Loss : 207.618886, Valid Loss 203.056389, MAE 11.895570
# Epoch : 19/2000, Train Loss : 213.473368, Valid Loss 199.422295, MAE 11.712140
# Best Valid Loss 199.4223
# Epoch : 20/2000, Train Loss : 200.995677, Valid Loss 207.685216, MAE 11.799335
# Epoch : 21/2000, Train Loss : 215.023475, Valid Loss 196.203158, MAE 11.497764
# Best Valid Loss 196.2032
# Epoch : 22/2000, Train Loss : 223.649739, Valid Loss 235.977933, MAE 12.729642
# Epoch : 23/2000, Train Loss : 205.374906, Valid Loss 204.049787, MAE 11.541966
# Epoch : 24/2000, Train Loss : 195.951963, Valid Loss 178.151967, MAE 10.882207
# Best Valid Loss 178.1520
# Epoch : 25/2000, Train Loss : 188.925120, Valid Loss 205.021194, MAE 11.425232
# Epoch : 26/2000, Train Loss : 185.403692, Valid Loss 166.906164, MAE 10.423314
# Best Valid Loss 166.9062
# Epoch : 27/2000, Train Loss : 173.845318, Valid Loss 159.396111, MAE 10.132872
# Best Valid Loss 159.3961
# Epoch : 28/2000, Train Loss : 160.198718, Valid Loss 151.814011, MAE 9.542158
# Best Valid Loss 151.8140
# Epoch : 29/2000, Train Loss : 154.828607, Valid Loss 138.444162, MAE 8.869831
# Best Valid Loss 138.4442
# Epoch : 30/2000, Train Loss : 141.341149, Valid Loss 128.074588, MAE 8.231473
# Best Valid Loss 128.0746
# Epoch : 31/2000, Train Loss : 136.203188, Valid Loss 111.884712, MAE 8.107002
# Best Valid Loss 111.8847
# Epoch : 32/2000, Train Loss : 112.052305, Valid Loss 112.339466, MAE 8.294457
# Epoch : 33/2000, Train Loss : 99.510347, Valid Loss 77.763972, MAE 6.442734
# Best Valid Loss 77.7640
# Epoch : 34/2000, Train Loss : 73.362459, Valid Loss 68.100551, MAE 6.434570
# Best Valid Loss 68.1006
# Epoch : 35/2000, Train Loss : 70.399206, Valid Loss 59.818256, MAE 5.711380
# Best Valid Loss 59.8183
# Epoch : 36/2000, Train Loss : 65.131871, Valid Loss 48.413531, MAE 5.134885
# Best Valid Loss 48.4135
# Epoch : 37/2000, Train Loss : 51.656481, Valid Loss 56.729210, MAE 5.527871
# Epoch : 38/2000, Train Loss : 59.915784, Valid Loss 103.841199, MAE 7.553636
# Epoch : 39/2000, Train Loss : 60.737746, Valid Loss 41.794694, MAE 4.613196
# Best Valid Loss 41.7947
# Epoch : 40/2000, Train Loss : 53.929993, Valid Loss 40.921678, MAE 4.489444
# Best Valid Loss 40.9217
# Epoch : 41/2000, Train Loss : 70.583177, Valid Loss 42.694760, MAE 4.770292
# Epoch : 42/2000, Train Loss : 42.066341, Valid Loss 39.966035, MAE 4.354200
# Best Valid Loss 39.9660
# Epoch : 43/2000, Train Loss : 46.144461, Valid Loss 48.200368, MAE 5.109429
# Epoch : 44/2000, Train Loss : 50.322758, Valid Loss 43.085425, MAE 4.652131
# Epoch : 45/2000, Train Loss : 55.015280, Valid Loss 53.843423, MAE 5.687893
# Epoch : 46/2000, Train Loss : 53.870153, Valid Loss 40.868704, MAE 4.524774
# Epoch : 47/2000, Train Loss : 60.026891, Valid Loss 39.363642, MAE 4.393616
# Best Valid Loss 39.3636
# Epoch : 48/2000, Train Loss : 44.696599, Valid Loss 53.398479, MAE 5.590528
# Epoch : 49/2000, Train Loss : 46.739110, Valid Loss 38.560628, MAE 4.177911
# Best Valid Loss 38.5606
# Epoch : 50/2000, Train Loss : 56.769510, Valid Loss 37.218065, MAE 4.261879
# Best Valid Loss 37.2181
# Epoch : 51/2000, Train Loss : 46.464462, Valid Loss 37.077644, MAE 4.214164
# Best Valid Loss 37.0776
# Epoch : 52/2000, Train Loss : 44.837903, Valid Loss 40.670224, MAE 4.303189
# Epoch : 53/2000, Train Loss : 40.331837, Valid Loss 49.282846, MAE 5.374907
# Epoch : 54/2000, Train Loss : 46.277544, Valid Loss 35.486031, MAE 3.997714
# Best Valid Loss 35.4860
# Epoch : 55/2000, Train Loss : 38.267209, Valid Loss 38.791817, MAE 4.245508
# Epoch : 56/2000, Train Loss : 37.448142, Valid Loss 37.047882, MAE 4.402042
# Epoch : 57/2000, Train Loss : 41.721814, Valid Loss 34.170310, MAE 3.921978
# Best Valid Loss 34.1703
# Epoch : 58/2000, Train Loss : 40.632565, Valid Loss 49.460620, MAE 5.235797
# Epoch : 59/2000, Train Loss : 45.387113, Valid Loss 38.946395, MAE 4.237482
# Epoch : 60/2000, Train Loss : 39.244361, Valid Loss 34.385489, MAE 4.032516
# Epoch : 61/2000, Train Loss : 39.958068, Valid Loss 41.104349, MAE 4.619031
# Epoch : 62/2000, Train Loss : 53.671318, Valid Loss 35.763107, MAE 3.983968
# Epoch : 63/2000, Train Loss : 52.999548, Valid Loss 65.767141, MAE 6.692248
# Epoch : 64/2000, Train Loss : 43.175708, Valid Loss 37.410142, MAE 4.233803
# Epoch : 65/2000, Train Loss : 44.032372, Valid Loss 87.472598, MAE 7.521151
# Epoch : 66/2000, Train Loss : 45.228528, Valid Loss 43.224854, MAE 4.958917
# Epoch : 67/2000, Train Loss : 39.920981, Valid Loss 34.629849, MAE 4.009794
# Epoch : 68/2000, Train Loss : 40.594967, Valid Loss 32.887800, MAE 3.852380
# Best Valid Loss 32.8878
# Epoch : 69/2000, Train Loss : 35.495710, Valid Loss 38.116942, MAE 4.371798
# Epoch : 70/2000, Train Loss : 42.768397, Valid Loss 43.455477, MAE 4.848736
# Epoch : 71/2000, Train Loss : 65.360227, Valid Loss 102.618818, MAE 8.508606
# Epoch : 72/2000, Train Loss : 46.838483, Valid Loss 54.094558, MAE 5.308337
# Epoch : 73/2000, Train Loss : 39.013124, Valid Loss 50.643717, MAE 5.443555
# Epoch : 74/2000, Train Loss : 44.454258, Valid Loss 30.760081, MAE 3.521820
# Best Valid Loss 30.7601
# Epoch : 75/2000, Train Loss : 50.268617, Valid Loss 59.529037, MAE 6.229937
# Epoch : 76/2000, Train Loss : 78.936000, Valid Loss 51.888446, MAE 5.451674
# Epoch : 77/2000, Train Loss : 58.722975, Valid Loss 31.393901, MAE 3.616676
# Epoch : 78/2000, Train Loss : 33.965555, Valid Loss 33.724910, MAE 3.867218
# Epoch : 79/2000, Train Loss : 35.658454, Valid Loss 55.167786, MAE 5.513889
# Epoch : 80/2000, Train Loss : 40.731694, Valid Loss 42.752599, MAE 4.779235
# Epoch : 81/2000, Train Loss : 36.162774, Valid Loss 41.746529, MAE 4.532994
# Epoch : 82/2000, Train Loss : 38.449454, Valid Loss 31.508764, MAE 3.597742
# Epoch : 83/2000, Train Loss : 41.988385, Valid Loss 30.668357, MAE 3.650210
# Best Valid Loss 30.6684
# Epoch : 84/2000, Train Loss : 34.376213, Valid Loss 32.739745, MAE 3.751639
# Epoch : 85/2000, Train Loss : 38.510635, Valid Loss 31.540458, MAE 3.476914
# Epoch : 86/2000, Train Loss : 35.791927, Valid Loss 30.715653, MAE 3.458231
# Epoch : 87/2000, Train Loss : 33.381251, Valid Loss 33.156116, MAE 3.783117
# Epoch : 88/2000, Train Loss : 35.506698, Valid Loss 45.926820, MAE 4.732314
# Epoch : 89/2000, Train Loss : 32.362432, Valid Loss 32.257892, MAE 3.661492
# Epoch : 90/2000, Train Loss : 39.713400, Valid Loss 28.250438, MAE 3.274059
# Best Valid Loss 28.2504
# Epoch : 91/2000, Train Loss : 41.980013, Valid Loss 46.621770, MAE 5.161680
# Epoch : 92/2000, Train Loss : 44.531623, Valid Loss 29.093645, MAE 3.563305
# Epoch : 93/2000, Train Loss : 51.438906, Valid Loss 33.496254, MAE 3.840176
# Epoch : 94/2000, Train Loss : 48.681498, Valid Loss 34.088320, MAE 4.094054
# Epoch : 95/2000, Train Loss : 42.339382, Valid Loss 28.323343, MAE 3.311499
# Epoch : 96/2000, Train Loss : 36.748939, Valid Loss 51.667736, MAE 5.168609
# Epoch : 97/2000, Train Loss : 37.109599, Valid Loss 28.733579, MAE 3.584707
# Epoch : 98/2000, Train Loss : 33.359232, Valid Loss 30.067620, MAE 3.467336
# Epoch : 99/2000, Train Loss : 32.593034, Valid Loss 28.274392, MAE 3.327130
# Epoch : 100/2000, Train Loss : 38.061912, Valid Loss 26.812831, MAE 3.193783
# Best Valid Loss 26.8128
# Epoch : 101/2000, Train Loss : 31.381788, Valid Loss 28.176177, MAE 3.371308
# Epoch : 102/2000, Train Loss : 32.464003, Valid Loss 51.699924, MAE 5.485721
# Epoch : 103/2000, Train Loss : 34.663943, Valid Loss 26.448321, MAE 3.251493
# Best Valid Loss 26.4483
# Epoch : 104/2000, Train Loss : 33.863060, Valid Loss 37.677169, MAE 4.433468
# Epoch : 105/2000, Train Loss : 41.880779, Valid Loss 65.300717, MAE 6.333389
# Epoch : 106/2000, Train Loss : 66.008823, Valid Loss 46.804860, MAE 5.276776
# Epoch : 107/2000, Train Loss : 43.571939, Valid Loss 42.405494, MAE 4.896914
# Epoch : 108/2000, Train Loss : 38.871317, Valid Loss 27.415330, MAE 3.273065
# Epoch : 109/2000, Train Loss : 30.456834, Valid Loss 29.700940, MAE 3.466736
# Epoch : 110/2000, Train Loss : 35.693272, Valid Loss 31.415049, MAE 3.992985
# Epoch : 111/2000, Train Loss : 44.664261, Valid Loss 26.008978, MAE 3.143530
# Best Valid Loss 26.0090
# Epoch : 112/2000, Train Loss : 29.218387, Valid Loss 29.836214, MAE 3.511770
# Epoch : 113/2000, Train Loss : 37.862259, Valid Loss 37.475471, MAE 4.329517
# Epoch : 114/2000, Train Loss : 40.674333, Valid Loss 27.027841, MAE 2.848033
# Epoch : 115/2000, Train Loss : 37.108581, Valid Loss 35.981948, MAE 3.809496
# Epoch : 116/2000, Train Loss : 31.717424, Valid Loss 32.570013, MAE 3.977315
# Epoch : 117/2000, Train Loss : 34.313832, Valid Loss 41.102707, MAE 4.357145
# Epoch : 118/2000, Train Loss : 30.844344, Valid Loss 27.717746, MAE 3.251917
# Epoch : 119/2000, Train Loss : 29.734376, Valid Loss 25.741653, MAE 3.153306
# Best Valid Loss 25.7417
# Epoch : 120/2000, Train Loss : 30.696002, Valid Loss 82.719285, MAE 7.526345
# Epoch : 121/2000, Train Loss : 55.604140, Valid Loss 43.147087, MAE 4.981192
# Epoch : 122/2000, Train Loss : 46.127611, Valid Loss 32.231774, MAE 4.025900
# Epoch : 123/2000, Train Loss : 28.580000, Valid Loss 28.570678, MAE 3.611346
# Epoch : 124/2000, Train Loss : 46.025909, Valid Loss 26.532892, MAE 3.011720
# Epoch : 125/2000, Train Loss : 28.832801, Valid Loss 24.173914, MAE 3.154496
# Best Valid Loss 24.1739
# Epoch : 126/2000, Train Loss : 35.707163, Valid Loss 25.983197, MAE 3.261787
# Epoch : 127/2000, Train Loss : 29.113363, Valid Loss 24.968237, MAE 3.248676
# Epoch : 128/2000, Train Loss : 26.969190, Valid Loss 24.088174, MAE 3.028788
# Best Valid Loss 24.0882
# Epoch : 129/2000, Train Loss : 25.599931, Valid Loss 23.507253, MAE 3.010921
# Best Valid Loss 23.5073
# Epoch : 130/2000, Train Loss : 39.840405, Valid Loss 89.443996, MAE 7.914155
# Epoch : 131/2000, Train Loss : 40.050864, Valid Loss 24.544990, MAE 3.252842
# Epoch : 132/2000, Train Loss : 27.102611, Valid Loss 35.640392, MAE 4.561912
# Epoch : 133/2000, Train Loss : 28.935674, Valid Loss 28.429750, MAE 3.417814
# Epoch : 134/2000, Train Loss : 26.284990, Valid Loss 40.242314, MAE 4.661803
# Epoch : 135/2000, Train Loss : 33.500091, Valid Loss 30.819572, MAE 4.050694
# Epoch : 136/2000, Train Loss : 29.224423, Valid Loss 32.625344, MAE 3.965436
# Epoch : 137/2000, Train Loss : 25.058571, Valid Loss 21.953852, MAE 2.868105
# Best Valid Loss 21.9539
# Epoch : 138/2000, Train Loss : 32.311090, Valid Loss 22.740827, MAE 2.918751
# Epoch : 139/2000, Train Loss : 38.639655, Valid Loss 49.660927, MAE 6.074388
# Epoch : 140/2000, Train Loss : 43.811531, Valid Loss 22.615028, MAE 2.782824
# Epoch : 141/2000, Train Loss : 32.798166, Valid Loss 49.090146, MAE 5.474413
# Epoch : 142/2000, Train Loss : 29.684669, Valid Loss 45.392909, MAE 5.674434
# Epoch : 143/2000, Train Loss : 43.598825, Valid Loss 31.069186, MAE 3.980528
# Epoch : 144/2000, Train Loss : 26.532011, Valid Loss 26.337449, MAE 3.423515
# Epoch : 145/2000, Train Loss : 26.427414, Valid Loss 32.159336, MAE 4.280311
# Epoch : 146/2000, Train Loss : 33.656916, Valid Loss 21.268366, MAE 2.917974
# Best Valid Loss 21.2684
# Epoch : 147/2000, Train Loss : 37.293375, Valid Loss 26.945563, MAE 3.645081
# Epoch : 148/2000, Train Loss : 25.589225, Valid Loss 28.280706, MAE 3.805489
# Epoch : 149/2000, Train Loss : 30.757169, Valid Loss 30.138124, MAE 3.556937
# Epoch : 150/2000, Train Loss : 29.422655, Valid Loss 29.195234, MAE 3.890144
# Epoch : 151/2000, Train Loss : 56.301453, Valid Loss 70.978291, MAE 7.550276
# Epoch : 152/2000, Train Loss : 33.149301, Valid Loss 22.470386, MAE 3.138482
# Epoch : 153/2000, Train Loss : 25.787588, Valid Loss 20.559046, MAE 2.813802
# Best Valid Loss 20.5590
# Epoch : 154/2000, Train Loss : 25.297965, Valid Loss 29.425711, MAE 3.639440
# Epoch : 155/2000, Train Loss : 24.710737, Valid Loss 20.762020, MAE 2.859534
# Epoch : 156/2000, Train Loss : 45.542260, Valid Loss 94.766229, MAE 9.237349
# Epoch : 157/2000, Train Loss : 58.957328, Valid Loss 26.181937, MAE 3.356776
# Epoch : 158/2000, Train Loss : 27.641525, Valid Loss 25.961359, MAE 3.537826
# Epoch : 159/2000, Train Loss : 30.262559, Valid Loss 21.050897, MAE 2.999217
# Epoch : 160/2000, Train Loss : 26.859510, Valid Loss 24.289167, MAE 3.457522
# Epoch : 161/2000, Train Loss : 26.575999, Valid Loss 19.940007, MAE 2.766089
# Best Valid Loss 19.9400
# Epoch : 162/2000, Train Loss : 45.989871, Valid Loss 22.966118, MAE 2.889059
# Epoch : 163/2000, Train Loss : 48.876107, Valid Loss 104.096231, MAE 9.730433
# Epoch : 164/2000, Train Loss : 70.840155, Valid Loss 52.443483, MAE 6.355639
# Epoch : 165/2000, Train Loss : 31.954529, Valid Loss 23.979605, MAE 3.435117
# Epoch : 166/2000, Train Loss : 22.913178, Valid Loss 20.809899, MAE 3.011856
# Epoch : 167/2000, Train Loss : 25.920904, Valid Loss 22.438522, MAE 2.963340
# Epoch : 168/2000, Train Loss : 23.793759, Valid Loss 20.046731, MAE 2.856509
# Epoch : 169/2000, Train Loss : 28.704340, Valid Loss 20.066674, MAE 2.933232
# Epoch : 170/2000, Train Loss : 25.392748, Valid Loss 19.432202, MAE 2.756741
# Best Valid Loss 19.4322
# Epoch : 171/2000, Train Loss : 35.804088, Valid Loss 20.470727, MAE 2.979899
# Epoch : 172/2000, Train Loss : 31.539373, Valid Loss 20.864420, MAE 2.844408
# Epoch : 173/2000, Train Loss : 23.486821, Valid Loss 19.569408, MAE 2.668199
# Epoch : 174/2000, Train Loss : 22.729815, Valid Loss 20.492317, MAE 3.009362
# Epoch : 175/2000, Train Loss : 22.351234, Valid Loss 29.280256, MAE 3.643823
# Epoch : 176/2000, Train Loss : 23.120776, Valid Loss 20.129180, MAE 2.737904
# Epoch : 177/2000, Train Loss : 21.214314, Valid Loss 18.790442, MAE 2.685503
# Best Valid Loss 18.7904
# Epoch : 178/2000, Train Loss : 20.850164, Valid Loss 19.282722, MAE 2.843111
# Epoch : 179/2000, Train Loss : 21.253193, Valid Loss 19.417911, MAE 2.753095
# Epoch : 180/2000, Train Loss : 22.153478, Valid Loss 28.188601, MAE 4.151103
# Epoch : 181/2000, Train Loss : 23.213811, Valid Loss 21.986703, MAE 3.185810
# Epoch : 182/2000, Train Loss : 20.395437, Valid Loss 25.957317, MAE 3.800766
# Epoch : 183/2000, Train Loss : 40.769928, Valid Loss 22.844893, MAE 3.351362
# Epoch : 184/2000, Train Loss : 62.112917, Valid Loss 60.114113, MAE 6.999923
# Epoch : 185/2000, Train Loss : 32.582332, Valid Loss 23.174910, MAE 3.387387
# Epoch : 186/2000, Train Loss : 22.683339, Valid Loss 32.384924, MAE 4.080436
# Epoch : 187/2000, Train Loss : 21.874893, Valid Loss 18.994836, MAE 2.805763
# Epoch : 188/2000, Train Loss : 21.895712, Valid Loss 25.884535, MAE 3.928463
# Epoch : 189/2000, Train Loss : 26.000074, Valid Loss 31.098601, MAE 3.796467
# Epoch : 190/2000, Train Loss : 26.708748, Valid Loss 19.537712, MAE 2.924045
# Epoch : 191/2000, Train Loss : 28.066316, Valid Loss 32.691548, MAE 4.658004
# Epoch : 192/2000, Train Loss : 30.085934, Valid Loss 30.273857, MAE 3.993636
# Epoch : 193/2000, Train Loss : 31.098686, Valid Loss 28.507752, MAE 4.279517
# Epoch : 194/2000, Train Loss : 22.337927, Valid Loss 20.737375, MAE 3.080997
# Epoch : 195/2000, Train Loss : 24.047351, Valid Loss 20.467080, MAE 3.095972
# Epoch : 196/2000, Train Loss : 21.807607, Valid Loss 18.956130, MAE 2.659858
# Epoch : 197/2000, Train Loss : 21.178189, Valid Loss 29.784920, MAE 4.429771
# Epoch : 198/2000, Train Loss : 23.871010, Valid Loss 19.743055, MAE 2.994084
# Early stopping
# Best Result : Epoch 177, Valid Loss 18.790442, MAE 2.685503

# %%
### scatter plot
file_path = "D:\gait_dataset/salted/test/*"
inputs_acc, inputs_gyr, stride_length = get_sensor_salted(file_path, normalization=True)
inputs_acc, inputs_gyr, stride_length = torch.Tensor(np.array(inputs_acc)), torch.Tensor(np.array(inputs_gyr)), torch.Tensor(np.array(stride_length))
inputs_acc, inputs_gyr, stride_length = inputs_acc.float(), inputs_gyr.float(), stride_length.float()
inputs_acc, inputs_gyr = inputs_acc.to(device), inputs_gyr.to(device)

# %%
input_dim = 3
conv1d_dim1 = 16
conv1d_dim2 = 32
dense_dim = 512

model = Encoder(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
model.load_state_dict(torch.load('./encoder_1_best_ks60.pth'))
model.eval()
# Out:
# Encoder(
#   (conv1d_acc): Sequential(
#     (0): Conv1d(3, 16, kernel_size=(60,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(60,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (conv1d_gyr): Sequential(
#     (0): Conv1d(3, 16, kernel_size=(60,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(60,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (dense): Sequential(
#     (0): Linear(in_features=11648, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=128, out_features=64, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %%
pred = model(inputs_acc, inputs_gyr).detach().cpu().numpy()

plt.figure(figsize=(10, 10))
plt.scatter(stride_length, np.round(pred, 4))
plt.xlim([100, 200])
plt.xlabel('stride_length')
plt.ylim([100, 200])
plt.ylabel('pred')

xpoints = ypoints = plt.xlim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)

plt.show()

# %% [markdown]
# # Encoder-based Model : Acc, Gyro 각각 입력, 최종 노드 3개
# - 최종적으로 출력된 노드 3개를 각 축별 distance와 곱

# %% [markdown]
# ## Model & Scatter Plot
# - Best Result : Epoch 259, Valid Loss 40.381912, MAE 4.223338

# %%
# seed 고정
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

class Encoder_dist(nn.Module):
    def __init__(self, input_dim, conv1d_dim1, conv1d_dim2, dense_dim):
        super(Encoder_dist, self).__init__()
             
        self.conv1d_acc = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 30),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 30),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.conv1d_gyr = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 30),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 30),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.dense = nn.Sequential(
            nn.Linear(7744*2, dense_dim),
            nn.ReLU(inplace=True),
            nn.Linear(dense_dim, int(dense_dim/2)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/2), int(dense_dim/4)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/4), int(dense_dim/8)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/8), 3)
        )
        

    def forward(self, inputs_acc, inputs_gyr): 
        
        conv1d_output_acc = self.conv1d_acc(inputs_acc)
        conv1d_output_gyr = self.conv1d_gyr(inputs_gyr)
        
        enc_output = torch.concat((conv1d_output_acc, conv1d_output_gyr), 1)
        dense_output = self.dense(enc_output)
        
        return dense_output

# %%
input_dim = 3
conv1d_dim1 = 16
conv1d_dim2 = 32
dense_dim = 512

model = Encoder_dist(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
n_epochs = 2000

criterion = nn.MSELoss()

# %%
# Early Stopping을 위한 변수
best = 1000
converge_cnt = 0
best_MAE = 0
best_epoch = 0

# Run Training loop
for epoch in range(0, n_epochs) :
    # Set current loss value 
    tot_trn_loss = 0.0
    
    # Train Mode
    model.train()
    
    # Iterate over the DataLoader for training data 
    for i, data in enumerate(train_loader) :
        inputs_acc, inputs_gyr, stride_length, inputs_pst = data
        inputs_acc, inputs_gyr, stride_length, inputs_pst = inputs_acc.float(), inputs_gyr.float(), stride_length.float(), inputs_pst.float()
        inputs_acc, inputs_gyr, inputs_pst = inputs_acc.to(device), inputs_gyr.to(device), inputs_pst.to(device)
        stride_length = stride_length.reshape(-1, 1)
        stride_length = stride_length.to(device)

        # 순전파 
        outputs = model(inputs_acc, inputs_gyr)
        outputs = torch.unsqueeze(torch.sum(outputs*inputs_pst, axis=1), 1)

        
        # Loss 계산
        loss = criterion(outputs, stride_length)
        
        # 기울기 초기화 
        optimizer.zero_grad()
        # 역전파
        loss.backward()
        # 옵티마이저
        optimizer.step()
        
        # Print statistics
        tot_trn_loss += loss.item()
        
    # Evaluation Mode
    model.eval()
    
    tot_val_loss = 0
    val_epoch_loss = []

    with torch.no_grad() :
        for i, data in enumerate(val_loader):
            inputs_acc, inputs_gyr, stride_length, inputs_pst = data
            inputs_acc, inputs_gyr, stride_length, inputs_pst = inputs_acc.float(), inputs_gyr.float(), stride_length.float(), inputs_pst.float()
            inputs_acc, inputs_gyr, inputs_pst = inputs_acc.to(device), inputs_gyr.to(device), inputs_pst.to(device)
            stride_length = stride_length.reshape(-1, 1)
            stride_length = stride_length.to(device)

            # 순전파 
            outputs = model(inputs_acc, inputs_gyr)
            outputs = torch.unsqueeze(torch.sum(outputs*inputs_pst, axis=1), 1)
            
            # Loss 계산
            loss = criterion(outputs, stride_length)
            tot_val_loss += loss.item()            
            

    # Epoch 별 Loss
    trn_loss = tot_trn_loss / len(train_loader)
    val_loss = tot_val_loss / len(val_loader)
    MAE = torch.sum(torch.abs(outputs - stride_length)) / len(stride_length)
    
    
    print("Epoch : {}/{}, Train Loss : {:.6f}, Valid Loss {:.6f}, MAE {:.6f}".format(epoch+1, n_epochs,
                                                                                       trn_loss, val_loss,
                                                                                      MAE))
    
    # Early Stopping
    if val_loss < best:
        best = np.mean(val_loss)
        best_MAE = MAE
        best_epoch = epoch+1
        torch.save(model.state_dict(), './encoder_dist_best_ks30.pth')
        print('Best Valid Loss {:.4f}'.format(best))
        converge_cnt = 0
    else:
        converge_cnt += 1
    
    if converge_cnt > 20:
        print('Early stopping')
        print('Best Result : Epoch {}, Valid Loss {:4f}, MAE {:4f}'.format(best_epoch, best, best_MAE))
        break
    
#     print("Epoch : {}/{} Epoch Loss : {:.6f}".format(epoch+1, n_epochs, current_loss / len(trainloader.dataset)))
# Out:
# Epoch : 1/2000, Train Loss : 7149.619652, Valid Loss 1189.682658, MAE 34.657738
# Epoch : 2/2000, Train Loss : 926.689648, Valid Loss 758.439626, MAE 24.260277
# Best Valid Loss 758.4396
# Epoch : 3/2000, Train Loss : 571.247713, Valid Loss 646.989380, MAE 23.121986
# Best Valid Loss 646.9894
# Epoch : 4/2000, Train Loss : 523.347839, Valid Loss 614.578135, MAE 23.523153
# Best Valid Loss 614.5781
# Epoch : 5/2000, Train Loss : 496.440107, Valid Loss 615.710866, MAE 23.909782
# Epoch : 6/2000, Train Loss : 484.257493, Valid Loss 595.289449, MAE 23.213823
# Best Valid Loss 595.2894
# Epoch : 7/2000, Train Loss : 469.962442, Valid Loss 586.671666, MAE 23.123833
# Best Valid Loss 586.6717
# Epoch : 8/2000, Train Loss : 455.588360, Valid Loss 574.069224, MAE 22.813021
# Best Valid Loss 574.0692
# Epoch : 9/2000, Train Loss : 436.112337, Valid Loss 543.728724, MAE 22.320431
# Best Valid Loss 543.7287
# Epoch : 10/2000, Train Loss : 415.052519, Valid Loss 522.167099, MAE 21.726231
# Best Valid Loss 522.1671
# Epoch : 11/2000, Train Loss : 397.774769, Valid Loss 491.423467, MAE 21.094458
# Best Valid Loss 491.4235
# Epoch : 12/2000, Train Loss : 365.668876, Valid Loss 459.865224, MAE 20.353056
# Best Valid Loss 459.8652
# Epoch : 13/2000, Train Loss : 341.955991, Valid Loss 440.605611, MAE 19.401039
# Best Valid Loss 440.6056
# Epoch : 14/2000, Train Loss : 310.253076, Valid Loss 397.911865, MAE 18.915968
# Best Valid Loss 397.9119
# Epoch : 15/2000, Train Loss : 308.955508, Valid Loss 363.259120, MAE 17.723988
# Best Valid Loss 363.2591
# Epoch : 16/2000, Train Loss : 270.862033, Valid Loss 366.187902, MAE 18.039011
# Epoch : 17/2000, Train Loss : 280.054082, Valid Loss 325.529612, MAE 16.048145
# Best Valid Loss 325.5296
# Epoch : 18/2000, Train Loss : 269.900630, Valid Loss 320.242971, MAE 16.009941
# Best Valid Loss 320.2430
# Epoch : 19/2000, Train Loss : 246.635617, Valid Loss 307.853905, MAE 15.262897
# Best Valid Loss 307.8539
# Epoch : 20/2000, Train Loss : 248.144876, Valid Loss 303.667895, MAE 15.724724
# Best Valid Loss 303.6679
# Epoch : 21/2000, Train Loss : 239.532008, Valid Loss 403.688395, MAE 16.691158
# Epoch : 22/2000, Train Loss : 251.652625, Valid Loss 280.533628, MAE 14.881029
# Best Valid Loss 280.5336
# Epoch : 23/2000, Train Loss : 228.472895, Valid Loss 308.094653, MAE 15.949353
# Epoch : 24/2000, Train Loss : 230.186841, Valid Loss 298.148519, MAE 15.525780
# Epoch : 25/2000, Train Loss : 274.093770, Valid Loss 424.864873, MAE 19.159317
# Epoch : 26/2000, Train Loss : 227.065054, Valid Loss 257.844676, MAE 13.969234
# Best Valid Loss 257.8447
# Epoch : 27/2000, Train Loss : 211.326237, Valid Loss 296.231336, MAE 15.333687
# Epoch : 28/2000, Train Loss : 221.603965, Valid Loss 263.214396, MAE 14.244907
# Epoch : 29/2000, Train Loss : 213.720406, Valid Loss 256.240204, MAE 13.926963
# Best Valid Loss 256.2402
# Epoch : 30/2000, Train Loss : 197.542807, Valid Loss 236.419070, MAE 13.403703
# Best Valid Loss 236.4191
# Epoch : 31/2000, Train Loss : 189.856656, Valid Loss 226.259260, MAE 13.055101
# Best Valid Loss 226.2593
# Epoch : 32/2000, Train Loss : 192.181200, Valid Loss 230.898852, MAE 12.864379
# Epoch : 33/2000, Train Loss : 225.715419, Valid Loss 230.303373, MAE 13.118830
# Epoch : 34/2000, Train Loss : 195.682830, Valid Loss 263.329318, MAE 13.950866
# Epoch : 35/2000, Train Loss : 189.760414, Valid Loss 217.886813, MAE 12.550676
# Best Valid Loss 217.8868
# Epoch : 36/2000, Train Loss : 173.256508, Valid Loss 219.391523, MAE 12.250516
# Epoch : 37/2000, Train Loss : 178.120088, Valid Loss 229.166936, MAE 12.520317
# Epoch : 38/2000, Train Loss : 207.885551, Valid Loss 297.292913, MAE 15.470040
# Epoch : 39/2000, Train Loss : 187.479233, Valid Loss 216.752101, MAE 12.815650
# Best Valid Loss 216.7521
# Epoch : 40/2000, Train Loss : 156.317633, Valid Loss 195.858479, MAE 11.381356
# Best Valid Loss 195.8585
# Epoch : 41/2000, Train Loss : 158.510577, Valid Loss 242.037051, MAE 14.056739
# Epoch : 42/2000, Train Loss : 154.958104, Valid Loss 189.002886, MAE 10.967955
# Best Valid Loss 189.0029
# Epoch : 43/2000, Train Loss : 153.142367, Valid Loss 189.975182, MAE 10.657967
# Epoch : 44/2000, Train Loss : 158.018679, Valid Loss 206.690575, MAE 11.624628
# Epoch : 45/2000, Train Loss : 154.029338, Valid Loss 213.738523, MAE 12.912359
# Epoch : 46/2000, Train Loss : 140.091220, Valid Loss 181.914444, MAE 10.341188
# Best Valid Loss 181.9144
# Epoch : 47/2000, Train Loss : 134.824609, Valid Loss 180.574565, MAE 10.790134
# Best Valid Loss 180.5746
# Epoch : 48/2000, Train Loss : 155.514188, Valid Loss 222.580282, MAE 12.281741
# Epoch : 49/2000, Train Loss : 142.919330, Valid Loss 189.942822, MAE 10.891451
# Epoch : 50/2000, Train Loss : 137.016180, Valid Loss 167.870265, MAE 9.623201
# Best Valid Loss 167.8703
# Epoch : 51/2000, Train Loss : 162.347135, Valid Loss 172.433665, MAE 9.903071
# Epoch : 52/2000, Train Loss : 133.458048, Valid Loss 181.447149, MAE 10.602883
# Epoch : 53/2000, Train Loss : 136.276869, Valid Loss 164.203513, MAE 9.631540
# Best Valid Loss 164.2035
# Epoch : 54/2000, Train Loss : 128.408148, Valid Loss 180.590940, MAE 10.977653
# Epoch : 55/2000, Train Loss : 138.667729, Valid Loss 165.958973, MAE 9.447927
# Epoch : 56/2000, Train Loss : 130.493702, Valid Loss 213.472722, MAE 11.985947
# Epoch : 57/2000, Train Loss : 160.488136, Valid Loss 186.457911, MAE 10.566249
# Epoch : 58/2000, Train Loss : 147.039526, Valid Loss 173.498352, MAE 9.564374
# Epoch : 59/2000, Train Loss : 147.942956, Valid Loss 176.498517, MAE 9.912166
# Epoch : 60/2000, Train Loss : 136.805951, Valid Loss 169.212536, MAE 9.748178
# Epoch : 61/2000, Train Loss : 137.780632, Valid Loss 172.822711, MAE 10.554239
# Epoch : 62/2000, Train Loss : 120.295036, Valid Loss 165.973231, MAE 9.791488
# Epoch : 63/2000, Train Loss : 118.451599, Valid Loss 173.392480, MAE 10.463181
# Epoch : 64/2000, Train Loss : 119.900815, Valid Loss 155.147116, MAE 8.719927
# Best Valid Loss 155.1471
# Epoch : 65/2000, Train Loss : 119.649680, Valid Loss 176.411697, MAE 10.201993
# Epoch : 66/2000, Train Loss : 126.963343, Valid Loss 159.990781, MAE 9.268000
# Epoch : 67/2000, Train Loss : 117.976161, Valid Loss 148.594818, MAE 8.561394
# Best Valid Loss 148.5948
# Epoch : 68/2000, Train Loss : 132.255289, Valid Loss 151.332204, MAE 8.420168
# Epoch : 69/2000, Train Loss : 140.563362, Valid Loss 169.715467, MAE 9.862986
# Epoch : 70/2000, Train Loss : 115.401761, Valid Loss 157.874921, MAE 9.601671
# Epoch : 71/2000, Train Loss : 112.848906, Valid Loss 148.281843, MAE 8.681552
# Best Valid Loss 148.2818
# Epoch : 72/2000, Train Loss : 112.092164, Valid Loss 145.082732, MAE 8.356939
# Best Valid Loss 145.0827
# Epoch : 73/2000, Train Loss : 110.343424, Valid Loss 144.340168, MAE 8.441730
# Best Valid Loss 144.3402
# Epoch : 74/2000, Train Loss : 119.516702, Valid Loss 186.665098, MAE 11.225638
# Epoch : 75/2000, Train Loss : 147.194116, Valid Loss 173.537721, MAE 10.540823
# Epoch : 76/2000, Train Loss : 115.201723, Valid Loss 141.262794, MAE 8.115543
# Best Valid Loss 141.2628
# Epoch : 77/2000, Train Loss : 108.439781, Valid Loss 145.774349, MAE 7.936963
# Epoch : 78/2000, Train Loss : 109.356669, Valid Loss 147.358774, MAE 7.697283
# Epoch : 79/2000, Train Loss : 109.706129, Valid Loss 141.826647, MAE 8.043411
# Epoch : 80/2000, Train Loss : 114.954723, Valid Loss 138.450029, MAE 7.948974
# Best Valid Loss 138.4500
# Epoch : 81/2000, Train Loss : 106.634717, Valid Loss 140.401957, MAE 7.893609
# Epoch : 82/2000, Train Loss : 108.628689, Valid Loss 139.242017, MAE 8.088772
# Epoch : 83/2000, Train Loss : 103.191420, Valid Loss 142.315196, MAE 8.336679
# Epoch : 84/2000, Train Loss : 99.811988, Valid Loss 140.286856, MAE 8.276437
# Epoch : 85/2000, Train Loss : 103.638984, Valid Loss 145.245015, MAE 8.304255
# Epoch : 86/2000, Train Loss : 113.320844, Valid Loss 164.194190, MAE 9.737124
# Epoch : 87/2000, Train Loss : 120.405346, Valid Loss 133.262271, MAE 7.750060
# Best Valid Loss 133.2623
# Epoch : 88/2000, Train Loss : 107.989757, Valid Loss 144.797325, MAE 8.690475
# Epoch : 89/2000, Train Loss : 111.017045, Valid Loss 142.698659, MAE 8.580380
# Epoch : 90/2000, Train Loss : 115.760972, Valid Loss 134.649119, MAE 8.367152
# Epoch : 91/2000, Train Loss : 95.417732, Valid Loss 149.398931, MAE 7.961727
# Epoch : 92/2000, Train Loss : 115.752313, Valid Loss 152.404573, MAE 9.190550
# Epoch : 93/2000, Train Loss : 103.650353, Valid Loss 128.670546, MAE 7.809905
# Best Valid Loss 128.6705
# Epoch : 94/2000, Train Loss : 96.843541, Valid Loss 156.021950, MAE 10.105060
# Epoch : 95/2000, Train Loss : 112.566843, Valid Loss 155.869556, MAE 8.437404
# Epoch : 96/2000, Train Loss : 121.605730, Valid Loss 140.581547, MAE 9.012805
# Epoch : 97/2000, Train Loss : 106.373594, Valid Loss 134.209761, MAE 8.331826
# Epoch : 98/2000, Train Loss : 90.016880, Valid Loss 132.953189, MAE 8.451293
# Epoch : 99/2000, Train Loss : 93.423788, Valid Loss 128.444646, MAE 8.192470
# Best Valid Loss 128.4446
# Epoch : 100/2000, Train Loss : 99.881033, Valid Loss 131.868801, MAE 8.421336
# Epoch : 101/2000, Train Loss : 93.873319, Valid Loss 142.533735, MAE 9.471630
# Epoch : 102/2000, Train Loss : 110.623926, Valid Loss 175.679654, MAE 11.712895
# Epoch : 103/2000, Train Loss : 117.101210, Valid Loss 132.312791, MAE 8.587847
# Epoch : 104/2000, Train Loss : 110.032742, Valid Loss 141.726926, MAE 7.715115
# Epoch : 105/2000, Train Loss : 104.187491, Valid Loss 125.584393, MAE 8.098479
# Best Valid Loss 125.5844
# Epoch : 106/2000, Train Loss : 90.557429, Valid Loss 129.365337, MAE 9.191767
# Epoch : 107/2000, Train Loss : 91.118591, Valid Loss 116.880349, MAE 7.772871
# Best Valid Loss 116.8803
# Epoch : 108/2000, Train Loss : 90.733828, Valid Loss 135.393851, MAE 9.430305
# Epoch : 109/2000, Train Loss : 89.951068, Valid Loss 121.188910, MAE 8.223767
# Epoch : 110/2000, Train Loss : 85.036922, Valid Loss 124.236146, MAE 8.843113
# Epoch : 111/2000, Train Loss : 85.830290, Valid Loss 168.025345, MAE 10.537645
# Epoch : 112/2000, Train Loss : 93.952718, Valid Loss 114.001386, MAE 7.760206
# Best Valid Loss 114.0014
# Epoch : 113/2000, Train Loss : 90.543612, Valid Loss 111.474396, MAE 7.317899
# Best Valid Loss 111.4744
# Epoch : 114/2000, Train Loss : 81.378534, Valid Loss 123.901905, MAE 9.329021
# Epoch : 115/2000, Train Loss : 87.006032, Valid Loss 117.950371, MAE 7.901599
# Epoch : 116/2000, Train Loss : 82.483651, Valid Loss 119.385868, MAE 8.214058
# Epoch : 117/2000, Train Loss : 80.836039, Valid Loss 124.100222, MAE 7.056430
# Epoch : 118/2000, Train Loss : 88.581192, Valid Loss 114.213369, MAE 7.966241
# Epoch : 119/2000, Train Loss : 111.210036, Valid Loss 157.046495, MAE 11.195179
# Epoch : 120/2000, Train Loss : 86.368374, Valid Loss 114.035099, MAE 7.933621
# Epoch : 121/2000, Train Loss : 93.385026, Valid Loss 111.631869, MAE 7.337150
# Epoch : 122/2000, Train Loss : 93.504791, Valid Loss 124.072965, MAE 8.521158
# Epoch : 123/2000, Train Loss : 87.621373, Valid Loss 139.086842, MAE 8.759367
# Epoch : 124/2000, Train Loss : 90.734008, Valid Loss 112.466515, MAE 7.938405
# Epoch : 125/2000, Train Loss : 85.921624, Valid Loss 105.021149, MAE 7.377970
# Best Valid Loss 105.0211
# Epoch : 126/2000, Train Loss : 79.249841, Valid Loss 108.086252, MAE 7.568592
# Epoch : 127/2000, Train Loss : 83.196422, Valid Loss 116.481991, MAE 8.038204
# Epoch : 128/2000, Train Loss : 83.994390, Valid Loss 106.854748, MAE 7.837227
# Epoch : 129/2000, Train Loss : 76.300397, Valid Loss 101.163414, MAE 7.640781
# Best Valid Loss 101.1634
# Epoch : 130/2000, Train Loss : 93.255925, Valid Loss 114.082902, MAE 7.700418
# Epoch : 131/2000, Train Loss : 79.730476, Valid Loss 103.554761, MAE 7.057786
# Epoch : 132/2000, Train Loss : 89.805397, Valid Loss 131.242625, MAE 9.655389
# Epoch : 133/2000, Train Loss : 84.598826, Valid Loss 107.532654, MAE 7.721718
# Epoch : 134/2000, Train Loss : 82.459747, Valid Loss 103.477346, MAE 8.259351
# Epoch : 135/2000, Train Loss : 82.678823, Valid Loss 98.477169, MAE 7.389054
# Best Valid Loss 98.4772
# Epoch : 136/2000, Train Loss : 72.373652, Valid Loss 99.841230, MAE 7.701122
# Epoch : 137/2000, Train Loss : 74.236446, Valid Loss 94.360181, MAE 6.797596
# Best Valid Loss 94.3602
# Epoch : 138/2000, Train Loss : 74.917914, Valid Loss 99.835527, MAE 7.427814
# Epoch : 139/2000, Train Loss : 85.860680, Valid Loss 95.793043, MAE 7.149506
# Epoch : 140/2000, Train Loss : 69.058084, Valid Loss 98.377581, MAE 7.800647
# Epoch : 141/2000, Train Loss : 83.575553, Valid Loss 94.940445, MAE 6.714184
# Epoch : 142/2000, Train Loss : 73.328267, Valid Loss 98.504004, MAE 7.004515
# Epoch : 143/2000, Train Loss : 70.598318, Valid Loss 91.627979, MAE 6.663058
# Best Valid Loss 91.6280
# Epoch : 144/2000, Train Loss : 66.069530, Valid Loss 112.234343, MAE 7.494942
# Epoch : 145/2000, Train Loss : 79.214962, Valid Loss 117.029818, MAE 8.069085
# Epoch : 146/2000, Train Loss : 77.422293, Valid Loss 114.777459, MAE 9.168490
# Epoch : 147/2000, Train Loss : 67.782817, Valid Loss 102.806105, MAE 8.460920
# Epoch : 148/2000, Train Loss : 62.523586, Valid Loss 90.902374, MAE 7.118842
# Best Valid Loss 90.9024
# Epoch : 149/2000, Train Loss : 64.087438, Valid Loss 117.069406, MAE 9.303706
# Epoch : 150/2000, Train Loss : 68.090513, Valid Loss 96.648591, MAE 7.835133
# Epoch : 151/2000, Train Loss : 64.957773, Valid Loss 125.148298, MAE 8.383640
# Epoch : 152/2000, Train Loss : 68.814303, Valid Loss 110.552578, MAE 7.397143
# Epoch : 153/2000, Train Loss : 71.698653, Valid Loss 92.977516, MAE 6.227474
# Epoch : 154/2000, Train Loss : 65.150231, Valid Loss 104.142045, MAE 8.221094
# Epoch : 155/2000, Train Loss : 72.053184, Valid Loss 96.399131, MAE 7.693365
# Epoch : 156/2000, Train Loss : 60.991269, Valid Loss 99.069026, MAE 7.491295
# Epoch : 157/2000, Train Loss : 61.288605, Valid Loss 93.528460, MAE 7.825781
# Epoch : 158/2000, Train Loss : 59.924418, Valid Loss 85.351640, MAE 6.390427
# Best Valid Loss 85.3516
# Epoch : 159/2000, Train Loss : 58.483480, Valid Loss 103.275349, MAE 8.362237
# Epoch : 160/2000, Train Loss : 62.941547, Valid Loss 84.762754, MAE 7.052814
# Best Valid Loss 84.7628
# Epoch : 161/2000, Train Loss : 62.754023, Valid Loss 81.392923, MAE 7.270078
# Best Valid Loss 81.3929
# Epoch : 162/2000, Train Loss : 59.952473, Valid Loss 86.842552, MAE 7.089673
# Epoch : 163/2000, Train Loss : 54.858770, Valid Loss 76.280600, MAE 6.380810
# Best Valid Loss 76.2806
# Epoch : 164/2000, Train Loss : 62.879339, Valid Loss 78.774046, MAE 6.598713
# Epoch : 165/2000, Train Loss : 52.435699, Valid Loss 81.026363, MAE 7.114708
# Epoch : 166/2000, Train Loss : 56.260752, Valid Loss 80.172437, MAE 6.993490
# Epoch : 167/2000, Train Loss : 53.515172, Valid Loss 77.608683, MAE 6.199084
# Epoch : 168/2000, Train Loss : 71.610708, Valid Loss 87.284130, MAE 6.119070
# Epoch : 169/2000, Train Loss : 61.399121, Valid Loss 98.447666, MAE 8.619184
# Epoch : 170/2000, Train Loss : 58.375331, Valid Loss 73.217295, MAE 6.314982
# Best Valid Loss 73.2173
# Epoch : 171/2000, Train Loss : 52.064390, Valid Loss 70.576466, MAE 5.562321
# Best Valid Loss 70.5765
# Epoch : 172/2000, Train Loss : 57.127271, Valid Loss 83.186155, MAE 7.141903
# Epoch : 173/2000, Train Loss : 73.988956, Valid Loss 94.094547, MAE 6.891345
# Epoch : 174/2000, Train Loss : 51.296405, Valid Loss 77.478326, MAE 7.032045
# Epoch : 175/2000, Train Loss : 49.720919, Valid Loss 86.704109, MAE 8.159920
# Epoch : 176/2000, Train Loss : 58.717060, Valid Loss 84.847378, MAE 6.516906
# Epoch : 177/2000, Train Loss : 66.460057, Valid Loss 117.837490, MAE 8.704202
# Epoch : 178/2000, Train Loss : 60.261122, Valid Loss 75.658703, MAE 6.759944
# Epoch : 179/2000, Train Loss : 46.422810, Valid Loss 65.119106, MAE 5.742166
# Best Valid Loss 65.1191
# Epoch : 180/2000, Train Loss : 49.057967, Valid Loss 103.925686, MAE 9.527881
# Epoch : 181/2000, Train Loss : 46.936707, Valid Loss 106.299132, MAE 9.437098
# Epoch : 182/2000, Train Loss : 53.481251, Valid Loss 112.310396, MAE 9.890345
# Epoch : 183/2000, Train Loss : 48.495455, Valid Loss 72.564044, MAE 5.977451
# Epoch : 184/2000, Train Loss : 47.741069, Valid Loss 82.770522, MAE 7.123316
# Epoch : 185/2000, Train Loss : 48.044168, Valid Loss 63.219647, MAE 5.916639
# Best Valid Loss 63.2196
# Epoch : 186/2000, Train Loss : 57.096996, Valid Loss 65.058399, MAE 5.603741
# Epoch : 187/2000, Train Loss : 47.208254, Valid Loss 63.975286, MAE 5.999901
# Epoch : 188/2000, Train Loss : 42.545139, Valid Loss 78.730031, MAE 6.725225
# Epoch : 189/2000, Train Loss : 40.430336, Valid Loss 62.597378, MAE 5.784373
# Best Valid Loss 62.5974
# Epoch : 190/2000, Train Loss : 39.989061, Valid Loss 72.011002, MAE 6.114845
# Epoch : 191/2000, Train Loss : 48.596894, Valid Loss 82.636361, MAE 7.155337
# Epoch : 192/2000, Train Loss : 48.042663, Valid Loss 62.229937, MAE 6.067691
# Best Valid Loss 62.2299
# Epoch : 193/2000, Train Loss : 46.804967, Valid Loss 86.229628, MAE 7.402561
# Epoch : 194/2000, Train Loss : 47.065030, Valid Loss 62.085991, MAE 5.980819
# Best Valid Loss 62.0860
# Epoch : 195/2000, Train Loss : 36.522270, Valid Loss 60.920818, MAE 6.035301
# Best Valid Loss 60.9208
# Epoch : 196/2000, Train Loss : 35.574135, Valid Loss 57.162093, MAE 5.425461
# Best Valid Loss 57.1621
# Epoch : 197/2000, Train Loss : 35.133240, Valid Loss 58.549232, MAE 5.269915
# Epoch : 198/2000, Train Loss : 34.894101, Valid Loss 56.483390, MAE 5.520320
# Best Valid Loss 56.4834
# Epoch : 199/2000, Train Loss : 35.240672, Valid Loss 81.203354, MAE 7.214118
# Epoch : 200/2000, Train Loss : 36.350185, Valid Loss 55.176113, MAE 5.443563
# Best Valid Loss 55.1761
# Epoch : 201/2000, Train Loss : 33.322231, Valid Loss 55.622069, MAE 5.666264
# Epoch : 202/2000, Train Loss : 33.959995, Valid Loss 66.440168, MAE 6.489676
# Epoch : 203/2000, Train Loss : 41.729085, Valid Loss 59.294913, MAE 5.746737
# Epoch : 204/2000, Train Loss : 35.345620, Valid Loss 59.775726, MAE 5.461426
# Epoch : 205/2000, Train Loss : 40.783294, Valid Loss 57.520193, MAE 6.106817
# Epoch : 206/2000, Train Loss : 42.522715, Valid Loss 59.014386, MAE 5.975634
# Epoch : 207/2000, Train Loss : 53.414883, Valid Loss 73.265785, MAE 5.871137
# Epoch : 208/2000, Train Loss : 54.927941, Valid Loss 55.202387, MAE 5.063203
# Epoch : 209/2000, Train Loss : 34.242604, Valid Loss 69.757581, MAE 6.810470
# Epoch : 210/2000, Train Loss : 34.726113, Valid Loss 61.606142, MAE 6.101103
# Epoch : 211/2000, Train Loss : 43.549395, Valid Loss 55.099921, MAE 5.576112
# Best Valid Loss 55.0999
# Epoch : 212/2000, Train Loss : 34.308098, Valid Loss 55.504907, MAE 5.635109
# Epoch : 213/2000, Train Loss : 43.329723, Valid Loss 53.094799, MAE 5.479548
# Best Valid Loss 53.0948
# Epoch : 214/2000, Train Loss : 41.368493, Valid Loss 67.536237, MAE 6.784606
# Epoch : 215/2000, Train Loss : 45.780933, Valid Loss 74.993459, MAE 7.345284
# Epoch : 216/2000, Train Loss : 41.294902, Valid Loss 54.001071, MAE 5.781365
# Epoch : 217/2000, Train Loss : 32.735672, Valid Loss 49.345439, MAE 5.079549
# Best Valid Loss 49.3454
# Epoch : 218/2000, Train Loss : 34.864028, Valid Loss 62.318588, MAE 5.828150
# Epoch : 219/2000, Train Loss : 34.122966, Valid Loss 52.431942, MAE 5.473672
# Epoch : 220/2000, Train Loss : 33.296687, Valid Loss 63.135306, MAE 6.383712
# Epoch : 221/2000, Train Loss : 36.075387, Valid Loss 67.949458, MAE 5.803289
# Epoch : 222/2000, Train Loss : 32.592184, Valid Loss 49.803878, MAE 5.369921
# Epoch : 223/2000, Train Loss : 34.854801, Valid Loss 59.002744, MAE 6.111485
# Epoch : 224/2000, Train Loss : 32.895832, Valid Loss 51.631772, MAE 5.202915
# Epoch : 225/2000, Train Loss : 29.233606, Valid Loss 47.619644, MAE 4.669550
# Best Valid Loss 47.6196
# Epoch : 226/2000, Train Loss : 35.766337, Valid Loss 73.057974, MAE 6.460038
# Epoch : 227/2000, Train Loss : 33.351427, Valid Loss 62.083936, MAE 5.434423
# Epoch : 228/2000, Train Loss : 30.610235, Valid Loss 47.587977, MAE 4.746938
# Best Valid Loss 47.5880
# Epoch : 229/2000, Train Loss : 25.116944, Valid Loss 45.163730, MAE 4.729163
# Best Valid Loss 45.1637
# Epoch : 230/2000, Train Loss : 30.028270, Valid Loss 52.984046, MAE 5.007425
# Epoch : 231/2000, Train Loss : 31.024135, Valid Loss 48.992354, MAE 5.406852
# Epoch : 232/2000, Train Loss : 29.442708, Valid Loss 48.458977, MAE 5.042770
# Epoch : 233/2000, Train Loss : 24.618915, Valid Loss 60.459435, MAE 6.100543
# Epoch : 234/2000, Train Loss : 25.557057, Valid Loss 47.821547, MAE 4.993396
# Epoch : 235/2000, Train Loss : 25.601708, Valid Loss 52.757271, MAE 4.810232
# Epoch : 236/2000, Train Loss : 39.226474, Valid Loss 54.314238, MAE 5.054646
# Epoch : 237/2000, Train Loss : 52.813146, Valid Loss 68.431392, MAE 6.864754
# Epoch : 238/2000, Train Loss : 28.322641, Valid Loss 44.798820, MAE 4.946529
# Best Valid Loss 44.7988
# Epoch : 239/2000, Train Loss : 22.910873, Valid Loss 47.162008, MAE 4.887922
# Epoch : 240/2000, Train Loss : 27.056875, Valid Loss 51.532424, MAE 5.602092
# Epoch : 241/2000, Train Loss : 27.260572, Valid Loss 44.313956, MAE 4.794465
# Best Valid Loss 44.3140
# Epoch : 242/2000, Train Loss : 25.028796, Valid Loss 44.930876, MAE 5.030701
# Epoch : 243/2000, Train Loss : 28.711777, Valid Loss 75.979459, MAE 7.662893
# Epoch : 244/2000, Train Loss : 29.913081, Valid Loss 59.227148, MAE 5.344102
# Epoch : 245/2000, Train Loss : 24.833708, Valid Loss 43.358374, MAE 4.760138
# Best Valid Loss 43.3584
# Epoch : 246/2000, Train Loss : 29.873084, Valid Loss 67.293331, MAE 7.458849
# Epoch : 247/2000, Train Loss : 39.194463, Valid Loss 46.568752, MAE 4.628001
# Epoch : 248/2000, Train Loss : 26.291404, Valid Loss 47.993568, MAE 5.003077
# Epoch : 249/2000, Train Loss : 24.235889, Valid Loss 43.463699, MAE 4.686484
# Epoch : 250/2000, Train Loss : 22.216833, Valid Loss 47.289213, MAE 4.955538
# Epoch : 251/2000, Train Loss : 25.861221, Valid Loss 43.161359, MAE 4.604490
# Best Valid Loss 43.1614
# Epoch : 252/2000, Train Loss : 27.621038, Valid Loss 43.704868, MAE 4.807126
# Epoch : 253/2000, Train Loss : 22.444493, Valid Loss 48.222650, MAE 5.227858
# Epoch : 254/2000, Train Loss : 23.896565, Valid Loss 43.413488, MAE 4.874633
# Epoch : 255/2000, Train Loss : 24.368592, Valid Loss 43.891967, MAE 5.083943
# Epoch : 256/2000, Train Loss : 21.681345, Valid Loss 52.931838, MAE 6.064562
# Epoch : 257/2000, Train Loss : 21.049157, Valid Loss 53.024574, MAE 4.903529
# Epoch : 258/2000, Train Loss : 22.245660, Valid Loss 41.740692, MAE 4.501065
# Best Valid Loss 41.7407
# Epoch : 259/2000, Train Loss : 25.580240, Valid Loss 40.381912, MAE 4.223338
# Best Valid Loss 40.3819
# Epoch : 260/2000, Train Loss : 31.828499, Valid Loss 70.687365, MAE 5.979605
# Epoch : 261/2000, Train Loss : 32.299267, Valid Loss 69.602889, MAE 7.457488
# Epoch : 262/2000, Train Loss : 27.409671, Valid Loss 45.685175, MAE 4.994197
# Epoch : 263/2000, Train Loss : 19.407900, Valid Loss 44.095397, MAE 4.863507
# Epoch : 264/2000, Train Loss : 19.319022, Valid Loss 44.726639, MAE 5.115204
# Epoch : 265/2000, Train Loss : 25.351503, Valid Loss 59.161844, MAE 4.894956
# Epoch : 266/2000, Train Loss : 27.589379, Valid Loss 50.760761, MAE 5.592723
# Epoch : 267/2000, Train Loss : 27.074542, Valid Loss 44.674369, MAE 4.800947
# Epoch : 268/2000, Train Loss : 24.468179, Valid Loss 59.269791, MAE 5.299854
# Epoch : 269/2000, Train Loss : 34.082326, Valid Loss 47.096223, MAE 4.814781
# Epoch : 270/2000, Train Loss : 26.745075, Valid Loss 52.115702, MAE 4.472061
# Epoch : 271/2000, Train Loss : 33.880809, Valid Loss 62.398630, MAE 6.711820
# Epoch : 272/2000, Train Loss : 27.116456, Valid Loss 52.762325, MAE 4.527940
# Epoch : 273/2000, Train Loss : 22.211924, Valid Loss 47.708912, MAE 5.180466
# Epoch : 274/2000, Train Loss : 26.818505, Valid Loss 66.174828, MAE 7.071288
# Epoch : 275/2000, Train Loss : 33.426077, Valid Loss 53.313058, MAE 4.748547
# Epoch : 276/2000, Train Loss : 45.137083, Valid Loss 46.629815, MAE 4.525445
# Epoch : 277/2000, Train Loss : 29.494830, Valid Loss 53.404942, MAE 5.659238
# Epoch : 278/2000, Train Loss : 23.804275, Valid Loss 45.689407, MAE 5.066932
# Epoch : 279/2000, Train Loss : 20.363709, Valid Loss 45.235236, MAE 4.737111
# Epoch : 280/2000, Train Loss : 22.539862, Valid Loss 42.618189, MAE 4.731901
# Early stopping
# Best Result : Epoch 259, Valid Loss 40.381912, MAE 4.223338

# %%
# scatter plot

file_path = "D:\gait_dataset/salted/test/*"
inputs_acc, inputs_gyr, stride_length = get_sensor_salted(file_path, normalization=True)
inputs_pst = get_position_salted(file_path, distance=True)
inputs_acc, inputs_gyr, stride_length, inputs_pst = torch.Tensor(np.array(inputs_acc)), torch.Tensor(np.array(inputs_gyr)), torch.Tensor(np.array(stride_length)), torch.Tensor(np.array(inputs_pst))
inputs_acc, inputs_gyr, stride_length, inputs_pst = inputs_acc.float(), inputs_gyr.float(), stride_length.float(), inputs_pst.float()
inputs_acc, inputs_gyr, inputs_pst = inputs_acc.to(device), inputs_gyr.to(device), inputs_pst.to(device)

# %%
input_dim = 3
conv1d_dim1 = 16
conv1d_dim2 = 32
dense_dim = 512

model = Encoder_dist(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
model.load_state_dict(torch.load('./encoder_dist_best_ks30.pth'))
model.eval()
# Out:
# Encoder_dist(
#   (conv1d_acc): Sequential(
#     (0): Conv1d(3, 16, kernel_size=(30,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(30,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (conv1d_gyr): Sequential(
#     (0): Conv1d(3, 16, kernel_size=(30,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(30,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (dense): Sequential(
#     (0): Linear(in_features=15488, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=128, out_features=64, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Linear(in_features=64, out_features=3, bias=True)
#   )
# )

# %%
pred = model(inputs_acc, inputs_gyr)
pred = torch.unsqueeze(torch.sum(pred*inputs_pst, axis=1), 1).detach().cpu().numpy()

plt.figure(figsize=(10, 10))
plt.scatter(stride_length, np.round(pred, 4))
plt.xlim([50, 250])
plt.xlabel('stride_length')
plt.ylim([50, 250])
plt.ylabel('pred')

xpoints = ypoints = plt.xlim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)

plt.show()
# Out:
# torch.Size([431, 3])

# %% [markdown]
# # Encoder-based Model : Acc, Gyro 축별 입력
# - 각 축 Acc에서 얻어진 축별 distance를 곱해주기 때문에 축별로 데이터를 입력
#     - 축별 Acc/Gyro의 정보가 알맞은 축의 distance와 곱해져야 한다는 생각에 시도
# - 3개의 인코더에는 각각 (Acc_x, Gyro_x) / (Acc_y, Gyro_y) / (Acc_z, Gyro_z)가 입력으로 들어감
#     - 인코더의 각 output을 concat한 뒤 FC-Layer에 넣었을 때, 축별 정보가 순서대로 보존될 수 있을지는 의문 부호
# - Pressure는 축이 따로 없으므로 고려하지 않음

# %% [markdown]
# ## 데이터 불러오기

# %%
file_path = "D:\gait_dataset/salted/train/*"
dataset = Gait_Dataset_Axis_Salted(file_path)
val_percent = 0.2
n_val = int(len(dataset) * val_percent)
n_train = len(dataset) - n_val
train, val = random_split(dataset, [n_train, n_val])

# %%
train_loader = torch.utils.data.DataLoader(train,
                                           batch_size=128,
                                           shuffle=True)
val_loader = torch.utils.data.DataLoader(val,
                                         batch_size=128,
                                         shuffle=False)

# %% [markdown]
# ## Model & Scatter Plot
# - Best Result : Epoch 194, Valid Loss 32.528639, MAE 4.294555

# %%
# seed 고정
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

class Encoder_axis(nn.Module):
    def __init__(self, input_dim, conv1d_dim1, conv1d_dim2, dense_dim):
        super(Encoder_axis, self).__init__()
             
        self.conv1d_x = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 30),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 30),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.conv1d_y = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 30),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 30),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        
        self.conv1d_z = nn.Sequential(
            nn.Conv1d(input_dim, conv1d_dim1, 30),
            nn.ReLU(inplace=True),
            nn.Conv1d(conv1d_dim1, conv1d_dim2, 30),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        
        self.dense = nn.Sequential(
            nn.Linear(7744*3, dense_dim),
            nn.ReLU(inplace=True),
            nn.Linear(dense_dim, int(dense_dim/2)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/2), int(dense_dim/4)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/4), int(dense_dim/8)),
            nn.ReLU(inplace=True),
            nn.Linear(int(dense_dim/8), 3)
        )
        

    def forward(self, inputs_x, inputs_y, inputs_z): 
        conv1d_output_x = self.conv1d_x(inputs_x)
        conv1d_output_y = self.conv1d_y(inputs_y)
        conv1d_output_z = self.conv1d_z(inputs_z)
        
        enc_output = torch.concat((conv1d_output_x, conv1d_output_y, conv1d_output_z), 1)
        dense_output = self.dense(enc_output)
        
        return dense_output

# %%
input_dim = 2
conv1d_dim1 = 16
conv1d_dim2 = 32
dense_dim = 512

model = Encoder_dist(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
n_epochs = 2000

criterion = nn.MSELoss()

# %%
# Early Stopping을 위한 변수
best = 1000
converge_cnt = 0
best_MAE = 0
best_epoch = 0

# Run Training loop
for epoch in range(0, n_epochs) :
    # Set current loss value 
    tot_trn_loss = 0.0
    
    # Train Mode
    model.train()
    
    # Iterate over the DataLoader for training data 
    for i, data in enumerate(train_loader) :
        inputs_x, inputs_y, inputs_z, stride_length, inputs_pst = data
        inputs_x, inputs_y, inputs_z, stride_length, inputs_pst = inputs_x.float(), inputs_y.float(), inputs_z.float(), stride_length.float(), inputs_pst.float()
        inputs_x, inputs_y, inputs_z, inputs_pst = inputs_x.to(device), inputs_y.to(device), inputs_z.to(device), inputs_pst.to(device)
        stride_length = stride_length.reshape(-1, 1)
        stride_length = stride_length.to(device)

        # 순전파 
        outputs = model(inputs_x, inputs_y, inputs_z)
        outputs = torch.unsqueeze(torch.sum(outputs*inputs_pst, axis=1), 1)

        
        # Loss 계산
        loss = criterion(outputs, stride_length)
        
        # 기울기 초기화 
        optimizer.zero_grad()
        # 역전파
        loss.backward()
        # 옵티마이저
        optimizer.step()
        
        # Print statistics
        tot_trn_loss += loss.item()
        
    # Evaluation Mode
    model.eval()
    
    tot_val_loss = 0
    val_epoch_loss = []

    with torch.no_grad() :
        for i, data in enumerate(val_loader):
            inputs_x, inputs_y, inputs_z, stride_length, inputs_pst = data
            inputs_x, inputs_y, inputs_z, stride_length, inputs_pst = inputs_x.float(), inputs_y.float(), inputs_z.float(), stride_length.float(), inputs_pst.float()
            inputs_x, inputs_y, inputs_z, inputs_pst = inputs_x.to(device), inputs_y.to(device), inputs_z.to(device), inputs_pst.to(device)
            stride_length = stride_length.reshape(-1, 1)
            stride_length = stride_length.to(device)

            # 순전파 
            outputs = model(inputs_x, inputs_y, inputs_z)
            outputs = torch.unsqueeze(torch.sum(outputs*inputs_pst, axis=1), 1)
            
            # Loss 계산
            loss = criterion(outputs, stride_length)
            tot_val_loss += loss.item()            
            

    # Epoch 별 Loss
    trn_loss = tot_trn_loss / len(train_loader)
    val_loss = tot_val_loss / len(val_loader)
    MAE = torch.sum(torch.abs(outputs - stride_length)) / len(stride_length)
    
    
    print("Epoch : {}/{}, Train Loss : {:.6f}, Valid Loss {:.6f}, MAE {:.6f}".format(epoch+1, n_epochs,
                                                                                       trn_loss, val_loss,
                                                                                      MAE))
    
    # Early Stopping
    if val_loss < best:
        best = np.mean(val_loss)
        best_MAE = MAE
        best_epoch = epoch+1
        torch.save(model.state_dict(), './encoder_axis_best_ks30.pth')
        print('Best Valid Loss {:.4f}'.format(best))
        converge_cnt = 0
    else:
        converge_cnt += 1
    
    if converge_cnt > 20:
        print('Early stopping')
        print('Best Result : Epoch {}, Valid Loss {:4f}, MAE {:4f}'.format(best_epoch, best, best_MAE))
        break
    
#     print("Epoch : {}/{} Epoch Loss : {:.6f}".format(epoch+1, n_epochs, current_loss / len(trainloader.dataset)))
# Out:
# Epoch : 1/2000, Train Loss : 6849.530436, Valid Loss 1168.314697, MAE 31.355806
# Epoch : 2/2000, Train Loss : 864.669326, Valid Loss 612.329783, MAE 16.264860
# Best Valid Loss 612.3298
# Epoch : 3/2000, Train Loss : 589.246938, Valid Loss 526.594884, MAE 18.518312
# Best Valid Loss 526.5949
# Epoch : 4/2000, Train Loss : 553.286203, Valid Loss 512.176890, MAE 18.732841
# Best Valid Loss 512.1769
# Epoch : 5/2000, Train Loss : 548.926233, Valid Loss 526.086319, MAE 20.278049
# Epoch : 6/2000, Train Loss : 511.977479, Valid Loss 473.860921, MAE 17.935377
# Best Valid Loss 473.8609
# Epoch : 7/2000, Train Loss : 489.095901, Valid Loss 448.458491, MAE 17.434975
# Best Valid Loss 448.4585
# Epoch : 8/2000, Train Loss : 473.027990, Valid Loss 432.769114, MAE 16.332811
# Best Valid Loss 432.7691
# Epoch : 9/2000, Train Loss : 444.482322, Valid Loss 412.248550, MAE 15.951297
# Best Valid Loss 412.2486
# Epoch : 10/2000, Train Loss : 414.985577, Valid Loss 397.752101, MAE 17.163071
# Best Valid Loss 397.7521
# Epoch : 11/2000, Train Loss : 387.245276, Valid Loss 363.471802, MAE 15.551014
# Best Valid Loss 363.4718
# Epoch : 12/2000, Train Loss : 370.258083, Valid Loss 345.733149, MAE 15.711052
# Best Valid Loss 345.7331
# Epoch : 13/2000, Train Loss : 334.535508, Valid Loss 323.073110, MAE 14.290074
# Best Valid Loss 323.0731
# Epoch : 14/2000, Train Loss : 309.501123, Valid Loss 342.560786, MAE 15.948507
# Epoch : 15/2000, Train Loss : 304.398463, Valid Loss 280.962496, MAE 13.455321
# Best Valid Loss 280.9625
# Epoch : 16/2000, Train Loss : 288.542037, Valid Loss 264.794589, MAE 12.658875
# Best Valid Loss 264.7946
# Epoch : 17/2000, Train Loss : 264.723057, Valid Loss 307.637693, MAE 13.178854
# Epoch : 18/2000, Train Loss : 257.109468, Valid Loss 248.893519, MAE 12.430366
# Best Valid Loss 248.8935
# Epoch : 19/2000, Train Loss : 243.131791, Valid Loss 253.369685, MAE 12.966020
# Epoch : 20/2000, Train Loss : 231.704594, Valid Loss 228.472768, MAE 11.712345
# Best Valid Loss 228.4728
# Epoch : 21/2000, Train Loss : 219.131103, Valid Loss 224.833183, MAE 12.047770
# Best Valid Loss 224.8332
# Epoch : 22/2000, Train Loss : 243.995718, Valid Loss 281.983821, MAE 12.583950
# Epoch : 23/2000, Train Loss : 255.651252, Valid Loss 232.757001, MAE 12.591807
# Epoch : 24/2000, Train Loss : 222.157600, Valid Loss 334.496150, MAE 16.476152
# Epoch : 25/2000, Train Loss : 224.737459, Valid Loss 195.613584, MAE 10.723135
# Best Valid Loss 195.6136
# Epoch : 26/2000, Train Loss : 199.500159, Valid Loss 236.383794, MAE 12.281063
# Epoch : 27/2000, Train Loss : 192.249783, Valid Loss 183.271533, MAE 10.614248
# Best Valid Loss 183.2715
# Epoch : 28/2000, Train Loss : 177.668783, Valid Loss 209.438082, MAE 11.824372
# Epoch : 29/2000, Train Loss : 168.326333, Valid Loss 169.136859, MAE 9.913210
# Best Valid Loss 169.1369
# Epoch : 30/2000, Train Loss : 166.935015, Valid Loss 183.993439, MAE 10.421740
# Epoch : 31/2000, Train Loss : 153.822451, Valid Loss 165.646882, MAE 9.872968
# Best Valid Loss 165.6469
# Epoch : 32/2000, Train Loss : 152.737401, Valid Loss 190.205739, MAE 11.548679
# Epoch : 33/2000, Train Loss : 182.221328, Valid Loss 196.324437, MAE 10.722951
# Epoch : 34/2000, Train Loss : 164.214244, Valid Loss 185.101504, MAE 10.880881
# Epoch : 35/2000, Train Loss : 144.148109, Valid Loss 165.030413, MAE 9.966783
# Best Valid Loss 165.0304
# Epoch : 36/2000, Train Loss : 153.929985, Valid Loss 163.209073, MAE 10.483407
# Best Valid Loss 163.2091
# Epoch : 37/2000, Train Loss : 143.233499, Valid Loss 191.875102, MAE 11.707152
# Epoch : 38/2000, Train Loss : 143.730138, Valid Loss 154.545982, MAE 9.845748
# Best Valid Loss 154.5460
# Epoch : 39/2000, Train Loss : 138.237906, Valid Loss 153.729263, MAE 9.595087
# Best Valid Loss 153.7293
# Epoch : 40/2000, Train Loss : 139.253510, Valid Loss 165.515738, MAE 11.197406
# Epoch : 41/2000, Train Loss : 163.985495, Valid Loss 204.377482, MAE 13.376908
# Epoch : 42/2000, Train Loss : 148.351719, Valid Loss 141.829858, MAE 10.042327
# Best Valid Loss 141.8299
# Epoch : 43/2000, Train Loss : 142.518992, Valid Loss 142.729965, MAE 9.333824
# Epoch : 44/2000, Train Loss : 122.186106, Valid Loss 149.742625, MAE 10.209596
# Epoch : 45/2000, Train Loss : 128.158665, Valid Loss 141.451856, MAE 9.726485
# Best Valid Loss 141.4519
# Epoch : 46/2000, Train Loss : 130.396893, Valid Loss 148.011859, MAE 10.708977
# Epoch : 47/2000, Train Loss : 117.899459, Valid Loss 143.185591, MAE 8.646138
# Epoch : 48/2000, Train Loss : 135.372740, Valid Loss 138.971825, MAE 9.094011
# Best Valid Loss 138.9718
# Epoch : 49/2000, Train Loss : 126.291392, Valid Loss 135.981064, MAE 10.107448
# Best Valid Loss 135.9811
# Epoch : 50/2000, Train Loss : 120.435141, Valid Loss 129.808100, MAE 9.522839
# Best Valid Loss 129.8081
# Epoch : 51/2000, Train Loss : 136.697033, Valid Loss 132.896442, MAE 9.028161
# Epoch : 52/2000, Train Loss : 115.767964, Valid Loss 134.986811, MAE 10.072718
# Epoch : 53/2000, Train Loss : 114.507066, Valid Loss 132.165136, MAE 9.547529
# Epoch : 54/2000, Train Loss : 124.658691, Valid Loss 135.549098, MAE 9.173765
# Epoch : 55/2000, Train Loss : 105.062323, Valid Loss 135.144114, MAE 10.650173
# Epoch : 56/2000, Train Loss : 103.826369, Valid Loss 127.021620, MAE 9.461794
# Best Valid Loss 127.0216
# Epoch : 57/2000, Train Loss : 111.097172, Valid Loss 144.373898, MAE 11.462378
# Epoch : 58/2000, Train Loss : 113.153330, Valid Loss 125.154769, MAE 9.077899
# Best Valid Loss 125.1548
# Epoch : 59/2000, Train Loss : 125.827109, Valid Loss 128.483233, MAE 8.971922
# Epoch : 60/2000, Train Loss : 105.891735, Valid Loss 136.047394, MAE 10.528322
# Epoch : 61/2000, Train Loss : 111.257333, Valid Loss 123.148169, MAE 9.791872
# Best Valid Loss 123.1482
# Epoch : 62/2000, Train Loss : 101.413307, Valid Loss 119.689837, MAE 9.734125
# Best Valid Loss 119.6898
# Epoch : 63/2000, Train Loss : 92.917829, Valid Loss 134.371538, MAE 10.995436
# Epoch : 64/2000, Train Loss : 92.452849, Valid Loss 114.750917, MAE 9.371403
# Best Valid Loss 114.7509
# Epoch : 65/2000, Train Loss : 95.642601, Valid Loss 125.219182, MAE 10.213758
# Epoch : 66/2000, Train Loss : 97.009568, Valid Loss 116.993415, MAE 9.564902
# Epoch : 67/2000, Train Loss : 101.549719, Valid Loss 149.534696, MAE 12.135713
# Epoch : 68/2000, Train Loss : 98.382318, Valid Loss 116.180375, MAE 10.069129
# Epoch : 69/2000, Train Loss : 97.797745, Valid Loss 112.076228, MAE 8.417457
# Best Valid Loss 112.0762
# Epoch : 70/2000, Train Loss : 86.006707, Valid Loss 148.597519, MAE 11.443407
# Epoch : 71/2000, Train Loss : 88.055808, Valid Loss 110.524818, MAE 9.539676
# Best Valid Loss 110.5248
# Epoch : 72/2000, Train Loss : 87.404342, Valid Loss 114.434788, MAE 8.506341
# Epoch : 73/2000, Train Loss : 101.949634, Valid Loss 195.844523, MAE 14.403815
# Epoch : 74/2000, Train Loss : 89.125622, Valid Loss 112.583617, MAE 9.628480
# Epoch : 75/2000, Train Loss : 79.588739, Valid Loss 96.034125, MAE 8.447037
# Best Valid Loss 96.0341
# Epoch : 76/2000, Train Loss : 77.649046, Valid Loss 94.043612, MAE 8.483420
# Best Valid Loss 94.0436
# Epoch : 77/2000, Train Loss : 79.103427, Valid Loss 97.333369, MAE 9.027922
# Epoch : 78/2000, Train Loss : 74.872430, Valid Loss 96.437667, MAE 8.842958
# Epoch : 79/2000, Train Loss : 84.781935, Valid Loss 99.257956, MAE 8.516674
# Epoch : 80/2000, Train Loss : 87.987225, Valid Loss 93.194918, MAE 8.291640
# Best Valid Loss 93.1949
# Epoch : 81/2000, Train Loss : 77.692641, Valid Loss 104.632212, MAE 8.297071
# Epoch : 82/2000, Train Loss : 79.536039, Valid Loss 119.858407, MAE 9.863821
# Epoch : 83/2000, Train Loss : 71.275332, Valid Loss 86.367098, MAE 8.013584
# Best Valid Loss 86.3671
# Epoch : 84/2000, Train Loss : 73.310477, Valid Loss 139.782375, MAE 11.829194
# Epoch : 85/2000, Train Loss : 90.886523, Valid Loss 94.918449, MAE 8.542629
# Epoch : 86/2000, Train Loss : 84.247577, Valid Loss 163.519113, MAE 13.035497
# Epoch : 87/2000, Train Loss : 89.615854, Valid Loss 88.016961, MAE 7.755093
# Epoch : 88/2000, Train Loss : 69.260438, Valid Loss 98.733467, MAE 8.881948
# Epoch : 89/2000, Train Loss : 63.890947, Valid Loss 87.330814, MAE 8.226727
# Epoch : 90/2000, Train Loss : 73.525779, Valid Loss 91.027737, MAE 8.708851
# Epoch : 91/2000, Train Loss : 74.706654, Valid Loss 99.131299, MAE 8.958774
# Epoch : 92/2000, Train Loss : 75.636869, Valid Loss 86.391444, MAE 7.044824
# Epoch : 93/2000, Train Loss : 68.510008, Valid Loss 75.104710, MAE 7.469372
# Best Valid Loss 75.1047
# Epoch : 94/2000, Train Loss : 60.780403, Valid Loss 76.036847, MAE 7.179021
# Epoch : 95/2000, Train Loss : 67.996763, Valid Loss 79.636118, MAE 7.578677
# Epoch : 96/2000, Train Loss : 65.629438, Valid Loss 88.479898, MAE 7.678430
# Epoch : 97/2000, Train Loss : 58.668947, Valid Loss 74.371758, MAE 7.172230
# Best Valid Loss 74.3718
# Epoch : 98/2000, Train Loss : 57.906890, Valid Loss 76.306203, MAE 6.679660
# Epoch : 99/2000, Train Loss : 64.026802, Valid Loss 80.587857, MAE 7.149890
# Epoch : 100/2000, Train Loss : 61.044780, Valid Loss 85.293031, MAE 8.288418
# Epoch : 101/2000, Train Loss : 70.472009, Valid Loss 100.799805, MAE 8.421721
# Epoch : 102/2000, Train Loss : 81.524724, Valid Loss 93.171730, MAE 8.748089
# Epoch : 103/2000, Train Loss : 59.431019, Valid Loss 68.915815, MAE 6.823329
# Best Valid Loss 68.9158
# Epoch : 104/2000, Train Loss : 54.576843, Valid Loss 68.180007, MAE 6.618252
# Best Valid Loss 68.1800
# Epoch : 105/2000, Train Loss : 52.746727, Valid Loss 76.125436, MAE 7.439564
# Epoch : 106/2000, Train Loss : 57.834811, Valid Loss 78.864081, MAE 7.599059
# Epoch : 107/2000, Train Loss : 57.575296, Valid Loss 76.743680, MAE 8.215931
# Epoch : 108/2000, Train Loss : 75.541167, Valid Loss 79.600613, MAE 8.593306
# Epoch : 109/2000, Train Loss : 70.447941, Valid Loss 67.499453, MAE 6.664669
# Best Valid Loss 67.4995
# Epoch : 110/2000, Train Loss : 68.503809, Valid Loss 86.458166, MAE 6.573776
# Epoch : 111/2000, Train Loss : 65.485555, Valid Loss 92.024916, MAE 8.958922
# Epoch : 112/2000, Train Loss : 50.760483, Valid Loss 65.702554, MAE 6.707016
# Best Valid Loss 65.7026
# Epoch : 113/2000, Train Loss : 59.603678, Valid Loss 71.305937, MAE 7.415384
# Epoch : 114/2000, Train Loss : 63.133062, Valid Loss 66.389866, MAE 6.683492
# Epoch : 115/2000, Train Loss : 50.116899, Valid Loss 66.915868, MAE 7.409076
# Epoch : 116/2000, Train Loss : 52.870495, Valid Loss 60.660575, MAE 6.673170
# Best Valid Loss 60.6606
# Epoch : 117/2000, Train Loss : 49.126556, Valid Loss 59.697346, MAE 6.042588
# Best Valid Loss 59.6973
# Epoch : 118/2000, Train Loss : 48.232013, Valid Loss 74.548539, MAE 8.180537
# Epoch : 119/2000, Train Loss : 49.397938, Valid Loss 90.166941, MAE 7.563303
# Epoch : 120/2000, Train Loss : 64.979260, Valid Loss 64.695304, MAE 7.316425
# Epoch : 121/2000, Train Loss : 56.776794, Valid Loss 61.020588, MAE 7.175826
# Epoch : 122/2000, Train Loss : 48.665852, Valid Loss 61.374760, MAE 5.985227
# Epoch : 123/2000, Train Loss : 48.696562, Valid Loss 82.114561, MAE 8.530149
# Epoch : 124/2000, Train Loss : 59.088202, Valid Loss 60.345046, MAE 6.300944
# Epoch : 125/2000, Train Loss : 52.751222, Valid Loss 57.422431, MAE 5.725809
# Best Valid Loss 57.4224
# Epoch : 126/2000, Train Loss : 51.858141, Valid Loss 67.811942, MAE 7.415526
# Epoch : 127/2000, Train Loss : 43.272807, Valid Loss 68.741239, MAE 7.308789
# Epoch : 128/2000, Train Loss : 41.217724, Valid Loss 63.859947, MAE 6.862699
# Epoch : 129/2000, Train Loss : 40.223312, Valid Loss 52.497164, MAE 5.846940
# Best Valid Loss 52.4972
# Epoch : 130/2000, Train Loss : 45.796447, Valid Loss 52.533108, MAE 6.228130
# Epoch : 131/2000, Train Loss : 42.593058, Valid Loss 52.356743, MAE 5.770965
# Best Valid Loss 52.3567
# Epoch : 132/2000, Train Loss : 44.473044, Valid Loss 49.577597, MAE 5.667422
# Best Valid Loss 49.5776
# Epoch : 133/2000, Train Loss : 40.067452, Valid Loss 59.011324, MAE 6.491197
# Epoch : 134/2000, Train Loss : 43.043911, Valid Loss 53.287752, MAE 5.592583
# Epoch : 135/2000, Train Loss : 41.725649, Valid Loss 48.610457, MAE 5.202616
# Best Valid Loss 48.6105
# Epoch : 136/2000, Train Loss : 40.029612, Valid Loss 50.860301, MAE 5.911734
# Epoch : 137/2000, Train Loss : 42.189538, Valid Loss 54.279519, MAE 6.007038
# Epoch : 138/2000, Train Loss : 49.613403, Valid Loss 78.838868, MAE 8.567632
# Epoch : 139/2000, Train Loss : 57.263100, Valid Loss 62.978631, MAE 6.011249
# Epoch : 140/2000, Train Loss : 43.312609, Valid Loss 49.552670, MAE 5.875918
# Epoch : 141/2000, Train Loss : 43.910309, Valid Loss 108.473349, MAE 8.282476
# Epoch : 142/2000, Train Loss : 53.085534, Valid Loss 57.115216, MAE 6.616241
# Epoch : 143/2000, Train Loss : 44.619031, Valid Loss 59.849823, MAE 6.582692
# Epoch : 144/2000, Train Loss : 49.801326, Valid Loss 61.986410, MAE 5.906200
# Epoch : 145/2000, Train Loss : 49.117713, Valid Loss 48.163755, MAE 5.821173
# Best Valid Loss 48.1638
# Epoch : 146/2000, Train Loss : 35.484363, Valid Loss 50.082689, MAE 5.606406
# Epoch : 147/2000, Train Loss : 35.982584, Valid Loss 49.205837, MAE 5.807935
# Epoch : 148/2000, Train Loss : 35.123976, Valid Loss 46.833613, MAE 5.602286
# Best Valid Loss 46.8336
# Epoch : 149/2000, Train Loss : 33.023830, Valid Loss 59.380943, MAE 6.573398
# Epoch : 150/2000, Train Loss : 33.269161, Valid Loss 48.106468, MAE 5.644657
# Epoch : 151/2000, Train Loss : 39.047877, Valid Loss 49.082456, MAE 5.722898
# Epoch : 152/2000, Train Loss : 34.398106, Valid Loss 54.528721, MAE 6.376148
# Epoch : 153/2000, Train Loss : 32.238363, Valid Loss 47.745982, MAE 5.241077
# Epoch : 154/2000, Train Loss : 52.674860, Valid Loss 43.700290, MAE 4.962184
# Best Valid Loss 43.7003
# Epoch : 155/2000, Train Loss : 34.645091, Valid Loss 40.614431, MAE 4.931321
# Best Valid Loss 40.6144
# Epoch : 156/2000, Train Loss : 33.702477, Valid Loss 47.661685, MAE 6.085156
# Epoch : 157/2000, Train Loss : 34.097677, Valid Loss 44.689873, MAE 5.408656
# Epoch : 158/2000, Train Loss : 33.548459, Valid Loss 47.116184, MAE 4.993263
# Epoch : 159/2000, Train Loss : 32.930467, Valid Loss 45.696634, MAE 4.952268
# Epoch : 160/2000, Train Loss : 31.386195, Valid Loss 46.272777, MAE 5.594141
# Epoch : 161/2000, Train Loss : 31.399016, Valid Loss 48.469557, MAE 5.809306
# Epoch : 162/2000, Train Loss : 39.507804, Valid Loss 43.130447, MAE 5.130952
# Epoch : 163/2000, Train Loss : 28.692998, Valid Loss 39.743743, MAE 4.578847
# Best Valid Loss 39.7437
# Epoch : 164/2000, Train Loss : 34.197595, Valid Loss 42.546360, MAE 5.396434
# Epoch : 165/2000, Train Loss : 35.839237, Valid Loss 39.205948, MAE 4.941702
# Best Valid Loss 39.2059
# Epoch : 166/2000, Train Loss : 28.016380, Valid Loss 41.786905, MAE 4.955933
# Epoch : 167/2000, Train Loss : 34.337239, Valid Loss 45.943044, MAE 5.613954
# Epoch : 168/2000, Train Loss : 36.721594, Valid Loss 40.404570, MAE 5.254696
# Epoch : 169/2000, Train Loss : 28.183101, Valid Loss 45.104766, MAE 5.294269
# Epoch : 170/2000, Train Loss : 39.353953, Valid Loss 45.994598, MAE 5.414926
# Epoch : 171/2000, Train Loss : 52.069107, Valid Loss 57.853603, MAE 5.694982
# Epoch : 172/2000, Train Loss : 40.132072, Valid Loss 42.670593, MAE 5.218566
# Epoch : 173/2000, Train Loss : 27.110568, Valid Loss 40.949519, MAE 5.217942
# Epoch : 174/2000, Train Loss : 35.032241, Valid Loss 51.977168, MAE 5.972138
# Epoch : 175/2000, Train Loss : 30.537086, Valid Loss 37.873419, MAE 4.316422
# Best Valid Loss 37.8734
# Epoch : 176/2000, Train Loss : 30.773574, Valid Loss 47.467405, MAE 5.388588
# Epoch : 177/2000, Train Loss : 27.899824, Valid Loss 40.488739, MAE 4.718631
# Epoch : 178/2000, Train Loss : 25.082569, Valid Loss 37.814572, MAE 4.661010
# Best Valid Loss 37.8146
# Epoch : 179/2000, Train Loss : 27.584673, Valid Loss 42.175940, MAE 5.299731
# Epoch : 180/2000, Train Loss : 38.253813, Valid Loss 48.102062, MAE 5.815944
# Epoch : 181/2000, Train Loss : 28.370389, Valid Loss 43.656838, MAE 5.420093
# Epoch : 182/2000, Train Loss : 27.368175, Valid Loss 43.674180, MAE 5.208352
# Epoch : 183/2000, Train Loss : 27.419817, Valid Loss 37.004870, MAE 4.858326
# Best Valid Loss 37.0049
# Epoch : 184/2000, Train Loss : 28.416117, Valid Loss 36.205483, MAE 4.587934
# Best Valid Loss 36.2055
# Epoch : 185/2000, Train Loss : 31.318300, Valid Loss 49.901450, MAE 6.179817
# Epoch : 186/2000, Train Loss : 31.531459, Valid Loss 37.129492, MAE 4.823731
# Epoch : 187/2000, Train Loss : 25.611301, Valid Loss 36.477384, MAE 4.909324
# Epoch : 188/2000, Train Loss : 28.534552, Valid Loss 39.685956, MAE 4.960168
# Epoch : 189/2000, Train Loss : 27.828972, Valid Loss 35.531005, MAE 4.705150
# Best Valid Loss 35.5310
# Epoch : 190/2000, Train Loss : 22.946041, Valid Loss 36.070809, MAE 4.871584
# Epoch : 191/2000, Train Loss : 22.105016, Valid Loss 33.923166, MAE 4.389168
# Best Valid Loss 33.9232
# Epoch : 192/2000, Train Loss : 25.694903, Valid Loss 36.993320, MAE 4.671802
# Epoch : 193/2000, Train Loss : 26.176221, Valid Loss 42.891813, MAE 5.180143
# Epoch : 194/2000, Train Loss : 24.221730, Valid Loss 32.528639, MAE 4.294555
# Best Valid Loss 32.5286
# Epoch : 195/2000, Train Loss : 25.207433, Valid Loss 35.785869, MAE 4.636862
# Epoch : 196/2000, Train Loss : 26.416232, Valid Loss 37.128935, MAE 4.997412
# Epoch : 197/2000, Train Loss : 23.993095, Valid Loss 41.893327, MAE 4.866847
# Epoch : 198/2000, Train Loss : 23.133130, Valid Loss 33.576603, MAE 4.333020
# Epoch : 199/2000, Train Loss : 25.393146, Valid Loss 47.359198, MAE 5.171652
# Epoch : 200/2000, Train Loss : 35.671273, Valid Loss 45.330066, MAE 5.152297
# Epoch : 201/2000, Train Loss : 26.471109, Valid Loss 36.986179, MAE 4.440410
# Epoch : 202/2000, Train Loss : 26.766417, Valid Loss 41.681213, MAE 4.886549
# Epoch : 203/2000, Train Loss : 35.939796, Valid Loss 49.900145, MAE 5.942390
# Epoch : 204/2000, Train Loss : 25.655564, Valid Loss 44.643739, MAE 5.367122
# Epoch : 205/2000, Train Loss : 34.139870, Valid Loss 33.267732, MAE 4.349169
# Epoch : 206/2000, Train Loss : 20.260177, Valid Loss 47.404694, MAE 5.803188
# Epoch : 207/2000, Train Loss : 26.174275, Valid Loss 38.247211, MAE 4.584253
# Epoch : 208/2000, Train Loss : 25.185549, Valid Loss 40.002431, MAE 4.970451
# Epoch : 209/2000, Train Loss : 28.393414, Valid Loss 34.908066, MAE 4.425115
# Epoch : 210/2000, Train Loss : 24.180269, Valid Loss 43.537245, MAE 5.033843
# Epoch : 211/2000, Train Loss : 33.742741, Valid Loss 108.064372, MAE 10.159065
# Epoch : 212/2000, Train Loss : 38.704379, Valid Loss 42.351073, MAE 5.407018
# Epoch : 213/2000, Train Loss : 22.860700, Valid Loss 33.951815, MAE 4.178888
# Epoch : 214/2000, Train Loss : 29.195867, Valid Loss 54.231017, MAE 5.747066
# Epoch : 215/2000, Train Loss : 34.194812, Valid Loss 39.575134, MAE 4.914944
# Early stopping
# Best Result : Epoch 194, Valid Loss 32.528639, MAE 4.294555

# %%
### scatter plot

file_path = "D:\gait_dataset/salted/test/*"
inputs_x, inputs_y, inputs_z, stride_length = get_axis_sensor_salted(file_path)
inputs_pst = get_position_salted(file_path, distance=True)
inputs_x, inputs_y, inputs_z, stride_length, inputs_pst = torch.Tensor(np.array(inputs_x)), torch.Tensor(np.array(inputs_y)), torch.Tensor(np.array(inputs_z)), torch.Tensor(np.array(stride_length)), torch.Tensor(np.array(inputs_pst))
inputs_x, inputs_y, inputs_z, stride_length, inputs_pst = inputs_x.float(), inputs_y.float(), inputs_z.float(), stride_length.float(), inputs_pst.float()
inputs_x, inputs_y, inputs_z, inputs_pst = inputs_x.to(device), inputs_y.to(device), inputs_z.to(device), inputs_pst.to(device)

# stride_length = stride_length.reshape(-1, 1)
# stride_length = stride_length.to(device)

# %%
input_dim = 2
hidden_dim1 = 16
hidden_dim2 = 32
lstm_hidden = 64

model = Encoder_axis(input_dim, conv1d_dim1, conv1d_dim2, dense_dim).to(device)
model.load_state_dict(torch.load('./encoder_axis_best_ks30.pth'))
model.eval()
# Out:
# Encoder_axis(
#   (conv1d_x): Sequential(
#     (0): Conv1d(2, 16, kernel_size=(30,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(30,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (conv1d_y): Sequential(
#     (0): Conv1d(2, 16, kernel_size=(30,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(30,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (conv1d_z): Sequential(
#     (0): Conv1d(2, 16, kernel_size=(30,), stride=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(16, 32, kernel_size=(30,), stride=(1,))
#     (3): ReLU(inplace=True)
#     (4): Flatten(start_dim=1, end_dim=-1)
#   )
#   (dense): Sequential(
#     (0): Linear(in_features=23232, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=128, out_features=64, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Linear(in_features=64, out_features=3, bias=True)
#   )
# )

# %%
pred = model(inputs_x, inputs_y, inputs_z)
pred = torch.unsqueeze(torch.sum(pred*inputs_pst, axis=1), 1).detach().cpu().numpy()

plt.figure(figsize=(10, 10))
plt.scatter(stride_length, np.round(pred, 4))
plt.xlim([50, 250])
plt.xlabel('stride_length')
plt.ylim([50, 250])
plt.ylabel('pred')

xpoints = ypoints = plt.xlim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)

plt.show()
